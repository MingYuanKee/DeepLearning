# %% [markdown]
# Prep
# ==

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
# !pip install tensorboard einops scikit-image opencv-python pytorch_msssim warmup-scheduler
# Out:
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.10/dist-packages (2.14.1)
# Collecting einops
#   Downloading einops-0.7.0-py3-none-any.whl (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.6/44.6 kB 1.5 MB/s eta 0:00:00
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.10/dist-packages (0.19.3)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (4.8.0.76)
# Collecting pytorch_msssim
#   Downloading pytorch_msssim-1.0.0-py3-none-any.whl (7.7 kB)
# Collecting warmup-scheduler
#   Downloading warmup_scheduler-0.3.tar.gz (2.1 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (1.59.2)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (2.17.3)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (3.5.1)
# Requirement already satisfied: numpy>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (1.23.5)
# Requirement already satisfied: protobuf>=3.19.6 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (2.31.0)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (67.7.2)
# Requirement already satisfied: six>1.9 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (1.16.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (3.0.1)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image) (1.11.3)
# Requirement already satisfied: networkx>=2.2 in /usr/local/lib/python3.10/dist-packages (from scikit-image) (3.2.1)
# Requirement already satisfied: pillow!=7.1.0,!=7.1.1,!=8.3.0,>=6.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-image) (9.4.0)
# Requirement already satisfied: imageio>=2.4.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image) (2.31.6)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.10/dist-packages (from scikit-image) (2023.9.26)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image) (1.4.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from scikit-image) (23.2)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from pytorch_msssim) (2.1.0+cu118)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard) (2023.7.22)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard) (2.1.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->pytorch_msssim) (3.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch->pytorch_msssim) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->pytorch_msssim) (1.12)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->pytorch_msssim) (3.1.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch->pytorch_msssim) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch->pytorch_msssim) (2.1.0)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard) (3.2.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->pytorch_msssim) (1.3.0)
# Building wheels for collected packages: warmup-scheduler
#   Building wheel for warmup-scheduler (setup.py) ... done
#   Created wheel for warmup-scheduler: filename=warmup_scheduler-0.3-py3-none-any.whl size=2968 sha256=2ad7b02c837f80437d67d0f1dd2a1392b9a142841607f1408e06c8cf8ba4230d
#   Stored in directory: /root/.cache/pip/wheels/59/01/9e/d1820991c32916e9808c940f572b462f3e46427f3e76c4d852
# Successfully built warmup-scheduler
# Installing collected packages: warmup-scheduler, einops, pytorch_msssim
# Successfully installed einops-0.7.0 pytorch_msssim-1.0.0 warmup-scheduler-0.3

# %%
# !pip install pytorch-msssim
# Out:
# Requirement already satisfied: pytorch-msssim in /usr/local/lib/python3.10/dist-packages (1.0.0)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from pytorch-msssim) (2.1.0+cu118)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->pytorch-msssim) (3.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch->pytorch-msssim) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->pytorch-msssim) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->pytorch-msssim) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->pytorch-msssim) (3.1.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch->pytorch-msssim) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch->pytorch-msssim) (2.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->pytorch-msssim) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->pytorch-msssim) (1.3.0)

# %%
# !pip install warmup-scheduler
# Out:
# Requirement already satisfied: warmup-scheduler in /usr/local/lib/python3.10/dist-packages (0.3)

# %%
# !unzip  ./drive/MyDrive/temp/outdoor_train.zip -d ./reside-outdoorMY/ > trainlog.txt
# !unzip  ./drive/MyDrive/temp/outdoor_test.zip -d ./reside-outdoorMY/ > testlog.txt

#/content/drive/MyDrive/temp/outdoor_train.zip

# %%
path = "/content/reside-outdoorMY"
#/content/reside-indoorMY/train/hazy
#path = "/content/reside-indoorMY"
#path = "./reside-indoorMY"

# %% [markdown]
# Data Augment
# ==

# %%
import random
import torchvision.transforms as transforms
import torchvision.transforms.functional as FUNCTIONAL


class PairRandomCrop(transforms.RandomCrop):

    def __call__(self, image, label):

        if self.padding is not None:
            image = FUNCTIONAL.pad(image, self.padding, self.fill, self.padding_mode)
            label = FUNCTIONAL.pad(label, self.padding, self.fill, self.padding_mode)

        # pad the width if needed
        if self.pad_if_needed and image.size[0] < self.size[1]:
            image = FUNCTIONAL.pad(image, (self.size[1] - image.size[0], 0), self.fill, self.padding_mode)
            label = FUNCTIONAL.pad(label, (self.size[1] - label.size[0], 0), self.fill, self.padding_mode)
        # pad the height if needed
        if self.pad_if_needed and image.size[1] < self.size[0]:
            image = FUNCTIONAL.pad(image, (0, self.size[0] - image.size[1]), self.fill, self.padding_mode)
            label = FUNCTIONAL.pad(label, (0, self.size[0] - image.size[1]), self.fill, self.padding_mode)

        i, j, h, w = self.get_params(image, self.size)

        return FUNCTIONAL.crop(image, i, j, h, w), FUNCTIONAL.crop(label, i, j, h, w)


class PairCompose(transforms.Compose):
    def __call__(self, image, label):
        for t in self.transforms:
            image, label = t(image, label)
        return image, label


class PairRandomHorizontalFilp(transforms.RandomHorizontalFlip):
    def __call__(self, img, label):
        """
        Args:
            img (PIL Image): Image to be flipped.

        Returns:
            PIL Image: Randomly flipped image.
        """
        if random.random() < self.p:
            return FUNCTIONAL.hflip(img), FUNCTIONAL.hflip(label)
        return img, label


class PairToTensor(transforms.ToTensor):
    def __call__(self, pic, label):
        """
        Args:
            pic (PIL Image or numpy.ndarray): Image to be converted to tensor.

        Returns:
            Tensor: Converted image.
        """
        return FUNCTIONAL.to_tensor(pic), FUNCTIONAL.to_tensor(label)

# %% [markdown]
# Data Loader
# ==

# %%
import os
import torch
import numpy as np
from PIL import Image as Image
from torchvision.transforms import functional as Functional
from torch.utils.data import Dataset, DataLoader
from torchvision.transforms.functional import to_tensor, resize

def my_collate_fn(batch):
    images, labels = zip(*batch)  # Unzipping images and labels
    # Define the target size
    target_height = 256  # Example height
    target_width = 256   # Example width

    # Resize and ensure all tensors have the same number of channels, in this case, 3
    resized_images = [resize(img, (target_height, target_width))[:3, :, :] if img.shape[0] > 3 else resize(img, (target_height, target_width)) for img in images]
    resized_labels = [resize(lbl, (target_height, target_width))[:3, :, :] if lbl.shape[0] > 3 else resize(lbl, (target_height, target_width)) for lbl in labels]

    # Stack all images and labels
    images = torch.stack(resized_images)
    labels = torch.stack(resized_labels)

    return images, labels

def test_collate_fn(batch):
    images, labels, name = zip(*batch)
    # Define the target size
    target_height = 256  # Example height
    target_width = 256   # Example width

    # Resize and ensure all tensors have the same number of channels, in this case, 3
    resized_images = [resize(img, (target_height, target_width))[:3, :, :] if img.shape[0] > 3 else resize(img, (target_height, target_width)) for img in images]
    resized_labels = [resize(lbl, (target_height, target_width))[:3, :, :] if lbl.shape[0] > 3 else resize(lbl, (target_height, target_width)) for lbl in labels]

    # Stack all images and labels
    images = torch.stack(resized_images)
    labels = torch.stack(resized_labels)

    return images, labels, name

def my_collate_fn_backup2(batch):
    images, labels = zip(*batch)  # Unzipping images and labels

    # Ensure all tensors have the same number of channels, in this case, 3
    images = [img[:3, :, :] if img.shape[0] > 3 else img for img in images]
    labels = [lbl[:3, :, :] if lbl.shape[0] > 3 else lbl for lbl in labels]

    # Stack all images and labels
    images = torch.stack(images)
    labels = torch.stack(labels)

    return images, labels

def my_collate_fn_backup(batch):
    # Adjust the collate function to handle different number of channels
    images, labels = zip(*batch)  # Unzipping images and labels

    # Ensure that all images and labels have 3 channels
    # This assumes images are PIL Images or similar and have a 'convert' method
    images = [to_tensor(img.convert("RGB")) for img in images]
    labels = [to_tensor(lbl.convert("RGB")) for lbl in labels]

    # Stack all images and labels
    images = torch.stack(images)
    labels = torch.stack(labels)

    return images, labels

def train_dataloader(path, batch_size=8, num_workers=0, use_transform=True): # we change batch size = 1, but the original batch size = 64
    image_dir = os.path.join(path, 'train')

    transform = None
    if use_transform:
        transform = PairCompose(
            [
                PairRandomCrop(256),
                PairRandomHorizontalFilp(),
                PairToTensor()
            ]
        )
    dataloader = DataLoader(
        DeblurDataset(image_dir, transform=transform),
        batch_size=batch_size,
        shuffle=True,
        num_workers=num_workers,
        collate_fn=my_collate_fn,
        pin_memory=True
    )
    return dataloader


def test_dataloader(path, batch_size=1, num_workers=0):
    image_dir = os.path.join(path, 'test')
    dataloader = DataLoader(
        DeblurDataset(image_dir, is_test=True),
        batch_size=batch_size,
        shuffle=False,
        num_workers=num_workers,
        collate_fn=test_collate_fn,
        pin_memory=True
    )

    return dataloader


def valid_dataloader(path, batch_size=1, num_workers=0):
    dataloader = DataLoader(
        DeblurDataset(os.path.join(path, 'test', ), is_valid=True),
        batch_size=batch_size,
        shuffle=False,
        collate_fn=my_collate_fn,
        num_workers=num_workers
    )

    return dataloader


class DeblurDataset_ex(Dataset):
    def __init__(self, image_dir, transform=None, is_test=False):
        self.image_dir = image_dir
        self.image_list = os.listdir(os.path.join(image_dir, 'hazy/'))
        self._check_image(self.image_list)
        self.image_list.sort()
        self.transform = transform
        self.is_test = is_test

    def __len__(self):
        return len(self.image_list)

    def __getitem__(self, idx):
        image = Image.open(os.path.join(self.image_dir, 'hazy', self.image_list[idx]))
        label = Image.open(os.path.join(self.image_dir, 'gt', self.image_list[idx].split('_')[0]+'.png'))

        if self.transform:
            image, label = self.transform(image, label)
        else:
            image = Functional.to_tensor(image)
            label = Functional.to_tensor(label)
        if self.is_test:
            name = self.image_list[idx]
            return image, label, name
        return image, label

    @staticmethod
    def _check_image(lst):
        for x in lst:
            splits = x.split('.')
            if splits[-1] not in ['png', 'jpg', 'jpeg']:
                raise ValueError

import random
class DeblurDataset(Dataset):
    def __init__(self, image_dir, transform=None, is_test=False, is_valid=False, ps=None):
        self.image_dir = image_dir
        self.image_list = os.listdir(os.path.join(image_dir, 'hazy/'))
        self._check_image(self.image_list)
        self.image_list.sort()
        self.transform = transform
        self.is_test = is_test
        self.is_valid = is_valid
        self.ps = ps

    def __len__(self):
        return len(self.image_list)

    def __getitem__(self, idx):
        image = Image.open(os.path.join(self.image_dir, 'hazy', self.image_list[idx])).convert('RGB')
        if self.is_valid or self.is_test:
            label = Image.open(os.path.join(self.image_dir, 'gt', self.image_list[idx].split('_')[0]+'.png')).convert('RGB')
        else:
            try:
                label = Image.open(os.path.join(self.image_dir, 'gt', self.image_list[idx].split('_')[0]+'.jpg')).convert('RGB')
            except:
                label = Image.open(os.path.join(self.image_dir, 'gt', self.image_list[idx].split('_')[0]+'.png')).convert('RGB')
        ps = self.ps

        if self.ps is not None:
            image = Functional.to_tensor(image)
            label = Functional.to_tensor(label)

            hh, ww = label.shape[1], label.shape[2]

            rr = random.randint(0, hh-ps)
            cc = random.randint(0, ww-ps)

            image = image[:, rr:rr+ps, cc:cc+ps]
            label = label[:, rr:rr+ps, cc:cc+ps]

            if random.random() < 0.5:
                image = image.flip(2)
                label = label.flip(2)
        else:
            image = Functional.to_tensor(image)
            label = Functional.to_tensor(label)

        if self.is_test:
            name = self.image_list[idx]
            return image, label, name
        return image, label

    @staticmethod
    def _check_image(lst):
        for x in lst:
            splits = x.split('.')
            if splits[-1] not in ['png', 'jpg', 'jpeg']:
                raise ValueError

# %% [markdown]
# Utils
# ==

# %%
import time
import numpy as np


class Adder(object):
    def __init__(self):
        self.count = 0
        self.num = float(0)

    def reset(self):
        self.count = 0
        self.num = float(0)

    def __call__(self, num):
        self.count += 1
        self.num += num

    def average(self):
        return self.num / self.count


class Timer(object):
    def __init__(self, option='s'):
        self.tm = 0
        self.option = option
        if option == 's':
            self.devider = 1
        elif option == 'm':
            self.devider = 60
        else:
            self.devider = 3600

    def tic(self):
        self.tm = time.time()

    def toc(self):
        return (time.time() - self.tm) / self.devider


def check_lr(optimizer):
    for i, param_group in enumerate(optimizer.param_groups):
        lr = param_group['lr']
    return lr

# %% [markdown]
# Eval
# ==

# %%
from skimage.metrics import peak_signal_noise_ratio
from pytorch_msssim import ssim
import torch.nn.functional as fe

from skimage import img_as_ubyte
import cv2

def _eval(model, args):
    state_dict = torch.load(args.test_model)
    model.load_state_dict(state_dict['model'])
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    dataloader = test_dataloader(args.data_dir, batch_size=1, num_workers=0)
    torch.cuda.empty_cache()
    adder = Adder()
    model.eval()
    factor = 32
    with torch.no_grad():
        psnr_adder = Adder()
        ssim_adder = Adder()

        for iter_idx, data in enumerate(dataloader):
            input_img, label_img, name = data

            input_img = input_img.to(device)

            h, w = input_img.shape[2], input_img.shape[3]
            H, W = ((h+factor)//factor)*factor, ((w+factor)//factor*factor)
            padh = H-h if h%factor!=0 else 0
            padw = W-w if w%factor!=0 else 0
            input_img = fe.pad(input_img, (0, padw, 0, padh), 'reflect')

            tm = time.time()

            pred = model(input_img)[2]
            pred = pred[:,:,:h,:w]

            elapsed = time.time() - tm
            adder(elapsed)

            pred_clip = torch.clamp(pred, 0, 1)

            pred_numpy = pred_clip.squeeze(0).cpu().numpy()
            label_numpy = label_img.squeeze(0).cpu().numpy()


            label_img = (label_img).cuda()
            psnr_val = 10 * torch.log10(1 / fe.mse_loss(pred_clip, label_img))
            down_ratio = max(1, round(min(H, W) / 256))
            ssim_val = ssim(fe.adaptive_avg_pool2d(pred_clip, (int(H / down_ratio), int(W / down_ratio))),
                            fe.adaptive_avg_pool2d(label_img, (int(H / down_ratio), int(W / down_ratio))),
                            data_range=1, size_average=False)
            print('%d iter PSNR_dehazing: %.2f ssim: %f' % (iter_idx + 1, psnr_val, ssim_val))
            ssim_adder(ssim_val)

            if args.save_image:
                save_name = os.path.join(args.result_dir, name[0])
                pred_clip += 0.5 / 255
                pred = FUNCTIONAL.to_pil_image(pred_clip.squeeze(0).cpu(), 'RGB')
                pred.save(save_name)

            psnr_mimo = peak_signal_noise_ratio(pred_numpy, label_numpy, data_range=1)
            psnr_adder(psnr_val)

            print('%d iter PSNR: %.2f time: %f' % (iter_idx + 1, psnr_mimo, elapsed))

        print('==========================================================')
        print('The average PSNR is %.2f dB' % (psnr_adder.average()))
        print('The average SSIM is %.5f dB' % (ssim_adder.average()))

        print("Average time: %f" % adder.average())

# %% [markdown]
# Layers
# ==

# %%
import torch
import torch.nn as nn
import torch.nn.functional as fl
import math

class BasicConv(nn.Module):
    def __init__(self, in_channel, out_channel, kernel_size, stride, bias=True, norm=False, relu=True, transpose=False):
        super(BasicConv, self).__init__()
        if bias and norm:
            bias = False

        padding = kernel_size // 2
        layers = list()
        if transpose:
            padding = kernel_size // 2 -1
            layers.append(nn.ConvTranspose2d(in_channel, out_channel, kernel_size, padding=padding, stride=stride, bias=bias))
        else:
            layers.append(
                nn.Conv2d(in_channel, out_channel, kernel_size, padding=padding, stride=stride, bias=bias))
        if norm:
            layers.append(nn.BatchNorm2d(out_channel))
        if relu:
            layers.append(nn.GELU())
        self.main = nn.Sequential(*layers)

    def forward(self, x):
        return self.main(x)


class ResBlock(nn.Module):
    def __init__(self, in_channel, out_channel, filter=False):
        super(ResBlock, self).__init__()
        self.main = nn.Sequential(
            BasicConv(in_channel, out_channel, kernel_size=3, stride=1, relu=True),
            DeepPoolLayer(in_channel, out_channel) if filter else nn.Identity(),
            BasicConv(out_channel, out_channel, kernel_size=3, stride=1, relu=False)
        )

    def forward(self, x):
        return self.main(x) + x


class DeepPoolLayer(nn.Module):
    def __init__(self, k, k_out):
        super(DeepPoolLayer, self).__init__()
        self.pools_sizes = [8,4,2]
        pools, convs, dynas = [],[],[]
        for i in self.pools_sizes:
            pools.append(nn.AvgPool2d(kernel_size=i, stride=i))
            convs.append(nn.Conv2d(k, k, 3, 1, 1, bias=False))
            dynas.append(dynamic_filter(inchannels=k, kernel_size=3))
        self.pools = nn.ModuleList(pools)
        self.convs = nn.ModuleList(convs)
        self.dynas = nn.ModuleList(dynas)
        self.relu = nn.GELU()
        self.conv_sum = nn.Conv2d(k, k_out, 3, 1, 1, bias=False)

    def forward(self, x):
        x_size = x.size()
        resl = x
        for i in range(len(self.pools_sizes)):
            if i == 0:
                y = self.dynas[i](self.convs[i](self.pools[i](x)))
            else:
                y = self.dynas[i](self.convs[i](self.pools[i](x)+y_up))
            resl = torch.add(resl, fl.interpolate(y, x_size[2:], mode='bilinear', align_corners=True))
            if i != len(self.pools_sizes)-1:
                y_up = fl.interpolate(y, scale_factor=2, mode='bilinear', align_corners=True)
        resl = self.relu(resl)
        resl = self.conv_sum(resl)

        return resl

class dynamic_filter(nn.Module):
    def __init__(self, inchannels, kernel_size=3, stride=1, group=8):
        super(dynamic_filter, self).__init__()

        self.stride = stride
        self.kernel_size = kernel_size
        self.group = group

        self.conv = nn.Conv2d(inchannels, group*kernel_size**2, kernel_size=1, stride=1, bias=False)
        self.bn = nn.BatchNorm2d(group*kernel_size**2)
        self.act = nn.Tanh()

        nn.init.kaiming_normal_(self.conv.weight, mode='fan_out', nonlinearity='relu')
        self.lamb_l = nn.Parameter(torch.zeros(inchannels), requires_grad=True)
        self.lamb_h = nn.Parameter(torch.zeros(inchannels), requires_grad=True)
        self.pad = nn.ReflectionPad2d(kernel_size//2)

        self.ap = nn.AdaptiveAvgPool2d((1, 1))
        self.gap = nn.AdaptiveAvgPool2d(1)

        self.inside_all = nn.Parameter(torch.zeros(inchannels,1,1), requires_grad=True)

    def forward(self, x):
        identity_input = x
        # the Conv_{3x3} layer in eq.3 is included in DeepPoolLayer.convs
        low_filter = self.ap(x)
        low_filter = self.conv(low_filter)
        low_filter = self.bn(low_filter)

        n, c, h, w = x.shape
        x = fl.unfold(self.pad(x), kernel_size=self.kernel_size).reshape(n, self.group, c//self.group, self.kernel_size**2, h*w)

        n,c1,p,q = low_filter.shape
        low_filter = low_filter.reshape(n, c1//self.kernel_size**2, self.kernel_size**2, p*q).unsqueeze(2)
        low_filter = self.act(low_filter)
        low_part = torch.sum(x * low_filter, dim=3).reshape(n, c, h, w)

        # the variables here are slightly different from the paper: (code) --> (paper)
        # low_filter --> A (eq.3)
        # In Eq.7, X*A'= X*(A_{l} + WA_{h})
        #              = X*A_{l} + WX*(A - A_{l})
        #              = X*A_{l} + WX*A - WX*A_{l}
        #              = WX*A - X*A_{l}(W-1)
        # we substitute gap for A_{l} for simplicity, which is a coarser low-frequency filter
        out_low = low_part * (self.inside_all + 1.) - self.inside_all * self.gap(identity_input)

        out_low = out_low * self.lamb_l[None,:,None,None]
        out_high = (identity_input) * (self.lamb_h[None,:,None,None] + 1.)

        return out_low + out_high

# %% [markdown]
# IRNeXt
# ==

# %%
import torch
import torch.nn as nn
import torch.nn.functional as fwd

class EBlock(nn.Module):
    def __init__(self, out_channel, num_res=8):
        super(EBlock, self).__init__()

        layers = [ResBlock(out_channel, out_channel) for _ in range(num_res-1)]
        layers.append(ResBlock(out_channel, out_channel, filter=True))
        self.layers = nn.Sequential(*layers)

    def forward(self, x):
        return self.layers(x)


class DBlock(nn.Module):
    def __init__(self, channel, num_res=8):
        super(DBlock, self).__init__()

        layers = [ResBlock(channel, channel) for _ in range(num_res-1)]
        layers.append(ResBlock(channel, channel, filter=True))
        self.layers = nn.Sequential(*layers)

    def forward(self, x):
        return self.layers(x)


class SCM(nn.Module):
    def __init__(self, out_plane):
        super(SCM, self).__init__()

        self.main = nn.Sequential(
            BasicConv(3, out_plane//4, kernel_size=3, stride=1, relu=True),
            BasicConv(out_plane // 4, out_plane // 2, kernel_size=1, stride=1, relu=True),
            BasicConv(out_plane // 2, out_plane // 2, kernel_size=3, stride=1, relu=True),
            BasicConv(out_plane // 2, out_plane, kernel_size=1, stride=1, relu=False),
            nn.InstanceNorm2d(out_plane, affine=True)
        )

    def forward(self, x):
        x = self.main(x)
        return x

class FAM(nn.Module):
    def __init__(self, channel):
        super(FAM, self).__init__()

        self.merge = BasicConv(channel*2, channel, kernel_size=3, stride=1, relu=False)

    def forward(self, x1, x2):
        return self.merge(torch.cat([x1, x2], dim=1))

class IRNeXt(nn.Module):
    def __init__(self, num_res=4):
        super(IRNeXt, self).__init__()

        base_channel = 32
        self.Encoder = nn.ModuleList([
            EBlock(base_channel, num_res),
            EBlock(base_channel*2, num_res),
            EBlock(base_channel*4, num_res),
        ])

        self.feat_extract = nn.ModuleList([
            BasicConv(3, base_channel, kernel_size=3, relu=True, stride=1),
            BasicConv(base_channel, base_channel*2, kernel_size=3, relu=True, stride=2),
            BasicConv(base_channel*2, base_channel*4, kernel_size=3, relu=True, stride=2),
            BasicConv(base_channel*4, base_channel*2, kernel_size=4, relu=True, stride=2, transpose=True),
            BasicConv(base_channel*2, base_channel, kernel_size=4, relu=True, stride=2, transpose=True),
            BasicConv(base_channel, 3, kernel_size=3, relu=False, stride=1)
        ])

        self.Decoder = nn.ModuleList([
            DBlock(base_channel * 4, num_res),
            DBlock(base_channel * 2, num_res),
            DBlock(base_channel, num_res)
        ])

        self.Convs = nn.ModuleList([
            BasicConv(base_channel * 4, base_channel * 2, kernel_size=1, relu=True, stride=1),
            BasicConv(base_channel * 2, base_channel, kernel_size=1, relu=True, stride=1),
        ])

        self.ConvsOut = nn.ModuleList(
            [
                BasicConv(base_channel * 4, 3, kernel_size=3, relu=False, stride=1),
                BasicConv(base_channel * 2, 3, kernel_size=3, relu=False, stride=1),
            ]
        )

        self.FAM1 = FAM(base_channel * 4)
        self.SCM1 = SCM(base_channel * 4)
        self.FAM2 = FAM(base_channel * 2)
        self.SCM2 = SCM(base_channel * 2)

    def forward(self, x):
        x_2 = fwd.interpolate(x, scale_factor=0.5)
        x_4 = fwd.interpolate(x_2, scale_factor=0.5)
        z2 = self.SCM2(x_2)
        z4 = self.SCM1(x_4)

        outputs = list()
        # 256
        x_ = self.feat_extract[0](x)
        res1 = self.Encoder[0](x_)
        # 128
        z = self.feat_extract[1](res1)
        z = self.FAM2(z, z2)
        res2 = self.Encoder[1](z)
        # 64
        z = self.feat_extract[2](res2)
        z = self.FAM1(z, z4)
        z = self.Encoder[2](z)

        z = self.Decoder[0](z)
        z_ = self.ConvsOut[0](z)
        # 128
        z = self.feat_extract[3](z)
        outputs.append(z_+x_4)

        z = torch.cat([z, res2], dim=1)
        z = self.Convs[0](z)
        z = self.Decoder[1](z)
        z_ = self.ConvsOut[1](z)
        # 256
        z = self.feat_extract[4](z)
        outputs.append(z_+x_2)

        z = torch.cat([z, res1], dim=1)
        z = self.Convs[1](z)
        z = self.Decoder[2](z)
        z = self.feat_extract[5](z)
        outputs.append(z+x)

        return outputs


def build_net():
    return IRNeXt()

# %% [markdown]
# Valid
# ==

# %%
from skimage.metrics import peak_signal_noise_ratio
import torch.nn.functional as fv


def _valid(model, args, ep):
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    its = valid_dataloader(args.data_dir, batch_size=1, num_workers=0)
    model.eval()
    psnr_adder = Adder()

    with torch.no_grad():
        print('Start Evaluation')
        factor = 32
        for idx, data in enumerate(its):
            input_img, label_img = data
            input_img = input_img.to(device)

            h, w = input_img.shape[2], input_img.shape[3]
            H, W = ((h+factor)//factor)*factor, ((w+factor)//factor*factor)
            padh = H-h if h%factor!=0 else 0
            padw = W-w if w%factor!=0 else 0
            input_img = fv.pad(input_img, (0, padw, 0, padh), 'reflect')

            if not os.path.exists(os.path.join(args.result_dir, '%d' % (ep))):
                os.mkdir(os.path.join(args.result_dir, '%d' % (ep)))

            pred = model(input_img)[2]
            pred = pred[:,:,:h,:w]

            pred_clip = torch.clamp(pred, 0, 1)
            p_numpy = pred_clip.squeeze(0).cpu().numpy()
            label_numpy = label_img.squeeze(0).cpu().numpy()

            psnr = peak_signal_noise_ratio(p_numpy, label_numpy, data_range=1)

            psnr_adder(psnr)
            print('\r%03d'%idx, end=' ')

    print('\n')
    model.train()
    return psnr_adder.average()

# %% [markdown]
# TRAIN
# ==

# %%
from torch.utils.tensorboard import SummaryWriter
import torch.nn.functional as ft
import torch.optim as optim


from warmup_scheduler import GradualWarmupScheduler

def _train(model, args):
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    model.to(device)
    criterion = torch.nn.L1Loss().to(device)
    optimizer = optim.SGD(model.parameters(), lr=args.learning_rate, momentum=args.momentum_value, nesterov=True)

    #optimizer = SGLD(params=model.parameters(), lr=args.learning_rate, weight_decay=args.weight_decay)
    dataloader = train_dataloader(args.data_dir, args.batch_size, args.num_worker)
    max_iter = len(dataloader)
    warmup_epochs=3
    scheduler_cosine = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=args.num_epoch-warmup_epochs, eta_min=1e-6)
    scheduler = GradualWarmupScheduler(optimizer, multiplier=1, total_epoch=warmup_epochs, after_scheduler=scheduler_cosine)
    scheduler.step()
    epoch = 1
    if args.resume:
        state = torch.load(args.resume)
        epoch = state['epoch']
        optimizer.load_state_dict(state['optimizer'])
        model.load_state_dict(state['model'])
        print('Resume from %d'%epoch)
        epoch += 1
        for i in range(epoch-1):
          scheduler.step()

    writer = SummaryWriter()
    epoch_pixel_adder = Adder()
    epoch_fft_adder = Adder()
    iter_pixel_adder = Adder()
    iter_fft_adder = Adder()
    epoch_timer = Timer('m')
    iter_timer = Timer('m')
    best_psnr=-1

    for epoch_idx in range(epoch, args.num_epoch + 1):

        epoch_timer.tic()
        iter_timer.tic()
        for iter_idx, batch_data in enumerate(dataloader):

            input_img, label_img = batch_data
            input_img = input_img.to(device)
            label_img = label_img.to(device)

            optimizer.zero_grad()
            pred_img = model(input_img)
            label_img2 = ft.interpolate(label_img, scale_factor=0.5, mode='bilinear')
            label_img4 = ft.interpolate(label_img, scale_factor=0.25, mode='bilinear')
            l1 = criterion(pred_img[0], label_img4)
            l2 = criterion(pred_img[1], label_img2)
            l3 = criterion(pred_img[2], label_img)
            loss_content = l1+l2+l3

            label_fft1 = torch.fft.fft2(label_img4, dim=(-2,-1))
            label_fft1 = torch.stack((label_fft1.real, label_fft1.imag), -1)

            pred_fft1 = torch.fft.fft2(pred_img[0], dim=(-2,-1))
            pred_fft1 = torch.stack((pred_fft1.real, pred_fft1.imag), -1)

            label_fft2 = torch.fft.fft2(label_img2, dim=(-2,-1))
            label_fft2 = torch.stack((label_fft2.real, label_fft2.imag), -1)

            pred_fft2 = torch.fft.fft2(pred_img[1], dim=(-2,-1))
            pred_fft2 = torch.stack((pred_fft2.real, pred_fft2.imag), -1)

            label_fft3 = torch.fft.fft2(label_img, dim=(-2,-1))
            label_fft3 = torch.stack((label_fft3.real, label_fft3.imag), -1)

            pred_fft3 = torch.fft.fft2(pred_img[2], dim=(-2,-1))
            pred_fft3 = torch.stack((pred_fft3.real, pred_fft3.imag), -1)

            f1 = criterion(pred_fft1, label_fft1)
            f2 = criterion(pred_fft2, label_fft2)
            f3 = criterion(pred_fft3, label_fft3)
            loss_fft = f1+f2+f3

            loss = loss_content + 0.1 * loss_fft
            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), 0.001)
            optimizer.step()

            iter_pixel_adder(loss_content.item())
            iter_fft_adder(loss_fft.item())

            epoch_pixel_adder(loss_content.item())
            epoch_fft_adder(loss_fft.item())

            if (iter_idx + 1) % args.print_freq == 0:
                print("Time: %7.4f Epoch: %03d Iter: %4d/%4d LR: %.10f Loss content: %7.4f Loss fft: %7.4f" % (
                    iter_timer.toc(), epoch_idx, iter_idx + 1, max_iter, scheduler.get_lr()[0], iter_pixel_adder.average(),
                    iter_fft_adder.average()))
                writer.add_scalar('Pixel Loss', iter_pixel_adder.average(), iter_idx + (epoch_idx-1)* max_iter)
                writer.add_scalar('FFT Loss', iter_fft_adder.average(), iter_idx + (epoch_idx - 1) * max_iter)

                iter_timer.tic()
                iter_pixel_adder.reset()
                iter_fft_adder.reset()
        overwrite_name = os.path.join(args.model_save_dir, 'model.pkl')
        torch.save({'model': model.state_dict(),
                    'optimizer': optimizer.state_dict(),
                    'epoch': epoch_idx}, overwrite_name)

        if epoch_idx % args.save_freq == 0:
            save_name = os.path.join(args.model_save_dir, 'model_%d.pkl' % epoch_idx)
            torch.save({'model': model.state_dict()}, save_name)
        print("EPOCH: %02d\nElapsed time: %4.2f Epoch Pixel Loss: %7.4f Epoch FFT Loss: %7.4f" % (
            epoch_idx, epoch_timer.toc(), epoch_pixel_adder.average(), epoch_fft_adder.average()))
        epoch_fft_adder.reset()
        epoch_pixel_adder.reset()
        scheduler.step()
        if epoch_idx % args.valid_freq == 0:
            val = _valid(model, args, epoch_idx)
            print('%03d epoch \n Average PSNR %.2f dB' % (epoch_idx, val))
            writer.add_scalar('PSNR', val, epoch_idx)
            if val >= best_psnr:
                torch.save({'model': model.state_dict()}, os.path.join(args.model_save_dir, 'Best.pkl'))
    save_name = os.path.join(args.model_save_dir, 'Final.pkl')
    torch.save({'model': model.state_dict()}, save_name)

# %% [markdown]
# Main (Train)
# ==

# %%
import os
import torch
import torchvision.transforms as transforms
# from torch.backends import cudnn # Uncomment if you need it

class Args:
    model_name = 'IRNeXt'
    mode = 'train'
    data_dir = path

    # Train
    batch_size = 8
    learning_rate = 1e-4
    weight_decay = 0
    num_epoch = 5
    print_freq = 100
    num_worker = 8
    save_freq = 10
    valid_freq = 10
    momentum_value = 0.8

    resume = '/content/drive/MyDrive/OUTMYresults0_8/IRNeXt/ITS/model.pkl'
    #/content/drive/MyDrive/MYresults2/IRNeXt/ITS/model.pkl
    # Test
    test_model = '/content/drive/MyDrive/OUTMYresults0_8/IRNeXt/ITS/Final.pkl'
    save_image = False

    # Directories (set these as per your requirement)
    model_save_dir = os.path.join('/content/drive/MyDrive/OUTMYresults0_8/', 'IRNeXt', 'ITS/')
    result_dir = os.path.join('/content/drive/MyDrive/OUTMYresults0_8/', model_name, 'test')

def main(args):
    # CUDNN
    # cudnn.benchmark = True # Uncomment if you need it

    if not os.path.exists('/content/drive/MyDrive/OUTMYresults0_8/'):
        os.makedirs(args.model_save_dir)
    if not os.path.exists('/content/drive/MyDrive/OUTMYresults0_8/' + args.model_name + '/'):
        os.makedirs('/content/drive/MyDrive/OUTMYresults0_8/' + args.model_name + '/')
    if not os.path.exists(args.model_save_dir):
        os.makedirs(args.model_save_dir)
    if not os.path.exists(args.result_dir):
        os.makedirs(args.result_dir)

    model = build_net()  # Make sure to define build_net or import it if it's defined elsewhere
    print(model)

    if torch.cuda.is_available():
        model.cuda()
    if args.mode == 'train':
        _train(model, args)  # Make sure to define _train or import it if it's defined elsewhere

    elif args.mode == 'test':
        _eval(model, args)   # Make sure to define _eval or import it if it's defined elsewhere

# Replace parser.parse_args() with an instance of the Args class
args = Args()
if not os.path.exists(args.model_save_dir):
    os.makedirs(args.model_save_dir)
# Copying files (make sure these paths are correct)
command = 'cp ' + 'models/layers.py ' + args.model_save_dir
os.system(command)
command = 'cp ' + 'models/IRNeXt.py ' + args.model_save_dir
os.system(command)
command = 'cp ' + 'train.py ' + args.model_save_dir
os.system(command)
command = 'cp ' + 'main.py ' + args.model_save_dir
os.system(command)
print(args)
main(args)
# Out:
# <__main__.Args object at 0x7d184a984d00>
# IRNeXt(
#   (Encoder): ModuleList(
#     (0): EBlock(
#       (layers): Sequential(
#         (0): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (1): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (2): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (3): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): DeepPoolLayer(
#               (pools): ModuleList(
#                 (0): AvgPool2d(kernel_size=8, stride=8, padding=0)
#                 (1): AvgPool2d(kernel_size=4, stride=4, padding=0)
#                 (2): AvgPool2d(kernel_size=2, stride=2, padding=0)
#               )
#               (convs): ModuleList(
#                 (0-2): 3 x Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#               (dynas): ModuleList(
#                 (0-2): 3 x dynamic_filter(
#                   (conv): Conv2d(32, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (bn): BatchNorm2d(72, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (act): Tanh()
#                   (pad): ReflectionPad2d((1, 1, 1, 1))
#                   (ap): AdaptiveAvgPool2d(output_size=(1, 1))
#                   (gap): AdaptiveAvgPool2d(output_size=1)
#                 )
#               )
#               (relu): GELU(approximate='none')
#               (conv_sum): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             )
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#       )
#     )
#     (1): EBlock(
#       (layers): Sequential(
#         (0): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (1): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (2): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (3): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): DeepPoolLayer(
#               (pools): ModuleList(
#                 (0): AvgPool2d(kernel_size=8, stride=8, padding=0)
#                 (1): AvgPool2d(kernel_size=4, stride=4, padding=0)
#                 (2): AvgPool2d(kernel_size=2, stride=2, padding=0)
#               )
#               (convs): ModuleList(
#                 (0-2): 3 x Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#               (dynas): ModuleList(
#                 (0-2): 3 x dynamic_filter(
#                   (conv): Conv2d(64, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (bn): BatchNorm2d(72, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (act): Tanh()
#                   (pad): ReflectionPad2d((1, 1, 1, 1))
#                   (ap): AdaptiveAvgPool2d(output_size=(1, 1))
#                   (gap): AdaptiveAvgPool2d(output_size=1)
#                 )
#               )
#               (relu): GELU(approximate='none')
#               (conv_sum): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             )
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#       )
#     )
#     (2): EBlock(
#       (layers): Sequential(
#         (0): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (1): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (2): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (3): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): DeepPoolLayer(
#               (pools): ModuleList(
#                 (0): AvgPool2d(kernel_size=8, stride=8, padding=0)
#                 (1): AvgPool2d(kernel_size=4, stride=4, padding=0)
#                 (2): AvgPool2d(kernel_size=2, stride=2, padding=0)
#               )
#               (convs): ModuleList(
#                 (0-2): 3 x Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#               (dynas): ModuleList(
#                 (0-2): 3 x dynamic_filter(
#                   (conv): Conv2d(128, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (bn): BatchNorm2d(72, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (act): Tanh()
#                   (pad): ReflectionPad2d((1, 1, 1, 1))
#                   (ap): AdaptiveAvgPool2d(output_size=(1, 1))
#                   (gap): AdaptiveAvgPool2d(output_size=1)
#                 )
#               )
#               (relu): GELU(approximate='none')
#               (conv_sum): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             )
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#       )
#     )
#   )
#   (feat_extract): ModuleList(
#     (0): BasicConv(
#       (main): Sequential(
#         (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): GELU(approximate='none')
#       )
#     )
#     (1): BasicConv(
#       (main): Sequential(
#         (0): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         (1): GELU(approximate='none')
#       )
#     )
#     (2): BasicConv(
#       (main): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         (1): GELU(approximate='none')
#       )
#     )
#     (3): BasicConv(
#       (main): Sequential(
#         (0): ConvTranspose2d(128, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#         (1): GELU(approximate='none')
#       )
#     )
#     (4): BasicConv(
#       (main): Sequential(
#         (0): ConvTranspose2d(64, 32, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#         (1): GELU(approximate='none')
#       )
#     )
#     (5): BasicConv(
#       (main): Sequential(
#         (0): Conv2d(32, 3, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#     )
#   )
#   (Decoder): ModuleList(
#     (0): DBlock(
#       (layers): Sequential(
#         (0): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (1): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (2): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (3): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): DeepPoolLayer(
#               (pools): ModuleList(
#                 (0): AvgPool2d(kernel_size=8, stride=8, padding=0)
#                 (1): AvgPool2d(kernel_size=4, stride=4, padding=0)
#                 (2): AvgPool2d(kernel_size=2, stride=2, padding=0)
#               )
#               (convs): ModuleList(
#                 (0-2): 3 x Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#               (dynas): ModuleList(
#                 (0-2): 3 x dynamic_filter(
#                   (conv): Conv2d(128, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (bn): BatchNorm2d(72, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (act): Tanh()
#                   (pad): ReflectionPad2d((1, 1, 1, 1))
#                   (ap): AdaptiveAvgPool2d(output_size=(1, 1))
#                   (gap): AdaptiveAvgPool2d(output_size=1)
#                 )
#               )
#               (relu): GELU(approximate='none')
#               (conv_sum): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             )
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#       )
#     )
#     (1): DBlock(
#       (layers): Sequential(
#         (0): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (1): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (2): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (3): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): DeepPoolLayer(
#               (pools): ModuleList(
#                 (0): AvgPool2d(kernel_size=8, stride=8, padding=0)
#                 (1): AvgPool2d(kernel_size=4, stride=4, padding=0)
#                 (2): AvgPool2d(kernel_size=2, stride=2, padding=0)
#               )
#               (convs): ModuleList(
#                 (0-2): 3 x Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#               (dynas): ModuleList(
#                 (0-2): 3 x dynamic_filter(
#                   (conv): Conv2d(64, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (bn): BatchNorm2d(72, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (act): Tanh()
#                   (pad): ReflectionPad2d((1, 1, 1, 1))
#                   (ap): AdaptiveAvgPool2d(output_size=(1, 1))
#                   (gap): AdaptiveAvgPool2d(output_size=1)
#                 )
#               )
#               (relu): GELU(approximate='none')
#               (conv_sum): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             )
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#       )
#     )
#     (2): DBlock(
#       (layers): Sequential(
#         (0): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (1): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (2): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (3): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): DeepPoolLayer(
#               (pools): ModuleList(
#                 (0): AvgPool2d(kernel_size=8, stride=8, padding=0)
#                 (1): AvgPool2d(kernel_size=4, stride=4, padding=0)
#                 (2): AvgPool2d(kernel_size=2, stride=2, padding=0)
#               )
#               (convs): ModuleList(
#                 (0-2): 3 x Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#               (dynas): ModuleList(
#                 (0-2): 3 x dynamic_filter(
#                   (conv): Conv2d(32, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (bn): BatchNorm2d(72, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (act): Tanh()
#                   (pad): ReflectionPad2d((1, 1, 1, 1))
#                   (ap): AdaptiveAvgPool2d(output_size=(1, 1))
#                   (gap): AdaptiveAvgPool2d(output_size=1)
#                 )
#               )
#               (relu): GELU(approximate='none')
#               (conv_sum): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             )
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#       )
#     )
#   )
#   (Convs): ModuleList(
#     (0): BasicConv(
#       (main): Sequential(
#         (0): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1))
#         (1): GELU(approximate='none')
#       )
#     )
#     (1): BasicConv(
#       (main): Sequential(
#         (0): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#         (1): GELU(approximate='none')
#       )
#     )
#   )
#   (ConvsOut): ModuleList(
#     (0): BasicConv(
#       (main): Sequential(
#         (0): Conv2d(128, 3, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#     )
#     (1): BasicConv(
#       (main): Sequential(
#         (0): Conv2d(64, 3, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#     )
#   )
#   (FAM1): FAM(
#     (merge): BasicConv(
#       (main): Sequential(
#         (0): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#     )
#   )
#   (SCM1): SCM(
#     (main): Sequential(
#       (0): BasicConv(
#         (main): Sequential(
#           (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): GELU(approximate='none')
#         )
#       )
#       (1): BasicConv(
#         (main): Sequential(
#           (0): Conv2d(32, 64, kernel_size=(1, 1), stride=(1, 1))
#           (1): GELU(approximate='none')
#         )
#       )
#       (2): BasicConv(
#         (main): Sequential(
#           (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): GELU(approximate='none')
#         )
#       )
#       (3): BasicConv(
#         (main): Sequential(
#           (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1))
#         )
#       )
#       (4): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#     )
#   )
#   (FAM2): FAM(
#     (merge): BasicConv(
#       (main): Sequential(
#         (0): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#     )
#   )
#   (SCM2): SCM(
#     (main): Sequential(
#       (0): BasicConv(
#         (main): Sequential(
#           (0): Conv2d(3, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): GELU(approximate='none')
#         )
#       )
#       (1): BasicConv(
#         (main): Sequential(
#           (0): Conv2d(16, 32, kernel_size=(1, 1), stride=(1, 1))
#           (1): GELU(approximate='none')
#         )
#       )
#       (2): BasicConv(
#         (main): Sequential(
#           (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): GELU(approximate='none')
#         )
#       )
#       (3): BasicConv(
#         (main): Sequential(
#           (0): Conv2d(32, 64, kernel_size=(1, 1), stride=(1, 1))
#         )
#       )
#       (4): InstanceNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#     )
#   )
# )
# Resume from 5

# %% [markdown]
# Test
# ==

# %%
import os
import torch
import torchvision.transforms as transforms
# from torch.backends import cudnn # Uncomment if you need it

class Args:
    model_name = 'IRNeXt'
    mode = 'test'
    data_dir = path

    # Train
    batch_size = 8
    learning_rate = 1e-4
    weight_decay = 0
    num_epoch = 300
    print_freq = 100
    num_worker = 8
    save_freq = 10
    valid_freq = 10
    momentum_value = 0.8

    resume = ''
    #/content/drive/MyDrive/MYresults2/IRNeXt/ITS/model.pkl
    # Test
    test_model = '/content/drive/MyDrive/OUTMYresults0_8/IRNeXt/ITS/Final.pkl'
    save_image = False

    # Directories (set these as per your requirement)
    model_save_dir = os.path.join('/content/drive/MyDrive/OUTMYresults0_8/', 'IRNeXt', 'ITS/')
    result_dir = os.path.join('/content/drive/MyDrive/OUTMYresults0_8/', model_name, 'test')

def main(args):
    # CUDNN
    # cudnn.benchmark = True # Uncomment if you need it

    if not os.path.exists('/content/drive/MyDrive/OUTMYresults0_8/'):
        os.makedirs(args.model_save_dir)
    if not os.path.exists('/content/drive/MyDrive/OUTMYresults0_8/' + args.model_name + '/'):
        os.makedirs('/content/drive/MyDrive/OUTMYresults0_8/' + args.model_name + '/')
    if not os.path.exists(args.model_save_dir):
        os.makedirs(args.model_save_dir)
    if not os.path.exists(args.result_dir):
        os.makedirs(args.result_dir)

    model = build_net()  # Make sure to define build_net or import it if it's defined elsewhere
    print(model)

    if torch.cuda.is_available():
        model.cuda()
    if args.mode == 'train':
        _train(model, args)  # Make sure to define _train or import it if it's defined elsewhere

    elif args.mode == 'test':
        _eval(model, args)   # Make sure to define _eval or import it if it's defined elsewhere

# Replace parser.parse_args() with an instance of the Args class
args = Args()
if not os.path.exists(args.model_save_dir):
    os.makedirs(args.model_save_dir)
# Copying files (make sure these paths are correct)
command = 'cp ' + 'models/layers.py ' + args.model_save_dir
os.system(command)
command = 'cp ' + 'models/IRNeXt.py ' + args.model_save_dir
os.system(command)
command = 'cp ' + 'train.py ' + args.model_save_dir
os.system(command)
command = 'cp ' + 'main.py ' + args.model_save_dir
os.system(command)
print(args)
main(args)
# Out:
# <__main__.Args object at 0x7d16d0162350>
# IRNeXt(
#   (Encoder): ModuleList(
#     (0): EBlock(
#       (layers): Sequential(
#         (0): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (1): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (2): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (3): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): DeepPoolLayer(
#               (pools): ModuleList(
#                 (0): AvgPool2d(kernel_size=8, stride=8, padding=0)
#                 (1): AvgPool2d(kernel_size=4, stride=4, padding=0)
#                 (2): AvgPool2d(kernel_size=2, stride=2, padding=0)
#               )
#               (convs): ModuleList(
#                 (0-2): 3 x Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#               (dynas): ModuleList(
#                 (0-2): 3 x dynamic_filter(
#                   (conv): Conv2d(32, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (bn): BatchNorm2d(72, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (act): Tanh()
#                   (pad): ReflectionPad2d((1, 1, 1, 1))
#                   (ap): AdaptiveAvgPool2d(output_size=(1, 1))
#                   (gap): AdaptiveAvgPool2d(output_size=1)
#                 )
#               )
#               (relu): GELU(approximate='none')
#               (conv_sum): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             )
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#       )
#     )
#     (1): EBlock(
#       (layers): Sequential(
#         (0): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (1): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (2): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (3): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): DeepPoolLayer(
#               (pools): ModuleList(
#                 (0): AvgPool2d(kernel_size=8, stride=8, padding=0)
#                 (1): AvgPool2d(kernel_size=4, stride=4, padding=0)
#                 (2): AvgPool2d(kernel_size=2, stride=2, padding=0)
#               )
#               (convs): ModuleList(
#                 (0-2): 3 x Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#               (dynas): ModuleList(
#                 (0-2): 3 x dynamic_filter(
#                   (conv): Conv2d(64, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (bn): BatchNorm2d(72, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (act): Tanh()
#                   (pad): ReflectionPad2d((1, 1, 1, 1))
#                   (ap): AdaptiveAvgPool2d(output_size=(1, 1))
#                   (gap): AdaptiveAvgPool2d(output_size=1)
#                 )
#               )
#               (relu): GELU(approximate='none')
#               (conv_sum): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             )
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#       )
#     )
#     (2): EBlock(
#       (layers): Sequential(
#         (0): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (1): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (2): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (3): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): DeepPoolLayer(
#               (pools): ModuleList(
#                 (0): AvgPool2d(kernel_size=8, stride=8, padding=0)
#                 (1): AvgPool2d(kernel_size=4, stride=4, padding=0)
#                 (2): AvgPool2d(kernel_size=2, stride=2, padding=0)
#               )
#               (convs): ModuleList(
#                 (0-2): 3 x Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#               (dynas): ModuleList(
#                 (0-2): 3 x dynamic_filter(
#                   (conv): Conv2d(128, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (bn): BatchNorm2d(72, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (act): Tanh()
#                   (pad): ReflectionPad2d((1, 1, 1, 1))
#                   (ap): AdaptiveAvgPool2d(output_size=(1, 1))
#                   (gap): AdaptiveAvgPool2d(output_size=1)
#                 )
#               )
#               (relu): GELU(approximate='none')
#               (conv_sum): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             )
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#       )
#     )
#   )
#   (feat_extract): ModuleList(
#     (0): BasicConv(
#       (main): Sequential(
#         (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): GELU(approximate='none')
#       )
#     )
#     (1): BasicConv(
#       (main): Sequential(
#         (0): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         (1): GELU(approximate='none')
#       )
#     )
#     (2): BasicConv(
#       (main): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         (1): GELU(approximate='none')
#       )
#     )
#     (3): BasicConv(
#       (main): Sequential(
#         (0): ConvTranspose2d(128, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#         (1): GELU(approximate='none')
#       )
#     )
#     (4): BasicConv(
#       (main): Sequential(
#         (0): ConvTranspose2d(64, 32, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#         (1): GELU(approximate='none')
#       )
#     )
#     (5): BasicConv(
#       (main): Sequential(
#         (0): Conv2d(32, 3, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#     )
#   )
#   (Decoder): ModuleList(
#     (0): DBlock(
#       (layers): Sequential(
#         (0): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (1): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (2): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (3): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): DeepPoolLayer(
#               (pools): ModuleList(
#                 (0): AvgPool2d(kernel_size=8, stride=8, padding=0)
#                 (1): AvgPool2d(kernel_size=4, stride=4, padding=0)
#                 (2): AvgPool2d(kernel_size=2, stride=2, padding=0)
#               )
#               (convs): ModuleList(
#                 (0-2): 3 x Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#               (dynas): ModuleList(
#                 (0-2): 3 x dynamic_filter(
#                   (conv): Conv2d(128, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (bn): BatchNorm2d(72, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (act): Tanh()
#                   (pad): ReflectionPad2d((1, 1, 1, 1))
#                   (ap): AdaptiveAvgPool2d(output_size=(1, 1))
#                   (gap): AdaptiveAvgPool2d(output_size=1)
#                 )
#               )
#               (relu): GELU(approximate='none')
#               (conv_sum): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             )
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#       )
#     )
#     (1): DBlock(
#       (layers): Sequential(
#         (0): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (1): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (2): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (3): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): DeepPoolLayer(
#               (pools): ModuleList(
#                 (0): AvgPool2d(kernel_size=8, stride=8, padding=0)
#                 (1): AvgPool2d(kernel_size=4, stride=4, padding=0)
#                 (2): AvgPool2d(kernel_size=2, stride=2, padding=0)
#               )
#               (convs): ModuleList(
#                 (0-2): 3 x Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#               (dynas): ModuleList(
#                 (0-2): 3 x dynamic_filter(
#                   (conv): Conv2d(64, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (bn): BatchNorm2d(72, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (act): Tanh()
#                   (pad): ReflectionPad2d((1, 1, 1, 1))
#                   (ap): AdaptiveAvgPool2d(output_size=(1, 1))
#                   (gap): AdaptiveAvgPool2d(output_size=1)
#                 )
#               )
#               (relu): GELU(approximate='none')
#               (conv_sum): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             )
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#       )
#     )
#     (2): DBlock(
#       (layers): Sequential(
#         (0): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (1): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (2): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (3): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): DeepPoolLayer(
#               (pools): ModuleList(
#                 (0): AvgPool2d(kernel_size=8, stride=8, padding=0)
#                 (1): AvgPool2d(kernel_size=4, stride=4, padding=0)
#                 (2): AvgPool2d(kernel_size=2, stride=2, padding=0)
#               )
#               (convs): ModuleList(
#                 (0-2): 3 x Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#               (dynas): ModuleList(
#                 (0-2): 3 x dynamic_filter(
#                   (conv): Conv2d(32, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (bn): BatchNorm2d(72, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (act): Tanh()
#                   (pad): ReflectionPad2d((1, 1, 1, 1))
#                   (ap): AdaptiveAvgPool2d(output_size=(1, 1))
#                   (gap): AdaptiveAvgPool2d(output_size=1)
#                 )
#               )
#               (relu): GELU(approximate='none')
#               (conv_sum): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             )
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#       )
#     )
#   )
#   (Convs): ModuleList(
#     (0): BasicConv(
#       (main): Sequential(
#         (0): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1))
#         (1): GELU(approximate='none')
#       )
#     )
#     (1): BasicConv(
#       (main): Sequential(
#         (0): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#         (1): GELU(approximate='none')
#       )
#     )
#   )
#   (ConvsOut): ModuleList(
#     (0): BasicConv(
#       (main): Sequential(
#         (0): Conv2d(128, 3, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#     )
#     (1): BasicConv(
#       (main): Sequential(
#         (0): Conv2d(64, 3, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#     )
#   )
#   (FAM1): FAM(
#     (merge): BasicConv(
#       (main): Sequential(
#         (0): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#     )
#   )
#   (SCM1): SCM(
#     (main): Sequential(
#       (0): BasicConv(
#         (main): Sequential(
#           (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): GELU(approximate='none')
#         )
#       )
#       (1): BasicConv(
#         (main): Sequential(
#           (0): Conv2d(32, 64, kernel_size=(1, 1), stride=(1, 1))
#           (1): GELU(approximate='none')
#         )
#       )
#       (2): BasicConv(
#         (main): Sequential(
#           (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): GELU(approximate='none')
#         )
#       )
#       (3): BasicConv(
#         (main): Sequential(
#           (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1))
#         )
#       )
#       (4): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#     )
#   )
#   (FAM2): FAM(
#     (merge): BasicConv(
#       (main): Sequential(
#         (0): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#     )
#   )
#   (SCM2): SCM(
#     (main): Sequential(
#       (0): BasicConv(
#         (main): Sequential(
#           (0): Conv2d(3, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): GELU(approximate='none')
#         )
#       )
#       (1): BasicConv(
#         (main): Sequential(
#           (0): Conv2d(16, 32, kernel_size=(1, 1), stride=(1, 1))
#           (1): GELU(approximate='none')
#         )
#       )
#       (2): BasicConv(
#         (main): Sequential(
#           (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): GELU(approximate='none')
#         )
#       )
#       (3): BasicConv(
#         (main): Sequential(
#           (0): Conv2d(32, 64, kernel_size=(1, 1), stride=(1, 1))
#         )
#       )
#       (4): InstanceNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#     )
#   )
# )
# /usr/local/lib/python3.10/dist-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# 1 iter PSNR_dehazing: 16.16 ssim: 0.859789
# 1 iter PSNR: 16.16 time: 0.523084
# 2 iter PSNR_dehazing: 20.86 ssim: 0.939445
# 2 iter PSNR: 20.86 time: 0.022793
# 3 iter PSNR_dehazing: 17.03 ssim: 0.924112
# 3 iter PSNR: 17.03 time: 0.021239
# 4 iter PSNR_dehazing: 21.52 ssim: 0.957853
# 4 iter PSNR: 21.52 time: 0.019902
# 5 iter PSNR_dehazing: 20.31 ssim: 0.919263
# 5 iter PSNR: 20.31 time: 0.020992
# 6 iter PSNR_dehazing: 12.95 ssim: 0.770071
# 6 iter PSNR: 12.95 time: 0.019874
# 7 iter PSNR_dehazing: 14.28 ssim: 0.791314
# 7 iter PSNR: 14.28 time: 0.019852
# 8 iter PSNR_dehazing: 10.05 ssim: 0.625996
# 8 iter PSNR: 10.05 time: 0.023105
# 9 iter PSNR_dehazing: 11.90 ssim: 0.650255
# 9 iter PSNR: 11.90 time: 0.020611
# 10 iter PSNR_dehazing: 17.17 ssim: 0.901300
# 10 iter PSNR: 17.17 time: 0.020563
# 11 iter PSNR_dehazing: 23.85 ssim: 0.968117
# 11 iter PSNR: 23.85 time: 0.019696
# 12 iter PSNR_dehazing: 18.65 ssim: 0.849485
# 12 iter PSNR: 18.65 time: 0.020096
# 13 iter PSNR_dehazing: 14.22 ssim: 0.829812
# 13 iter PSNR: 14.22 time: 0.019431
# 14 iter PSNR_dehazing: 14.91 ssim: 0.808020
# 14 iter PSNR: 14.91 time: 0.024544
# 15 iter PSNR_dehazing: 23.31 ssim: 0.964371
# 15 iter PSNR: 23.31 time: 0.019665
# 16 iter PSNR_dehazing: 24.21 ssim: 0.970043
# 16 iter PSNR: 24.21 time: 0.019461
# 17 iter PSNR_dehazing: 14.80 ssim: 0.739811
# 17 iter PSNR: 14.80 time: 0.019656
# 18 iter PSNR_dehazing: 18.74 ssim: 0.705333
# 18 iter PSNR: 18.74 time: 0.020466
# 19 iter PSNR_dehazing: 13.25 ssim: 0.750688
# 19 iter PSNR: 13.25 time: 0.021911
# 20 iter PSNR_dehazing: 16.85 ssim: 0.850841
# 20 iter PSNR: 16.85 time: 0.021507
# 21 iter PSNR_dehazing: 18.41 ssim: 0.902157
# 21 iter PSNR: 18.41 time: 0.022269
# 22 iter PSNR_dehazing: 14.90 ssim: 0.817019
# 22 iter PSNR: 14.90 time: 0.021560
# 23 iter PSNR_dehazing: 21.89 ssim: 0.957070
# 23 iter PSNR: 21.89 time: 0.022354
# 24 iter PSNR_dehazing: 14.82 ssim: 0.817814
# 24 iter PSNR: 14.82 time: 0.023222
# 25 iter PSNR_dehazing: 20.30 ssim: 0.958299
# 25 iter PSNR: 20.30 time: 0.020368
# 26 iter PSNR_dehazing: 12.91 ssim: 0.724975
# 26 iter PSNR: 12.91 time: 0.020238
# 27 iter PSNR_dehazing: 18.63 ssim: 0.922298
# 27 iter PSNR: 18.63 time: 0.019829
# 28 iter PSNR_dehazing: 14.54 ssim: 0.817483
# 28 iter PSNR: 14.54 time: 0.020487
# 29 iter PSNR_dehazing: 16.66 ssim: 0.900595
# 29 iter PSNR: 16.66 time: 0.019743
# 30 iter PSNR_dehazing: 13.24 ssim: 0.751932
# 30 iter PSNR: 13.24 time: 0.020108
# 31 iter PSNR_dehazing: 18.07 ssim: 0.873774
# 31 iter PSNR: 18.07 time: 0.019843
# 32 iter PSNR_dehazing: 13.18 ssim: 0.819418
# 32 iter PSNR: 13.18 time: 0.020030
# 33 iter PSNR_dehazing: 19.09 ssim: 0.926921
# 33 iter PSNR: 19.09 time: 0.021292
# 34 iter PSNR_dehazing: 13.95 ssim: 0.739169
# 34 iter PSNR: 13.95 time: 0.021472
# 35 iter PSNR_dehazing: 15.71 ssim: 0.807567
# 35 iter PSNR: 15.71 time: 0.020118
# 36 iter PSNR_dehazing: 12.56 ssim: 0.764368
# 36 iter PSNR: 12.56 time: 0.019536
# 37 iter PSNR_dehazing: 13.90 ssim: 0.767557
# 37 iter PSNR: 13.90 time: 0.019932
# 38 iter PSNR_dehazing: 14.87 ssim: 0.792964
# 38 iter PSNR: 14.87 time: 0.021319
# 39 iter PSNR_dehazing: 17.35 ssim: 0.838297
# 39 iter PSNR: 17.35 time: 0.019872
# 40 iter PSNR_dehazing: 16.19 ssim: 0.810225
# 40 iter PSNR: 16.19 time: 0.020378
# 41 iter PSNR_dehazing: 23.01 ssim: 0.958998
# 41 iter PSNR: 23.01 time: 0.019650
# 42 iter PSNR_dehazing: 13.59 ssim: 0.732978
# 42 iter PSNR: 13.59 time: 0.023863
# 43 iter PSNR_dehazing: 16.58 ssim: 0.890115
# 43 iter PSNR: 16.58 time: 0.020574
# 44 iter PSNR_dehazing: 12.76 ssim: 0.741814
# 44 iter PSNR: 12.76 time: 0.020085
# 45 iter PSNR_dehazing: 14.25 ssim: 0.748859
# 45 iter PSNR: 14.25 time: 0.019976
# 46 iter PSNR_dehazing: 11.11 ssim: 0.712124
# 46 iter PSNR: 11.11 time: 0.021554
# 47 iter PSNR_dehazing: 12.88 ssim: 0.740076
# 47 iter PSNR: 12.88 time: 0.020680
# 48 iter PSNR_dehazing: 12.83 ssim: 0.755846
# 48 iter PSNR: 12.83 time: 0.020188
# 49 iter PSNR_dehazing: 14.52 ssim: 0.794548
# 49 iter PSNR: 14.52 time: 0.022511
# 50 iter PSNR_dehazing: 22.08 ssim: 0.932742
# 50 iter PSNR: 22.08 time: 0.020873
# 51 iter PSNR_dehazing: 13.35 ssim: 0.794258
# 51 iter PSNR: 13.35 time: 0.020077
# 52 iter PSNR_dehazing: 14.01 ssim: 0.800341
# 52 iter PSNR: 14.01 time: 0.020062
# 53 iter PSNR_dehazing: 16.44 ssim: 0.886134
# 53 iter PSNR: 16.44 time: 0.021298
# 54 iter PSNR_dehazing: 16.14 ssim: 0.827896
# 54 iter PSNR: 16.14 time: 0.020843
# 55 iter PSNR_dehazing: 14.07 ssim: 0.797513
# 55 iter PSNR: 14.07 time: 0.020034
# 56 iter PSNR_dehazing: 15.99 ssim: 0.689413
# 56 iter PSNR: 15.99 time: 0.020257
# 57 iter PSNR_dehazing: 13.43 ssim: 0.699554
# 57 iter PSNR: 13.43 time: 0.020787
# 58 iter PSNR_dehazing: 14.94 ssim: 0.799338
# 58 iter PSNR: 14.94 time: 0.020122
# 59 iter PSNR_dehazing: 13.30 ssim: 0.739590
# 59 iter PSNR: 13.30 time: 0.019493
# 60 iter PSNR_dehazing: 11.96 ssim: 0.739994
# 60 iter PSNR: 11.96 time: 0.021585
# 61 iter PSNR_dehazing: 14.65 ssim: 0.732324
# 61 iter PSNR: 14.65 time: 0.021235
# 62 iter PSNR_dehazing: 15.94 ssim: 0.833227
# 62 iter PSNR: 15.94 time: 0.020985
# 63 iter PSNR_dehazing: 18.14 ssim: 0.913005
# 63 iter PSNR: 18.14 time: 0.020464
# 64 iter PSNR_dehazing: 15.54 ssim: 0.869774
# 64 iter PSNR: 15.54 time: 0.022415
# 65 iter PSNR_dehazing: 17.43 ssim: 0.894174
# 65 iter PSNR: 17.43 time: 0.020052
# 66 iter PSNR_dehazing: 13.42 ssim: 0.751719
# 66 iter PSNR: 13.42 time: 0.020046
# 67 iter PSNR_dehazing: 17.50 ssim: 0.841831
# 67 iter PSNR: 17.50 time: 0.020406
# 68 iter PSNR_dehazing: 13.35 ssim: 0.708389
# 68 iter PSNR: 13.35 time: 0.021138
# 69 iter PSNR_dehazing: 14.88 ssim: 0.779913
# 69 iter PSNR: 14.88 time: 0.020919
# 70 iter PSNR_dehazing: 13.90 ssim: 0.806795
# 70 iter PSNR: 13.90 time: 0.020612
# 71 iter PSNR_dehazing: 16.01 ssim: 0.807230
# 71 iter PSNR: 16.01 time: 0.019665
# 72 iter PSNR_dehazing: 13.14 ssim: 0.791640
# 72 iter PSNR: 13.14 time: 0.024843
# 73 iter PSNR_dehazing: 16.98 ssim: 0.894634
# 73 iter PSNR: 16.98 time: 0.020738
# 74 iter PSNR_dehazing: 15.23 ssim: 0.855620
# 74 iter PSNR: 15.23 time: 0.019483
# 75 iter PSNR_dehazing: 14.15 ssim: 0.795232
# 75 iter PSNR: 14.15 time: 0.020736
# 76 iter PSNR_dehazing: 23.18 ssim: 0.968187
# 76 iter PSNR: 23.18 time: 0.022640
# 77 iter PSNR_dehazing: 13.95 ssim: 0.810806
# 77 iter PSNR: 13.95 time: 0.020164
# 78 iter PSNR_dehazing: 17.80 ssim: 0.879574
# 78 iter PSNR: 17.80 time: 0.020636
# 79 iter PSNR_dehazing: 16.22 ssim: 0.828248
# 79 iter PSNR: 16.22 time: 0.019918
# 80 iter PSNR_dehazing: 21.28 ssim: 0.963253
# 80 iter PSNR: 21.28 time: 0.020460
# 81 iter PSNR_dehazing: 12.19 ssim: 0.726585
# 81 iter PSNR: 12.19 time: 0.020453
# 82 iter PSNR_dehazing: 12.67 ssim: 0.744361
# 82 iter PSNR: 12.67 time: 0.020660
# 83 iter PSNR_dehazing: 16.64 ssim: 0.881167
# 83 iter PSNR: 16.64 time: 0.019834
# 84 iter PSNR_dehazing: 20.77 ssim: 0.895019
# 84 iter PSNR: 20.77 time: 0.019518
# 85 iter PSNR_dehazing: 17.65 ssim: 0.876021
# 85 iter PSNR: 17.65 time: 0.021359
# 86 iter PSNR_dehazing: 15.42 ssim: 0.771797
# 86 iter PSNR: 15.42 time: 0.019846
# 87 iter PSNR_dehazing: 12.37 ssim: 0.786877
# 87 iter PSNR: 12.37 time: 0.019878
# 88 iter PSNR_dehazing: 20.70 ssim: 0.951780
# 88 iter PSNR: 20.70 time: 0.019444
# 89 iter PSNR_dehazing: 19.85 ssim: 0.951161
# 89 iter PSNR: 19.85 time: 0.019888
# 90 iter PSNR_dehazing: 13.42 ssim: 0.710020
# 90 iter PSNR: 13.42 time: 0.020913
# 91 iter PSNR_dehazing: 9.47 ssim: 0.621920
# 91 iter PSNR: 9.47 time: 0.021261
# 92 iter PSNR_dehazing: 18.93 ssim: 0.909318
# 92 iter PSNR: 18.93 time: 0.021357
# 93 iter PSNR_dehazing: 18.31 ssim: 0.894902
# 93 iter PSNR: 18.31 time: 0.021032
# 94 iter PSNR_dehazing: 12.83 ssim: 0.659096
# 94 iter PSNR: 12.83 time: 0.020447
# 95 iter PSNR_dehazing: 17.34 ssim: 0.912269
# 95 iter PSNR: 17.34 time: 0.021191
# 96 iter PSNR_dehazing: 17.09 ssim: 0.710873
# 96 iter PSNR: 17.09 time: 0.020168
# 97 iter PSNR_dehazing: 16.14 ssim: 0.799843
# 97 iter PSNR: 16.14 time: 0.020618
# 98 iter PSNR_dehazing: 14.02 ssim: 0.839161
# 98 iter PSNR: 14.02 time: 0.019300
# 99 iter PSNR_dehazing: 17.99 ssim: 0.928999
# 99 iter PSNR: 17.99 time: 0.020985
# 100 iter PSNR_dehazing: 11.89 ssim: 0.733163
# 100 iter PSNR: 11.89 time: 0.021175
# 101 iter PSNR_dehazing: 16.25 ssim: 0.882577
# 101 iter PSNR: 16.25 time: 0.020835
# 102 iter PSNR_dehazing: 20.77 ssim: 0.922671
# 102 iter PSNR: 20.77 time: 0.020795
# 103 iter PSNR_dehazing: 14.54 ssim: 0.841883
# 103 iter PSNR: 14.54 time: 0.021081
# 104 iter PSNR_dehazing: 15.66 ssim: 0.742405
# 104 iter PSNR: 15.66 time: 0.020571
# 105 iter PSNR_dehazing: 19.66 ssim: 0.918555
# 105 iter PSNR: 19.66 time: 0.020547
# 106 iter PSNR_dehazing: 14.52 ssim: 0.799228
# 106 iter PSNR: 14.52 time: 0.020652
# 107 iter PSNR_dehazing: 14.80 ssim: 0.841222
# 107 iter PSNR: 14.80 time: 0.019896
# 108 iter PSNR_dehazing: 14.03 ssim: 0.768421
# 108 iter PSNR: 14.03 time: 0.020198
# 109 iter PSNR_dehazing: 15.90 ssim: 0.782634
# 109 iter PSNR: 15.90 time: 0.020399
# 110 iter PSNR_dehazing: 17.00 ssim: 0.904415
# 110 iter PSNR: 17.00 time: 0.020316
# 111 iter PSNR_dehazing: 10.20 ssim: 0.725473
# 111 iter PSNR: 10.20 time: 0.021091
# 112 iter PSNR_dehazing: 13.26 ssim: 0.750303
# 112 iter PSNR: 13.26 time: 0.021420
# 113 iter PSNR_dehazing: 15.63 ssim: 0.856139
# 113 iter PSNR: 15.63 time: 0.020986
# 114 iter PSNR_dehazing: 13.41 ssim: 0.781971
# 114 iter PSNR: 13.41 time: 0.021202
# 115 iter PSNR_dehazing: 18.96 ssim: 0.895315
# 115 iter PSNR: 18.96 time: 0.020274
# 116 iter PSNR_dehazing: 16.28 ssim: 0.879694
# 116 iter PSNR: 16.28 time: 0.019116
# 117 iter PSNR_dehazing: 16.06 ssim: 0.889223
# 117 iter PSNR: 16.06 time: 0.019629
# 118 iter PSNR_dehazing: 13.02 ssim: 0.773396
# 118 iter PSNR: 13.02 time: 0.020042
# 119 iter PSNR_dehazing: 17.01 ssim: 0.899357
# 119 iter PSNR: 17.01 time: 0.019633
# 120 iter PSNR_dehazing: 8.88 ssim: 0.605133
# 120 iter PSNR: 8.88 time: 0.019735
# 121 iter PSNR_dehazing: 17.10 ssim: 0.865245
# 121 iter PSNR: 17.10 time: 0.019802
# 122 iter PSNR_dehazing: 13.13 ssim: 0.720064
# 122 iter PSNR: 13.13 time: 0.021002
# 123 iter PSNR_dehazing: 10.73 ssim: 0.643086
# 123 iter PSNR: 10.73 time: 0.020546
# 124 iter PSNR_dehazing: 15.08 ssim: 0.721532
# 124 iter PSNR: 15.08 time: 0.019657
# 125 iter PSNR_dehazing: 18.15 ssim: 0.857554
# 125 iter PSNR: 18.15 time: 0.020121
# 126 iter PSNR_dehazing: 21.03 ssim: 0.945421
# 126 iter PSNR: 21.03 time: 0.020819
# 127 iter PSNR_dehazing: 22.54 ssim: 0.951497
# 127 iter PSNR: 22.54 time: 0.021831
# 128 iter PSNR_dehazing: 16.49 ssim: 0.885289
# 128 iter PSNR: 16.49 time: 0.020923
# 129 iter PSNR_dehazing: 21.80 ssim: 0.904252
# 129 iter PSNR: 21.80 time: 0.020711
# 130 iter PSNR_dehazing: 12.67 ssim: 0.738336
# 130 iter PSNR: 12.67 time: 0.019654
# 131 iter PSNR_dehazing: 15.66 ssim: 0.886671
# 131 iter PSNR: 15.66 time: 0.020324
# 132 iter PSNR_dehazing: 18.51 ssim: 0.910556
# 132 iter PSNR: 18.51 time: 0.019474
# 133 iter PSNR_dehazing: 10.75 ssim: 0.627145
# 133 iter PSNR: 10.75 time: 0.019764
# 134 iter PSNR_dehazing: 14.90 ssim: 0.886149
# 134 iter PSNR: 14.90 time: 0.020267
# 135 iter PSNR_dehazing: 22.57 ssim: 0.967997
# 135 iter PSNR: 22.57 time: 0.021111
# 136 iter PSNR_dehazing: 17.41 ssim: 0.923850
# 136 iter PSNR: 17.41 time: 0.020515
# 137 iter PSNR_dehazing: 21.12 ssim: 0.951404
# 137 iter PSNR: 21.12 time: 0.019180
# 138 iter PSNR_dehazing: 11.00 ssim: 0.705435
# 138 iter PSNR: 11.00 time: 0.021127
# 139 iter PSNR_dehazing: 10.70 ssim: 0.645562
# 139 iter PSNR: 10.70 time: 0.019444
# 140 iter PSNR_dehazing: 12.35 ssim: 0.770195
# 140 iter PSNR: 12.35 time: 0.019708
# 141 iter PSNR_dehazing: 16.22 ssim: 0.840505
# 141 iter PSNR: 16.22 time: 0.019959
# 142 iter PSNR_dehazing: 12.59 ssim: 0.738647
# 142 iter PSNR: 12.59 time: 0.020249
# 143 iter PSNR_dehazing: 14.04 ssim: 0.755570
# 143 iter PSNR: 14.04 time: 0.020919
# 144 iter PSNR_dehazing: 11.27 ssim: 0.628722
# 144 iter PSNR: 11.27 time: 0.020211
# 145 iter PSNR_dehazing: 15.59 ssim: 0.748365
# 145 iter PSNR: 15.59 time: 0.019830
# 146 iter PSNR_dehazing: 20.72 ssim: 0.925823
# 146 iter PSNR: 20.72 time: 0.019866
# 147 iter PSNR_dehazing: 21.28 ssim: 0.952093
# 147 iter PSNR: 21.28 time: 0.020337
# 148 iter PSNR_dehazing: 12.51 ssim: 0.662472
# 148 iter PSNR: 12.51 time: 0.019989
# 149 iter PSNR_dehazing: 11.86 ssim: 0.725567
# 149 iter PSNR: 11.86 time: 0.019294
# 150 iter PSNR_dehazing: 17.48 ssim: 0.867421
# 150 iter PSNR: 17.48 time: 0.020967
# 151 iter PSNR_dehazing: 14.95 ssim: 0.770933
# 151 iter PSNR: 14.95 time: 0.020167
# 152 iter PSNR_dehazing: 14.12 ssim: 0.805093
# 152 iter PSNR: 14.12 time: 0.021176
# 153 iter PSNR_dehazing: 17.62 ssim: 0.872700
# 153 iter PSNR: 17.62 time: 0.019565
# 154 iter PSNR_dehazing: 15.37 ssim: 0.779511
# 154 iter PSNR: 15.37 time: 0.019768
# 155 iter PSNR_dehazing: 13.57 ssim: 0.698759
# 155 iter PSNR: 13.57 time: 0.021225
# 156 iter PSNR_dehazing: 17.26 ssim: 0.914167
# 156 iter PSNR: 17.26 time: 0.021107
# 157 iter PSNR_dehazing: 14.45 ssim: 0.854638
# 157 iter PSNR: 14.45 time: 0.019894
# 158 iter PSNR_dehazing: 12.15 ssim: 0.708133
# 158 iter PSNR: 12.15 time: 0.020230
# 159 iter PSNR_dehazing: 21.35 ssim: 0.953865
# 159 iter PSNR: 21.35 time: 0.021766
# 160 iter PSNR_dehazing: 11.19 ssim: 0.624982
# 160 iter PSNR: 11.19 time: 0.020214
# 161 iter PSNR_dehazing: 16.45 ssim: 0.824471
# 161 iter PSNR: 16.45 time: 0.020511
# 162 iter PSNR_dehazing: 9.53 ssim: 0.577187
# 162 iter PSNR: 9.53 time: 0.020119
# 163 iter PSNR_dehazing: 17.80 ssim: 0.897104
# 163 iter PSNR: 17.80 time: 0.019784
# 164 iter PSNR_dehazing: 13.30 ssim: 0.741204
# 164 iter PSNR: 13.30 time: 0.019509
# 165 iter PSNR_dehazing: 13.56 ssim: 0.744493
# 165 iter PSNR: 13.56 time: 0.021495
# 166 iter PSNR_dehazing: 13.38 ssim: 0.762391
# 166 iter PSNR: 13.38 time: 0.019669
# 167 iter PSNR_dehazing: 12.22 ssim: 0.784791
# 167 iter PSNR: 12.22 time: 0.020858
# 168 iter PSNR_dehazing: 12.13 ssim: 0.706619
# 168 iter PSNR: 12.13 time: 0.020513
# 169 iter PSNR_dehazing: 16.49 ssim: 0.756260
# 169 iter PSNR: 16.49 time: 0.020597
# 170 iter PSNR_dehazing: 16.93 ssim: 0.825461
# 170 iter PSNR: 16.93 time: 0.020739
# 171 iter PSNR_dehazing: 22.30 ssim: 0.961386
# 171 iter PSNR: 22.30 time: 0.020911
# 172 iter PSNR_dehazing: 11.57 ssim: 0.716382
# 172 iter PSNR: 11.57 time: 0.022727
# 173 iter PSNR_dehazing: 13.50 ssim: 0.844431
# 173 iter PSNR: 13.50 time: 0.020887
# 174 iter PSNR_dehazing: 17.79 ssim: 0.881693
# 174 iter PSNR: 17.79 time: 0.021856
# 175 iter PSNR_dehazing: 18.23 ssim: 0.920941
# 175 iter PSNR: 18.23 time: 0.021281
# 176 iter PSNR_dehazing: 20.47 ssim: 0.910607
# 176 iter PSNR: 20.47 time: 0.021768
# 177 iter PSNR_dehazing: 13.40 ssim: 0.740521
# 177 iter PSNR: 13.40 time: 0.020730
# 178 iter PSNR_dehazing: 16.04 ssim: 0.899176
# 178 iter PSNR: 16.04 time: 0.020036
# 179 iter PSNR_dehazing: 10.94 ssim: 0.689508
# 179 iter PSNR: 10.94 time: 0.020710
# 180 iter PSNR_dehazing: 18.83 ssim: 0.769035
# 180 iter PSNR: 18.83 time: 0.020826
# 181 iter PSNR_dehazing: 15.87 ssim: 0.893803
# 181 iter PSNR: 15.87 time: 0.022035
# 182 iter PSNR_dehazing: 11.10 ssim: 0.692249
# 182 iter PSNR: 11.10 time: 0.020321
# 183 iter PSNR_dehazing: 13.45 ssim: 0.807847
# 183 iter PSNR: 13.45 time: 0.022198
# 184 iter PSNR_dehazing: 21.52 ssim: 0.952089
# 184 iter PSNR: 21.52 time: 0.020741
# 185 iter PSNR_dehazing: 14.10 ssim: 0.702996
# 185 iter PSNR: 14.10 time: 0.021001
# 186 iter PSNR_dehazing: 15.21 ssim: 0.775662
# 186 iter PSNR: 15.21 time: 0.020393
# 187 iter PSNR_dehazing: 12.61 ssim: 0.786024
# 187 iter PSNR: 12.61 time: 0.022742
# 188 iter PSNR_dehazing: 12.29 ssim: 0.613527
# 188 iter PSNR: 12.29 time: 0.021067
# 189 iter PSNR_dehazing: 18.70 ssim: 0.908302
# 189 iter PSNR: 18.70 time: 0.020854
# 190 iter PSNR_dehazing: 10.17 ssim: 0.674939
# 190 iter PSNR: 10.17 time: 0.021238
# 191 iter PSNR_dehazing: 16.54 ssim: 0.917530
# 191 iter PSNR: 16.54 time: 0.023471
# 192 iter PSNR_dehazing: 18.87 ssim: 0.906568
# 192 iter PSNR: 18.87 time: 0.020983
# 193 iter PSNR_dehazing: 18.35 ssim: 0.831494
# 193 iter PSNR: 18.35 time: 0.020910
# 194 iter PSNR_dehazing: 16.53 ssim: 0.861428
# 194 iter PSNR: 16.53 time: 0.020756
# 195 iter PSNR_dehazing: 13.87 ssim: 0.790756
# 195 iter PSNR: 13.87 time: 0.021915
# 196 iter PSNR_dehazing: 13.48 ssim: 0.805936
# 196 iter PSNR: 13.48 time: 0.021189
# 197 iter PSNR_dehazing: 16.17 ssim: 0.800698
# 197 iter PSNR: 16.17 time: 0.020681
# 198 iter PSNR_dehazing: 16.43 ssim: 0.853395
# 198 iter PSNR: 16.43 time: 0.020521
# 199 iter PSNR_dehazing: 23.08 ssim: 0.965543
# 199 iter PSNR: 23.08 time: 0.023431
# 200 iter PSNR_dehazing: 16.29 ssim: 0.820385
# 200 iter PSNR: 16.29 time: 0.022160
# 201 iter PSNR_dehazing: 12.56 ssim: 0.780329
# 201 iter PSNR: 12.56 time: 0.020805
# 202 iter PSNR_dehazing: 15.42 ssim: 0.681225
# 202 iter PSNR: 15.42 time: 0.020247
# 203 iter PSNR_dehazing: 19.70 ssim: 0.838444
# 203 iter PSNR: 19.70 time: 0.020725
# 204 iter PSNR_dehazing: 11.76 ssim: 0.658846
# 204 iter PSNR: 11.76 time: 0.020342
# 205 iter PSNR_dehazing: 11.54 ssim: 0.668140
# 205 iter PSNR: 11.54 time: 0.020516
# 206 iter PSNR_dehazing: 13.79 ssim: 0.754914
# 206 iter PSNR: 13.79 time: 0.020453
# 207 iter PSNR_dehazing: 12.04 ssim: 0.754644
# 207 iter PSNR: 12.04 time: 0.020161
# 208 iter PSNR_dehazing: 20.47 ssim: 0.893763
# 208 iter PSNR: 20.47 time: 0.020271
# 209 iter PSNR_dehazing: 14.12 ssim: 0.788286
# 209 iter PSNR: 14.12 time: 0.021159
# 210 iter PSNR_dehazing: 12.34 ssim: 0.617094
# 210 iter PSNR: 12.34 time: 0.020393
# 211 iter PSNR_dehazing: 20.82 ssim: 0.859860
# 211 iter PSNR: 20.82 time: 0.020834
# 212 iter PSNR_dehazing: 13.72 ssim: 0.785931
# 212 iter PSNR: 13.72 time: 0.020384
# 213 iter PSNR_dehazing: 22.31 ssim: 0.917552
# 213 iter PSNR: 22.31 time: 0.020753
# 214 iter PSNR_dehazing: 15.16 ssim: 0.710434
# 214 iter PSNR: 15.16 time: 0.020886
# 215 iter PSNR_dehazing: 16.69 ssim: 0.861983
# 215 iter PSNR: 16.69 time: 0.021531
# 216 iter PSNR_dehazing: 14.50 ssim: 0.868725
# 216 iter PSNR: 14.50 time: 0.022857
# 217 iter PSNR_dehazing: 19.38 ssim: 0.924681
# 217 iter PSNR: 19.38 time: 0.020977
# 218 iter PSNR_dehazing: 14.71 ssim: 0.836940
# 218 iter PSNR: 14.71 time: 0.020434
# 219 iter PSNR_dehazing: 13.62 ssim: 0.780686
# 219 iter PSNR: 13.62 time: 0.020912
# 220 iter PSNR_dehazing: 14.99 ssim: 0.876160
# 220 iter PSNR: 14.99 time: 0.020478
# 221 iter PSNR_dehazing: 13.10 ssim: 0.739751
# 221 iter PSNR: 13.10 time: 0.020473
# 222 iter PSNR_dehazing: 15.45 ssim: 0.751811
# 222 iter PSNR: 15.45 time: 0.021136
# 223 iter PSNR_dehazing: 21.35 ssim: 0.940552
# 223 iter PSNR: 21.35 time: 0.021479
# 224 iter PSNR_dehazing: 17.77 ssim: 0.913858
# 224 iter PSNR: 17.77 time: 0.020413
# 225 iter PSNR_dehazing: 16.45 ssim: 0.903527
# 225 iter PSNR: 16.45 time: 0.020757
# 226 iter PSNR_dehazing: 10.62 ssim: 0.636111
# 226 iter PSNR: 10.62 time: 0.021238
# 227 iter PSNR_dehazing: 14.44 ssim: 0.777154
# 227 iter PSNR: 14.44 time: 0.022422
# 228 iter PSNR_dehazing: 17.40 ssim: 0.839359
# 228 iter PSNR: 17.40 time: 0.019908
# 229 iter PSNR_dehazing: 17.49 ssim: 0.891663
# 229 iter PSNR: 17.49 time: 0.019980
# 230 iter PSNR_dehazing: 15.79 ssim: 0.874122
# 230 iter PSNR: 15.79 time: 0.019844
# 231 iter PSNR_dehazing: 17.48 ssim: 0.905221
# 231 iter PSNR: 17.48 time: 0.019773
# 232 iter PSNR_dehazing: 18.01 ssim: 0.913525
# 232 iter PSNR: 18.01 time: 0.020232
# 233 iter PSNR_dehazing: 16.86 ssim: 0.874537
# 233 iter PSNR: 16.86 time: 0.020013
# 234 iter PSNR_dehazing: 15.95 ssim: 0.817204
# 234 iter PSNR: 15.95 time: 0.020863
# 235 iter PSNR_dehazing: 12.56 ssim: 0.721097
# 235 iter PSNR: 12.56 time: 0.020467
# 236 iter PSNR_dehazing: 23.70 ssim: 0.968017
# 236 iter PSNR: 23.70 time: 0.020908
# 237 iter PSNR_dehazing: 13.04 ssim: 0.746913
# 237 iter PSNR: 13.04 time: 0.020373
# 238 iter PSNR_dehazing: 17.67 ssim: 0.848887
# 238 iter PSNR: 17.67 time: 0.020607
# 239 iter PSNR_dehazing: 10.06 ssim: 0.643823
# 239 iter PSNR: 10.06 time: 0.021096
# 240 iter PSNR_dehazing: 19.65 ssim: 0.897703
# 240 iter PSNR: 19.65 time: 0.021534
# 241 iter PSNR_dehazing: 15.89 ssim: 0.877182
# 241 iter PSNR: 15.89 time: 0.020491
# 242 iter PSNR_dehazing: 12.96 ssim: 0.804755
# 242 iter PSNR: 12.96 time: 0.019928
# 243 iter PSNR_dehazing: 11.01 ssim: 0.751173
# 243 iter PSNR: 11.01 time: 0.020355
# 244 iter PSNR_dehazing: 18.43 ssim: 0.861957
# 244 iter PSNR: 18.43 time: 0.020310
# 245 iter PSNR_dehazing: 13.76 ssim: 0.824331
# 245 iter PSNR: 13.76 time: 0.020697
# 246 iter PSNR_dehazing: 16.29 ssim: 0.831634
# 246 iter PSNR: 16.29 time: 0.022062
# 247 iter PSNR_dehazing: 17.03 ssim: 0.895307
# 247 iter PSNR: 17.03 time: 0.021111
# 248 iter PSNR_dehazing: 19.80 ssim: 0.913011
# 248 iter PSNR: 19.80 time: 0.020637
# 249 iter PSNR_dehazing: 12.73 ssim: 0.842435
# 249 iter PSNR: 12.73 time: 0.020573
# 250 iter PSNR_dehazing: 11.96 ssim: 0.737552
# 250 iter PSNR: 11.96 time: 0.020348
# 251 iter PSNR_dehazing: 16.99 ssim: 0.881280
# 251 iter PSNR: 16.99 time: 0.020765
# 252 iter PSNR_dehazing: 18.63 ssim: 0.875002
# 252 iter PSNR: 18.63 time: 0.021595
# 253 iter PSNR_dehazing: 11.12 ssim: 0.718450
# 253 iter PSNR: 11.12 time: 0.024450
# 254 iter PSNR_dehazing: 15.42 ssim: 0.834087
# 254 iter PSNR: 15.42 time: 0.022038
# 255 iter PSNR_dehazing: 17.10 ssim: 0.888704
# 255 iter PSNR: 17.10 time: 0.020804
# 256 iter PSNR_dehazing: 12.63 ssim: 0.795179
# 256 iter PSNR: 12.63 time: 0.021167
# 257 iter PSNR_dehazing: 18.10 ssim: 0.915587
# 257 iter PSNR: 18.10 time: 0.021608
# 258 iter PSNR_dehazing: 13.80 ssim: 0.745968
# 258 iter PSNR: 13.80 time: 0.020601
# 259 iter PSNR_dehazing: 19.96 ssim: 0.924401
# 259 iter PSNR: 19.96 time: 0.020854
# 260 iter PSNR_dehazing: 15.07 ssim: 0.826182
# 260 iter PSNR: 15.07 time: 0.020457
# 261 iter PSNR_dehazing: 14.21 ssim: 0.798632
# 261 iter PSNR: 14.21 time: 0.020393
# 262 iter PSNR_dehazing: 20.14 ssim: 0.943421
# 262 iter PSNR: 20.14 time: 0.020445
# 263 iter PSNR_dehazing: 17.67 ssim: 0.875400
# 263 iter PSNR: 17.67 time: 0.020145
# 264 iter PSNR_dehazing: 18.78 ssim: 0.821162
# 264 iter PSNR: 18.78 time: 0.022590
# 265 iter PSNR_dehazing: 12.25 ssim: 0.718711
# 265 iter PSNR: 12.25 time: 0.020190
# 266 iter PSNR_dehazing: 13.95 ssim: 0.786222
# 266 iter PSNR: 13.95 time: 0.020116
# 267 iter PSNR_dehazing: 17.63 ssim: 0.814010
# 267 iter PSNR: 17.63 time: 0.020489
# 268 iter PSNR_dehazing: 11.17 ssim: 0.666816
# 268 iter PSNR: 11.17 time: 0.020588
# 269 iter PSNR_dehazing: 12.12 ssim: 0.612361
# 269 iter PSNR: 12.12 time: 0.020960
# 270 iter PSNR_dehazing: 14.88 ssim: 0.801274
# 270 iter PSNR: 14.88 time: 0.019979
# 271 iter PSNR_dehazing: 17.94 ssim: 0.900973
# 271 iter PSNR: 17.94 time: 0.020219
# 272 iter PSNR_dehazing: 18.46 ssim: 0.925589
# 272 iter PSNR: 18.46 time: 0.022296
# 273 iter PSNR_dehazing: 15.57 ssim: 0.849178
# 273 iter PSNR: 15.57 time: 0.019948
# 274 iter PSNR_dehazing: 16.38 ssim: 0.867530
# 274 iter PSNR: 16.38 time: 0.020937
# 275 iter PSNR_dehazing: 14.69 ssim: 0.803091
# 275 iter PSNR: 14.69 time: 0.019668
# 276 iter PSNR_dehazing: 20.18 ssim: 0.926762
# 276 iter PSNR: 20.18 time: 0.021760
# 277 iter PSNR_dehazing: 14.66 ssim: 0.853422
# 277 iter PSNR: 14.66 time: 0.021643
# 278 iter PSNR_dehazing: 13.59 ssim: 0.806618
# 278 iter PSNR: 13.59 time: 0.021362
# 279 iter PSNR_dehazing: 15.30 ssim: 0.826707
# 279 iter PSNR: 15.30 time: 0.021989
# 280 iter PSNR_dehazing: 10.27 ssim: 0.675101
# 280 iter PSNR: 10.27 time: 0.022111
# 281 iter PSNR_dehazing: 14.50 ssim: 0.767067
# 281 iter PSNR: 14.50 time: 0.019876
# 282 iter PSNR_dehazing: 11.28 ssim: 0.785833
# 282 iter PSNR: 11.28 time: 0.020669
# 283 iter PSNR_dehazing: 25.80 ssim: 0.984159
# 283 iter PSNR: 25.80 time: 0.022210
# 284 iter PSNR_dehazing: 18.60 ssim: 0.937986
# 284 iter PSNR: 18.60 time: 0.019510
# 285 iter PSNR_dehazing: 19.11 ssim: 0.905536
# 285 iter PSNR: 19.11 time: 0.020091
# 286 iter PSNR_dehazing: 13.83 ssim: 0.788271
# 286 iter PSNR: 13.83 time: 0.020335
# 287 iter PSNR_dehazing: 15.83 ssim: 0.799014
# 287 iter PSNR: 15.83 time: 0.020139
# 288 iter PSNR_dehazing: 11.62 ssim: 0.727125
# 288 iter PSNR: 11.62 time: 0.020576
# 289 iter PSNR_dehazing: 18.58 ssim: 0.924459
# 289 iter PSNR: 18.58 time: 0.020787
# 290 iter PSNR_dehazing: 17.78 ssim: 0.751339
# 290 iter PSNR: 17.78 time: 0.020427
# 291 iter PSNR_dehazing: 15.97 ssim: 0.829864
# 291 iter PSNR: 15.97 time: 0.020440
# 292 iter PSNR_dehazing: 13.37 ssim: 0.653787
# 292 iter PSNR: 13.37 time: 0.022238
# 293 iter PSNR_dehazing: 19.38 ssim: 0.919397
# 293 iter PSNR: 19.38 time: 0.020434
# 294 iter PSNR_dehazing: 16.01 ssim: 0.789248
# 294 iter PSNR: 16.01 time: 0.020392
# 295 iter PSNR_dehazing: 13.42 ssim: 0.819905
# 295 iter PSNR: 13.42 time: 0.019736
# 296 iter PSNR_dehazing: 18.87 ssim: 0.893043
# 296 iter PSNR: 18.87 time: 0.023098
# 297 iter PSNR_dehazing: 19.64 ssim: 0.882797
# 297 iter PSNR: 19.64 time: 0.020729
# 298 iter PSNR_dehazing: 18.03 ssim: 0.899633
# 298 iter PSNR: 18.03 time: 0.020359
# 299 iter PSNR_dehazing: 18.91 ssim: 0.894220
# 299 iter PSNR: 18.91 time: 0.020625
# 300 iter PSNR_dehazing: 14.75 ssim: 0.789248
# 300 iter PSNR: 14.75 time: 0.020075
# 301 iter PSNR_dehazing: 15.25 ssim: 0.765580
# 301 iter PSNR: 15.25 time: 0.020858
# 302 iter PSNR_dehazing: 13.78 ssim: 0.734021
# 302 iter PSNR: 13.78 time: 0.021337
# 303 iter PSNR_dehazing: 17.50 ssim: 0.907761
# 303 iter PSNR: 17.50 time: 0.020863
# 304 iter PSNR_dehazing: 17.19 ssim: 0.874991
# ...
# 305 iter PSNR: 15.39 time: 0.022907
# 306 iter PSNR_dehazing: 14.61 ssim: 0.790063
# 306 iter PSNR: 14.61 time: 0.019751
# 307 iter PSNR_dehazing: 18.48 ssim: 0.839944
# 307 iter PSNR: 18.48 time: 0.019879
# 308 iter PSNR_dehazing: 15.10 ssim: 0.728903
# 308 iter PSNR: 15.10 time: 0.020709
# 309 iter PSNR_dehazing: 13.36 ssim: 0.737260
# 309 iter PSNR: 13.36 time: 0.020304
# 310 iter PSNR_dehazing: 10.12 ssim: 0.614940
# 310 iter PSNR: 10.12 time: 0.019729
# 311 iter PSNR_dehazing: 19.45 ssim: 0.893538
# 311 iter PSNR: 19.45 time: 0.019707
# 312 iter PSNR_dehazing: 12.98 ssim: 0.775745
# 312 iter PSNR: 12.98 time: 0.020825
# 313 iter PSNR_dehazing: 21.56 ssim: 0.837420
# 313 iter PSNR: 21.56 time: 0.021655
# 314 iter PSNR_dehazing: 14.62 ssim: 0.813153
# 314 iter PSNR: 14.62 time: 0.021447
# 315 iter PSNR_dehazing: 13.21 ssim: 0.664176
# 315 iter PSNR: 13.21 time: 0.019804
# 316 iter PSNR_dehazing: 16.91 ssim: 0.838969
# 316 iter PSNR: 16.91 time: 0.020403
# 317 iter PSNR_dehazing: 18.69 ssim: 0.910730
# 317 iter PSNR: 18.69 time: 0.021251
# 318 iter PSNR_dehazing: 12.98 ssim: 0.833146
# 318 iter PSNR: 12.98 time: 0.019951
# 319 iter PSNR_dehazing: 14.68 ssim: 0.879262
# 319 iter PSNR: 14.68 time: 0.020824
# 320 iter PSNR_dehazing: 16.88 ssim: 0.903071
# 320 iter PSNR: 16.88 time: 0.020292
# 321 iter PSNR_dehazing: 18.08 ssim: 0.922023
# 321 iter PSNR: 18.08 time: 0.021938
# 322 iter PSNR_dehazing: 20.10 ssim: 0.906258
# 322 iter PSNR: 20.10 time: 0.020259
# 323 iter PSNR_dehazing: 14.11 ssim: 0.796988
# 323 iter PSNR: 14.11 time: 0.019684
# 324 iter PSNR_dehazing: 15.23 ssim: 0.786977
# 324 iter PSNR: 15.23 time: 0.020136
# 325 iter PSNR_dehazing: 14.26 ssim: 0.783998
# 325 iter PSNR: 14.26 time: 0.020698
# 326 iter PSNR_dehazing: 17.89 ssim: 0.925024
# 326 iter PSNR: 17.89 time: 0.019870
# 327 iter PSNR_dehazing: 13.73 ssim: 0.884699
# 327 iter PSNR: 13.73 time: 0.020149
# 328 iter PSNR_dehazing: 12.98 ssim: 0.794988
# 328 iter PSNR: 12.98 time: 0.018860
# 329 iter PSNR_dehazing: 14.70 ssim: 0.866485
# 329 iter PSNR: 14.70 time: 0.019990
# 330 iter PSNR_dehazing: 13.28 ssim: 0.825863
# 330 iter PSNR: 13.28 time: 0.019512
# 331 iter PSNR_dehazing: 11.67 ssim: 0.734514
# 331 iter PSNR: 11.67 time: 0.019960
# 332 iter PSNR_dehazing: 13.84 ssim: 0.726425
# 332 iter PSNR: 13.84 time: 0.019610
# 333 iter PSNR_dehazing: 14.62 ssim: 0.827492
# 333 iter PSNR: 14.62 time: 0.020688
# 334 iter PSNR_dehazing: 18.15 ssim: 0.908419
# 334 iter PSNR: 18.15 time: 0.020477
# 335 iter PSNR_dehazing: 14.41 ssim: 0.888521
# 335 iter PSNR: 14.41 time: 0.019635
# 336 iter PSNR_dehazing: 17.37 ssim: 0.827584
# 336 iter PSNR: 17.37 time: 0.019307
# 337 iter PSNR_dehazing: 15.33 ssim: 0.756781
# 337 iter PSNR: 15.33 time: 0.019787
# 338 iter PSNR_dehazing: 15.23 ssim: 0.828372
# 338 iter PSNR: 15.23 time: 0.019933
# 339 iter PSNR_dehazing: 20.27 ssim: 0.919794
# 339 iter PSNR: 20.27 time: 0.020159
# 340 iter PSNR_dehazing: 12.80 ssim: 0.742659
# 340 iter PSNR: 12.80 time: 0.019460
# 341 iter PSNR_dehazing: 15.07 ssim: 0.829328
# 341 iter PSNR: 15.07 time: 0.019253
# 342 iter PSNR_dehazing: 14.95 ssim: 0.843471
# 342 iter PSNR: 14.95 time: 0.020550
# 343 iter PSNR_dehazing: 13.52 ssim: 0.760441
# 343 iter PSNR: 13.52 time: 0.019607
# 344 iter PSNR_dehazing: 18.82 ssim: 0.933945
# 344 iter PSNR: 18.82 time: 0.020219
# 345 iter PSNR_dehazing: 22.86 ssim: 0.979425
# 345 iter PSNR: 22.86 time: 0.020129
# 346 iter PSNR_dehazing: 17.43 ssim: 0.907663
# 346 iter PSNR: 17.43 time: 0.019875
# 347 iter PSNR_dehazing: 17.72 ssim: 0.828767
# 347 iter PSNR: 17.72 time: 0.019781
# 348 iter PSNR_dehazing: 13.04 ssim: 0.799989
# 348 iter PSNR: 13.04 time: 0.019986
# 349 iter PSNR_dehazing: 13.99 ssim: 0.820542
# 349 iter PSNR: 13.99 time: 0.019573
# 350 iter PSNR_dehazing: 21.17 ssim: 0.957898
# 350 iter PSNR: 21.17 time: 0.020067
# 351 iter PSNR_dehazing: 15.21 ssim: 0.896618
# 351 iter PSNR: 15.21 time: 0.020296
# 352 iter PSNR_dehazing: 12.15 ssim: 0.799621
# 352 iter PSNR: 12.15 time: 0.019631
# 353 iter PSNR_dehazing: 17.75 ssim: 0.866015
# 353 iter PSNR: 17.75 time: 0.019887
# 354 iter PSNR_dehazing: 14.94 ssim: 0.758615
# 354 iter PSNR: 14.94 time: 0.020439
# 355 iter PSNR_dehazing: 11.20 ssim: 0.630524
# 355 iter PSNR: 11.20 time: 0.020624
# 356 iter PSNR_dehazing: 10.19 ssim: 0.619290
# 356 iter PSNR: 10.19 time: 0.019675
# 357 iter PSNR_dehazing: 18.19 ssim: 0.836751
# 357 iter PSNR: 18.19 time: 0.020965
# 358 iter PSNR_dehazing: 15.56 ssim: 0.824758
# 358 iter PSNR: 15.56 time: 0.020527
# 359 iter PSNR_dehazing: 14.65 ssim: 0.854864
# 359 iter PSNR: 14.65 time: 0.021573
# 360 iter PSNR_dehazing: 12.99 ssim: 0.745338
# 360 iter PSNR: 12.99 time: 0.019959
# 361 iter PSNR_dehazing: 13.67 ssim: 0.827892
# 361 iter PSNR: 13.67 time: 0.020321
# 362 iter PSNR_dehazing: 10.96 ssim: 0.702860
# 362 iter PSNR: 10.96 time: 0.020578
# 363 iter PSNR_dehazing: 14.98 ssim: 0.829839
# 363 iter PSNR: 14.98 time: 0.022377
# 364 iter PSNR_dehazing: 13.12 ssim: 0.773618
# 364 iter PSNR: 13.12 time: 0.019682
# 365 iter PSNR_dehazing: 20.51 ssim: 0.876263
# 365 iter PSNR: 20.51 time: 0.020188
# 366 iter PSNR_dehazing: 22.56 ssim: 0.951251
# 366 iter PSNR: 22.56 time: 0.019731
# 367 iter PSNR_dehazing: 20.95 ssim: 0.949530
# 367 iter PSNR: 20.95 time: 0.019824
# 368 iter PSNR_dehazing: 10.34 ssim: 0.643043
# 368 iter PSNR: 10.34 time: 0.020097
# 369 iter PSNR_dehazing: 16.29 ssim: 0.786616
# 369 iter PSNR: 16.29 time: 0.019846
# 370 iter PSNR_dehazing: 14.80 ssim: 0.850755
# 370 iter PSNR: 14.80 time: 0.020355
# 371 iter PSNR_dehazing: 13.46 ssim: 0.691380
# 371 iter PSNR: 13.46 time: 0.021168
# 372 iter PSNR_dehazing: 11.97 ssim: 0.724165
# 372 iter PSNR: 11.97 time: 0.021412
# 373 iter PSNR_dehazing: 18.94 ssim: 0.917536
# 373 iter PSNR: 18.94 time: 0.023581
# 374 iter PSNR_dehazing: 16.67 ssim: 0.861854
# 374 iter PSNR: 16.67 time: 0.021317
# 375 iter PSNR_dehazing: 20.05 ssim: 0.892534
# 375 iter PSNR: 20.05 time: 0.019761
# 376 iter PSNR_dehazing: 13.02 ssim: 0.690345
# 376 iter PSNR: 13.02 time: 0.020364
# 377 iter PSNR_dehazing: 9.42 ssim: 0.619967
# 377 iter PSNR: 9.42 time: 0.022866
# 378 iter PSNR_dehazing: 17.89 ssim: 0.910669
# 378 iter PSNR: 17.89 time: 0.020817
# 379 iter PSNR_dehazing: 20.12 ssim: 0.889775
# 379 iter PSNR: 20.12 time: 0.019823
# 380 iter PSNR_dehazing: 10.96 ssim: 0.707724
# 380 iter PSNR: 10.96 time: 0.021917
# 381 iter PSNR_dehazing: 14.04 ssim: 0.743717
# 381 iter PSNR: 14.04 time: 0.021831
# 382 iter PSNR_dehazing: 17.65 ssim: 0.858211
# 382 iter PSNR: 17.65 time: 0.021389
# 383 iter PSNR_dehazing: 22.42 ssim: 0.879097
# 383 iter PSNR: 22.42 time: 0.019725
# 384 iter PSNR_dehazing: 20.27 ssim: 0.854232
# 384 iter PSNR: 20.27 time: 0.020497
# 385 iter PSNR_dehazing: 13.92 ssim: 0.793174
# 385 iter PSNR: 13.92 time: 0.022502
# 386 iter PSNR_dehazing: 12.68 ssim: 0.692026
# 386 iter PSNR: 12.68 time: 0.020310
# 387 iter PSNR_dehazing: 16.64 ssim: 0.873028
# 387 iter PSNR: 16.64 time: 0.020020
# 388 iter PSNR_dehazing: 15.54 ssim: 0.818015
# 388 iter PSNR: 15.54 time: 0.019475
# 389 iter PSNR_dehazing: 16.14 ssim: 0.829710
# 389 iter PSNR: 16.14 time: 0.019754
# 390 iter PSNR_dehazing: 16.76 ssim: 0.832602
# 390 iter PSNR: 16.76 time: 0.023219
# 391 iter PSNR_dehazing: 14.47 ssim: 0.856659
# 391 iter PSNR: 14.47 time: 0.022225
# 392 iter PSNR_dehazing: 18.92 ssim: 0.915544
# 392 iter PSNR: 18.92 time: 0.021532
# 393 iter PSNR_dehazing: 15.91 ssim: 0.903267
# 393 iter PSNR: 15.91 time: 0.019888
# 394 iter PSNR_dehazing: 11.83 ssim: 0.750565
# 394 iter PSNR: 11.83 time: 0.020723
# 395 iter PSNR_dehazing: 18.96 ssim: 0.907272
# 395 iter PSNR: 18.96 time: 0.021113
# 396 iter PSNR_dehazing: 14.49 ssim: 0.804821
# 396 iter PSNR: 14.49 time: 0.020435
# 397 iter PSNR_dehazing: 20.68 ssim: 0.914745
# 397 iter PSNR: 20.68 time: 0.020087
# 398 iter PSNR_dehazing: 12.02 ssim: 0.664070
# 398 iter PSNR: 12.02 time: 0.019546
# 399 iter PSNR_dehazing: 14.21 ssim: 0.846876
# 399 iter PSNR: 14.21 time: 0.021014
# 400 iter PSNR_dehazing: 17.65 ssim: 0.917446
# 400 iter PSNR: 17.65 time: 0.019898
# 401 iter PSNR_dehazing: 9.79 ssim: 0.643097
# 401 iter PSNR: 9.79 time: 0.019858
# 402 iter PSNR_dehazing: 11.77 ssim: 0.734362
# 402 iter PSNR: 11.77 time: 0.019926
# 403 iter PSNR_dehazing: 17.92 ssim: 0.857920
# 403 iter PSNR: 17.92 time: 0.021007
# 404 iter PSNR_dehazing: 22.04 ssim: 0.946461
# 404 iter PSNR: 22.04 time: 0.020219
# 405 iter PSNR_dehazing: 16.55 ssim: 0.870832
# 405 iter PSNR: 16.55 time: 0.020200
# 406 iter PSNR_dehazing: 18.00 ssim: 0.756295
# 406 iter PSNR: 18.00 time: 0.020265
# 407 iter PSNR_dehazing: 22.97 ssim: 0.945225
# 407 iter PSNR: 22.97 time: 0.019936
# 408 iter PSNR_dehazing: 22.28 ssim: 0.956968
# 408 iter PSNR: 22.28 time: 0.021099
# 409 iter PSNR_dehazing: 17.00 ssim: 0.817254
# 409 iter PSNR: 17.00 time: 0.020094
# 410 iter PSNR_dehazing: 17.36 ssim: 0.802939
# 410 iter PSNR: 17.36 time: 0.020078
# 411 iter PSNR_dehazing: 21.45 ssim: 0.933177
# 411 iter PSNR: 21.45 time: 0.020978
# 412 iter PSNR_dehazing: 17.19 ssim: 0.809805
# 412 iter PSNR: 17.19 time: 0.019869
# 413 iter PSNR_dehazing: 17.47 ssim: 0.866183
# 413 iter PSNR: 17.47 time: 0.019502
# 414 iter PSNR_dehazing: 20.25 ssim: 0.922847
# 414 iter PSNR: 20.25 time: 0.021831
# 415 iter PSNR_dehazing: 16.92 ssim: 0.753634
# 415 iter PSNR: 16.92 time: 0.021339
# 416 iter PSNR_dehazing: 19.49 ssim: 0.890984
# 416 iter PSNR: 19.49 time: 0.020387
# 417 iter PSNR_dehazing: 16.57 ssim: 0.803508
# 417 iter PSNR: 16.57 time: 0.022652
# 418 iter PSNR_dehazing: 15.90 ssim: 0.849090
# 418 iter PSNR: 15.90 time: 0.020026
# 419 iter PSNR_dehazing: 14.36 ssim: 0.788668
# 419 iter PSNR: 14.36 time: 0.021517
# 420 iter PSNR_dehazing: 17.41 ssim: 0.831171
# 420 iter PSNR: 17.41 time: 0.020234
# 421 iter PSNR_dehazing: 17.45 ssim: 0.747480
# 421 iter PSNR: 17.45 time: 0.020685
# 422 iter PSNR_dehazing: 23.06 ssim: 0.959303
# 422 iter PSNR: 23.06 time: 0.020046
# 423 iter PSNR_dehazing: 22.10 ssim: 0.952676
# 423 iter PSNR: 22.10 time: 0.020266
# 424 iter PSNR_dehazing: 14.75 ssim: 0.789889
# 424 iter PSNR: 14.75 time: 0.019739
# 425 iter PSNR_dehazing: 16.89 ssim: 0.828370
# 425 iter PSNR: 16.89 time: 0.020250
# 426 iter PSNR_dehazing: 19.86 ssim: 0.950516
# 426 iter PSNR: 19.86 time: 0.021707
# 427 iter PSNR_dehazing: 14.50 ssim: 0.782436
# 427 iter PSNR: 14.50 time: 0.019679
# 428 iter PSNR_dehazing: 17.06 ssim: 0.823137
# 428 iter PSNR: 17.06 time: 0.020257
# 429 iter PSNR_dehazing: 16.24 ssim: 0.821350
# 429 iter PSNR: 16.24 time: 0.019602
# 430 iter PSNR_dehazing: 18.49 ssim: 0.909000
# 430 iter PSNR: 18.49 time: 0.022660
# 431 iter PSNR_dehazing: 13.42 ssim: 0.750079
# 431 iter PSNR: 13.42 time: 0.021183
# 432 iter PSNR_dehazing: 18.00 ssim: 0.819539
# 432 iter PSNR: 18.00 time: 0.021974
# 433 iter PSNR_dehazing: 13.96 ssim: 0.847844
# 433 iter PSNR: 13.96 time: 0.019983
# 434 iter PSNR_dehazing: 18.11 ssim: 0.847446
# 434 iter PSNR: 18.11 time: 0.020046
# 435 iter PSNR_dehazing: 18.51 ssim: 0.866976
# 435 iter PSNR: 18.51 time: 0.021146
# 436 iter PSNR_dehazing: 16.51 ssim: 0.858827
# 436 iter PSNR: 16.51 time: 0.019514
# 437 iter PSNR_dehazing: 15.21 ssim: 0.762859
# 437 iter PSNR: 15.21 time: 0.021079
# 438 iter PSNR_dehazing: 18.45 ssim: 0.861746
# 438 iter PSNR: 18.45 time: 0.020285
# 439 iter PSNR_dehazing: 14.59 ssim: 0.777530
# 439 iter PSNR: 14.59 time: 0.020810
# 440 iter PSNR_dehazing: 14.60 ssim: 0.780573
# 440 iter PSNR: 14.60 time: 0.019794
# 441 iter PSNR_dehazing: 17.59 ssim: 0.891790
# 441 iter PSNR: 17.59 time: 0.019713
# 442 iter PSNR_dehazing: 20.37 ssim: 0.879509
# 442 iter PSNR: 20.37 time: 0.019645
# 443 iter PSNR_dehazing: 20.06 ssim: 0.879587
# 443 iter PSNR: 20.06 time: 0.020105
# 444 iter PSNR_dehazing: 15.98 ssim: 0.813764
# 444 iter PSNR: 15.98 time: 0.020140
# 445 iter PSNR_dehazing: 14.49 ssim: 0.778724
# 445 iter PSNR: 14.49 time: 0.020551
# 446 iter PSNR_dehazing: 18.64 ssim: 0.908583
# 446 iter PSNR: 18.64 time: 0.019960
# 447 iter PSNR_dehazing: 18.01 ssim: 0.809682
# 447 iter PSNR: 18.01 time: 0.020404
# 448 iter PSNR_dehazing: 21.78 ssim: 0.894489
# 448 iter PSNR: 21.78 time: 0.020145
# 449 iter PSNR_dehazing: 14.09 ssim: 0.771921
# 449 iter PSNR: 14.09 time: 0.020173
# 450 iter PSNR_dehazing: 11.36 ssim: 0.615551
# 450 iter PSNR: 11.36 time: 0.020908
# 451 iter PSNR_dehazing: 16.44 ssim: 0.798424
# 451 iter PSNR: 16.44 time: 0.020374
# 452 iter PSNR_dehazing: 19.30 ssim: 0.933352
# 452 iter PSNR: 19.30 time: 0.019931
# 453 iter PSNR_dehazing: 21.81 ssim: 0.893701
# 453 iter PSNR: 21.81 time: 0.020268
# 454 iter PSNR_dehazing: 19.62 ssim: 0.837759
# 454 iter PSNR: 19.62 time: 0.019737
# 455 iter PSNR_dehazing: 17.41 ssim: 0.836814
# 455 iter PSNR: 17.41 time: 0.020252
# 456 iter PSNR_dehazing: 13.22 ssim: 0.756171
# 456 iter PSNR: 13.22 time: 0.020547
# 457 iter PSNR_dehazing: 16.80 ssim: 0.853095
# 457 iter PSNR: 16.80 time: 0.019604
# 458 iter PSNR_dehazing: 21.15 ssim: 0.936616
# 458 iter PSNR: 21.15 time: 0.020136
# 459 iter PSNR_dehazing: 11.18 ssim: 0.629721
# 459 iter PSNR: 11.18 time: 0.021250
# 460 iter PSNR_dehazing: 20.68 ssim: 0.938720
# 460 iter PSNR: 20.68 time: 0.021168
# 461 iter PSNR_dehazing: 16.16 ssim: 0.891900
# 461 iter PSNR: 16.16 time: 0.020711
# 462 iter PSNR_dehazing: 18.73 ssim: 0.906187
# 462 iter PSNR: 18.73 time: 0.020464
# 463 iter PSNR_dehazing: 17.72 ssim: 0.883493
# 463 iter PSNR: 17.72 time: 0.021643
# 464 iter PSNR_dehazing: 17.27 ssim: 0.849526
# 464 iter PSNR: 17.27 time: 0.020105
# 465 iter PSNR_dehazing: 15.28 ssim: 0.861266
# 465 iter PSNR: 15.28 time: 0.020279
# 466 iter PSNR_dehazing: 19.11 ssim: 0.896050
# 466 iter PSNR: 19.11 time: 0.019865
# 467 iter PSNR_dehazing: 19.41 ssim: 0.932209
# 467 iter PSNR: 19.41 time: 0.020376
# 468 iter PSNR_dehazing: 22.20 ssim: 0.957296
# 468 iter PSNR: 22.20 time: 0.021349
# 469 iter PSNR_dehazing: 21.66 ssim: 0.953949
# 469 iter PSNR: 21.66 time: 0.020295
# 470 iter PSNR_dehazing: 15.84 ssim: 0.837803
# 470 iter PSNR: 15.84 time: 0.020759
# 471 iter PSNR_dehazing: 15.58 ssim: 0.816942
# 471 iter PSNR: 15.58 time: 0.021568
# 472 iter PSNR_dehazing: 19.17 ssim: 0.902532
# 472 iter PSNR: 19.17 time: 0.020889
# 473 iter PSNR_dehazing: 17.22 ssim: 0.886856
# 473 iter PSNR: 17.22 time: 0.020520
# 474 iter PSNR_dehazing: 19.72 ssim: 0.943314
# 474 iter PSNR: 19.72 time: 0.020036
# 475 iter PSNR_dehazing: 15.74 ssim: 0.887609
# 475 iter PSNR: 15.74 time: 0.020575
# 476 iter PSNR_dehazing: 22.75 ssim: 0.948415
# 476 iter PSNR: 22.75 time: 0.021359
# 477 iter PSNR_dehazing: 16.99 ssim: 0.899354
# 477 iter PSNR: 16.99 time: 0.020504
# 478 iter PSNR_dehazing: 17.14 ssim: 0.907218
# 478 iter PSNR: 17.14 time: 0.021449
# 479 iter PSNR_dehazing: 17.72 ssim: 0.888314
# 479 iter PSNR: 17.72 time: 0.022011
# 480 iter PSNR_dehazing: 16.32 ssim: 0.862085
# 480 iter PSNR: 16.32 time: 0.022187
# 481 iter PSNR_dehazing: 16.28 ssim: 0.844960
# 481 iter PSNR: 16.28 time: 0.020953
# 482 iter PSNR_dehazing: 14.93 ssim: 0.815299
# 482 iter PSNR: 14.93 time: 0.021766
# 483 iter PSNR_dehazing: 17.26 ssim: 0.871223
# 483 iter PSNR: 17.26 time: 0.021105
# 484 iter PSNR_dehazing: 16.49 ssim: 0.824163
# 484 iter PSNR: 16.49 time: 0.021869
# 485 iter PSNR_dehazing: 27.28 ssim: 0.986296
# 485 iter PSNR: 27.28 time: 0.020901
# 486 iter PSNR_dehazing: 13.13 ssim: 0.721842
# 486 iter PSNR: 13.13 time: 0.020342
# 487 iter PSNR_dehazing: 20.31 ssim: 0.919768
# 487 iter PSNR: 20.31 time: 0.020479
# 488 iter PSNR_dehazing: 13.17 ssim: 0.775370
# 488 iter PSNR: 13.17 time: 0.020383
# 489 iter PSNR_dehazing: 20.00 ssim: 0.905387
# 489 iter PSNR: 20.00 time: 0.020946
# 490 iter PSNR_dehazing: 17.38 ssim: 0.855598
# 490 iter PSNR: 17.38 time: 0.021378
# 491 iter PSNR_dehazing: 15.41 ssim: 0.755621
# 491 iter PSNR: 15.41 time: 0.022108
# 492 iter PSNR_dehazing: 16.98 ssim: 0.879661
# 492 iter PSNR: 16.98 time: 0.021775
# 493 iter PSNR_dehazing: 19.32 ssim: 0.910049
# 493 iter PSNR: 19.32 time: 0.021692
# 494 iter PSNR_dehazing: 17.29 ssim: 0.772999
# 494 iter PSNR: 17.29 time: 0.020197
# 495 iter PSNR_dehazing: 18.11 ssim: 0.853755
# 495 iter PSNR: 18.11 time: 0.021731
# 496 iter PSNR_dehazing: 18.03 ssim: 0.860021
# 496 iter PSNR: 18.03 time: 0.023308
# 497 iter PSNR_dehazing: 16.40 ssim: 0.842078
# 497 iter PSNR: 16.40 time: 0.022368
# 498 iter PSNR_dehazing: 19.03 ssim: 0.840836
# 498 iter PSNR: 19.03 time: 0.022126
# 499 iter PSNR_dehazing: 16.49 ssim: 0.826564
# 499 iter PSNR: 16.49 time: 0.020848
# 500 iter PSNR_dehazing: 16.21 ssim: 0.825939
# 500 iter PSNR: 16.21 time: 0.023383
# ==========================================================
# The average PSNR is 16.14 dB
# The average SSIM is 0.82540 dB
# Average time: 0.021678
