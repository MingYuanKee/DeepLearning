# %%
import re
import matplotlib.pyplot as plt
import os

# Assuming the content is read from a file named "abc.txt"

file_path = r'C:\Users\mingy\Downloads\author_sots_indoor.txt'

# Read the file content
with open(file_path, 'r') as file:
    text_data = file.read()
    
psnr_ssim_pattern = r"PSNR_dehazing: (\d+\.\d+) ssim: (\d+\.\d+)"

# Extract PSNR and SSIM values using the same regex pattern
extracted_values = re.findall(psnr_ssim_pattern, text_data)

# Convert string tuples to float tuples
psnr_ssim_values = [(float(psnr), float(ssim)) for psnr, ssim in extracted_values]

# Splitting the PSNR and SSIM values into separate lists
psnr_author = [value[0] for value in psnr_ssim_values]
ssim_author = [value[1] for value in psnr_ssim_values]

file_path = r'C:\Users\mingy\Downloads\outdoor_SOTS.txt'

# Read the file content
with open(file_path, 'r') as file:
    text_data = file.read()
    
psnr_ssim_pattern = r"PSNR_dehazing: (\d+\.\d+) ssim: (\d+\.\d+)"

# Extract PSNR and SSIM values using the same regex pattern
extracted_values = re.findall(psnr_ssim_pattern, text_data)

# Convert string tuples to float tuples
psnr_ssim_values = [(float(psnr), float(ssim)) for psnr, ssim in extracted_values]

# Splitting the PSNR and SSIM values into separate lists
psnr_steve = [value[0] for value in psnr_ssim_values]
ssim_steve = [value[1] for value in psnr_ssim_values]



# Plotting the graph with PSNR and SSIM values
plt.figure(figsize=(10, 6))
plt.plot(psnr_author, label='PSNR author', linestyle='None', marker='o')
plt.plot(psnr_steve, label='PSNR Momemtum=0.2', linestyle='None', marker='x')
#plt.plot(epoch_psnr, label='PSNR')
plt.xlabel('Iteration')
plt.ylabel('PSNR (dB)')
plt.title('PSNR Outdoor Compare')
plt.legend()
file_path = os.path.join("./", "psnr_compare_dot_rm.png")
plt.savefig(file_path)

# Show the plot
plt.show()


# Plotting the graph with PSNR and SSIM values
plt.figure(figsize=(10, 6))
plt.plot(ssim_author, label='SSIM author', linestyle='None', marker='o')
plt.plot(ssim_steve, label='SSIM Momemtum=0.2', linestyle='None', marker='x')
#plt.plot(epoch_psnr, label='PSNR')
plt.xlabel('Iteration')
plt.ylabel('SSIM')
plt.title('SSIM Outdoor Compare')
plt.legend()
file_path = os.path.join("./", "ssim_compare_dot_rm.png")
plt.savefig(file_path)

# Show the plot
plt.show()

# %%
import re
import matplotlib.pyplot as plt
import os

# Assuming the content is read from a file named "abc.txt"

file_path = r'C:\Users\mingy\Downloads\val_M02_outdoor.txt'

# Read the file content
with open(file_path, 'r') as file:
    text_data = file.read()
    
psnr_ssim_pattern = r"The average PSNR is (\d+\.\d+) dB The average SSIM is (\d+\.\d+)"

# Extract PSNR and SSIM values using the same regex pattern
extracted_values2 = re.findall(psnr_ssim_pattern, text_data)
extracted_values2=extracted_values2[0]
extracted_values2x_value = float(extracted_values2[0])
extracted_values2y_value = float(extracted_values2[1])

# Convert string tuples to float tuples
psnr_ssim_values = [(float(psnr), float(ssim)) for psnr, ssim in extracted_values]

# Splitting the PSNR and SSIM values into separate lists
psnr_author = [value[0] for value in psnr_ssim_values]
ssim_author = [value[1] for value in psnr_ssim_values]




file_path = r'C:\Users\mingy\Downloads\val_M04_outdoor.txt'

# Read the file content
with open(file_path, 'r') as file:
    text_data = file.read()
    
psnr_ssim_pattern = r"The average PSNR is (\d+\.\d+) dB The average SSIM is (\d+\.\d+)"

# Extract PSNR and SSIM values using the same regex pattern
extracted_values4 = re.findall(psnr_ssim_pattern, text_data)
extracted_values4=extracted_values4[0]
extracted_values4x_value = float(extracted_values4[0])
extracted_values4y_value = float(extracted_values4[1])

# Convert string tuples to float tuples
psnr_ssim_values = [(float(psnr), float(ssim)) for psnr, ssim in extracted_values]

# Splitting the PSNR and SSIM values into separate lists
psnr_steve = [value[0] for value in psnr_ssim_values]
ssim_steve = [value[1] for value in psnr_ssim_values]






file_path = r'C:\Users\mingy\Downloads\val_M06_outdoor.txt'

# Read the file content
with open(file_path, 'r') as file:
    text_data = file.read()
    
psnr_ssim_pattern = r"The average PSNR is (\d+\.\d+) dB The average SSIM is (\d+\.\d+)"

# Extract PSNR and SSIM values using the same regex pattern
extracted_values6 = re.findall(psnr_ssim_pattern, text_data)
extracted_values6=extracted_values6[0]
extracted_values6x_value = float(extracted_values6[0])
extracted_values6y_value = float(extracted_values6[1])

# Convert string tuples to float tuples
psnr_ssim_values = [(float(psnr), float(ssim)) for psnr, ssim in extracted_values]

# Splitting the PSNR and SSIM values into separate lists
psnr_06 = [value[0] for value in psnr_ssim_values]
ssim_06 = [value[1] for value in psnr_ssim_values]





file_path = r'C:\Users\mingy\Downloads\val_M08_outdoor.txt'

# Read the file content
with open(file_path, 'r') as file:
    text_data = file.read()
    
psnr_ssim_pattern = r"The average PSNR is (\d+\.\d+) dB The average SSIM is (\d+\.\d+)"

# Extract PSNR and SSIM values using the same regex pattern
extracted_values8 = re.findall(psnr_ssim_pattern, text_data)
extracted_values8=extracted_values8[0]
extracted_values8x_value = float(extracted_values8[0])
extracted_values8y_value = float(extracted_values8[1])

# Convert string tuples to float tuples
psnr_ssim_values = [(float(psnr), float(ssim)) for psnr, ssim in extracted_values]

# Splitting the PSNR and SSIM values into separate lists
psnr_08 = [value[0] for value in psnr_ssim_values]
ssim_08 = [value[1] for value in psnr_ssim_values]












# Plotting the graph with PSNR and SSIM values
plt.figure(figsize=(10, 6))
plt.plot(extracted_values2x_value,extracted_values2y_value, label='Momemtum=0.2', linestyle='None', marker='x')
plt.plot(extracted_values4x_value,extracted_values4y_value, label='Momemtum=0.4', linestyle='None', marker='x')
plt.plot(extracted_values6x_value,extracted_values6y_value, label='Momemtum=0.6', linestyle='None', marker='x')
plt.plot(extracted_values8x_value,extracted_values8y_value, label='Momemtum=0.8', linestyle='None', marker='x')

#plt.plot(epoch_psnr, label='PSNR')
plt.xlabel('Average PSNR (dB)')
plt.ylabel('Average SSIM (dB)')
plt.title('Compare Outdoor PSNR and SSIM values across 4 Momentum Values')
plt.legend()
file_path = os.path.join("./", "psnr_compare_dot_rm.png")
plt.savefig(file_path)

# Show the plot
plt.show()

# %%
import re
import matplotlib.pyplot as plt
import os

# Assuming the content is read from a file named "abc.txt"

file_path = r'C:\Users\mingy\Downloads\val_M02_indoor.txt'

# Read the file content
with open(file_path, 'r') as file:
    text_data = file.read()
    
psnr_ssim_pattern = r"The average PSNR is (\d+\.\d+) dB The average SSIM is (\d+\.\d+)"

# Extract PSNR and SSIM values using the same regex pattern
extracted_values2 = re.findall(psnr_ssim_pattern, text_data)
extracted_values2=extracted_values2[0]
extracted_values2x_value = float(extracted_values2[0])
extracted_values2y_value = float(extracted_values2[1])

# Convert string tuples to float tuples
psnr_ssim_values = [(float(psnr), float(ssim)) for psnr, ssim in extracted_values]

# Splitting the PSNR and SSIM values into separate lists
psnr_author = [value[0] for value in psnr_ssim_values]
ssim_author = [value[1] for value in psnr_ssim_values]




file_path = r'C:\Users\mingy\Downloads\val_M04_indoor.txt'

# Read the file content
with open(file_path, 'r') as file:
    text_data = file.read()
    
psnr_ssim_pattern = r"The average PSNR is (\d+\.\d+) dB The average SSIM is (\d+\.\d+)"

# Extract PSNR and SSIM values using the same regex pattern
extracted_values4 = re.findall(psnr_ssim_pattern, text_data)
extracted_values4=extracted_values4[0]
extracted_values4x_value = float(extracted_values4[0])
extracted_values4y_value = float(extracted_values4[1])

# Convert string tuples to float tuples
psnr_ssim_values = [(float(psnr), float(ssim)) for psnr, ssim in extracted_values]

# Splitting the PSNR and SSIM values into separate lists
psnr_steve = [value[0] for value in psnr_ssim_values]
ssim_steve = [value[1] for value in psnr_ssim_values]






file_path = r'C:\Users\mingy\Downloads\val_M06_indoor.txt'

# Read the file content
with open(file_path, 'r') as file:
    text_data = file.read()
    
psnr_ssim_pattern = r"The average PSNR is (\d+\.\d+) dB The average SSIM is (\d+\.\d+)"

# Extract PSNR and SSIM values using the same regex pattern
extracted_values6 = re.findall(psnr_ssim_pattern, text_data)
extracted_values6=extracted_values6[0]
extracted_values6x_value = float(extracted_values6[0])
extracted_values6y_value = float(extracted_values6[1])

# Convert string tuples to float tuples
psnr_ssim_values = [(float(psnr), float(ssim)) for psnr, ssim in extracted_values]

# Splitting the PSNR and SSIM values into separate lists
psnr_06 = [value[0] for value in psnr_ssim_values]
ssim_06 = [value[1] for value in psnr_ssim_values]





file_path = r'C:\Users\mingy\Downloads\val_M08_indoor.txt'

# Read the file content
with open(file_path, 'r') as file:
    text_data = file.read()
    
psnr_ssim_pattern = r"The average PSNR is (\d+\.\d+) dB The average SSIM is (\d+\.\d+)"

# Extract PSNR and SSIM values using the same regex pattern
extracted_values8 = re.findall(psnr_ssim_pattern, text_data)
extracted_values8=extracted_values8[0]
extracted_values8x_value = float(extracted_values8[0])
extracted_values8y_value = float(extracted_values8[1])

# Convert string tuples to float tuples
psnr_ssim_values = [(float(psnr), float(ssim)) for psnr, ssim in extracted_values]

# Splitting the PSNR and SSIM values into separate lists
psnr_08 = [value[0] for value in psnr_ssim_values]
ssim_08 = [value[1] for value in psnr_ssim_values]












# Plotting the graph with PSNR and SSIM values
plt.figure(figsize=(10, 6))
plt.plot(extracted_values2x_value,extracted_values2y_value, label='Momemtum=0.2', linestyle='None', marker='x')
plt.plot(extracted_values4x_value,extracted_values4y_value, label='Momemtum=0.4', linestyle='None', marker='x')
plt.plot(extracted_values6x_value,extracted_values6y_value, label='Momemtum=0.6', linestyle='None', marker='x')
plt.plot(extracted_values8x_value,extracted_values8y_value, label='Momemtum=0.8', linestyle='None', marker='x')

#plt.plot(epoch_psnr, label='PSNR')
plt.xlabel('Average PSNR (dB)')
plt.ylabel('Average SSIM (dB)')
plt.title('Compare Indoor PSNR and SSIM values across 4 Momentum Values')
plt.legend()
file_path = os.path.join("./", "psnr_compare_dot_rm.png")
plt.savefig(file_path)

# Show the plot
plt.show()

# %%
plt.figure(figsize=(10, 6))

# Plotting the graph with PSNR and SSIM values along with lines connecting the points
plt.plot(extracted_values2x_value, extracted_values2y_value, label='Momemtum=0.2', linestyle='-', marker='o')
plt.plot(extracted_values4x_value, extracted_values4y_value, label='Momemtum=0.4', linestyle='-', marker='o')
plt.plot(extracted_values6x_value, extracted_values6y_value, label='Momemtum=0.6', linestyle='-', marker='o')
plt.plot(extracted_values8x_value, extracted_values8y_value, label='Momemtum=0.8', linestyle='-', marker='o')

plt.xlabel('Average PSNR (dB)')
plt.ylabel('Average SSIM (dB)')
plt.title('Compare Indoor PSNR and SSIM values across 4 Momentum Values')
plt.legend()

# Adding lines between the points
plt.plot([extracted_values2x_value, extracted_values4x_value], [extracted_values2y_value, extracted_values4y_value], linestyle='-', color='gray')
plt.plot([extracted_values4x_value, extracted_values6x_value], [extracted_values4y_value, extracted_values6y_value], linestyle='-', color='gray')
plt.plot([extracted_values6x_value, extracted_values8x_value], [extracted_values6y_value, extracted_values8y_value], linestyle='-', color='gray')

file_path = os.path.join("./", "psnr_compare_dot_rm_with_lines.png")
plt.savefig(file_path)

plt.show()
