# %% [markdown]
# Prep
# ==

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
# !pip install tensorboard einops scikit-image opencv-python pytorch_msssim warmup-scheduler
# Out:
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.10/dist-packages (2.14.1)
# Collecting einops
#   Downloading einops-0.7.0-py3-none-any.whl (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.6/44.6 kB 1.7 MB/s eta 0:00:00
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.10/dist-packages (0.19.3)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (4.8.0.76)
# Collecting pytorch_msssim
#   Downloading pytorch_msssim-1.0.0-py3-none-any.whl (7.7 kB)
# Collecting warmup-scheduler
#   Downloading warmup_scheduler-0.3.tar.gz (2.1 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (1.59.2)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (2.17.3)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (3.5.1)
# Requirement already satisfied: numpy>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (1.23.5)
# Requirement already satisfied: protobuf>=3.19.6 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (2.31.0)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (67.7.2)
# Requirement already satisfied: six>1.9 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (1.16.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (3.0.1)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image) (1.11.3)
# Requirement already satisfied: networkx>=2.2 in /usr/local/lib/python3.10/dist-packages (from scikit-image) (3.2.1)
# Requirement already satisfied: pillow!=7.1.0,!=7.1.1,!=8.3.0,>=6.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-image) (9.4.0)
# Requirement already satisfied: imageio>=2.4.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image) (2.31.6)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.10/dist-packages (from scikit-image) (2023.9.26)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image) (1.4.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from scikit-image) (23.2)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from pytorch_msssim) (2.1.0+cu118)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard) (2023.7.22)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard) (2.1.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->pytorch_msssim) (3.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch->pytorch_msssim) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->pytorch_msssim) (1.12)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->pytorch_msssim) (3.1.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch->pytorch_msssim) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch->pytorch_msssim) (2.1.0)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard) (3.2.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->pytorch_msssim) (1.3.0)
# Building wheels for collected packages: warmup-scheduler
#   Building wheel for warmup-scheduler (setup.py) ... done
#   Created wheel for warmup-scheduler: filename=warmup_scheduler-0.3-py3-none-any.whl size=2968 sha256=2897408afdd13a4385ba742fd565c61f2f9968f58ad1a399d6f20f3ea0971855
#   Stored in directory: /root/.cache/pip/wheels/59/01/9e/d1820991c32916e9808c940f572b462f3e46427f3e76c4d852
# Successfully built warmup-scheduler
# Installing collected packages: warmup-scheduler, einops, pytorch_msssim
# Successfully installed einops-0.7.0 pytorch_msssim-1.0.0 warmup-scheduler-0.3

# %%
# !pip install pytorch-msssim
# Out:
# Requirement already satisfied: pytorch-msssim in /usr/local/lib/python3.10/dist-packages (1.0.0)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from pytorch-msssim) (2.1.0+cu118)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->pytorch-msssim) (3.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch->pytorch-msssim) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->pytorch-msssim) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->pytorch-msssim) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->pytorch-msssim) (3.1.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch->pytorch-msssim) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch->pytorch-msssim) (2.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->pytorch-msssim) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->pytorch-msssim) (1.3.0)

# %%
# !pip install warmup-scheduler
# Out:
# Requirement already satisfied: warmup-scheduler in /usr/local/lib/python3.10/dist-packages (0.3)

# %%
#path = "/content/drive/MyDrive/reside-indoor"
# !unzip  ./drive/MyDrive/reside-indoor/indoor_train.zip -d ./reside-indoorMY/ > trainlog.txt
# !unzip  ./drive/MyDrive/reside-indoor/indoor_test.zip -d ./reside-indoorMY/ >testlog.txt
#/content/reside-indoorMY/train/hazy

# %%
path = "/content/reside-indoorMY"
#/content/reside-indoorMY/train/hazy
#path = "/content/reside-indoorMY"
#path = "./reside-indoorMY"

# %% [markdown]
# Data Augment
# ==

# %%
import random
import torchvision.transforms as transforms
import torchvision.transforms.functional as FUNCTIONAL


class PairRandomCrop(transforms.RandomCrop):

    def __call__(self, image, label):

        if self.padding is not None:
            image = FUNCTIONAL.pad(image, self.padding, self.fill, self.padding_mode)
            label = FUNCTIONAL.pad(label, self.padding, self.fill, self.padding_mode)

        # pad the width if needed
        if self.pad_if_needed and image.size[0] < self.size[1]:
            image = FUNCTIONAL.pad(image, (self.size[1] - image.size[0], 0), self.fill, self.padding_mode)
            label = FUNCTIONAL.pad(label, (self.size[1] - label.size[0], 0), self.fill, self.padding_mode)
        # pad the height if needed
        if self.pad_if_needed and image.size[1] < self.size[0]:
            image = FUNCTIONAL.pad(image, (0, self.size[0] - image.size[1]), self.fill, self.padding_mode)
            label = FUNCTIONAL.pad(label, (0, self.size[0] - image.size[1]), self.fill, self.padding_mode)

        i, j, h, w = self.get_params(image, self.size)

        return FUNCTIONAL.crop(image, i, j, h, w), FUNCTIONAL.crop(label, i, j, h, w)


class PairCompose(transforms.Compose):
    def __call__(self, image, label):
        for t in self.transforms:
            image, label = t(image, label)
        return image, label


class PairRandomHorizontalFilp(transforms.RandomHorizontalFlip):
    def __call__(self, img, label):
        """
        Args:
            img (PIL Image): Image to be flipped.

        Returns:
            PIL Image: Randomly flipped image.
        """
        if random.random() < self.p:
            return FUNCTIONAL.hflip(img), FUNCTIONAL.hflip(label)
        return img, label


class PairToTensor(transforms.ToTensor):
    def __call__(self, pic, label):
        """
        Args:
            pic (PIL Image or numpy.ndarray): Image to be converted to tensor.

        Returns:
            Tensor: Converted image.
        """
        return FUNCTIONAL.to_tensor(pic), FUNCTIONAL.to_tensor(label)

# %% [markdown]
# Data Loader
# ==

# %%
import os
import torch
import numpy as np
from PIL import Image as Image
from torch.utils.data import Dataset, DataLoader


def train_dataloader(path, batch_size=1, num_workers=0, use_transform=True): # we change batch size = 1, but the original batch size = 64
    image_dir = os.path.join(path, 'train')

    transform = None
    if use_transform:
        transform = PairCompose(
            [
                PairRandomCrop(256),
                PairRandomHorizontalFilp(),
                PairToTensor()
            ]
        )
    dataloader = DataLoader(
        DeblurDataset(image_dir, transform=transform),
        batch_size=batch_size,
        shuffle=True,
        num_workers=num_workers,
        pin_memory=True
    )
    return dataloader


def test_dataloader(path, batch_size=1, num_workers=0):
    image_dir = os.path.join(path, 'test')
    dataloader = DataLoader(
        DeblurDataset(image_dir, is_test=True),
        batch_size=batch_size,
        shuffle=False,
        num_workers=num_workers,
        pin_memory=True
    )

    return dataloader


def valid_dataloader(path, batch_size=1, num_workers=0):
    dataloader = DataLoader(
        DeblurDataset(os.path.join(path, 'test')),
        batch_size=batch_size,
        shuffle=False,
        num_workers=num_workers
    )

    return dataloader


class DeblurDataset(Dataset):
    def __init__(self, image_dir, transform=None, is_test=False):
        self.image_dir = image_dir
        self.image_list = os.listdir(os.path.join(image_dir, 'hazy/'))
        self._check_image(self.image_list)
        self.image_list.sort()
        self.transform = transform
        self.is_test = is_test

    def __len__(self):
        return len(self.image_list)

    def __getitem__(self, idx):
        image = Image.open(os.path.join(self.image_dir, 'hazy', self.image_list[idx]))
        label = Image.open(os.path.join(self.image_dir, 'gt', self.image_list[idx].split('_')[0]+'.png'))

        if self.transform:
            image, label = self.transform(image, label)
        else:
            image = FUNCTIONAL.to_tensor(image)
            label = FUNCTIONAL.to_tensor(label)
        if self.is_test:
            name = self.image_list[idx]
            return image, label, name
        return image, label

    @staticmethod
    def _check_image(lst):
        for x in lst:
            splits = x.split('.')
            if splits[-1] not in ['png', 'jpg', 'jpeg']:
                raise ValueError

# %% [markdown]
# Utils
# ==

# %%
import time
import numpy as np


class Adder(object):
    def __init__(self):
        self.count = 0
        self.num = float(0)

    def reset(self):
        self.count = 0
        self.num = float(0)

    def __call__(self, num):
        self.count += 1
        self.num += num

    def average(self):
        return self.num / self.count


class Timer(object):
    def __init__(self, option='s'):
        self.tm = 0
        self.option = option
        if option == 's':
            self.devider = 1
        elif option == 'm':
            self.devider = 60
        else:
            self.devider = 3600

    def tic(self):
        self.tm = time.time()

    def toc(self):
        return (time.time() - self.tm) / self.devider


def check_lr(optimizer):
    for i, param_group in enumerate(optimizer.param_groups):
        lr = param_group['lr']
    return lr

# %% [markdown]
# Eval
# ==

# %%
from skimage.metrics import peak_signal_noise_ratio
from pytorch_msssim import ssim
import torch.nn.functional as fe

from skimage import img_as_ubyte
import cv2

def _eval(model, args):
    state_dict = torch.load(args.test_model)
    model.load_state_dict(state_dict['model'])
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    dataloader = test_dataloader(args.data_dir, batch_size=1, num_workers=0)
    torch.cuda.empty_cache()
    adder = Adder()
    model.eval()
    factor = 32
    with torch.no_grad():
        psnr_adder = Adder()
        ssim_adder = Adder()

        for iter_idx, data in enumerate(dataloader):
            input_img, label_img, name = data

            input_img = input_img.to(device)

            h, w = input_img.shape[2], input_img.shape[3]
            H, W = ((h+factor)//factor)*factor, ((w+factor)//factor*factor)
            padh = H-h if h%factor!=0 else 0
            padw = W-w if w%factor!=0 else 0
            input_img = fe.pad(input_img, (0, padw, 0, padh), 'reflect')

            tm = time.time()

            pred = model(input_img)[2]
            pred = pred[:,:,:h,:w]

            elapsed = time.time() - tm
            adder(elapsed)

            pred_clip = torch.clamp(pred, 0, 1)

            pred_numpy = pred_clip.squeeze(0).cpu().numpy()
            label_numpy = label_img.squeeze(0).cpu().numpy()


            label_img = (label_img).cuda()
            psnr_val = 10 * torch.log10(1 / fe.mse_loss(pred_clip, label_img))
            down_ratio = max(1, round(min(H, W) / 256))
            ssim_val = ssim(fe.adaptive_avg_pool2d(pred_clip, (int(H / down_ratio), int(W / down_ratio))),
                            fe.adaptive_avg_pool2d(label_img, (int(H / down_ratio), int(W / down_ratio))),
                            data_range=1, size_average=False)
            print('%d iter PSNR_dehazing: %.2f ssim: %f' % (iter_idx + 1, psnr_val, ssim_val))
            ssim_adder(ssim_val)

            if args.save_image:
                save_name = os.path.join(args.result_dir, name[0])
                pred_clip += 0.5 / 255
                pred = FUNCTIONAL.to_pil_image(pred_clip.squeeze(0).cpu(), 'RGB')
                pred.save(save_name)

            psnr_mimo = peak_signal_noise_ratio(pred_numpy, label_numpy, data_range=1)
            psnr_adder(psnr_val)

            print('%d iter PSNR: %.2f time: %f' % (iter_idx + 1, psnr_mimo, elapsed))

        print('==========================================================')
        print('The average PSNR is %.2f dB' % (psnr_adder.average()))
        print('The average SSIM is %.5f dB' % (ssim_adder.average()))

        print("Average time: %f" % adder.average())

# %% [markdown]
# Layers
# ==

# %%
import torch
import torch.nn as nn
import torch.nn.functional as fl
import math

class BasicConv(nn.Module):
    def __init__(self, in_channel, out_channel, kernel_size, stride, bias=True, norm=False, relu=True, transpose=False):
        super(BasicConv, self).__init__()
        if bias and norm:
            bias = False

        padding = kernel_size // 2
        layers = list()
        if transpose:
            padding = kernel_size // 2 -1
            layers.append(nn.ConvTranspose2d(in_channel, out_channel, kernel_size, padding=padding, stride=stride, bias=bias))
        else:
            layers.append(
                nn.Conv2d(in_channel, out_channel, kernel_size, padding=padding, stride=stride, bias=bias))
        if norm:
            layers.append(nn.BatchNorm2d(out_channel))
        if relu:
            layers.append(nn.GELU())
        self.main = nn.Sequential(*layers)

    def forward(self, x):
        return self.main(x)


class ResBlock(nn.Module):
    def __init__(self, in_channel, out_channel, filter=False):
        super(ResBlock, self).__init__()
        self.main = nn.Sequential(
            BasicConv(in_channel, out_channel, kernel_size=3, stride=1, relu=True),
            DeepPoolLayer(in_channel, out_channel) if filter else nn.Identity(),
            BasicConv(out_channel, out_channel, kernel_size=3, stride=1, relu=False)
        )

    def forward(self, x):
        return self.main(x) + x


class DeepPoolLayer(nn.Module):
    def __init__(self, k, k_out):
        super(DeepPoolLayer, self).__init__()
        self.pools_sizes = [8,4,2]
        pools, convs, dynas = [],[],[]
        for i in self.pools_sizes:
            pools.append(nn.AvgPool2d(kernel_size=i, stride=i))
            convs.append(nn.Conv2d(k, k, 3, 1, 1, bias=False))
            dynas.append(dynamic_filter(inchannels=k, kernel_size=3))
        self.pools = nn.ModuleList(pools)
        self.convs = nn.ModuleList(convs)
        self.dynas = nn.ModuleList(dynas)
        self.relu = nn.GELU()
        self.conv_sum = nn.Conv2d(k, k_out, 3, 1, 1, bias=False)

    def forward(self, x):
        x_size = x.size()
        resl = x
        for i in range(len(self.pools_sizes)):
            if i == 0:
                y = self.dynas[i](self.convs[i](self.pools[i](x)))
            else:
                y = self.dynas[i](self.convs[i](self.pools[i](x)+y_up))
            resl = torch.add(resl, fl.interpolate(y, x_size[2:], mode='bilinear', align_corners=True))
            if i != len(self.pools_sizes)-1:
                y_up = fl.interpolate(y, scale_factor=2, mode='bilinear', align_corners=True)
        resl = self.relu(resl)
        resl = self.conv_sum(resl)

        return resl

class dynamic_filter(nn.Module):
    def __init__(self, inchannels, kernel_size=3, stride=1, group=8):
        super(dynamic_filter, self).__init__()

        self.stride = stride
        self.kernel_size = kernel_size
        self.group = group

        self.conv = nn.Conv2d(inchannels, group*kernel_size**2, kernel_size=1, stride=1, bias=False)
        self.bn = nn.BatchNorm2d(group*kernel_size**2)
        self.act = nn.Tanh()

        nn.init.kaiming_normal_(self.conv.weight, mode='fan_out', nonlinearity='relu')
        self.lamb_l = nn.Parameter(torch.zeros(inchannels), requires_grad=True)
        self.lamb_h = nn.Parameter(torch.zeros(inchannels), requires_grad=True)
        self.pad = nn.ReflectionPad2d(kernel_size//2)

        self.ap = nn.AdaptiveAvgPool2d((1, 1))
        self.gap = nn.AdaptiveAvgPool2d(1)

        self.inside_all = nn.Parameter(torch.zeros(inchannels,1,1), requires_grad=True)

    def forward(self, x):
        identity_input = x
        # the Conv_{3x3} layer in eq.3 is included in DeepPoolLayer.convs
        low_filter = self.ap(x)
        low_filter = self.conv(low_filter)
        low_filter = self.bn(low_filter)

        n, c, h, w = x.shape
        x = fl.unfold(self.pad(x), kernel_size=self.kernel_size).reshape(n, self.group, c//self.group, self.kernel_size**2, h*w)

        n,c1,p,q = low_filter.shape
        low_filter = low_filter.reshape(n, c1//self.kernel_size**2, self.kernel_size**2, p*q).unsqueeze(2)
        low_filter = self.act(low_filter)
        low_part = torch.sum(x * low_filter, dim=3).reshape(n, c, h, w)

        # the variables here are slightly different from the paper: (code) --> (paper)
        # low_filter --> A (eq.3)
        # In Eq.7, X*A'= X*(A_{l} + WA_{h})
        #              = X*A_{l} + WX*(A - A_{l})
        #              = X*A_{l} + WX*A - WX*A_{l}
        #              = WX*A - X*A_{l}(W-1)
        # we substitute gap for A_{l} for simplicity, which is a coarser low-frequency filter
        out_low = low_part * (self.inside_all + 1.) - self.inside_all * self.gap(identity_input)

        out_low = out_low * self.lamb_l[None,:,None,None]
        out_high = (identity_input) * (self.lamb_h[None,:,None,None] + 1.)

        return out_low + out_high

# %% [markdown]
# IRNeXt
# ==

# %%
import torch
import torch.nn as nn
import torch.nn.functional as fwd

class EBlock(nn.Module):
    def __init__(self, out_channel, num_res=8):
        super(EBlock, self).__init__()

        layers = [ResBlock(out_channel, out_channel) for _ in range(num_res-1)]
        layers.append(ResBlock(out_channel, out_channel, filter=True))
        self.layers = nn.Sequential(*layers)

    def forward(self, x):
        return self.layers(x)


class DBlock(nn.Module):
    def __init__(self, channel, num_res=8):
        super(DBlock, self).__init__()

        layers = [ResBlock(channel, channel) for _ in range(num_res-1)]
        layers.append(ResBlock(channel, channel, filter=True))
        self.layers = nn.Sequential(*layers)

    def forward(self, x):
        return self.layers(x)


class SCM(nn.Module):
    def __init__(self, out_plane):
        super(SCM, self).__init__()

        self.main = nn.Sequential(
            BasicConv(3, out_plane//4, kernel_size=3, stride=1, relu=True),
            BasicConv(out_plane // 4, out_plane // 2, kernel_size=1, stride=1, relu=True),
            BasicConv(out_plane // 2, out_plane // 2, kernel_size=3, stride=1, relu=True),
            BasicConv(out_plane // 2, out_plane, kernel_size=1, stride=1, relu=False),
            nn.InstanceNorm2d(out_plane, affine=True)
        )

    def forward(self, x):
        x = self.main(x)
        return x

class FAM(nn.Module):
    def __init__(self, channel):
        super(FAM, self).__init__()

        self.merge = BasicConv(channel*2, channel, kernel_size=3, stride=1, relu=False)

    def forward(self, x1, x2):
        return self.merge(torch.cat([x1, x2], dim=1))

class IRNeXt(nn.Module):
    def __init__(self, num_res=4):
        super(IRNeXt, self).__init__()

        base_channel = 32
        self.Encoder = nn.ModuleList([
            EBlock(base_channel, num_res),
            EBlock(base_channel*2, num_res),
            EBlock(base_channel*4, num_res),
        ])

        self.feat_extract = nn.ModuleList([
            BasicConv(3, base_channel, kernel_size=3, relu=True, stride=1),
            BasicConv(base_channel, base_channel*2, kernel_size=3, relu=True, stride=2),
            BasicConv(base_channel*2, base_channel*4, kernel_size=3, relu=True, stride=2),
            BasicConv(base_channel*4, base_channel*2, kernel_size=4, relu=True, stride=2, transpose=True),
            BasicConv(base_channel*2, base_channel, kernel_size=4, relu=True, stride=2, transpose=True),
            BasicConv(base_channel, 3, kernel_size=3, relu=False, stride=1)
        ])

        self.Decoder = nn.ModuleList([
            DBlock(base_channel * 4, num_res),
            DBlock(base_channel * 2, num_res),
            DBlock(base_channel, num_res)
        ])

        self.Convs = nn.ModuleList([
            BasicConv(base_channel * 4, base_channel * 2, kernel_size=1, relu=True, stride=1),
            BasicConv(base_channel * 2, base_channel, kernel_size=1, relu=True, stride=1),
        ])

        self.ConvsOut = nn.ModuleList(
            [
                BasicConv(base_channel * 4, 3, kernel_size=3, relu=False, stride=1),
                BasicConv(base_channel * 2, 3, kernel_size=3, relu=False, stride=1),
            ]
        )

        self.FAM1 = FAM(base_channel * 4)
        self.SCM1 = SCM(base_channel * 4)
        self.FAM2 = FAM(base_channel * 2)
        self.SCM2 = SCM(base_channel * 2)

    def forward(self, x):
        x_2 = fwd.interpolate(x, scale_factor=0.5)
        x_4 = fwd.interpolate(x_2, scale_factor=0.5)
        z2 = self.SCM2(x_2)
        z4 = self.SCM1(x_4)

        outputs = list()
        # 256
        x_ = self.feat_extract[0](x)
        res1 = self.Encoder[0](x_)
        # 128
        z = self.feat_extract[1](res1)
        z = self.FAM2(z, z2)
        res2 = self.Encoder[1](z)
        # 64
        z = self.feat_extract[2](res2)
        z = self.FAM1(z, z4)
        z = self.Encoder[2](z)

        z = self.Decoder[0](z)
        z_ = self.ConvsOut[0](z)
        # 128
        z = self.feat_extract[3](z)
        outputs.append(z_+x_4)

        z = torch.cat([z, res2], dim=1)
        z = self.Convs[0](z)
        z = self.Decoder[1](z)
        z_ = self.ConvsOut[1](z)
        # 256
        z = self.feat_extract[4](z)
        outputs.append(z_+x_2)

        z = torch.cat([z, res1], dim=1)
        z = self.Convs[1](z)
        z = self.Decoder[2](z)
        z = self.feat_extract[5](z)
        outputs.append(z+x)

        return outputs


def build_net():
    return IRNeXt()

# %% [markdown]
# Valid
# ==

# %%
from skimage.metrics import peak_signal_noise_ratio
import torch.nn.functional as fv


def _valid(model, args, ep):
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    its = valid_dataloader(args.data_dir, batch_size=1, num_workers=0)
    model.eval()
    psnr_adder = Adder()

    with torch.no_grad():
        print('Start Evaluation')
        factor = 32
        for idx, data in enumerate(its):
            input_img, label_img = data
            input_img = input_img.to(device)

            h, w = input_img.shape[2], input_img.shape[3]
            H, W = ((h+factor)//factor)*factor, ((w+factor)//factor*factor)
            padh = H-h if h%factor!=0 else 0
            padw = W-w if w%factor!=0 else 0
            input_img = fv.pad(input_img, (0, padw, 0, padh), 'reflect')

            if not os.path.exists(os.path.join(args.result_dir, '%d' % (ep))):
                os.mkdir(os.path.join(args.result_dir, '%d' % (ep)))

            pred = model(input_img)[2]
            pred = pred[:,:,:h,:w]

            pred_clip = torch.clamp(pred, 0, 1)
            p_numpy = pred_clip.squeeze(0).cpu().numpy()
            label_numpy = label_img.squeeze(0).cpu().numpy()

            psnr = peak_signal_noise_ratio(p_numpy, label_numpy, data_range=1)

            psnr_adder(psnr)
            print('\r%03d'%idx, end=' ')

    print('\n')
    model.train()
    return psnr_adder.average()

# %% [markdown]
# TRAIN
# ==

# %%
from torch.utils.tensorboard import SummaryWriter
import torch.nn.functional as ft
import torch.optim as optim


from warmup_scheduler import GradualWarmupScheduler

def _train(model, args):
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    model.to(device)
    criterion = torch.nn.L1Loss().to(device)
    optimizer = optim.SGD(model.parameters(), lr=args.learning_rate, momentum=args.momentum_value, nesterov=True)

    #optimizer = SGLD(params=model.parameters(), lr=args.learning_rate, weight_decay=args.weight_decay)
    dataloader = train_dataloader(args.data_dir, args.batch_size, args.num_worker)
    max_iter = len(dataloader)
    warmup_epochs=3
    scheduler_cosine = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=args.num_epoch-warmup_epochs, eta_min=1e-6)
    scheduler = GradualWarmupScheduler(optimizer, multiplier=1, total_epoch=warmup_epochs, after_scheduler=scheduler_cosine)
    scheduler.step()
    epoch = 1
    if args.resume:
        state = torch.load(args.resume)
        epoch = state['epoch']
        optimizer.load_state_dict(state['optimizer'])
        model.load_state_dict(state['model'])
        print('Resume from %d'%epoch)
        epoch += 1
        for i in range(epoch-1):
          scheduler.step()

    writer = SummaryWriter()
    epoch_pixel_adder = Adder()
    epoch_fft_adder = Adder()
    iter_pixel_adder = Adder()
    iter_fft_adder = Adder()
    epoch_timer = Timer('m')
    iter_timer = Timer('m')
    best_psnr=-1

    for epoch_idx in range(epoch, args.num_epoch + 1):

        epoch_timer.tic()
        iter_timer.tic()
        for iter_idx, batch_data in enumerate(dataloader):

            input_img, label_img = batch_data
            input_img = input_img.to(device)
            label_img = label_img.to(device)

            optimizer.zero_grad()
            pred_img = model(input_img)
            label_img2 = ft.interpolate(label_img, scale_factor=0.5, mode='bilinear')
            label_img4 = ft.interpolate(label_img, scale_factor=0.25, mode='bilinear')
            l1 = criterion(pred_img[0], label_img4)
            l2 = criterion(pred_img[1], label_img2)
            l3 = criterion(pred_img[2], label_img)
            loss_content = l1+l2+l3

            label_fft1 = torch.fft.fft2(label_img4, dim=(-2,-1))
            label_fft1 = torch.stack((label_fft1.real, label_fft1.imag), -1)

            pred_fft1 = torch.fft.fft2(pred_img[0], dim=(-2,-1))
            pred_fft1 = torch.stack((pred_fft1.real, pred_fft1.imag), -1)

            label_fft2 = torch.fft.fft2(label_img2, dim=(-2,-1))
            label_fft2 = torch.stack((label_fft2.real, label_fft2.imag), -1)

            pred_fft2 = torch.fft.fft2(pred_img[1], dim=(-2,-1))
            pred_fft2 = torch.stack((pred_fft2.real, pred_fft2.imag), -1)

            label_fft3 = torch.fft.fft2(label_img, dim=(-2,-1))
            label_fft3 = torch.stack((label_fft3.real, label_fft3.imag), -1)

            pred_fft3 = torch.fft.fft2(pred_img[2], dim=(-2,-1))
            pred_fft3 = torch.stack((pred_fft3.real, pred_fft3.imag), -1)

            f1 = criterion(pred_fft1, label_fft1)
            f2 = criterion(pred_fft2, label_fft2)
            f3 = criterion(pred_fft3, label_fft3)
            loss_fft = f1+f2+f3

            loss = loss_content + 0.1 * loss_fft
            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), 0.001)
            optimizer.step()

            iter_pixel_adder(loss_content.item())
            iter_fft_adder(loss_fft.item())

            epoch_pixel_adder(loss_content.item())
            epoch_fft_adder(loss_fft.item())

            if (iter_idx + 1) % args.print_freq == 0:
                print("Time: %7.4f Epoch: %03d Iter: %4d/%4d LR: %.10f Loss content: %7.4f Loss fft: %7.4f" % (
                    iter_timer.toc(), epoch_idx, iter_idx + 1, max_iter, scheduler.get_lr()[0], iter_pixel_adder.average(),
                    iter_fft_adder.average()))
                writer.add_scalar('Pixel Loss', iter_pixel_adder.average(), iter_idx + (epoch_idx-1)* max_iter)
                writer.add_scalar('FFT Loss', iter_fft_adder.average(), iter_idx + (epoch_idx - 1) * max_iter)

                iter_timer.tic()
                iter_pixel_adder.reset()
                iter_fft_adder.reset()
        overwrite_name = os.path.join(args.model_save_dir, 'model.pkl')
        torch.save({'model': model.state_dict(),
                    'optimizer': optimizer.state_dict(),
                    'epoch': epoch_idx}, overwrite_name)

        if epoch_idx % args.save_freq == 0:
            save_name = os.path.join(args.model_save_dir, 'model_%d.pkl' % epoch_idx)
            torch.save({'model': model.state_dict()}, save_name)
        print("EPOCH: %02d\nElapsed time: %4.2f Epoch Pixel Loss: %7.4f Epoch FFT Loss: %7.4f" % (
            epoch_idx, epoch_timer.toc(), epoch_pixel_adder.average(), epoch_fft_adder.average()))
        epoch_fft_adder.reset()
        epoch_pixel_adder.reset()
        scheduler.step()
        if epoch_idx % args.valid_freq == 0:
            val = _valid(model, args, epoch_idx)
            print('%03d epoch \n Average PSNR %.2f dB' % (epoch_idx, val))
            writer.add_scalar('PSNR', val, epoch_idx)
            if val >= best_psnr:
                torch.save({'model': model.state_dict()}, os.path.join(args.model_save_dir, 'Best.pkl'))
    save_name = os.path.join(args.model_save_dir, 'Final.pkl')
    torch.save({'model': model.state_dict()}, save_name)

# %% [markdown]
# Main (test model)
# ==

# %%
import os
import torch
import torchvision.transforms as transforms
# from torch.backends import cudnn # Uncomment if you need it

class Args:
    model_name = 'IRNeXt'
    mode = 'train'
    data_dir = path

    # Train
    batch_size = 4
    learning_rate = 1e-4
    weight_decay = 0
    num_epoch = 20
    print_freq = 100
    num_worker = 8
    save_freq = 10
    valid_freq = 10
    momentum_value = 0.8

    resume = ''
    #/content/drive/MyDrive/MYresults2/IRNeXt/ITS/model.pkl
    # Test
    test_model = '/content/drive/MyDrive/MYresults2_8/IRNeXt/ITS/Final.pkl'
    save_image = False

    # Directories (set these as per your requirement)
    model_save_dir = os.path.join('/content/drive/MyDrive/MYresults2_8/', 'IRNeXt', 'ITS/')
    result_dir = os.path.join('/content/drive/MyDrive/MYresults2_8/', model_name, 'test')

def main(args):
    # CUDNN
    # cudnn.benchmark = True # Uncomment if you need it

    if not os.path.exists('/content/drive/MyDrive/MYresults2_8/'):
        os.makedirs(args.model_save_dir)
    if not os.path.exists('/content/drive/MyDrive/MYresults2_8/' + args.model_name + '/'):
        os.makedirs('/content/drive/MyDrive/MYresults2_8/' + args.model_name + '/')
    if not os.path.exists(args.model_save_dir):
        os.makedirs(args.model_save_dir)
    if not os.path.exists(args.result_dir):
        os.makedirs(args.result_dir)

    model = build_net()  # Make sure to define build_net or import it if it's defined elsewhere
    print(model)

    if torch.cuda.is_available():
        model.cuda()
    if args.mode == 'train':
        _train(model, args)  # Make sure to define _train or import it if it's defined elsewhere

    elif args.mode == 'test':
        _eval(model, args)   # Make sure to define _eval or import it if it's defined elsewhere

# Replace parser.parse_args() with an instance of the Args class
args = Args()
if not os.path.exists(args.model_save_dir):
    os.makedirs(args.model_save_dir)
# Copying files (make sure these paths are correct)
command = 'cp ' + 'models/layers.py ' + args.model_save_dir
os.system(command)
command = 'cp ' + 'models/IRNeXt.py ' + args.model_save_dir
os.system(command)
command = 'cp ' + 'train.py ' + args.model_save_dir
os.system(command)
command = 'cp ' + 'main.py ' + args.model_save_dir
os.system(command)
print(args)
main(args)
# Out:
# <__main__.Args object at 0x7d9dbc5edb40>
# IRNeXt(
#   (Encoder): ModuleList(
#     (0): EBlock(
#       (layers): Sequential(
#         (0): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (1): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (2): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (3): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): DeepPoolLayer(
#               (pools): ModuleList(
#                 (0): AvgPool2d(kernel_size=8, stride=8, padding=0)
#                 (1): AvgPool2d(kernel_size=4, stride=4, padding=0)
#                 (2): AvgPool2d(kernel_size=2, stride=2, padding=0)
#               )
#               (convs): ModuleList(
#                 (0-2): 3 x Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#               (dynas): ModuleList(
#                 (0-2): 3 x dynamic_filter(
#                   (conv): Conv2d(32, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (bn): BatchNorm2d(72, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (act): Tanh()
#                   (pad): ReflectionPad2d((1, 1, 1, 1))
#                   (ap): AdaptiveAvgPool2d(output_size=(1, 1))
#                   (gap): AdaptiveAvgPool2d(output_size=1)
#                 )
#               )
#               (relu): GELU(approximate='none')
#               (conv_sum): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             )
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#       )
#     )
#     (1): EBlock(
#       (layers): Sequential(
#         (0): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (1): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (2): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (3): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): DeepPoolLayer(
#               (pools): ModuleList(
#                 (0): AvgPool2d(kernel_size=8, stride=8, padding=0)
#                 (1): AvgPool2d(kernel_size=4, stride=4, padding=0)
#                 (2): AvgPool2d(kernel_size=2, stride=2, padding=0)
#               )
#               (convs): ModuleList(
#                 (0-2): 3 x Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#               (dynas): ModuleList(
#                 (0-2): 3 x dynamic_filter(
#                   (conv): Conv2d(64, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (bn): BatchNorm2d(72, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (act): Tanh()
#                   (pad): ReflectionPad2d((1, 1, 1, 1))
#                   (ap): AdaptiveAvgPool2d(output_size=(1, 1))
#                   (gap): AdaptiveAvgPool2d(output_size=1)
#                 )
#               )
#               (relu): GELU(approximate='none')
#               (conv_sum): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             )
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#       )
#     )
#     (2): EBlock(
#       (layers): Sequential(
#         (0): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (1): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (2): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (3): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): DeepPoolLayer(
#               (pools): ModuleList(
#                 (0): AvgPool2d(kernel_size=8, stride=8, padding=0)
#                 (1): AvgPool2d(kernel_size=4, stride=4, padding=0)
#                 (2): AvgPool2d(kernel_size=2, stride=2, padding=0)
#               )
#               (convs): ModuleList(
#                 (0-2): 3 x Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#               (dynas): ModuleList(
#                 (0-2): 3 x dynamic_filter(
#                   (conv): Conv2d(128, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (bn): BatchNorm2d(72, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (act): Tanh()
#                   (pad): ReflectionPad2d((1, 1, 1, 1))
#                   (ap): AdaptiveAvgPool2d(output_size=(1, 1))
#                   (gap): AdaptiveAvgPool2d(output_size=1)
#                 )
#               )
#               (relu): GELU(approximate='none')
#               (conv_sum): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             )
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#       )
#     )
#   )
#   (feat_extract): ModuleList(
#     (0): BasicConv(
#       (main): Sequential(
#         (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): GELU(approximate='none')
#       )
#     )
#     (1): BasicConv(
#       (main): Sequential(
#         (0): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         (1): GELU(approximate='none')
#       )
#     )
#     (2): BasicConv(
#       (main): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         (1): GELU(approximate='none')
#       )
#     )
#     (3): BasicConv(
#       (main): Sequential(
#         (0): ConvTranspose2d(128, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#         (1): GELU(approximate='none')
#       )
#     )
#     (4): BasicConv(
#       (main): Sequential(
#         (0): ConvTranspose2d(64, 32, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#         (1): GELU(approximate='none')
#       )
#     )
#     (5): BasicConv(
#       (main): Sequential(
#         (0): Conv2d(32, 3, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#     )
#   )
#   (Decoder): ModuleList(
#     (0): DBlock(
#       (layers): Sequential(
#         (0): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (1): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (2): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (3): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): DeepPoolLayer(
#               (pools): ModuleList(
#                 (0): AvgPool2d(kernel_size=8, stride=8, padding=0)
#                 (1): AvgPool2d(kernel_size=4, stride=4, padding=0)
#                 (2): AvgPool2d(kernel_size=2, stride=2, padding=0)
#               )
#               (convs): ModuleList(
#                 (0-2): 3 x Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#               (dynas): ModuleList(
#                 (0-2): 3 x dynamic_filter(
#                   (conv): Conv2d(128, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (bn): BatchNorm2d(72, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (act): Tanh()
#                   (pad): ReflectionPad2d((1, 1, 1, 1))
#                   (ap): AdaptiveAvgPool2d(output_size=(1, 1))
#                   (gap): AdaptiveAvgPool2d(output_size=1)
#                 )
#               )
#               (relu): GELU(approximate='none')
#               (conv_sum): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             )
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#       )
#     )
#     (1): DBlock(
#       (layers): Sequential(
#         (0): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (1): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (2): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (3): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): DeepPoolLayer(
#               (pools): ModuleList(
#                 (0): AvgPool2d(kernel_size=8, stride=8, padding=0)
#                 (1): AvgPool2d(kernel_size=4, stride=4, padding=0)
#                 (2): AvgPool2d(kernel_size=2, stride=2, padding=0)
#               )
#               (convs): ModuleList(
#                 (0-2): 3 x Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#               (dynas): ModuleList(
#                 (0-2): 3 x dynamic_filter(
#                   (conv): Conv2d(64, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (bn): BatchNorm2d(72, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (act): Tanh()
#                   (pad): ReflectionPad2d((1, 1, 1, 1))
#                   (ap): AdaptiveAvgPool2d(output_size=(1, 1))
#                   (gap): AdaptiveAvgPool2d(output_size=1)
#                 )
#               )
#               (relu): GELU(approximate='none')
#               (conv_sum): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             )
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#       )
#     )
#     (2): DBlock(
#       (layers): Sequential(
#         (0): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (1): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (2): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (3): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): DeepPoolLayer(
#               (pools): ModuleList(
#                 (0): AvgPool2d(kernel_size=8, stride=8, padding=0)
#                 (1): AvgPool2d(kernel_size=4, stride=4, padding=0)
#                 (2): AvgPool2d(kernel_size=2, stride=2, padding=0)
#               )
#               (convs): ModuleList(
#                 (0-2): 3 x Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#               (dynas): ModuleList(
#                 (0-2): 3 x dynamic_filter(
#                   (conv): Conv2d(32, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (bn): BatchNorm2d(72, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (act): Tanh()
#                   (pad): ReflectionPad2d((1, 1, 1, 1))
#                   (ap): AdaptiveAvgPool2d(output_size=(1, 1))
#                   (gap): AdaptiveAvgPool2d(output_size=1)
#                 )
#               )
#               (relu): GELU(approximate='none')
#               (conv_sum): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             )
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#       )
#     )
#   )
#   (Convs): ModuleList(
#     (0): BasicConv(
#       (main): Sequential(
#         (0): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1))
#         (1): GELU(approximate='none')
#       )
#     )
#     (1): BasicConv(
#       (main): Sequential(
#         (0): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#         (1): GELU(approximate='none')
#       )
#     )
#   )
#   (ConvsOut): ModuleList(
#     (0): BasicConv(
#       (main): Sequential(
#         (0): Conv2d(128, 3, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#     )
#     (1): BasicConv(
#       (main): Sequential(
#         (0): Conv2d(64, 3, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#     )
#   )
#   (FAM1): FAM(
#     (merge): BasicConv(
#       (main): Sequential(
#         (0): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#     )
#   )
#   (SCM1): SCM(
#     (main): Sequential(
#       (0): BasicConv(
#         (main): Sequential(
#           (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): GELU(approximate='none')
#         )
#       )
#       (1): BasicConv(
#         (main): Sequential(
#           (0): Conv2d(32, 64, kernel_size=(1, 1), stride=(1, 1))
#           (1): GELU(approximate='none')
#         )
#       )
#       (2): BasicConv(
#         (main): Sequential(
#           (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): GELU(approximate='none')
#         )
#       )
#       (3): BasicConv(
#         (main): Sequential(
#           (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1))
#         )
#       )
#       (4): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#     )
#   )
#   (FAM2): FAM(
#     (merge): BasicConv(
#       (main): Sequential(
#         (0): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#     )
#   )
#   (SCM2): SCM(
#     (main): Sequential(
#       (0): BasicConv(
#         (main): Sequential(
#           (0): Conv2d(3, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): GELU(approximate='none')
#         )
#       )
#       (1): BasicConv(
#         (main): Sequential(
#           (0): Conv2d(16, 32, kernel_size=(1, 1), stride=(1, 1))
#           (1): GELU(approximate='none')
#         )
#       )
#       (2): BasicConv(
#         (main): Sequential(
#           (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): GELU(approximate='none')
#         )
#       )
#       (3): BasicConv(
#         (main): Sequential(
#           (0): Conv2d(32, 64, kernel_size=(1, 1), stride=(1, 1))
#         )
#       )
#       (4): InstanceNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#     )
#   )
# )
# /usr/local/lib/python3.10/dist-packages/torch/optim/lr_scheduler.py:136: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   warnings.warn("Detected call of `lr_scheduler.step()` before `optimizer.step()`. "
# Time:  0.3317 Epoch: 001 Iter:  100/3498 LR: 0.0000333333 Loss content:  0.7163 Loss fft:  9.9803
# Time:  0.1875 Epoch: 001 Iter:  200/3498 LR: 0.0000333333 Loss content:  0.7469 Loss fft:  9.9234
# Time:  0.1874 Epoch: 001 Iter:  300/3498 LR: 0.0000333333 Loss content:  0.7350 Loss fft:  9.7927
# Time:  0.1876 Epoch: 001 Iter:  400/3498 LR: 0.0000333333 Loss content:  0.7759 Loss fft:  9.7313
# Time:  0.1875 Epoch: 001 Iter:  500/3498 LR: 0.0000333333 Loss content:  0.7501 Loss fft:  9.7819
# Time:  0.1875 Epoch: 001 Iter:  600/3498 LR: 0.0000333333 Loss content:  0.7550 Loss fft:  9.8738
# Time:  0.1877 Epoch: 001 Iter:  700/3498 LR: 0.0000333333 Loss content:  0.7346 Loss fft: 10.0917
# Time:  0.1877 Epoch: 001 Iter:  800/3498 LR: 0.0000333333 Loss content:  0.7493 Loss fft: 10.0356
# Time:  0.1876 Epoch: 001 Iter:  900/3498 LR: 0.0000333333 Loss content:  0.7448 Loss fft:  9.8058
# Time:  0.1875 Epoch: 001 Iter: 1000/3498 LR: 0.0000333333 Loss content:  0.7386 Loss fft:  9.9925
# Time:  0.1876 Epoch: 001 Iter: 1100/3498 LR: 0.0000333333 Loss content:  0.7586 Loss fft:  9.8110
# Time:  0.1877 Epoch: 001 Iter: 1200/3498 LR: 0.0000333333 Loss content:  0.7240 Loss fft:  9.8818
# Time:  0.1921 Epoch: 001 Iter: 1300/3498 LR: 0.0000333333 Loss content:  0.7402 Loss fft: 10.1328
# Time:  0.1878 Epoch: 001 Iter: 1400/3498 LR: 0.0000333333 Loss content:  0.7275 Loss fft:  9.5454
# Time:  0.1878 Epoch: 001 Iter: 1500/3498 LR: 0.0000333333 Loss content:  0.7379 Loss fft: 10.1066
# Time:  0.1878 Epoch: 001 Iter: 1600/3498 LR: 0.0000333333 Loss content:  0.7412 Loss fft:  9.6872
# Time:  0.1878 Epoch: 001 Iter: 1700/3498 LR: 0.0000333333 Loss content:  0.7426 Loss fft:  9.9795
# Time:  0.1877 Epoch: 001 Iter: 1800/3498 LR: 0.0000333333 Loss content:  0.7592 Loss fft:  9.9092
# Time:  0.1878 Epoch: 001 Iter: 1900/3498 LR: 0.0000333333 Loss content:  0.7445 Loss fft:  9.8585
# Time:  0.1878 Epoch: 001 Iter: 2000/3498 LR: 0.0000333333 Loss content:  0.7464 Loss fft:  9.9044
# Time:  0.1878 Epoch: 001 Iter: 2100/3498 LR: 0.0000333333 Loss content:  0.7438 Loss fft:  9.8439
# Time:  0.1879 Epoch: 001 Iter: 2200/3498 LR: 0.0000333333 Loss content:  0.7269 Loss fft:  9.5610
# Time:  0.1878 Epoch: 001 Iter: 2300/3498 LR: 0.0000333333 Loss content:  0.7466 Loss fft:  9.7217
# Time:  0.1878 Epoch: 001 Iter: 2400/3498 LR: 0.0000333333 Loss content:  0.7424 Loss fft:  9.9071
# Time:  0.1879 Epoch: 001 Iter: 2500/3498 LR: 0.0000333333 Loss content:  0.7305 Loss fft:  9.7542
# Time:  0.1879 Epoch: 001 Iter: 2600/3498 LR: 0.0000333333 Loss content:  0.7364 Loss fft:  9.9305
# Time:  0.1879 Epoch: 001 Iter: 2700/3498 LR: 0.0000333333 Loss content:  0.7422 Loss fft:  9.8642
# Time:  0.1881 Epoch: 001 Iter: 2800/3498 LR: 0.0000333333 Loss content:  0.7580 Loss fft:  9.5009
# Time:  0.1879 Epoch: 001 Iter: 2900/3498 LR: 0.0000333333 Loss content:  0.7328 Loss fft:  9.8180
# Time:  0.1906 Epoch: 001 Iter: 3000/3498 LR: 0.0000333333 Loss content:  0.7467 Loss fft:  9.7963
# Time:  0.1881 Epoch: 001 Iter: 3100/3498 LR: 0.0000333333 Loss content:  0.7544 Loss fft:  9.9011
# Time:  0.1883 Epoch: 001 Iter: 3200/3498 LR: 0.0000333333 Loss content:  0.7342 Loss fft:  9.9565
# Time:  0.1880 Epoch: 001 Iter: 3300/3498 LR: 0.0000333333 Loss content:  0.7446 Loss fft:  9.8903
# Time:  0.1879 Epoch: 001 Iter: 3400/3498 LR: 0.0000333333 Loss content:  0.7367 Loss fft: 10.0402
# EPOCH: 01
# Elapsed time: 6.73 Epoch Pixel Loss:  0.7422 Epoch FFT Loss:  9.8590
# Time:  0.1962 Epoch: 002 Iter:  100/3498 LR: 0.0000666667 Loss content:  0.7422 Loss fft:  9.9600
# Time:  0.1880 Epoch: 002 Iter:  200/3498 LR: 0.0000666667 Loss content:  0.7405 Loss fft:  9.6641
# Time:  0.1878 Epoch: 002 Iter:  300/3498 LR: 0.0000666667 Loss content:  0.7376 Loss fft: 10.0795
# Time:  0.1880 Epoch: 002 Iter:  400/3498 LR: 0.0000666667 Loss content:  0.7443 Loss fft:  9.7421
# Time:  0.1878 Epoch: 002 Iter:  500/3498 LR: 0.0000666667 Loss content:  0.7547 Loss fft:  9.7575
# Time:  0.1878 Epoch: 002 Iter:  600/3498 LR: 0.0000666667 Loss content:  0.7252 Loss fft:  9.8381
# Time:  0.1878 Epoch: 002 Iter:  700/3498 LR: 0.0000666667 Loss content:  0.7305 Loss fft: 10.0123
# Time:  0.1877 Epoch: 002 Iter:  800/3498 LR: 0.0000666667 Loss content:  0.7122 Loss fft:  9.7545
# Time:  0.1878 Epoch: 002 Iter:  900/3498 LR: 0.0000666667 Loss content:  0.7319 Loss fft: 10.0974
# Time:  0.1879 Epoch: 002 Iter: 1000/3498 LR: 0.0000666667 Loss content:  0.7510 Loss fft: 10.0119
# Time:  0.1880 Epoch: 002 Iter: 1100/3498 LR: 0.0000666667 Loss content:  0.7394 Loss fft:  9.7467
# Time:  0.1878 Epoch: 002 Iter: 1200/3498 LR: 0.0000666667 Loss content:  0.7304 Loss fft:  9.9860
# Time:  0.1876 Epoch: 002 Iter: 1300/3498 LR: 0.0000666667 Loss content:  0.7385 Loss fft:  9.7783
# Time:  0.1877 Epoch: 002 Iter: 1400/3498 LR: 0.0000666667 Loss content:  0.7376 Loss fft:  9.8682
# Time:  0.1877 Epoch: 002 Iter: 1500/3498 LR: 0.0000666667 Loss content:  0.7534 Loss fft:  9.7967
# Time:  0.1879 Epoch: 002 Iter: 1600/3498 LR: 0.0000666667 Loss content:  0.7159 Loss fft:  9.9660
# Time:  0.1877 Epoch: 002 Iter: 1700/3498 LR: 0.0000666667 Loss content:  0.7350 Loss fft:  9.9633
# Time:  0.1877 Epoch: 002 Iter: 1800/3498 LR: 0.0000666667 Loss content:  0.7727 Loss fft:  9.8602
# Time:  0.1878 Epoch: 002 Iter: 1900/3498 LR: 0.0000666667 Loss content:  0.7255 Loss fft:  9.8202
# Time:  0.1877 Epoch: 002 Iter: 2000/3498 LR: 0.0000666667 Loss content:  0.7571 Loss fft:  9.9071
# Time:  0.1881 Epoch: 002 Iter: 2100/3498 LR: 0.0000666667 Loss content:  0.7457 Loss fft:  9.9079
# Time:  0.1923 Epoch: 002 Iter: 2200/3498 LR: 0.0000666667 Loss content:  0.7572 Loss fft:  9.8986
# Time:  0.1878 Epoch: 002 Iter: 2300/3498 LR: 0.0000666667 Loss content:  0.7378 Loss fft:  9.9150
# Time:  0.1880 Epoch: 002 Iter: 2400/3498 LR: 0.0000666667 Loss content:  0.7408 Loss fft:  9.9269
# Time:  0.1879 Epoch: 002 Iter: 2500/3498 LR: 0.0000666667 Loss content:  0.7629 Loss fft:  9.7669
# Time:  0.1879 Epoch: 002 Iter: 2600/3498 LR: 0.0000666667 Loss content:  0.7112 Loss fft: 10.0272
# Time:  0.1877 Epoch: 002 Iter: 2700/3498 LR: 0.0000666667 Loss content:  0.7653 Loss fft:  9.7314
# Time:  0.1877 Epoch: 002 Iter: 2800/3498 LR: 0.0000666667 Loss content:  0.7493 Loss fft:  9.6357
# Time:  0.1878 Epoch: 002 Iter: 2900/3498 LR: 0.0000666667 Loss content:  0.7437 Loss fft:  9.9074
# Time:  0.1882 Epoch: 002 Iter: 3000/3498 LR: 0.0000666667 Loss content:  0.7099 Loss fft:  9.8016
# Time:  0.1879 Epoch: 002 Iter: 3100/3498 LR: 0.0000666667 Loss content:  0.7410 Loss fft:  9.7070
# Time:  0.1879 Epoch: 002 Iter: 3200/3498 LR: 0.0000666667 Loss content:  0.7294 Loss fft:  9.9767
# Time:  0.1878 Epoch: 002 Iter: 3300/3498 LR: 0.0000666667 Loss content:  0.7451 Loss fft:  9.9827
# Time:  0.1879 Epoch: 002 Iter: 3400/3498 LR: 0.0000666667 Loss content:  0.7215 Loss fft:  9.6700
# EPOCH: 02
# Elapsed time: 6.59 Epoch Pixel Loss:  0.7397 Epoch FFT Loss:  9.8633
# Time:  0.1974 Epoch: 003 Iter:  100/3498 LR: 0.0001000000 Loss content:  0.7475 Loss fft:  9.7138
# Time:  0.1883 Epoch: 003 Iter:  200/3498 LR: 0.0001000000 Loss content:  0.7420 Loss fft:  9.8515
# Time:  0.1878 Epoch: 003 Iter:  300/3498 LR: 0.0001000000 Loss content:  0.7413 Loss fft:  9.9318
# Time:  0.1879 Epoch: 003 Iter:  400/3498 LR: 0.0001000000 Loss content:  0.7288 Loss fft:  9.9051
# Time:  0.1880 Epoch: 003 Iter:  500/3498 LR: 0.0001000000 Loss content:  0.7349 Loss fft:  9.7457
# Time:  0.1878 Epoch: 003 Iter:  600/3498 LR: 0.0001000000 Loss content:  0.7445 Loss fft:  9.8624
# Time:  0.1881 Epoch: 003 Iter:  700/3498 LR: 0.0001000000 Loss content:  0.7371 Loss fft:  9.5696
# Time:  0.1923 Epoch: 003 Iter:  800/3498 LR: 0.0001000000 Loss content:  0.7627 Loss fft:  9.7667
# Time:  0.1880 Epoch: 003 Iter:  900/3498 LR: 0.0001000000 Loss content:  0.7484 Loss fft:  9.9155
# Time:  0.1879 Epoch: 003 Iter: 1000/3498 LR: 0.0001000000 Loss content:  0.7384 Loss fft:  9.7446
# Time:  0.1880 Epoch: 003 Iter: 1100/3498 LR: 0.0001000000 Loss content:  0.7317 Loss fft:  9.6098
# Time:  0.1878 Epoch: 003 Iter: 1200/3498 LR: 0.0001000000 Loss content:  0.7550 Loss fft:  9.8188
# Time:  0.1878 Epoch: 003 Iter: 1300/3498 LR: 0.0001000000 Loss content:  0.7227 Loss fft:  9.7202
# Time:  0.1880 Epoch: 003 Iter: 1400/3498 LR: 0.0001000000 Loss content:  0.7295 Loss fft:  9.7826
# Time:  0.1883 Epoch: 003 Iter: 1500/3498 LR: 0.0001000000 Loss content:  0.7437 Loss fft:  9.7910
# Time:  0.1882 Epoch: 003 Iter: 1600/3498 LR: 0.0001000000 Loss content:  0.7362 Loss fft:  9.9776
# Time:  0.1879 Epoch: 003 Iter: 1700/3498 LR: 0.0001000000 Loss content:  0.7248 Loss fft:  9.8613
# Time:  0.1880 Epoch: 003 Iter: 1800/3498 LR: 0.0001000000 Loss content:  0.7121 Loss fft:  9.6732
# Time:  0.1880 Epoch: 003 Iter: 1900/3498 LR: 0.0001000000 Loss content:  0.7356 Loss fft:  9.9738
# Time:  0.1880 Epoch: 003 Iter: 2000/3498 LR: 0.0001000000 Loss content:  0.7041 Loss fft:  9.5837
# Time:  0.1879 Epoch: 003 Iter: 2100/3498 LR: 0.0001000000 Loss content:  0.7489 Loss fft:  9.6793
# Time:  0.1879 Epoch: 003 Iter: 2200/3498 LR: 0.0001000000 Loss content:  0.7547 Loss fft:  9.7346
# Time:  0.1879 Epoch: 003 Iter: 2300/3498 LR: 0.0001000000 Loss content:  0.7356 Loss fft:  9.8948
# Time:  0.1879 Epoch: 003 Iter: 2400/3498 LR: 0.0001000000 Loss content:  0.7538 Loss fft:  9.8416
# Time:  0.1880 Epoch: 003 Iter: 2500/3498 LR: 0.0001000000 Loss content:  0.7005 Loss fft:  9.7205
# Time:  0.1881 Epoch: 003 Iter: 2600/3498 LR: 0.0001000000 Loss content:  0.7400 Loss fft:  9.8963
# Time:  0.1879 Epoch: 003 Iter: 2700/3498 LR: 0.0001000000 Loss content:  0.7119 Loss fft:  9.8663
# Time:  0.1880 Epoch: 003 Iter: 2800/3498 LR: 0.0001000000 Loss content:  0.7704 Loss fft: 10.1037
# Time:  0.1881 Epoch: 003 Iter: 2900/3498 LR: 0.0001000000 Loss content:  0.7321 Loss fft:  9.8182
# Time:  0.1914 Epoch: 003 Iter: 3000/3498 LR: 0.0001000000 Loss content:  0.7432 Loss fft:  9.9418
# Time:  0.1880 Epoch: 003 Iter: 3100/3498 LR: 0.0001000000 Loss content:  0.7310 Loss fft:  9.6617
# Time:  0.1880 Epoch: 003 Iter: 3200/3498 LR: 0.0001000000 Loss content:  0.7363 Loss fft:  9.9312
# Time:  0.1882 Epoch: 003 Iter: 3300/3498 LR: 0.0001000000 Loss content:  0.7480 Loss fft:  9.8146
# Time:  0.1881 Epoch: 003 Iter: 3400/3498 LR: 0.0001000000 Loss content:  0.7716 Loss fft:  9.5581
# EPOCH: 03
# Elapsed time: 6.60 Epoch Pixel Loss:  0.7380 Epoch FFT Loss:  9.8077
# /usr/local/lib/python3.10/dist-packages/torch/optim/lr_scheduler.py:809: UserWarning: To get the last learning rate computed by the scheduler, please use `get_last_lr()`.
#   warnings.warn("To get the last learning rate computed by the scheduler, "
# Time:  0.1965 Epoch: 004 Iter:  100/3498 LR: 0.0001000000 Loss content:  0.7277 Loss fft:  9.8507
# Time:  0.1879 Epoch: 004 Iter:  200/3498 LR: 0.0001000000 Loss content:  0.7267 Loss fft:  9.9278
# Time:  0.1879 Epoch: 004 Iter:  300/3498 LR: 0.0001000000 Loss content:  0.7330 Loss fft:  9.9849
# Time:  0.1879 Epoch: 004 Iter:  400/3498 LR: 0.0001000000 Loss content:  0.7057 Loss fft:  9.5633
# Time:  0.1880 Epoch: 004 Iter:  500/3498 LR: 0.0001000000 Loss content:  0.7185 Loss fft:  9.7568
# Time:  0.1879 Epoch: 004 Iter:  600/3498 LR: 0.0001000000 Loss content:  0.7477 Loss fft:  9.8246
# Time:  0.1881 Epoch: 004 Iter:  700/3498 LR: 0.0001000000 Loss content:  0.7242 Loss fft:  9.6446
# Time:  0.1884 Epoch: 004 Iter:  800/3498 LR: 0.0001000000 Loss content:  0.7203 Loss fft:  9.6107
# Time:  0.1879 Epoch: 004 Iter:  900/3498 LR: 0.0001000000 Loss content:  0.7512 Loss fft: 10.0972
# Time:  0.1880 Epoch: 004 Iter: 1000/3498 LR: 0.0001000000 Loss content:  0.7639 Loss fft:  9.7816
# Time:  0.1879 Epoch: 004 Iter: 1100/3498 LR: 0.0001000000 Loss content:  0.7212 Loss fft:  9.8892
# Time:  0.1879 Epoch: 004 Iter: 1200/3498 LR: 0.0001000000 Loss content:  0.7198 Loss fft:  9.7150
# Time:  0.1879 Epoch: 004 Iter: 1300/3498 LR: 0.0001000000 Loss content:  0.7443 Loss fft:  9.8105
# Time:  0.1879 Epoch: 004 Iter: 1400/3498 LR: 0.0001000000 Loss content:  0.7414 Loss fft:  9.8918
# Time:  0.1879 Epoch: 004 Iter: 1500/3498 LR: 0.0001000000 Loss content:  0.7189 Loss fft:  9.8495
# Time:  0.1879 Epoch: 004 Iter: 1600/3498 LR: 0.0001000000 Loss content:  0.7382 Loss fft:  9.8284
# Time:  0.1930 Epoch: 004 Iter: 1700/3498 LR: 0.0001000000 Loss content:  0.7351 Loss fft:  9.8725
# Time:  0.1881 Epoch: 004 Iter: 1800/3498 LR: 0.0001000000 Loss content:  0.7289 Loss fft:  9.9508
# Time:  0.1879 Epoch: 004 Iter: 1900/3498 LR: 0.0001000000 Loss content:  0.7291 Loss fft:  9.7064
# Time:  0.1879 Epoch: 004 Iter: 2000/3498 LR: 0.0001000000 Loss content:  0.7395 Loss fft:  9.9092
# Time:  0.1879 Epoch: 004 Iter: 2100/3498 LR: 0.0001000000 Loss content:  0.7276 Loss fft:  9.9189
# Time:  0.1879 Epoch: 004 Iter: 2200/3498 LR: 0.0001000000 Loss content:  0.7156 Loss fft:  9.7531
# Time:  0.1880 Epoch: 004 Iter: 2300/3498 LR: 0.0001000000 Loss content:  0.7378 Loss fft:  9.6946
# Time:  0.1880 Epoch: 004 Iter: 2400/3498 LR: 0.0001000000 Loss content:  0.7434 Loss fft:  9.7253
# Time:  0.1879 Epoch: 004 Iter: 2500/3498 LR: 0.0001000000 Loss content:  0.7414 Loss fft:  9.8093
# Time:  0.1882 Epoch: 004 Iter: 2600/3498 LR: 0.0001000000 Loss content:  0.7284 Loss fft:  9.5162
# Time:  0.1880 Epoch: 004 Iter: 2700/3498 LR: 0.0001000000 Loss content:  0.7484 Loss fft:  9.6791
# Time:  0.1879 Epoch: 004 Iter: 2800/3498 LR: 0.0001000000 Loss content:  0.7321 Loss fft:  9.9766
# Time:  0.1880 Epoch: 004 Iter: 2900/3498 LR: 0.0001000000 Loss content:  0.7454 Loss fft:  9.8671
# Time:  0.1879 Epoch: 004 Iter: 3000/3498 LR: 0.0001000000 Loss content:  0.7377 Loss fft:  9.6190
# Time:  0.1878 Epoch: 004 Iter: 3100/3498 LR: 0.0001000000 Loss content:  0.7204 Loss fft:  9.7653
# Time:  0.1880 Epoch: 004 Iter: 3200/3498 LR: 0.0001000000 Loss content:  0.7167 Loss fft:  9.7871
# Time:  0.1880 Epoch: 004 Iter: 3300/3498 LR: 0.0001000000 Loss content:  0.7652 Loss fft: 10.0146
# Time:  0.1881 Epoch: 004 Iter: 3400/3498 LR: 0.0001000000 Loss content:  0.7389 Loss fft:  9.8535
# EPOCH: 04
# Elapsed time: 6.59 Epoch Pixel Loss:  0.7326 Epoch FFT Loss:  9.8091
# Time:  0.1974 Epoch: 005 Iter:  100/3498 LR: 0.0000983215 Loss content:  0.7150 Loss fft:  9.7968
# Time:  0.1880 Epoch: 005 Iter:  200/3498 LR: 0.0000983215 Loss content:  0.7229 Loss fft:  9.9626
# Time:  0.1879 Epoch: 005 Iter:  300/3498 LR: 0.0000983215 Loss content:  0.7235 Loss fft:  9.9461
# Time:  0.1926 Epoch: 005 Iter:  400/3498 LR: 0.0000983215 Loss content:  0.7553 Loss fft:  9.4500
# Time:  0.1880 Epoch: 005 Iter:  500/3498 LR: 0.0000983215 Loss content:  0.7392 Loss fft:  9.9075
# Time:  0.1879 Epoch: 005 Iter:  600/3498 LR: 0.0000983215 Loss content:  0.7314 Loss fft:  9.8077
# Time:  0.1881 Epoch: 005 Iter:  700/3498 LR: 0.0000983215 Loss content:  0.7247 Loss fft:  9.8930
# Time:  0.1879 Epoch: 005 Iter:  800/3498 LR: 0.0000983215 Loss content:  0.7378 Loss fft:  9.9052
# Time:  0.1881 Epoch: 005 Iter:  900/3498 LR: 0.0000983215 Loss content:  0.7160 Loss fft:  9.6358
# Time:  0.1879 Epoch: 005 Iter: 1000/3498 LR: 0.0000983215 Loss content:  0.7321 Loss fft:  9.7652
# Time:  0.1879 Epoch: 005 Iter: 1100/3498 LR: 0.0000983215 Loss content:  0.7270 Loss fft:  9.9479
# Time:  0.1880 Epoch: 005 Iter: 1200/3498 LR: 0.0000983215 Loss content:  0.7260 Loss fft:  9.8180
# Time:  0.1880 Epoch: 005 Iter: 1300/3498 LR: 0.0000983215 Loss content:  0.7332 Loss fft:  9.6705
# Time:  0.1879 Epoch: 005 Iter: 1400/3498 LR: 0.0000983215 Loss content:  0.7523 Loss fft:  9.7075
# Time:  0.1878 Epoch: 005 Iter: 1500/3498 LR: 0.0000983215 Loss content:  0.7445 Loss fft:  9.9593
# Time:  0.1879 Epoch: 005 Iter: 1600/3498 LR: 0.0000983215 Loss content:  0.7396 Loss fft:  9.8556
# Time:  0.1879 Epoch: 005 Iter: 1700/3498 LR: 0.0000983215 Loss content:  0.7631 Loss fft:  9.7567
# Time:  0.1880 Epoch: 005 Iter: 1800/3498 LR: 0.0000983215 Loss content:  0.7346 Loss fft:  9.6875
# Time:  0.1879 Epoch: 005 Iter: 1900/3498 LR: 0.0000983215 Loss content:  0.7277 Loss fft:  9.8016
# Time:  0.1878 Epoch: 005 Iter: 2000/3498 LR: 0.0000983215 Loss content:  0.7232 Loss fft:  9.6049
# Time:  0.1880 Epoch: 005 Iter: 2100/3498 LR: 0.0000983215 Loss content:  0.7137 Loss fft:  9.6344
# Time:  0.1880 Epoch: 005 Iter: 2200/3498 LR: 0.0000983215 Loss content:  0.7328 Loss fft:  9.7211
# Time:  0.1879 Epoch: 005 Iter: 2300/3498 LR: 0.0000983215 Loss content:  0.7202 Loss fft:  9.5797
# Time:  0.1879 Epoch: 005 Iter: 2400/3498 LR: 0.0000983215 Loss content:  0.7306 Loss fft:  9.4227
# Time:  0.1879 Epoch: 005 Iter: 2500/3498 LR: 0.0000983215 Loss content:  0.7270 Loss fft:  9.6442
# Time:  0.1911 Epoch: 005 Iter: 2600/3498 LR: 0.0000983215 Loss content:  0.7407 Loss fft:  9.7712
# Time:  0.1882 Epoch: 005 Iter: 2700/3498 LR: 0.0000983215 Loss content:  0.7127 Loss fft:  9.8080
# Time:  0.1880 Epoch: 005 Iter: 2800/3498 LR: 0.0000983215 Loss content:  0.7076 Loss fft:  9.8112
# Time:  0.1878 Epoch: 005 Iter: 2900/3498 LR: 0.0000983215 Loss content:  0.7065 Loss fft:  9.6212
# Time:  0.1878 Epoch: 005 Iter: 3000/3498 LR: 0.0000983215 Loss content:  0.7114 Loss fft:  9.5465
# Time:  0.1878 Epoch: 005 Iter: 3100/3498 LR: 0.0000983215 Loss content:  0.7474 Loss fft:  9.8332
# Time:  0.1881 Epoch: 005 Iter: 3200/3498 LR: 0.0000983215 Loss content:  0.7153 Loss fft:  9.8361
# Time:  0.1880 Epoch: 005 Iter: 3300/3498 LR: 0.0000983215 Loss content:  0.7152 Loss fft:  9.9332
# Time:  0.1878 Epoch: 005 Iter: 3400/3498 LR: 0.0000983215 Loss content:  0.7387 Loss fft:  9.8363
# EPOCH: 05
# Elapsed time: 6.60 Epoch Pixel Loss:  0.7286 Epoch FFT Loss:  9.7515
# Time:  0.1967 Epoch: 006 Iter:  100/3498 LR: 0.0000942212 Loss content:  0.7139 Loss fft:  9.6808
# Time:  0.1881 Epoch: 006 Iter:  200/3498 LR: 0.0000942212 Loss content:  0.7271 Loss fft:  9.9534
# Time:  0.1879 Epoch: 006 Iter:  300/3498 LR: 0.0000942212 Loss content:  0.7320 Loss fft:  9.5995
# Time:  0.1879 Epoch: 006 Iter:  400/3498 LR: 0.0000942212 Loss content:  0.7195 Loss fft:  9.6109
# Time:  0.1878 Epoch: 006 Iter:  500/3498 LR: 0.0000942212 Loss content:  0.7098 Loss fft:  9.6806
# Time:  0.1879 Epoch: 006 Iter:  600/3498 LR: 0.0000942212 Loss content:  0.7179 Loss fft:  9.7219
# Time:  0.1879 Epoch: 006 Iter:  700/3498 LR: 0.0000942212 Loss content:  0.7299 Loss fft:  9.6856
# Time:  0.1880 Epoch: 006 Iter:  800/3498 LR: 0.0000942212 Loss content:  0.7607 Loss fft:  9.8369
# Time:  0.1879 Epoch: 006 Iter:  900/3498 LR: 0.0000942212 Loss content:  0.7141 Loss fft:  9.3548
# Time:  0.1879 Epoch: 006 Iter: 1000/3498 LR: 0.0000942212 Loss content:  0.7376 Loss fft:  9.4424
# Time:  0.1881 Epoch: 006 Iter: 1100/3498 LR: 0.0000942212 Loss content:  0.7319 Loss fft:  9.7717
# Time:  0.1925 Epoch: 006 Iter: 1200/3498 LR: 0.0000942212 Loss content:  0.6812 Loss fft: 10.0130
# Time:  0.1880 Epoch: 006 Iter: 1300/3498 LR: 0.0000942212 Loss content:  0.7156 Loss fft:  9.7155
# Time:  0.1879 Epoch: 006 Iter: 1400/3498 LR: 0.0000942212 Loss content:  0.7117 Loss fft:  9.6936
# Time:  0.1879 Epoch: 006 Iter: 1500/3498 LR: 0.0000942212 Loss content:  0.7172 Loss fft:  9.7539
# Time:  0.1880 Epoch: 006 Iter: 1600/3498 LR: 0.0000942212 Loss content:  0.7446 Loss fft:  9.9636
# Time:  0.1879 Epoch: 006 Iter: 1700/3498 LR: 0.0000942212 Loss content:  0.7182 Loss fft:  9.6717
# Time:  0.1879 Epoch: 006 Iter: 1800/3498 LR: 0.0000942212 Loss content:  0.7592 Loss fft:  9.6837
# Time:  0.1881 Epoch: 006 Iter: 1900/3498 LR: 0.0000942212 Loss content:  0.7313 Loss fft:  9.6546
# Time:  0.1880 Epoch: 006 Iter: 2000/3498 LR: 0.0000942212 Loss content:  0.7427 Loss fft: 10.0170
# Time:  0.1879 Epoch: 006 Iter: 2100/3498 LR: 0.0000942212 Loss content:  0.7120 Loss fft:  9.6175
# Time:  0.1878 Epoch: 006 Iter: 2200/3498 LR: 0.0000942212 Loss content:  0.7278 Loss fft:  9.9853
# Time:  0.1879 Epoch: 006 Iter: 2300/3498 LR: 0.0000942212 Loss content:  0.7203 Loss fft:  9.7216
# Time:  0.1878 Epoch: 006 Iter: 2400/3498 LR: 0.0000942212 Loss content:  0.7192 Loss fft:  9.7729
# Time:  0.1904 Epoch: 006 Iter: 2500/3498 LR: 0.0000942212 Loss content:  0.7438 Loss fft:  9.5377
# Time:  0.1880 Epoch: 006 Iter: 2600/3498 LR: 0.0000942212 Loss content:  0.7465 Loss fft:  9.6333
# Time:  0.1884 Epoch: 006 Iter: 2700/3498 LR: 0.0000942212 Loss content:  0.7365 Loss fft:  9.7489
# Time:  0.1879 Epoch: 006 Iter: 2800/3498 LR: 0.0000942212 Loss content:  0.7013 Loss fft:  9.9694
# Time:  0.1876 Epoch: 006 Iter: 2900/3498 LR: 0.0000942212 Loss content:  0.7225 Loss fft:  9.5462
# Time:  0.1878 Epoch: 006 Iter: 3000/3498 LR: 0.0000942212 Loss content:  0.7309 Loss fft:  9.8127
# Time:  0.1881 Epoch: 006 Iter: 3100/3498 LR: 0.0000942212 Loss content:  0.7182 Loss fft:  9.5367
# Time:  0.1878 Epoch: 006 Iter: 3200/3498 LR: 0.0000942212 Loss content:  0.7276 Loss fft:  9.9602
# Time:  0.1877 Epoch: 006 Iter: 3300/3498 LR: 0.0000942212 Loss content:  0.7254 Loss fft:  9.3821
# Time:  0.1911 Epoch: 006 Iter: 3400/3498 LR: 0.0000942212 Loss content:  0.7196 Loss fft:  9.8447
# EPOCH: 06
# Elapsed time: 6.60 Epoch Pixel Loss:  0.7256 Epoch FFT Loss:  9.7301
# Time:  0.1965 Epoch: 007 Iter:  100/3498 LR: 0.0000886874 Loss content:  0.7211 Loss fft:  9.7319
# Time:  0.1878 Epoch: 007 Iter:  200/3498 LR: 0.0000886874 Loss content:  0.7194 Loss fft:  9.8223
# Time:  0.1878 Epoch: 007 Iter:  300/3498 LR: 0.0000886874 Loss content:  0.7124 Loss fft:  9.7777
# Time:  0.1877 Epoch: 007 Iter:  400/3498 LR: 0.0000886874 Loss content:  0.7449 Loss fft:  9.7781
# Time:  0.1879 Epoch: 007 Iter:  500/3498 LR: 0.0000886874 Loss content:  0.7295 Loss fft:  9.5940
# Time:  0.1878 Epoch: 007 Iter:  600/3498 LR: 0.0000886874 Loss content:  0.7311 Loss fft:  9.8045
# Time:  0.1879 Epoch: 007 Iter:  700/3498 LR: 0.0000886874 Loss content:  0.7151 Loss fft:  9.6171
# Time:  0.1877 Epoch: 007 Iter:  800/3498 LR: 0.0000886874 Loss content:  0.7190 Loss fft:  9.4833
# Time:  0.1877 Epoch: 007 Iter:  900/3498 LR: 0.0000886874 Loss content:  0.7176 Loss fft:  9.4868
# Time:  0.1877 Epoch: 007 Iter: 1000/3498 LR: 0.0000886874 Loss content:  0.7443 Loss fft:  9.6378
# Time:  0.1879 Epoch: 007 Iter: 1100/3498 LR: 0.0000886874 Loss content:  0.7293 Loss fft:  9.7673
# Time:  0.1879 Epoch: 007 Iter: 1200/3498 LR: 0.0000886874 Loss content:  0.7155 Loss fft:  9.6355
# Time:  0.1878 Epoch: 007 Iter: 1300/3498 LR: 0.0000886874 Loss content:  0.7364 Loss fft:  9.8985
# Time:  0.1879 Epoch: 007 Iter: 1400/3498 LR: 0.0000886874 Loss content:  0.7198 Loss fft:  9.6686
# Time:  0.1879 Epoch: 007 Iter: 1500/3498 LR: 0.0000886874 Loss content:  0.6990 Loss fft:  9.6594
# Time:  0.1880 Epoch: 007 Iter: 1600/3498 LR: 0.0000886874 Loss content:  0.7054 Loss fft:  9.8403
# Time:  0.1879 Epoch: 007 Iter: 1700/3498 LR: 0.0000886874 Loss content:  0.7273 Loss fft:  9.7527
# Time:  0.1879 Epoch: 007 Iter: 1800/3498 LR: 0.0000886874 Loss content:  0.7178 Loss fft: 10.2380
# Time:  0.1880 Epoch: 007 Iter: 1900/3498 LR: 0.0000886874 Loss content:  0.7287 Loss fft:  9.5929
# Time:  0.1880 Epoch: 007 Iter: 2000/3498 LR: 0.0000886874 Loss content:  0.7332 Loss fft:  9.8339
# Time:  0.1926 Epoch: 007 Iter: 2100/3498 LR: 0.0000886874 Loss content:  0.7078 Loss fft:  9.8269
# Time:  0.1878 Epoch: 007 Iter: 2200/3498 LR: 0.0000886874 Loss content:  0.7301 Loss fft:  9.8037
# Time:  0.1877 Epoch: 007 Iter: 2300/3498 LR: 0.0000886874 Loss content:  0.7514 Loss fft:  9.5736
# Time:  0.1877 Epoch: 007 Iter: 2400/3498 LR: 0.0000886874 Loss content:  0.7129 Loss fft:  9.7639
# Time:  0.1877 Epoch: 007 Iter: 2500/3498 LR: 0.0000886874 Loss content:  0.7131 Loss fft:  9.4759
# Time:  0.1879 Epoch: 007 Iter: 2600/3498 LR: 0.0000886874 Loss content:  0.7298 Loss fft:  9.4778
# Time:  0.1878 Epoch: 007 Iter: 2700/3498 LR: 0.0000886874 Loss content:  0.7020 Loss fft:  9.6026
# Time:  0.1877 Epoch: 007 Iter: 2800/3498 LR: 0.0000886874 Loss content:  0.7146 Loss fft:  9.6774
# Time:  0.1880 Epoch: 007 Iter: 2900/3498 LR: 0.0000886874 Loss content:  0.7305 Loss fft:  9.6372
# Time:  0.1878 Epoch: 007 Iter: 3000/3498 LR: 0.0000886874 Loss content:  0.7024 Loss fft:  9.7755
# Time:  0.1880 Epoch: 007 Iter: 3100/3498 LR: 0.0000886874 Loss content:  0.7280 Loss fft:  9.8678
# Time:  0.1879 Epoch: 007 Iter: 3200/3498 LR: 0.0000886874 Loss content:  0.7262 Loss fft:  9.5640
# Time:  0.1878 Epoch: 007 Iter: 3300/3498 LR: 0.0000886874 Loss content:  0.7245 Loss fft:  9.4699
# Time:  0.1879 Epoch: 007 Iter: 3400/3498 LR: 0.0000886874 Loss content:  0.7118 Loss fft:  9.5995
# EPOCH: 07
# Elapsed time: 6.59 Epoch Pixel Loss:  0.7216 Epoch FFT Loss:  9.6961
# Time:  0.1967 Epoch: 008 Iter:  100/3498 LR: 0.0000819070 Loss content:  0.7140 Loss fft:  9.7340
# Time:  0.1879 Epoch: 008 Iter:  200/3498 LR: 0.0000819070 Loss content:  0.7147 Loss fft:  9.6877
# Time:  0.1880 Epoch: 008 Iter:  300/3498 LR: 0.0000819070 Loss content:  0.7231 Loss fft: 10.0362
# Time:  0.1884 Epoch: 008 Iter:  400/3498 LR: 0.0000819070 Loss content:  0.7150 Loss fft:  9.5517
# ...
# Time:  0.1880 Epoch: 016 Iter: 1300/3498 LR: 0.0000151017 Loss content:  0.7125 Loss fft:  9.5716
# Time:  0.1881 Epoch: 016 Iter: 1400/3498 LR: 0.0000151017 Loss content:  0.6997 Loss fft:  9.6224
# Time:  0.1880 Epoch: 016 Iter: 1500/3498 LR: 0.0000151017 Loss content:  0.7022 Loss fft:  9.5064
# Time:  0.1880 Epoch: 016 Iter: 1600/3498 LR: 0.0000151017 Loss content:  0.6669 Loss fft:  9.5334
# Time:  0.1879 Epoch: 016 Iter: 1700/3498 LR: 0.0000151017 Loss content:  0.7296 Loss fft:  9.5879
# Time:  0.1879 Epoch: 016 Iter: 1800/3498 LR: 0.0000151017 Loss content:  0.7322 Loss fft:  9.4284
# Time:  0.1881 Epoch: 016 Iter: 1900/3498 LR: 0.0000151017 Loss content:  0.7176 Loss fft:  9.4613
# Time:  0.1880 Epoch: 016 Iter: 2000/3498 LR: 0.0000151017 Loss content:  0.7143 Loss fft:  9.5369
# Time:  0.1882 Epoch: 016 Iter: 2100/3498 LR: 0.0000151017 Loss content:  0.7019 Loss fft:  9.4815
# Time:  0.1881 Epoch: 016 Iter: 2200/3498 LR: 0.0000151017 Loss content:  0.7214 Loss fft:  9.3221
# Time:  0.1882 Epoch: 016 Iter: 2300/3498 LR: 0.0000151017 Loss content:  0.7070 Loss fft:  9.4702
# Time:  0.1880 Epoch: 016 Iter: 2400/3498 LR: 0.0000151017 Loss content:  0.6940 Loss fft:  9.5488
# Time:  0.1881 Epoch: 016 Iter: 2500/3498 LR: 0.0000151017 Loss content:  0.7057 Loss fft:  9.7917
# Time:  0.1880 Epoch: 016 Iter: 2600/3498 LR: 0.0000151017 Loss content:  0.6968 Loss fft:  9.4772
# Time:  0.1880 Epoch: 016 Iter: 2700/3498 LR: 0.0000151017 Loss content:  0.7063 Loss fft:  9.6753
# Time:  0.1879 Epoch: 016 Iter: 2800/3498 LR: 0.0000151017 Loss content:  0.6987 Loss fft:  9.7743
# Time:  0.1880 Epoch: 016 Iter: 2900/3498 LR: 0.0000151017 Loss content:  0.7032 Loss fft:  9.3805
# Time:  0.1882 Epoch: 016 Iter: 3000/3498 LR: 0.0000151017 Loss content:  0.7186 Loss fft:  9.5300
# Time:  0.1880 Epoch: 016 Iter: 3100/3498 LR: 0.0000151017 Loss content:  0.7129 Loss fft:  9.5717
# Time:  0.1880 Epoch: 016 Iter: 3200/3498 LR: 0.0000151017 Loss content:  0.7027 Loss fft:  9.4859
# Time:  0.1880 Epoch: 016 Iter: 3300/3498 LR: 0.0000151017 Loss content:  0.7121 Loss fft:  9.5927
# Time:  0.1914 Epoch: 016 Iter: 3400/3498 LR: 0.0000151017 Loss content:  0.6967 Loss fft:  9.6192
# EPOCH: 16
# Elapsed time: 6.60 Epoch Pixel Loss:  0.7060 Epoch FFT Loss:  9.5694
# Time:  0.1974 Epoch: 017 Iter:  100/3498 LR: 0.0000094853 Loss content:  0.6804 Loss fft:  9.3480
# Time:  0.1882 Epoch: 017 Iter:  200/3498 LR: 0.0000094853 Loss content:  0.7111 Loss fft:  9.3857
# Time:  0.1882 Epoch: 017 Iter:  300/3498 LR: 0.0000094853 Loss content:  0.6926 Loss fft:  9.5170
# Time:  0.1880 Epoch: 017 Iter:  400/3498 LR: 0.0000094853 Loss content:  0.7188 Loss fft:  9.6439
# Time:  0.1881 Epoch: 017 Iter:  500/3498 LR: 0.0000094853 Loss content:  0.7066 Loss fft:  9.5657
# Time:  0.1880 Epoch: 017 Iter:  600/3498 LR: 0.0000094853 Loss content:  0.7208 Loss fft:  9.6916
# Time:  0.1880 Epoch: 017 Iter:  700/3498 LR: 0.0000094853 Loss content:  0.7192 Loss fft:  9.5807
# Time:  0.1881 Epoch: 017 Iter:  800/3498 LR: 0.0000094853 Loss content:  0.6951 Loss fft:  9.4551
# Time:  0.1883 Epoch: 017 Iter:  900/3498 LR: 0.0000094853 Loss content:  0.7128 Loss fft:  9.3857
# Time:  0.1886 Epoch: 017 Iter: 1000/3498 LR: 0.0000094853 Loss content:  0.6816 Loss fft:  9.8465
# Time:  0.1880 Epoch: 017 Iter: 1100/3498 LR: 0.0000094853 Loss content:  0.7061 Loss fft:  9.6935
# Time:  0.1881 Epoch: 017 Iter: 1200/3498 LR: 0.0000094853 Loss content:  0.6806 Loss fft:  9.8835
# Time:  0.1882 Epoch: 017 Iter: 1300/3498 LR: 0.0000094853 Loss content:  0.7110 Loss fft:  9.4020
# Time:  0.1885 Epoch: 017 Iter: 1400/3498 LR: 0.0000094853 Loss content:  0.7006 Loss fft:  9.6037
# Time:  0.1881 Epoch: 017 Iter: 1500/3498 LR: 0.0000094853 Loss content:  0.6791 Loss fft:  9.6977
# Time:  0.1881 Epoch: 017 Iter: 1600/3498 LR: 0.0000094853 Loss content:  0.7279 Loss fft:  9.4429
# Time:  0.1881 Epoch: 017 Iter: 1700/3498 LR: 0.0000094853 Loss content:  0.6941 Loss fft:  9.8472
# Time:  0.1883 Epoch: 017 Iter: 1800/3498 LR: 0.0000094853 Loss content:  0.7005 Loss fft:  9.4793
# Time:  0.1880 Epoch: 017 Iter: 1900/3498 LR: 0.0000094853 Loss content:  0.6797 Loss fft:  9.4061
# Time:  0.1880 Epoch: 017 Iter: 2000/3498 LR: 0.0000094853 Loss content:  0.7107 Loss fft:  9.8894
# Time:  0.1927 Epoch: 017 Iter: 2100/3498 LR: 0.0000094853 Loss content:  0.6902 Loss fft:  9.2039
# Time:  0.1879 Epoch: 017 Iter: 2200/3498 LR: 0.0000094853 Loss content:  0.7128 Loss fft:  9.6682
# Time:  0.1880 Epoch: 017 Iter: 2300/3498 LR: 0.0000094853 Loss content:  0.7095 Loss fft:  9.6825
# Time:  0.1881 Epoch: 017 Iter: 2400/3498 LR: 0.0000094853 Loss content:  0.7072 Loss fft:  9.8503
# Time:  0.1879 Epoch: 017 Iter: 2500/3498 LR: 0.0000094853 Loss content:  0.7305 Loss fft:  9.5955
# Time:  0.1880 Epoch: 017 Iter: 2600/3498 LR: 0.0000094853 Loss content:  0.7274 Loss fft:  9.5463
# Time:  0.1881 Epoch: 017 Iter: 2700/3498 LR: 0.0000094853 Loss content:  0.7044 Loss fft:  9.5961
# Time:  0.1880 Epoch: 017 Iter: 2800/3498 LR: 0.0000094853 Loss content:  0.6860 Loss fft:  9.4355
# Time:  0.1880 Epoch: 017 Iter: 2900/3498 LR: 0.0000094853 Loss content:  0.7302 Loss fft:  9.5548
# Time:  0.1879 Epoch: 017 Iter: 3000/3498 LR: 0.0000094853 Loss content:  0.7084 Loss fft:  9.6269
# Time:  0.1881 Epoch: 017 Iter: 3100/3498 LR: 0.0000094853 Loss content:  0.7284 Loss fft: 10.0633
# Time:  0.1881 Epoch: 017 Iter: 3200/3498 LR: 0.0000094853 Loss content:  0.7078 Loss fft:  9.5353
# Time:  0.1880 Epoch: 017 Iter: 3300/3498 LR: 0.0000094853 Loss content:  0.7196 Loss fft:  9.6586
# Time:  0.1880 Epoch: 017 Iter: 3400/3498 LR: 0.0000094853 Loss content:  0.6889 Loss fft:  9.4959
# EPOCH: 17
# Elapsed time: 6.60 Epoch Pixel Loss:  0.7061 Epoch FFT Loss:  9.5961
# Time:  0.1981 Epoch: 018 Iter:  100/3498 LR: 0.0000052550 Loss content:  0.7038 Loss fft:  9.6762
# Time:  0.1879 Epoch: 018 Iter:  200/3498 LR: 0.0000052550 Loss content:  0.7196 Loss fft:  9.7335
# Time:  0.1879 Epoch: 018 Iter:  300/3498 LR: 0.0000052550 Loss content:  0.7073 Loss fft:  9.6138
# Time:  0.1879 Epoch: 018 Iter:  400/3498 LR: 0.0000052550 Loss content:  0.7392 Loss fft:  9.6393
# Time:  0.1882 Epoch: 018 Iter:  500/3498 LR: 0.0000052550 Loss content:  0.7178 Loss fft:  9.3665
# Time:  0.1898 Epoch: 018 Iter:  600/3498 LR: 0.0000052550 Loss content:  0.7130 Loss fft:  9.3972
# Time:  0.1885 Epoch: 018 Iter:  700/3498 LR: 0.0000052550 Loss content:  0.7226 Loss fft:  9.6725
# Time:  0.1930 Epoch: 018 Iter:  800/3498 LR: 0.0000052550 Loss content:  0.7048 Loss fft:  9.7334
# Time:  0.1882 Epoch: 018 Iter:  900/3498 LR: 0.0000052550 Loss content:  0.7025 Loss fft:  9.8686
# Time:  0.1882 Epoch: 018 Iter: 1000/3498 LR: 0.0000052550 Loss content:  0.7098 Loss fft:  9.6841
# Time:  0.1879 Epoch: 018 Iter: 1100/3498 LR: 0.0000052550 Loss content:  0.7062 Loss fft:  9.7946
# Time:  0.1881 Epoch: 018 Iter: 1200/3498 LR: 0.0000052550 Loss content:  0.7012 Loss fft:  9.5465
# Time:  0.1882 Epoch: 018 Iter: 1300/3498 LR: 0.0000052550 Loss content:  0.6840 Loss fft:  9.4490
# Time:  0.1878 Epoch: 018 Iter: 1400/3498 LR: 0.0000052550 Loss content:  0.7157 Loss fft:  9.6730
# Time:  0.1880 Epoch: 018 Iter: 1500/3498 LR: 0.0000052550 Loss content:  0.7157 Loss fft:  9.5234
# Time:  0.1879 Epoch: 018 Iter: 1600/3498 LR: 0.0000052550 Loss content:  0.7172 Loss fft:  9.6823
# Time:  0.1878 Epoch: 018 Iter: 1700/3498 LR: 0.0000052550 Loss content:  0.6952 Loss fft:  9.5019
# Time:  0.1878 Epoch: 018 Iter: 1800/3498 LR: 0.0000052550 Loss content:  0.6978 Loss fft:  9.6005
# Time:  0.1878 Epoch: 018 Iter: 1900/3498 LR: 0.0000052550 Loss content:  0.6941 Loss fft:  9.5229
# Time:  0.1879 Epoch: 018 Iter: 2000/3498 LR: 0.0000052550 Loss content:  0.7071 Loss fft:  9.6206
# Time:  0.1881 Epoch: 018 Iter: 2100/3498 LR: 0.0000052550 Loss content:  0.6828 Loss fft:  9.5781
# Time:  0.1880 Epoch: 018 Iter: 2200/3498 LR: 0.0000052550 Loss content:  0.7096 Loss fft:  9.7089
# Time:  0.1883 Epoch: 018 Iter: 2300/3498 LR: 0.0000052550 Loss content:  0.6935 Loss fft:  9.6862
# Time:  0.1879 Epoch: 018 Iter: 2400/3498 LR: 0.0000052550 Loss content:  0.6942 Loss fft:  9.7229
# Time:  0.1879 Epoch: 018 Iter: 2500/3498 LR: 0.0000052550 Loss content:  0.6977 Loss fft:  9.5757
# Time:  0.1878 Epoch: 018 Iter: 2600/3498 LR: 0.0000052550 Loss content:  0.7260 Loss fft:  9.2503
# Time:  0.1878 Epoch: 018 Iter: 2700/3498 LR: 0.0000052550 Loss content:  0.7158 Loss fft:  9.5766
# Time:  0.1879 Epoch: 018 Iter: 2800/3498 LR: 0.0000052550 Loss content:  0.7481 Loss fft:  9.5586
# Time:  0.1879 Epoch: 018 Iter: 2900/3498 LR: 0.0000052550 Loss content:  0.7032 Loss fft:  9.6114
# Time:  0.1914 Epoch: 018 Iter: 3000/3498 LR: 0.0000052550 Loss content:  0.6982 Loss fft:  9.2809
# Time:  0.1879 Epoch: 018 Iter: 3100/3498 LR: 0.0000052550 Loss content:  0.6917 Loss fft:  9.5889
# Time:  0.1879 Epoch: 018 Iter: 3200/3498 LR: 0.0000052550 Loss content:  0.7203 Loss fft:  9.4881
# Time:  0.1878 Epoch: 018 Iter: 3300/3498 LR: 0.0000052550 Loss content:  0.7170 Loss fft:  9.2806
# Time:  0.1878 Epoch: 018 Iter: 3400/3498 LR: 0.0000052550 Loss content:  0.6798 Loss fft:  9.4928
# EPOCH: 18
# Elapsed time: 6.60 Epoch Pixel Loss:  0.7061 Epoch FFT Loss:  9.5734
# Time:  0.1975 Epoch: 019 Iter:  100/3498 LR: 0.0000025070 Loss content:  0.6995 Loss fft:  9.5913
# Time:  0.1879 Epoch: 019 Iter:  200/3498 LR: 0.0000025070 Loss content:  0.7075 Loss fft:  9.5050
# Time:  0.1880 Epoch: 019 Iter:  300/3498 LR: 0.0000025070 Loss content:  0.6820 Loss fft:  9.6808
# Time:  0.1884 Epoch: 019 Iter:  400/3498 LR: 0.0000025070 Loss content:  0.7135 Loss fft:  9.5828
# Time:  0.1882 Epoch: 019 Iter:  500/3498 LR: 0.0000025070 Loss content:  0.6926 Loss fft:  9.8367
# Time:  0.1880 Epoch: 019 Iter:  600/3498 LR: 0.0000025070 Loss content:  0.7014 Loss fft:  9.6496
# Time:  0.1880 Epoch: 019 Iter:  700/3498 LR: 0.0000025070 Loss content:  0.7043 Loss fft:  9.4775
# Time:  0.1881 Epoch: 019 Iter:  800/3498 LR: 0.0000025070 Loss content:  0.7010 Loss fft:  9.5629
# Time:  0.1883 Epoch: 019 Iter:  900/3498 LR: 0.0000025070 Loss content:  0.7076 Loss fft:  9.8235
# Time:  0.1883 Epoch: 019 Iter: 1000/3498 LR: 0.0000025070 Loss content:  0.7257 Loss fft:  9.6117
# Time:  0.1881 Epoch: 019 Iter: 1100/3498 LR: 0.0000025070 Loss content:  0.6835 Loss fft:  9.6194
# Time:  0.1881 Epoch: 019 Iter: 1200/3498 LR: 0.0000025070 Loss content:  0.7160 Loss fft:  9.6770
# Time:  0.1883 Epoch: 019 Iter: 1300/3498 LR: 0.0000025070 Loss content:  0.7200 Loss fft:  9.6628
# Time:  0.1882 Epoch: 019 Iter: 1400/3498 LR: 0.0000025070 Loss content:  0.6891 Loss fft:  9.1583
# Time:  0.1881 Epoch: 019 Iter: 1500/3498 LR: 0.0000025070 Loss content:  0.6828 Loss fft:  9.4561
# Time:  0.1880 Epoch: 019 Iter: 1600/3498 LR: 0.0000025070 Loss content:  0.6917 Loss fft:  9.2849
# Time:  0.1929 Epoch: 019 Iter: 1700/3498 LR: 0.0000025070 Loss content:  0.7005 Loss fft:  9.6715
# Time:  0.1881 Epoch: 019 Iter: 1800/3498 LR: 0.0000025070 Loss content:  0.6888 Loss fft:  9.7279
# Time:  0.1882 Epoch: 019 Iter: 1900/3498 LR: 0.0000025070 Loss content:  0.6933 Loss fft:  9.7730
# Time:  0.1881 Epoch: 019 Iter: 2000/3498 LR: 0.0000025070 Loss content:  0.7120 Loss fft:  9.4158
# Time:  0.1881 Epoch: 019 Iter: 2100/3498 LR: 0.0000025070 Loss content:  0.7180 Loss fft:  9.5492
# Time:  0.1880 Epoch: 019 Iter: 2200/3498 LR: 0.0000025070 Loss content:  0.6979 Loss fft:  9.4281
# Time:  0.1880 Epoch: 019 Iter: 2300/3498 LR: 0.0000025070 Loss content:  0.6894 Loss fft:  9.4009
# Time:  0.1881 Epoch: 019 Iter: 2400/3498 LR: 0.0000025070 Loss content:  0.7203 Loss fft:  9.6156
# Time:  0.1882 Epoch: 019 Iter: 2500/3498 LR: 0.0000025070 Loss content:  0.7188 Loss fft:  9.4639
# Time:  0.1879 Epoch: 019 Iter: 2600/3498 LR: 0.0000025070 Loss content:  0.7125 Loss fft:  9.6087
# Time:  0.1881 Epoch: 019 Iter: 2700/3498 LR: 0.0000025070 Loss content:  0.7113 Loss fft:  9.3989
# Time:  0.1880 Epoch: 019 Iter: 2800/3498 LR: 0.0000025070 Loss content:  0.6928 Loss fft:  9.5278
# Time:  0.1880 Epoch: 019 Iter: 2900/3498 LR: 0.0000025070 Loss content:  0.7010 Loss fft:  9.6183
# Time:  0.1879 Epoch: 019 Iter: 3000/3498 LR: 0.0000025070 Loss content:  0.7306 Loss fft:  9.7586
# Time:  0.1879 Epoch: 019 Iter: 3100/3498 LR: 0.0000025070 Loss content:  0.7049 Loss fft:  9.6681
# Time:  0.1880 Epoch: 019 Iter: 3200/3498 LR: 0.0000025070 Loss content:  0.7181 Loss fft:  9.6381
# Time:  0.1882 Epoch: 019 Iter: 3300/3498 LR: 0.0000025070 Loss content:  0.7198 Loss fft:  9.5292
# Time:  0.1879 Epoch: 019 Iter: 3400/3498 LR: 0.0000025070 Loss content:  0.6925 Loss fft:  9.7285
# EPOCH: 19
# Elapsed time: 6.60 Epoch Pixel Loss:  0.7047 Epoch FFT Loss:  9.5782
# Time:  0.1967 Epoch: 020 Iter:  100/3498 LR: 0.0000012125 Loss content:  0.7026 Loss fft:  9.6128
# Time:  0.1883 Epoch: 020 Iter:  200/3498 LR: 0.0000012125 Loss content:  0.7058 Loss fft:  9.5655
# Time:  0.1879 Epoch: 020 Iter:  300/3498 LR: 0.0000012125 Loss content:  0.7025 Loss fft:  9.5746
# Time:  0.1931 Epoch: 020 Iter:  400/3498 LR: 0.0000012125 Loss content:  0.7092 Loss fft:  9.5893
# Time:  0.1880 Epoch: 020 Iter:  500/3498 LR: 0.0000012125 Loss content:  0.7148 Loss fft:  9.7546
# Time:  0.1878 Epoch: 020 Iter:  600/3498 LR: 0.0000012125 Loss content:  0.7015 Loss fft:  9.5099
# Time:  0.1878 Epoch: 020 Iter:  700/3498 LR: 0.0000012125 Loss content:  0.7103 Loss fft:  9.7284
# Time:  0.1879 Epoch: 020 Iter:  800/3498 LR: 0.0000012125 Loss content:  0.7076 Loss fft:  9.5569
# Time:  0.1879 Epoch: 020 Iter:  900/3498 LR: 0.0000012125 Loss content:  0.7144 Loss fft:  9.5401
# Time:  0.1880 Epoch: 020 Iter: 1000/3498 LR: 0.0000012125 Loss content:  0.6885 Loss fft:  9.6270
# Time:  0.1882 Epoch: 020 Iter: 1100/3498 LR: 0.0000012125 Loss content:  0.7234 Loss fft:  9.5905
# Time:  0.1880 Epoch: 020 Iter: 1200/3498 LR: 0.0000012125 Loss content:  0.7038 Loss fft:  9.6766
# Time:  0.1880 Epoch: 020 Iter: 1300/3498 LR: 0.0000012125 Loss content:  0.6743 Loss fft:  9.4218
# Time:  0.1879 Epoch: 020 Iter: 1400/3498 LR: 0.0000012125 Loss content:  0.7067 Loss fft:  9.6693
# Time:  0.1878 Epoch: 020 Iter: 1500/3498 LR: 0.0000012125 Loss content:  0.7121 Loss fft:  9.2915
# Time:  0.1879 Epoch: 020 Iter: 1600/3498 LR: 0.0000012125 Loss content:  0.7172 Loss fft:  9.6920
# Time:  0.1879 Epoch: 020 Iter: 1700/3498 LR: 0.0000012125 Loss content:  0.6826 Loss fft:  9.7648
# Time:  0.1878 Epoch: 020 Iter: 1800/3498 LR: 0.0000012125 Loss content:  0.7174 Loss fft:  9.7737
# Time:  0.1883 Epoch: 020 Iter: 1900/3498 LR: 0.0000012125 Loss content:  0.7122 Loss fft:  9.2489
# Time:  0.1879 Epoch: 020 Iter: 2000/3498 LR: 0.0000012125 Loss content:  0.6886 Loss fft:  9.7664
# Time:  0.1878 Epoch: 020 Iter: 2100/3498 LR: 0.0000012125 Loss content:  0.6965 Loss fft:  9.5686
# Time:  0.1878 Epoch: 020 Iter: 2200/3498 LR: 0.0000012125 Loss content:  0.7213 Loss fft:  9.3907
# Time:  0.1880 Epoch: 020 Iter: 2300/3498 LR: 0.0000012125 Loss content:  0.7033 Loss fft:  9.5293
# Time:  0.1882 Epoch: 020 Iter: 2400/3498 LR: 0.0000012125 Loss content:  0.7095 Loss fft:  9.5971
# Time:  0.1879 Epoch: 020 Iter: 2500/3498 LR: 0.0000012125 Loss content:  0.7026 Loss fft:  9.3976
# Time:  0.1913 Epoch: 020 Iter: 2600/3498 LR: 0.0000012125 Loss content:  0.6837 Loss fft:  9.4528
# Time:  0.1879 Epoch: 020 Iter: 2700/3498 LR: 0.0000012125 Loss content:  0.7215 Loss fft:  9.4720
# Time:  0.1879 Epoch: 020 Iter: 2800/3498 LR: 0.0000012125 Loss content:  0.7188 Loss fft:  9.4628
# Time:  0.1879 Epoch: 020 Iter: 2900/3498 LR: 0.0000012125 Loss content:  0.7029 Loss fft:  9.6249
# Time:  0.1882 Epoch: 020 Iter: 3000/3498 LR: 0.0000012125 Loss content:  0.7051 Loss fft:  9.4906
# Time:  0.1879 Epoch: 020 Iter: 3100/3498 LR: 0.0000012125 Loss content:  0.6951 Loss fft:  9.4990
# Time:  0.1878 Epoch: 020 Iter: 3200/3498 LR: 0.0000012125 Loss content:  0.7079 Loss fft:  9.6295
# Time:  0.1880 Epoch: 020 Iter: 3300/3498 LR: 0.0000012125 Loss content:  0.6764 Loss fft:  9.5811
# Time:  0.1880 Epoch: 020 Iter: 3400/3498 LR: 0.0000012125 Loss content:  0.6982 Loss fft:  9.5904
# EPOCH: 20
# Elapsed time: 6.60 Epoch Pixel Loss:  0.7042 Epoch FFT Loss:  9.5699
# Start Evaluation
# 499
#
# 020 epoch
#  Average PSNR 10.26 dB

# %% [markdown]
# Test
# ==

# %%
import os
import torch
import torchvision.transforms as transforms
# from torch.backends import cudnn # Uncomment if you need it

class Args:
    model_name = 'IRNeXt'
    mode = 'test'
    data_dir = path

    # Train
    batch_size = 4
    learning_rate = 1e-4
    weight_decay = 0
    num_epoch = 20
    print_freq = 100
    num_worker = 8
    save_freq = 10
    valid_freq = 10
    momentum_value = 0.8

    resume = ''
    #/content/drive/MyDrive/MYresults2/IRNeXt/ITS/model.pkl
    # Test
    test_model = '/content/drive/MyDrive/MYresults2_8/IRNeXt/ITS/Final.pkl'
    save_image = False

    # Directories (set these as per your requirement)
    model_save_dir = os.path.join('/content/drive/MyDrive/MYresults2_8/', 'IRNeXt', 'ITS/')
    result_dir = os.path.join('/content/drive/MyDrive/MYresults2_8/', model_name, 'test')

def main(args):
    # CUDNN
    # cudnn.benchmark = True # Uncomment if you need it

    if not os.path.exists('/content/drive/MyDrive/MYresults2_8/'):
        os.makedirs(args.model_save_dir)
    if not os.path.exists('/content/drive/MyDrive/MYresults2_8/' + args.model_name + '/'):
        os.makedirs('/content/drive/MyDrive/MYresults2_8/' + args.model_name + '/')
    if not os.path.exists(args.model_save_dir):
        os.makedirs(args.model_save_dir)
    if not os.path.exists(args.result_dir):
        os.makedirs(args.result_dir)

    model = build_net()  # Make sure to define build_net or import it if it's defined elsewhere
    print(model)

    if torch.cuda.is_available():
        model.cuda()
    if args.mode == 'train':
        _train(model, args)  # Make sure to define _train or import it if it's defined elsewhere

    elif args.mode == 'test':
        _eval(model, args)   # Make sure to define _eval or import it if it's defined elsewhere

# Replace parser.parse_args() with an instance of the Args class
args = Args()
if not os.path.exists(args.model_save_dir):
    os.makedirs(args.model_save_dir)
# Copying files (make sure these paths are correct)
command = 'cp ' + 'models/layers.py ' + args.model_save_dir
os.system(command)
command = 'cp ' + 'models/IRNeXt.py ' + args.model_save_dir
os.system(command)
command = 'cp ' + 'train.py ' + args.model_save_dir
os.system(command)
command = 'cp ' + 'main.py ' + args.model_save_dir
os.system(command)
print(args)
main(args)
# Out:
# <__main__.Args object at 0x7d9ee0ac0940>
# IRNeXt(
#   (Encoder): ModuleList(
#     (0): EBlock(
#       (layers): Sequential(
#         (0): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (1): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (2): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (3): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): DeepPoolLayer(
#               (pools): ModuleList(
#                 (0): AvgPool2d(kernel_size=8, stride=8, padding=0)
#                 (1): AvgPool2d(kernel_size=4, stride=4, padding=0)
#                 (2): AvgPool2d(kernel_size=2, stride=2, padding=0)
#               )
#               (convs): ModuleList(
#                 (0-2): 3 x Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#               (dynas): ModuleList(
#                 (0-2): 3 x dynamic_filter(
#                   (conv): Conv2d(32, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (bn): BatchNorm2d(72, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (act): Tanh()
#                   (pad): ReflectionPad2d((1, 1, 1, 1))
#                   (ap): AdaptiveAvgPool2d(output_size=(1, 1))
#                   (gap): AdaptiveAvgPool2d(output_size=1)
#                 )
#               )
#               (relu): GELU(approximate='none')
#               (conv_sum): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             )
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#       )
#     )
#     (1): EBlock(
#       (layers): Sequential(
#         (0): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (1): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (2): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (3): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): DeepPoolLayer(
#               (pools): ModuleList(
#                 (0): AvgPool2d(kernel_size=8, stride=8, padding=0)
#                 (1): AvgPool2d(kernel_size=4, stride=4, padding=0)
#                 (2): AvgPool2d(kernel_size=2, stride=2, padding=0)
#               )
#               (convs): ModuleList(
#                 (0-2): 3 x Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#               (dynas): ModuleList(
#                 (0-2): 3 x dynamic_filter(
#                   (conv): Conv2d(64, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (bn): BatchNorm2d(72, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (act): Tanh()
#                   (pad): ReflectionPad2d((1, 1, 1, 1))
#                   (ap): AdaptiveAvgPool2d(output_size=(1, 1))
#                   (gap): AdaptiveAvgPool2d(output_size=1)
#                 )
#               )
#               (relu): GELU(approximate='none')
#               (conv_sum): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             )
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#       )
#     )
#     (2): EBlock(
#       (layers): Sequential(
#         (0): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (1): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (2): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (3): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): DeepPoolLayer(
#               (pools): ModuleList(
#                 (0): AvgPool2d(kernel_size=8, stride=8, padding=0)
#                 (1): AvgPool2d(kernel_size=4, stride=4, padding=0)
#                 (2): AvgPool2d(kernel_size=2, stride=2, padding=0)
#               )
#               (convs): ModuleList(
#                 (0-2): 3 x Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#               (dynas): ModuleList(
#                 (0-2): 3 x dynamic_filter(
#                   (conv): Conv2d(128, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (bn): BatchNorm2d(72, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (act): Tanh()
#                   (pad): ReflectionPad2d((1, 1, 1, 1))
#                   (ap): AdaptiveAvgPool2d(output_size=(1, 1))
#                   (gap): AdaptiveAvgPool2d(output_size=1)
#                 )
#               )
#               (relu): GELU(approximate='none')
#               (conv_sum): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             )
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#       )
#     )
#   )
#   (feat_extract): ModuleList(
#     (0): BasicConv(
#       (main): Sequential(
#         (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): GELU(approximate='none')
#       )
#     )
#     (1): BasicConv(
#       (main): Sequential(
#         (0): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         (1): GELU(approximate='none')
#       )
#     )
#     (2): BasicConv(
#       (main): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         (1): GELU(approximate='none')
#       )
#     )
#     (3): BasicConv(
#       (main): Sequential(
#         (0): ConvTranspose2d(128, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#         (1): GELU(approximate='none')
#       )
#     )
#     (4): BasicConv(
#       (main): Sequential(
#         (0): ConvTranspose2d(64, 32, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#         (1): GELU(approximate='none')
#       )
#     )
#     (5): BasicConv(
#       (main): Sequential(
#         (0): Conv2d(32, 3, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#     )
#   )
#   (Decoder): ModuleList(
#     (0): DBlock(
#       (layers): Sequential(
#         (0): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (1): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (2): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (3): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): DeepPoolLayer(
#               (pools): ModuleList(
#                 (0): AvgPool2d(kernel_size=8, stride=8, padding=0)
#                 (1): AvgPool2d(kernel_size=4, stride=4, padding=0)
#                 (2): AvgPool2d(kernel_size=2, stride=2, padding=0)
#               )
#               (convs): ModuleList(
#                 (0-2): 3 x Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#               (dynas): ModuleList(
#                 (0-2): 3 x dynamic_filter(
#                   (conv): Conv2d(128, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (bn): BatchNorm2d(72, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (act): Tanh()
#                   (pad): ReflectionPad2d((1, 1, 1, 1))
#                   (ap): AdaptiveAvgPool2d(output_size=(1, 1))
#                   (gap): AdaptiveAvgPool2d(output_size=1)
#                 )
#               )
#               (relu): GELU(approximate='none')
#               (conv_sum): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             )
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#       )
#     )
#     (1): DBlock(
#       (layers): Sequential(
#         (0): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (1): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (2): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (3): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): DeepPoolLayer(
#               (pools): ModuleList(
#                 (0): AvgPool2d(kernel_size=8, stride=8, padding=0)
#                 (1): AvgPool2d(kernel_size=4, stride=4, padding=0)
#                 (2): AvgPool2d(kernel_size=2, stride=2, padding=0)
#               )
#               (convs): ModuleList(
#                 (0-2): 3 x Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#               (dynas): ModuleList(
#                 (0-2): 3 x dynamic_filter(
#                   (conv): Conv2d(64, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (bn): BatchNorm2d(72, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (act): Tanh()
#                   (pad): ReflectionPad2d((1, 1, 1, 1))
#                   (ap): AdaptiveAvgPool2d(output_size=(1, 1))
#                   (gap): AdaptiveAvgPool2d(output_size=1)
#                 )
#               )
#               (relu): GELU(approximate='none')
#               (conv_sum): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             )
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#       )
#     )
#     (2): DBlock(
#       (layers): Sequential(
#         (0): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (1): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (2): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (3): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): DeepPoolLayer(
#               (pools): ModuleList(
#                 (0): AvgPool2d(kernel_size=8, stride=8, padding=0)
#                 (1): AvgPool2d(kernel_size=4, stride=4, padding=0)
#                 (2): AvgPool2d(kernel_size=2, stride=2, padding=0)
#               )
#               (convs): ModuleList(
#                 (0-2): 3 x Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#               (dynas): ModuleList(
#                 (0-2): 3 x dynamic_filter(
#                   (conv): Conv2d(32, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (bn): BatchNorm2d(72, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (act): Tanh()
#                   (pad): ReflectionPad2d((1, 1, 1, 1))
#                   (ap): AdaptiveAvgPool2d(output_size=(1, 1))
#                   (gap): AdaptiveAvgPool2d(output_size=1)
#                 )
#               )
#               (relu): GELU(approximate='none')
#               (conv_sum): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             )
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#       )
#     )
#   )
#   (Convs): ModuleList(
#     (0): BasicConv(
#       (main): Sequential(
#         (0): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1))
#         (1): GELU(approximate='none')
#       )
#     )
#     (1): BasicConv(
#       (main): Sequential(
#         (0): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#         (1): GELU(approximate='none')
#       )
#     )
#   )
#   (ConvsOut): ModuleList(
#     (0): BasicConv(
#       (main): Sequential(
#         (0): Conv2d(128, 3, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#     )
#     (1): BasicConv(
#       (main): Sequential(
#         (0): Conv2d(64, 3, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#     )
#   )
#   (FAM1): FAM(
#     (merge): BasicConv(
#       (main): Sequential(
#         (0): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#     )
#   )
#   (SCM1): SCM(
#     (main): Sequential(
#       (0): BasicConv(
#         (main): Sequential(
#           (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): GELU(approximate='none')
#         )
#       )
#       (1): BasicConv(
#         (main): Sequential(
#           (0): Conv2d(32, 64, kernel_size=(1, 1), stride=(1, 1))
#           (1): GELU(approximate='none')
#         )
#       )
#       (2): BasicConv(
#         (main): Sequential(
#           (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): GELU(approximate='none')
#         )
#       )
#       (3): BasicConv(
#         (main): Sequential(
#           (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1))
#         )
#       )
#       (4): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#     )
#   )
#   (FAM2): FAM(
#     (merge): BasicConv(
#       (main): Sequential(
#         (0): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#     )
#   )
#   (SCM2): SCM(
#     (main): Sequential(
#       (0): BasicConv(
#         (main): Sequential(
#           (0): Conv2d(3, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): GELU(approximate='none')
#         )
#       )
#       (1): BasicConv(
#         (main): Sequential(
#           (0): Conv2d(16, 32, kernel_size=(1, 1), stride=(1, 1))
#           (1): GELU(approximate='none')
#         )
#       )
#       (2): BasicConv(
#         (main): Sequential(
#           (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): GELU(approximate='none')
#         )
#       )
#       (3): BasicConv(
#         (main): Sequential(
#           (0): Conv2d(32, 64, kernel_size=(1, 1), stride=(1, 1))
#         )
#       )
#       (4): InstanceNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#     )
#   )
# )
# 1 iter PSNR_dehazing: 12.16 ssim: 0.765093
# 1 iter PSNR: 12.16 time: 0.024195
# 2 iter PSNR_dehazing: 7.68 ssim: 0.613677
# 2 iter PSNR: 7.68 time: 0.019225
# 3 iter PSNR_dehazing: 11.38 ssim: 0.745900
# 3 iter PSNR: 11.38 time: 0.020110
# 4 iter PSNR_dehazing: 10.70 ssim: 0.727499
# 4 iter PSNR: 10.70 time: 0.021688
# 5 iter PSNR_dehazing: 10.10 ssim: 0.709715
# 5 iter PSNR: 10.10 time: 0.019853
# 6 iter PSNR_dehazing: 9.58 ssim: 0.692482
# 6 iter PSNR: 9.58 time: 0.018694
# 7 iter PSNR_dehazing: 9.11 ssim: 0.675718
# 7 iter PSNR: 9.11 time: 0.018820
# 8 iter PSNR_dehazing: 8.70 ssim: 0.659430
# 8 iter PSNR: 8.70 time: 0.024542
# 9 iter PSNR_dehazing: 8.32 ssim: 0.643628
# 9 iter PSNR: 8.32 time: 0.019287
# 10 iter PSNR_dehazing: 7.99 ssim: 0.628347
# 10 iter PSNR: 7.99 time: 0.019394
# 11 iter PSNR_dehazing: 14.22 ssim: 0.772247
# 11 iter PSNR: 14.22 time: 0.019384
# 12 iter PSNR_dehazing: 9.73 ssim: 0.661219
# 12 iter PSNR: 9.73 time: 0.019481
# 13 iter PSNR_dehazing: 13.50 ssim: 0.758302
# 13 iter PSNR: 13.50 time: 0.022863
# 14 iter PSNR_dehazing: 12.85 ssim: 0.744836
# 14 iter PSNR: 12.85 time: 0.019086
# 15 iter PSNR_dehazing: 12.27 ssim: 0.731778
# 15 iter PSNR: 12.27 time: 0.022330
# 16 iter PSNR_dehazing: 11.74 ssim: 0.719135
# 16 iter PSNR: 11.74 time: 0.019147
# 17 iter PSNR_dehazing: 11.26 ssim: 0.706855
# 17 iter PSNR: 11.26 time: 0.019747
# 18 iter PSNR_dehazing: 10.83 ssim: 0.694956
# 18 iter PSNR: 10.83 time: 0.019021
# 19 iter PSNR_dehazing: 10.43 ssim: 0.683372
# 19 iter PSNR: 10.43 time: 0.019628
# 20 iter PSNR_dehazing: 10.07 ssim: 0.672131
# 20 iter PSNR: 10.07 time: 0.023568
# 21 iter PSNR_dehazing: 13.59 ssim: 0.667110
# 21 iter PSNR: 13.59 time: 0.024675
# 22 iter PSNR_dehazing: 8.60 ssim: 0.519179
# 22 iter PSNR: 8.60 time: 0.019369
# 23 iter PSNR_dehazing: 12.75 ssim: 0.645156
# 23 iter PSNR: 12.75 time: 0.023002
# 24 iter PSNR_dehazing: 12.01 ssim: 0.625085
# 24 iter PSNR: 12.01 time: 0.019088
# 25 iter PSNR_dehazing: 11.36 ssim: 0.606595
# 25 iter PSNR: 11.36 time: 0.019277
# 26 iter PSNR_dehazing: 10.77 ssim: 0.589490
# 26 iter PSNR: 10.77 time: 0.018793
# 27 iter PSNR_dehazing: 10.25 ssim: 0.573575
# 27 iter PSNR: 10.25 time: 0.019811
# 28 iter PSNR_dehazing: 9.78 ssim: 0.558666
# 28 iter PSNR: 9.78 time: 0.019242
# 29 iter PSNR_dehazing: 9.35 ssim: 0.544739
# 29 iter PSNR: 9.35 time: 0.019451
# 30 iter PSNR_dehazing: 8.96 ssim: 0.531669
# 30 iter PSNR: 8.96 time: 0.020690
# 31 iter PSNR_dehazing: 11.30 ssim: 0.614604
# 31 iter PSNR: 11.30 time: 0.022384
# 32 iter PSNR_dehazing: 6.31 ssim: 0.445094
# 32 iter PSNR: 6.31 time: 0.020717
# 33 iter PSNR_dehazing: 10.42 ssim: 0.589811
# 33 iter PSNR: 10.42 time: 0.020851
# 34 iter PSNR_dehazing: 9.67 ssim: 0.566904
# 34 iter PSNR: 9.67 time: 0.021382
# 35 iter PSNR_dehazing: 9.01 ssim: 0.545698
# 35 iter PSNR: 9.01 time: 0.023000
# 36 iter PSNR_dehazing: 8.43 ssim: 0.525991
# 36 iter PSNR: 8.43 time: 0.025706
# 37 iter PSNR_dehazing: 7.91 ssim: 0.507639
# 37 iter PSNR: 7.91 time: 0.032572
# 38 iter PSNR_dehazing: 7.45 ssim: 0.490493
# 38 iter PSNR: 7.45 time: 0.021516
# 39 iter PSNR_dehazing: 7.03 ssim: 0.474464
# 39 iter PSNR: 7.03 time: 0.020044
# 40 iter PSNR_dehazing: 6.65 ssim: 0.459363
# 40 iter PSNR: 6.65 time: 0.021726
# 41 iter PSNR_dehazing: 13.67 ssim: 0.777744
# 41 iter PSNR: 13.67 time: 0.019709
# 42 iter PSNR_dehazing: 8.86 ssim: 0.599586
# 42 iter PSNR: 8.86 time: 0.021227
# 43 iter PSNR_dehazing: 12.85 ssim: 0.754278
# 43 iter PSNR: 12.85 time: 0.020472
# 44 iter PSNR_dehazing: 12.13 ssim: 0.731810
# 44 iter PSNR: 12.13 time: 0.022373
# 45 iter PSNR_dehazing: 11.50 ssim: 0.710317
# 45 iter PSNR: 11.50 time: 0.020601
# 46 iter PSNR_dehazing: 10.94 ssim: 0.689767
# 46 iter PSNR: 10.94 time: 0.022640
# 47 iter PSNR_dehazing: 10.43 ssim: 0.670129
# 47 iter PSNR: 10.43 time: 0.020085
# 48 iter PSNR_dehazing: 9.98 ssim: 0.651332
# 48 iter PSNR: 9.98 time: 0.020837
# 49 iter PSNR_dehazing: 9.57 ssim: 0.633339
# 49 iter PSNR: 9.57 time: 0.019304
# 50 iter PSNR_dehazing: 9.20 ssim: 0.616099
# 50 iter PSNR: 9.20 time: 0.020395
# 51 iter PSNR_dehazing: 13.23 ssim: 0.804077
# 51 iter PSNR: 13.23 time: 0.020517
# 52 iter PSNR_dehazing: 8.65 ssim: 0.633012
# 52 iter PSNR: 8.65 time: 0.020580
# 53 iter PSNR_dehazing: 12.44 ssim: 0.781999
# 53 iter PSNR: 12.44 time: 0.020446
# 54 iter PSNR_dehazing: 11.75 ssim: 0.760741
# 54 iter PSNR: 11.75 time: 0.021821
# 55 iter PSNR_dehazing: 11.14 ssim: 0.740290
# 55 iter PSNR: 11.14 time: 0.020499
# 56 iter PSNR_dehazing: 10.60 ssim: 0.720745
# 56 iter PSNR: 10.60 time: 0.020630
# 57 iter PSNR_dehazing: 10.12 ssim: 0.702014
# 57 iter PSNR: 10.12 time: 0.020625
# 58 iter PSNR_dehazing: 9.69 ssim: 0.683922
# 58 iter PSNR: 9.69 time: 0.022124
# 59 iter PSNR_dehazing: 9.31 ssim: 0.666282
# 59 iter PSNR: 9.31 time: 0.020816
# 60 iter PSNR_dehazing: 8.96 ssim: 0.649222
# 60 iter PSNR: 8.96 time: 0.024679
# 61 iter PSNR_dehazing: 14.60 ssim: 0.826581
# 61 iter PSNR: 14.60 time: 0.019787
# 62 iter PSNR_dehazing: 10.00 ssim: 0.670049
# 62 iter PSNR: 10.00 time: 0.021992
# 63 iter PSNR_dehazing: 13.83 ssim: 0.806661
# 63 iter PSNR: 13.83 time: 0.025108
# 64 iter PSNR_dehazing: 13.15 ssim: 0.787308
# 64 iter PSNR: 13.15 time: 0.024604
# 65 iter PSNR_dehazing: 12.55 ssim: 0.768580
# 65 iter PSNR: 12.55 time: 0.020618
# 66 iter PSNR_dehazing: 12.01 ssim: 0.750530
# 66 iter PSNR: 12.01 time: 0.020754
# 67 iter PSNR_dehazing: 11.53 ssim: 0.733191
# 67 iter PSNR: 11.53 time: 0.019726
# 68 iter PSNR_dehazing: 11.09 ssim: 0.716472
# 68 iter PSNR: 11.09 time: 0.020915
# 69 iter PSNR_dehazing: 10.70 ssim: 0.700390
# 69 iter PSNR: 10.70 time: 0.019616
# 70 iter PSNR_dehazing: 10.33 ssim: 0.684954
# 70 iter PSNR: 10.33 time: 0.019773
# 71 iter PSNR_dehazing: 14.34 ssim: 0.863758
# 71 iter PSNR: 14.34 time: 0.019965
# 72 iter PSNR_dehazing: 9.82 ssim: 0.710036
# 72 iter PSNR: 9.82 time: 0.019684
# 73 iter PSNR_dehazing: 13.57 ssim: 0.846202
# 73 iter PSNR: 13.57 time: 0.020369
# 74 iter PSNR_dehazing: 12.90 ssim: 0.828658
# 74 iter PSNR: 12.90 time: 0.019368
# 75 iter PSNR_dehazing: 12.31 ssim: 0.811193
# 75 iter PSNR: 12.31 time: 0.019283
# 76 iter PSNR_dehazing: 11.78 ssim: 0.793817
# 76 iter PSNR: 11.78 time: 0.022051
# 77 iter PSNR_dehazing: 11.31 ssim: 0.776637
# 77 iter PSNR: 11.31 time: 0.020694
# 78 iter PSNR_dehazing: 10.88 ssim: 0.759653
# 78 iter PSNR: 10.88 time: 0.023518
# 79 iter PSNR_dehazing: 10.49 ssim: 0.742789
# 79 iter PSNR: 10.49 time: 0.027081
# 80 iter PSNR_dehazing: 10.14 ssim: 0.726264
# 80 iter PSNR: 10.14 time: 0.024239
# 81 iter PSNR_dehazing: 14.47 ssim: 0.867863
# 81 iter PSNR: 14.47 time: 0.023741
# 82 iter PSNR_dehazing: 10.03 ssim: 0.707638
# 82 iter PSNR: 10.03 time: 0.026850
# 83 iter PSNR_dehazing: 13.73 ssim: 0.849880
# 83 iter PSNR: 13.73 time: 0.019405
# 84 iter PSNR_dehazing: 13.07 ssim: 0.831653
# 84 iter PSNR: 13.07 time: 0.020683
# 85 iter PSNR_dehazing: 12.49 ssim: 0.813323
# 85 iter PSNR: 12.49 time: 0.019498
# 86 iter PSNR_dehazing: 11.97 ssim: 0.795021
# 86 iter PSNR: 11.97 time: 0.019286
# 87 iter PSNR_dehazing: 11.50 ssim: 0.776917
# 87 iter PSNR: 11.50 time: 0.019583
# 88 iter PSNR_dehazing: 11.08 ssim: 0.759083
# 88 iter PSNR: 11.08 time: 0.019497
# 89 iter PSNR_dehazing: 10.70 ssim: 0.741557
# 89 iter PSNR: 10.70 time: 0.021323
# 90 iter PSNR_dehazing: 10.35 ssim: 0.724413
# 90 iter PSNR: 10.35 time: 0.018507
# 91 iter PSNR_dehazing: 14.80 ssim: 0.845309
# 91 iter PSNR: 14.80 time: 0.019630
# 92 iter PSNR_dehazing: 10.55 ssim: 0.674718
# 92 iter PSNR: 10.55 time: 0.019471
# 93 iter PSNR_dehazing: 14.07 ssim: 0.824730
# 93 iter PSNR: 14.07 time: 0.018408
# 94 iter PSNR_dehazing: 13.43 ssim: 0.804370
# 94 iter PSNR: 13.43 time: 0.019200
# 95 iter PSNR_dehazing: 12.87 ssim: 0.784329
# 95 iter PSNR: 12.87 time: 0.019411
# 96 iter PSNR_dehazing: 12.37 ssim: 0.764709
# 96 iter PSNR: 12.37 time: 0.020687
# 97 iter PSNR_dehazing: 11.93 ssim: 0.745511
# 97 iter PSNR: 11.93 time: 0.019748
# 98 iter PSNR_dehazing: 11.53 ssim: 0.726790
# 98 iter PSNR: 11.53 time: 0.018778
# 99 iter PSNR_dehazing: 11.17 ssim: 0.708682
# 99 iter PSNR: 11.17 time: 0.020259
# 100 iter PSNR_dehazing: 10.85 ssim: 0.691269
# 100 iter PSNR: 10.85 time: 0.020971
# 101 iter PSNR_dehazing: 14.22 ssim: 0.855632
# 101 iter PSNR: 14.22 time: 0.020188
# 102 iter PSNR_dehazing: 9.63 ssim: 0.722572
# 102 iter PSNR: 9.63 time: 0.019879
# 103 iter PSNR_dehazing: 13.45 ssim: 0.839038
# 103 iter PSNR: 13.45 time: 0.023891
# 104 iter PSNR_dehazing: 12.77 ssim: 0.822862
# 104 iter PSNR: 12.77 time: 0.023657
# 105 iter PSNR_dehazing: 12.17 ssim: 0.807159
# 105 iter PSNR: 12.17 time: 0.024369
# 106 iter PSNR_dehazing: 11.63 ssim: 0.791912
# 106 iter PSNR: 11.63 time: 0.025260
# 107 iter PSNR_dehazing: 11.15 ssim: 0.777154
# 107 iter PSNR: 11.15 time: 0.023216
# 108 iter PSNR_dehazing: 10.71 ssim: 0.762839
# 108 iter PSNR: 10.71 time: 0.024265
# 109 iter PSNR_dehazing: 10.32 ssim: 0.749004
# 109 iter PSNR: 10.32 time: 0.023318
# 110 iter PSNR_dehazing: 9.96 ssim: 0.735613
# 110 iter PSNR: 9.96 time: 0.026431
# 111 iter PSNR_dehazing: 12.04 ssim: 0.720002
# 111 iter PSNR: 12.04 time: 0.024103
# 112 iter PSNR_dehazing: 7.30 ssim: 0.556160
# 112 iter PSNR: 7.30 time: 0.024548
# 113 iter PSNR_dehazing: 11.19 ssim: 0.697005
# 113 iter PSNR: 11.19 time: 0.024292
# 114 iter PSNR_dehazing: 10.46 ssim: 0.675461
# 114 iter PSNR: 10.46 time: 0.020885
# 115 iter PSNR_dehazing: 9.82 ssim: 0.655213
# 115 iter PSNR: 9.82 time: 0.019405
# 116 iter PSNR_dehazing: 9.27 ssim: 0.636117
# 116 iter PSNR: 9.27 time: 0.020969
# 117 iter PSNR_dehazing: 8.78 ssim: 0.618154
# 117 iter PSNR: 8.78 time: 0.019729
# 118 iter PSNR_dehazing: 8.35 ssim: 0.601173
# 118 iter PSNR: 8.35 time: 0.020718
# 119 iter PSNR_dehazing: 7.96 ssim: 0.585095
# 119 iter PSNR: 7.96 time: 0.022421
# 120 iter PSNR_dehazing: 7.61 ssim: 0.570077
# 120 iter PSNR: 7.61 time: 0.020218
# 121 iter PSNR_dehazing: 13.36 ssim: 0.778377
# 121 iter PSNR: 13.36 time: 0.019519
# 122 iter PSNR_dehazing: 8.63 ssim: 0.617970
# 122 iter PSNR: 8.63 time: 0.019986
# 123 iter PSNR_dehazing: 12.54 ssim: 0.757260
# 123 iter PSNR: 12.54 time: 0.022423
# 124 iter PSNR_dehazing: 11.82 ssim: 0.737122
# 124 iter PSNR: 11.82 time: 0.019573
# 125 iter PSNR_dehazing: 11.20 ssim: 0.717843
# 125 iter PSNR: 11.20 time: 0.019082
# 126 iter PSNR_dehazing: 10.65 ssim: 0.699349
# 126 iter PSNR: 10.65 time: 0.019980
# 127 iter PSNR_dehazing: 10.16 ssim: 0.681668
# 127 iter PSNR: 10.16 time: 0.019997
# 128 iter PSNR_dehazing: 9.72 ssim: 0.664698
# 128 iter PSNR: 9.72 time: 0.019925
# 129 iter PSNR_dehazing: 9.32 ssim: 0.648430
# 129 iter PSNR: 9.32 time: 0.020044
# 130 iter PSNR_dehazing: 8.96 ssim: 0.632884
# 130 iter PSNR: 8.96 time: 0.019234
# 131 iter PSNR_dehazing: 10.55 ssim: 0.696435
# 131 iter PSNR: 10.55 time: 0.023618
# 132 iter PSNR_dehazing: 6.15 ssim: 0.486655
# 132 iter PSNR: 6.15 time: 0.025319
# 133 iter PSNR_dehazing: 9.72 ssim: 0.665139
# 133 iter PSNR: 9.72 time: 0.018704
# 134 iter PSNR_dehazing: 9.02 ssim: 0.636204
# 134 iter PSNR: 9.02 time: 0.020830
# 135 iter PSNR_dehazing: 8.42 ssim: 0.609641
# 135 iter PSNR: 8.42 time: 0.019723
# 136 iter PSNR_dehazing: 7.91 ssim: 0.584821
# 136 iter PSNR: 7.91 time: 0.018877
# 137 iter PSNR_dehazing: 7.46 ssim: 0.561919
# 137 iter PSNR: 7.46 time: 0.019157
# 138 iter PSNR_dehazing: 7.07 ssim: 0.540816
# 138 iter PSNR: 7.07 time: 0.019009
# 139 iter PSNR_dehazing: 6.72 ssim: 0.521335
# 139 iter PSNR: 6.72 time: 0.021456
# 140 iter PSNR_dehazing: 6.42 ssim: 0.503398
# 140 iter PSNR: 6.42 time: 0.020100
# 141 iter PSNR_dehazing: 12.00 ssim: 0.695489
# 141 iter PSNR: 12.00 time: 0.019429
# 142 iter PSNR_dehazing: 7.34 ssim: 0.496938
# 142 iter PSNR: 7.34 time: 0.018817
# 143 iter PSNR_dehazing: 11.16 ssim: 0.667547
# 143 iter PSNR: 11.16 time: 0.020759
# 144 iter PSNR_dehazing: 10.43 ssim: 0.641161
# 144 iter PSNR: 10.43 time: 0.019200
# 145 iter PSNR_dehazing: 9.81 ssim: 0.616313
# 145 iter PSNR: 9.81 time: 0.018977
# 146 iter PSNR_dehazing: 9.26 ssim: 0.592878
# 146 iter PSNR: 9.26 time: 0.020354
# 147 iter PSNR_dehazing: 8.78 ssim: 0.570868
# 147 iter PSNR: 8.78 time: 0.019753
# 148 iter PSNR_dehazing: 8.36 ssim: 0.550327
# 148 iter PSNR: 8.36 time: 0.019724
# 149 iter PSNR_dehazing: 7.98 ssim: 0.531203
# 149 iter PSNR: 7.98 time: 0.021144
# 150 iter PSNR_dehazing: 7.65 ssim: 0.513410
# 150 iter PSNR: 7.65 time: 0.019434
# 151 iter PSNR_dehazing: 13.16 ssim: 0.801758
# 151 iter PSNR: 13.16 time: 0.019705
# 152 iter PSNR_dehazing: 8.34 ssim: 0.632883
# 152 iter PSNR: 8.34 time: 0.018999
# 153 iter PSNR_dehazing: 12.33 ssim: 0.779040
# 153 iter PSNR: 12.33 time: 0.019071
# 154 iter PSNR_dehazing: 11.61 ssim: 0.757370
# 154 iter PSNR: 11.61 time: 0.018836
# 155 iter PSNR_dehazing: 10.97 ssim: 0.736775
# 155 iter PSNR: 10.97 time: 0.020114
# 156 iter PSNR_dehazing: 10.41 ssim: 0.717193
# 156 iter PSNR: 10.41 time: 0.019156
# 157 iter PSNR_dehazing: 9.91 ssim: 0.698491
# 157 iter PSNR: 9.91 time: 0.020377
# 158 iter PSNR_dehazing: 9.46 ssim: 0.680732
# 158 iter PSNR: 9.46 time: 0.020039
# 159 iter PSNR_dehazing: 9.05 ssim: 0.663875
# 159 iter PSNR: 9.05 time: 0.020932
# 160 iter PSNR_dehazing: 8.68 ssim: 0.647978
# 160 iter PSNR: 8.68 time: 0.018836
# 161 iter PSNR_dehazing: 15.35 ssim: 0.900265
# 161 iter PSNR: 15.35 time: 0.022508
# 162 iter PSNR_dehazing: 11.12 ssim: 0.811910
# 162 iter PSNR: 11.12 time: 0.021347
# 163 iter PSNR_dehazing: 14.65 ssim: 0.889132
# 163 iter PSNR: 14.65 time: 0.019747
# 164 iter PSNR_dehazing: 14.03 ssim: 0.878361
# 164 iter PSNR: 14.03 time: 0.019032
# 165 iter PSNR_dehazing: 13.48 ssim: 0.867938
# 165 iter PSNR: 13.48 time: 0.018785
# 166 iter PSNR_dehazing: 12.98 ssim: 0.857833
# 166 iter PSNR: 12.98 time: 0.019095
# 167 iter PSNR_dehazing: 12.53 ssim: 0.848045
# 167 iter PSNR: 12.53 time: 0.019114
# 168 iter PSNR_dehazing: 12.13 ssim: 0.838574
# 168 iter PSNR: 12.13 time: 0.019430
# 169 iter PSNR_dehazing: 11.76 ssim: 0.829404
# 169 iter PSNR: 11.76 time: 0.018773
# 170 iter PSNR_dehazing: 11.42 ssim: 0.820522
# 170 iter PSNR: 11.42 time: 0.018610
# 171 iter PSNR_dehazing: 13.06 ssim: 0.779397
# 171 iter PSNR: 13.06 time: 0.018676
# 172 iter PSNR_dehazing: 8.60 ssim: 0.557660
# 172 iter PSNR: 8.60 time: 0.019500
# 173 iter PSNR_dehazing: 12.27 ssim: 0.749757
# 173 iter PSNR: 12.27 time: 0.019549
# 174 iter PSNR_dehazing: 11.60 ssim: 0.721148
# 174 iter PSNR: 11.60 time: 0.019114
# 175 iter PSNR_dehazing: 11.00 ssim: 0.693860
# 175 iter PSNR: 11.00 time: 0.018532
# 176 iter PSNR_dehazing: 10.48 ssim: 0.667980
# 176 iter PSNR: 10.48 time: 0.020213
# 177 iter PSNR_dehazing: 10.02 ssim: 0.643495
# 177 iter PSNR: 10.02 time: 0.019340
# 178 iter PSNR_dehazing: 9.60 ssim: 0.620317
# 178 iter PSNR: 9.60 time: 0.022024
# 179 iter PSNR_dehazing: 9.23 ssim: 0.598264
# 179 iter PSNR: 9.23 time: 0.025832
# 180 iter PSNR_dehazing: 8.90 ssim: 0.577411
# 180 iter PSNR: 8.90 time: 0.024194
# 181 iter PSNR_dehazing: 13.59 ssim: 0.770972
# 181 iter PSNR: 13.59 time: 0.025541
# 182 iter PSNR_dehazing: 8.95 ssim: 0.567322
# 182 iter PSNR: 8.95 time: 0.019319
# 183 iter PSNR_dehazing: 12.80 ssim: 0.745526
# 183 iter PSNR: 12.80 time: 0.023295
# 184 iter PSNR_dehazing: 12.10 ssim: 0.720691
# 184 iter PSNR: 12.10 time: 0.023520
# 185 iter PSNR_dehazing: 11.49 ssim: 0.696578
# 185 iter PSNR: 11.49 time: 0.023134
# 186 iter PSNR_dehazing: 10.95 ssim: 0.673136
# 186 iter PSNR: 10.95 time: 0.020149
# 187 iter PSNR_dehazing: 10.46 ssim: 0.650426
# 187 iter PSNR: 10.46 time: 0.020820
# 188 iter PSNR_dehazing: 10.03 ssim: 0.628571
# 188 iter PSNR: 10.03 time: 0.020339
# 189 iter PSNR_dehazing: 9.63 ssim: 0.607398
# 189 iter PSNR: 9.63 time: 0.020559
# 190 iter PSNR_dehazing: 9.28 ssim: 0.587062
# 190 iter PSNR: 9.28 time: 0.023877
# 191 iter PSNR_dehazing: 13.50 ssim: 0.797470
# 191 iter PSNR: 13.50 time: 0.019338
# 192 iter PSNR_dehazing: 8.92 ssim: 0.603816
# 192 iter PSNR: 8.92 time: 0.021450
# 193 iter PSNR_dehazing: 12.71 ssim: 0.773746
# 193 iter PSNR: 12.71 time: 0.019404
# 194 iter PSNR_dehazing: 12.02 ssim: 0.750504
# 194 iter PSNR: 12.02 time: 0.019200
# 195 iter PSNR_dehazing: 11.42 ssim: 0.727841
# 195 iter PSNR: 11.42 time: 0.019437
# 196 iter PSNR_dehazing: 10.89 ssim: 0.705707
# 196 iter PSNR: 10.89 time: 0.019253
# 197 iter PSNR_dehazing: 10.41 ssim: 0.684061
# 197 iter PSNR: 10.41 time: 0.018612
# 198 iter PSNR_dehazing: 9.98 ssim: 0.662979
# 198 iter PSNR: 9.98 time: 0.018409
# 199 iter PSNR_dehazing: 9.59 ssim: 0.642563
# 199 iter PSNR: 9.59 time: 0.018510
# 200 iter PSNR_dehazing: 9.24 ssim: 0.622875
# 200 iter PSNR: 9.24 time: 0.019213
# 201 iter PSNR_dehazing: 10.77 ssim: 0.695313
# 201 iter PSNR: 10.77 time: 0.019312
# 202 iter PSNR_dehazing: 6.32 ssim: 0.449623
# 202 iter PSNR: 6.32 time: 0.019232
# 203 iter PSNR_dehazing: 9.94 ssim: 0.661547
# 203 iter PSNR: 9.94 time: 0.018403
# 204 iter PSNR_dehazing: 9.24 ssim: 0.629306
# 204 iter PSNR: 9.24 time: 0.018614
# 205 iter PSNR_dehazing: 8.64 ssim: 0.598688
# 205 iter PSNR: 8.64 time: 0.019449
# 206 iter PSNR_dehazing: 8.12 ssim: 0.569990
# 206 iter PSNR: 8.12 time: 0.018997
# 207 iter PSNR_dehazing: 7.66 ssim: 0.543059
# 207 iter PSNR: 7.66 time: 0.018987
# 208 iter PSNR_dehazing: 7.26 ssim: 0.517630
# 208 iter PSNR: 7.26 time: 0.020990
# 209 iter PSNR_dehazing: 6.91 ssim: 0.493631
# 209 iter PSNR: 6.91 time: 0.019560
# 210 iter PSNR_dehazing: 6.60 ssim: 0.470992
# 210 iter PSNR: 6.60 time: 0.019757
# 211 iter PSNR_dehazing: 13.73 ssim: 0.790275
# 211 iter PSNR: 13.73 time: 0.018674
# 212 iter PSNR_dehazing: 8.90 ssim: 0.648788
# 212 iter PSNR: 8.90 time: 0.018726
# 213 iter PSNR_dehazing: 12.93 ssim: 0.771976
# 213 iter PSNR: 12.93 time: 0.019319
# 214 iter PSNR_dehazing: 12.22 ssim: 0.754482
# 214 iter PSNR: 12.22 time: 0.019086
# 215 iter PSNR_dehazing: 11.59 ssim: 0.737715
# 215 iter PSNR: 11.59 time: 0.021705
# 216 iter PSNR_dehazing: 11.03 ssim: 0.721537
# 216 iter PSNR: 11.03 time: 0.019893
# 217 iter PSNR_dehazing: 10.52 ssim: 0.705967
# 217 iter PSNR: 10.52 time: 0.018990
# 218 iter PSNR_dehazing: 10.06 ssim: 0.690903
# 218 iter PSNR: 10.06 time: 0.020778
# 219 iter PSNR_dehazing: 9.64 ssim: 0.676385
# 219 iter PSNR: 9.64 time: 0.019435
# 220 iter PSNR_dehazing: 9.25 ssim: 0.662343
# 220 iter PSNR: 9.25 time: 0.018862
# 221 iter PSNR_dehazing: 12.24 ssim: 0.639509
# 221 iter PSNR: 12.24 time: 0.020468
# 222 iter PSNR_dehazing: 7.29 ssim: 0.502558
# 222 iter PSNR: 7.29 time: 0.019943
# 223 iter PSNR_dehazing: 11.39 ssim: 0.619614
# 223 iter PSNR: 11.39 time: 0.021628
# 224 iter PSNR_dehazing: 10.65 ssim: 0.601313
# 224 iter PSNR: 10.65 time: 0.022317
# 225 iter PSNR_dehazing: 10.00 ssim: 0.584325
# 225 iter PSNR: 10.00 time: 0.019955
# 226 iter PSNR_dehazing: 9.42 ssim: 0.568510
# 226 iter PSNR: 9.42 time: 0.024944
# 227 iter PSNR_dehazing: 8.91 ssim: 0.553703
# 227 iter PSNR: 8.91 time: 0.020266
# 228 iter PSNR_dehazing: 8.44 ssim: 0.539793
# 228 iter PSNR: 8.44 time: 0.020287
# 229 iter PSNR_dehazing: 8.02 ssim: 0.526675
# 229 iter PSNR: 8.02 time: 0.021180
# 230 iter PSNR_dehazing: 7.64 ssim: 0.514305
# 230 iter PSNR: 7.64 time: 0.020126
# 231 iter PSNR_dehazing: 10.73 ssim: 0.587253
# 231 iter PSNR: 10.73 time: 0.023216
# 232 iter PSNR_dehazing: 5.91 ssim: 0.436585
# 232 iter PSNR: 5.91 time: 0.022982
# 233 iter PSNR_dehazing: 9.87 ssim: 0.563658
# 233 iter PSNR: 9.87 time: 0.019760
# 234 iter PSNR_dehazing: 9.12 ssim: 0.542413
# 234 iter PSNR: 9.12 time: 0.018970
# 235 iter PSNR_dehazing: 8.48 ssim: 0.523164
# 235 iter PSNR: 8.48 time: 0.021424
# 236 iter PSNR_dehazing: 7.92 ssim: 0.505603
# 236 iter PSNR: 7.92 time: 0.019350
# 237 iter PSNR_dehazing: 7.42 ssim: 0.489518
# 237 iter PSNR: 7.42 time: 0.024143
# 238 iter PSNR_dehazing: 6.98 ssim: 0.474715
# 238 iter PSNR: 6.98 time: 0.023977
# 239 iter PSNR_dehazing: 6.59 ssim: 0.461020
# 239 iter PSNR: 6.59 time: 0.024107
# 240 iter PSNR_dehazing: 6.23 ssim: 0.448350
# 240 iter PSNR: 6.23 time: 0.024189
# 241 iter PSNR_dehazing: 12.46 ssim: 0.740075
# 241 iter PSNR: 12.46 time: 0.021206
# 242 iter PSNR_dehazing: 7.79 ssim: 0.573524
# 242 iter PSNR: 7.79 time: 0.024367
# 243 iter PSNR_dehazing: 11.65 ssim: 0.717906
# 243 iter PSNR: 11.65 time: 0.018994
# 244 iter PSNR_dehazing: 10.95 ssim: 0.696799
# 244 iter PSNR: 10.95 time: 0.018958
# 245 iter PSNR_dehazing: 10.33 ssim: 0.676698
# 245 iter PSNR: 10.33 time: 0.020329
# 246 iter PSNR_dehazing: 9.79 ssim: 0.657557
# 246 iter PSNR: 9.79 time: 0.022473
# 247 iter PSNR_dehazing: 9.30 ssim: 0.639311
# 247 iter PSNR: 9.30 time: 0.022862
# 248 iter PSNR_dehazing: 8.86 ssim: 0.621887
# 248 iter PSNR: 8.86 time: 0.019377
# 249 iter PSNR_dehazing: 8.47 ssim: 0.605252
# 249 iter PSNR: 8.47 time: 0.019167
# 250 iter PSNR_dehazing: 8.11 ssim: 0.589107
# 250 iter PSNR: 8.11 time: 0.018624
# 251 iter PSNR_dehazing: 10.64 ssim: 0.651194
# 251 iter PSNR: 10.64 time: 0.018829
# 252 iter PSNR_dehazing: 5.99 ssim: 0.446626
# 252 iter PSNR: 5.99 time: 0.018438
# 253 iter PSNR_dehazing: 9.78 ssim: 0.622286
# 253 iter PSNR: 9.78 time: 0.019242
# 254 iter PSNR_dehazing: 9.05 ssim: 0.595397
# 254 iter PSNR: 9.05 time: 0.019444
# 255 iter PSNR_dehazing: 8.43 ssim: 0.570318
# 255 iter PSNR: 8.43 time: 0.018568
# 256 iter PSNR_dehazing: 7.89 ssim: 0.546676
# 256 iter PSNR: 7.89 time: 0.018727
# 257 iter PSNR_dehazing: 7.41 ssim: 0.524404
# 257 iter PSNR: 7.41 time: 0.020627
# 258 iter PSNR_dehazing: 6.99 ssim: 0.503361
# 258 iter PSNR: 6.99 time: 0.018749
# 259 iter PSNR_dehazing: 6.62 ssim: 0.483403
# 259 iter PSNR: 6.62 time: 0.024641
# 260 iter PSNR_dehazing: 6.28 ssim: 0.464517
# 260 iter PSNR: 6.28 time: 0.019046
# 261 iter PSNR_dehazing: 12.06 ssim: 0.664731
# 261 iter PSNR: 12.06 time: 0.018521
# 262 iter PSNR_dehazing: 7.14 ssim: 0.500960
# 262 iter PSNR: 7.14 time: 0.018885
# 263 iter PSNR_dehazing: 11.20 ssim: 0.642000
# 263 iter PSNR: 11.20 time: 0.019096
# 264 iter PSNR_dehazing: 10.45 ssim: 0.620806
# 264 iter PSNR: 10.45 time: 0.018746
# 265 iter PSNR_dehazing: 9.80 ssim: 0.600855
# 265 iter PSNR: 9.80 time: 0.019480
# 266 iter PSNR_dehazing: 9.23 ssim: 0.582057
# 266 iter PSNR: 9.23 time: 0.018685
# 267 iter PSNR_dehazing: 8.72 ssim: 0.564247
# 267 iter PSNR: 8.72 time: 0.019125
# 268 iter PSNR_dehazing: 8.26 ssim: 0.547324
# 268 iter PSNR: 8.26 time: 0.019200
# 269 iter PSNR_dehazing: 7.85 ssim: 0.531180
# 269 iter PSNR: 7.85 time: 0.019376
# 270 iter PSNR_dehazing: 7.47 ssim: 0.515782
# 270 iter PSNR: 7.47 time: 0.019562
# 271 iter PSNR_dehazing: 14.99 ssim: 0.751689
# 271 iter PSNR: 14.99 time: 0.020813
# 272 iter PSNR_dehazing: 10.14 ssim: 0.640461
# 272 iter PSNR: 10.14 time: 0.018294
# 273 iter PSNR_dehazing: 14.21 ssim: 0.736139
# 273 iter PSNR: 14.21 time: 0.018687
# 274 iter PSNR_dehazing: 13.52 ssim: 0.721648
# 274 iter PSNR: 13.52 time: 0.018947
# 275 iter PSNR_dehazing: 12.90 ssim: 0.708098
# 275 iter PSNR: 12.90 time: 0.018924
# 276 iter PSNR_dehazing: 12.33 ssim: 0.695334
# 276 iter PSNR: 12.33 time: 0.018957
# 277 iter PSNR_dehazing: 11.81 ssim: 0.683256
# 277 iter PSNR: 11.81 time: 0.018660
# 278 iter PSNR_dehazing: 11.34 ssim: 0.671776
# 278 iter PSNR: 11.34 time: 0.019167
# 279 iter PSNR_dehazing: 10.91 ssim: 0.660841
# 279 iter PSNR: 10.91 time: 0.019250
# 280 iter PSNR_dehazing: 10.51 ssim: 0.650447
# 280 iter PSNR: 10.51 time: 0.020664
# 281 iter PSNR_dehazing: 12.46 ssim: 0.712592
# 281 iter PSNR: 12.46 time: 0.019599
# 282 iter PSNR_dehazing: 7.60 ssim: 0.558501
# 282 iter PSNR: 7.60 time: 0.019848
# 283 iter PSNR_dehazing: 11.61 ssim: 0.691551
# 283 iter PSNR: 11.61 time: 0.021841
# 284 iter PSNR_dehazing: 10.87 ssim: 0.671817
# 284 iter PSNR: 10.87 time: 0.019845
# 285 iter PSNR_dehazing: 10.23 ssim: 0.653188
# 285 iter PSNR: 10.23 time: 0.018829
# 286 iter PSNR_dehazing: 9.66 ssim: 0.635472
# 286 iter PSNR: 9.66 time: 0.018631
# 287 iter PSNR_dehazing: 9.16 ssim: 0.618669
# 287 iter PSNR: 9.16 time: 0.018786
# 288 iter PSNR_dehazing: 8.71 ssim: 0.602613
# 288 iter PSNR: 8.71 time: 0.021657
# 289 iter PSNR_dehazing: 8.30 ssim: 0.587261
# 289 iter PSNR: 8.30 time: 0.018525
# 290 iter PSNR_dehazing: 7.93 ssim: 0.572594
# 290 iter PSNR: 7.93 time: 0.019060
# 291 iter PSNR_dehazing: 10.51 ssim: 0.584774
# 291 iter PSNR: 10.51 time: 0.018416
# 292 iter PSNR_dehazing: 5.76 ssim: 0.407075
# 292 iter PSNR: 5.76 time: 0.017898
# 293 iter PSNR_dehazing: 9.63 ssim: 0.558180
# 293 iter PSNR: 9.63 time: 0.018097
# 294 iter PSNR_dehazing: 8.89 ssim: 0.533963
# 294 iter PSNR: 8.89 time: 0.018126
# 295 iter PSNR_dehazing: 8.26 ssim: 0.511749
# 295 iter PSNR: 8.26 time: 0.018052
# 296 iter PSNR_dehazing: 7.71 ssim: 0.491149
# 296 iter PSNR: 7.71 time: 0.018575
# 297 iter PSNR_dehazing: 7.22 ssim: 0.472041
# 297 iter PSNR: 7.22 time: 0.019519
# 298 iter PSNR_dehazing: 6.79 ssim: 0.454161
# 298 iter PSNR: 6.79 time: 0.019283
# 299 iter PSNR_dehazing: 6.41 ssim: 0.437468
# 299 iter PSNR: 6.41 time: 0.019516
# 300 iter PSNR_dehazing: 6.07 ssim: 0.421794
# 300 iter PSNR: 6.07 time: 0.018397
# 301 iter PSNR_dehazing: 11.63 ssim: 0.525704
# 301 iter PSNR: 11.63 time: 0.019608
# 302 iter PSNR_dehazing: 6.45 ssim: 0.378932
# 302 iter PSNR: 6.45 time: 0.019027
# 303 iter PSNR_dehazing: 10.73 ssim: 0.503004
# 303 iter PSNR: 10.73 time: 0.018704
# 304 iter PSNR_dehazing: 9.95 ssim: 0.482493
# 304 iter PSNR: 9.95 time: 0.019047
# 305 iter PSNR_dehazing: 9.26 ssim: 0.463833
# 305 iter PSNR: 9.26 time: 0.019227
# 306 iter PSNR_dehazing: 8.66 ssim: 0.446777
# 306 iter PSNR: 8.66 time: 0.019197
# 307 iter PSNR_dehazing: 8.12 ssim: 0.431058
# 307 iter PSNR: 8.12 time: 0.019913
# 308 iter PSNR_dehazing: 7.64 ssim: 0.416610
# 308 iter PSNR: 7.64 time: 0.019696
# 309 iter PSNR_dehazing: 7.20 ssim: 0.403137
# 309 iter PSNR: 7.20 time: 0.021082
# 310 iter PSNR_dehazing: 6.81 ssim: 0.390650
# 310 iter PSNR: 6.81 time: 0.018616
# 311 iter PSNR_dehazing: 12.04 ssim: 0.608364
# 311 iter PSNR: 12.04 time: 0.019098
# 312 iter PSNR_dehazing: 7.02 ssim: 0.432493
# 312 iter PSNR: 7.02 time: 0.018588
# 313 iter PSNR_dehazing: 11.15 ssim: 0.581822
# 313 iter PSNR: 11.15 time: 0.018187
# 314 iter PSNR_dehazing: 10.39 ssim: 0.557657
# 314 iter PSNR: 10.39 time: 0.019443
# 315 iter PSNR_dehazing: 9.73 ssim: 0.535458
# 315 iter PSNR: 9.73 time: 0.023261
# 316 iter PSNR_dehazing: 9.14 ssim: 0.515001
# 316 iter PSNR: 9.14 time: 0.023069
# 317 iter PSNR_dehazing: 8.62 ssim: 0.496081
# 317 iter PSNR: 8.62 time: 0.020746
# 318 iter PSNR_dehazing: 8.16 ssim: 0.478498
# 318 iter PSNR: 8.16 time: 0.018650
# 319 iter PSNR_dehazing: 7.74 ssim: 0.462111
# 319 iter PSNR: 7.74 time: 0.020520
# 320 iter PSNR_dehazing: 7.36 ssim: 0.446800
# 320 iter PSNR: 7.36 time: 0.020103
# 321 iter PSNR_dehazing: 14.47 ssim: 0.653456
# 321 iter PSNR: 14.47 time: 0.019919
# 322 iter PSNR_dehazing: 9.46 ssim: 0.493254
# 322 iter PSNR: 9.46 time: 0.019253
# 323 iter PSNR_dehazing: 13.64 ssim: 0.631061
# 323 iter PSNR: 13.64 time: 0.019326
# 324 iter PSNR_dehazing: 12.91 ssim: 0.610006
# 324 iter PSNR: 12.91 time: 0.020680
# 325 iter PSNR_dehazing: 12.26 ssim: 0.590175
# 325 iter PSNR: 12.26 time: 0.019034
# 326 iter PSNR_dehazing: 11.68 ssim: 0.571474
# 326 iter PSNR: 11.68 time: 0.019933
# 327 iter PSNR_dehazing: 11.15 ssim: 0.553857
# 327 iter PSNR: 11.15 time: 0.020770
# 328 iter PSNR_dehazing: 10.67 ssim: 0.537345
# 328 iter PSNR: 10.67 time: 0.025083
# 329 iter PSNR_dehazing: 10.23 ssim: 0.521800
# 329 iter PSNR: 10.23 time: 0.023296
# 330 iter PSNR_dehazing: 9.83 ssim: 0.507118
# 330 iter PSNR: 9.83 time: 0.023474
# 331 iter PSNR_dehazing: 13.66 ssim: 0.679785
# 331 iter PSNR: 13.66 time: 0.019934
# 332 iter PSNR_dehazing: 8.67 ssim: 0.504129
# 332 iter PSNR: 8.67 time: 0.019129
# 333 iter PSNR_dehazing: 12.82 ssim: 0.655124
# 333 iter PSNR: 12.82 time: 0.018979
# 334 iter PSNR_dehazing: 12.08 ssim: 0.632026
# 334 iter PSNR: 12.08 time: 0.018693
# 335 iter PSNR_dehazing: 11.42 ssim: 0.610337
# 335 iter PSNR: 11.42 time: 0.019550
# 336 iter PSNR_dehazing: 10.84 ssim: 0.589933
# 336 iter PSNR: 10.84 time: 0.018454
# 337 iter PSNR_dehazing: 10.32 ssim: 0.570681
# 337 iter PSNR: 10.32 time: 0.018437
# 338 iter PSNR_dehazing: 9.85 ssim: 0.552562
# 338 iter PSNR: 9.85 time: 0.018706
# 339 iter PSNR_dehazing: 9.42 ssim: 0.535452
# 339 iter PSNR: 9.42 time: 0.018459
# 340 iter PSNR_dehazing: 9.03 ssim: 0.519349
# 340 iter PSNR: 9.03 time: 0.021153
# 341 iter PSNR_dehazing: 12.75 ssim: 0.831789
# 341 iter PSNR: 12.75 time: 0.018487
# 342 iter PSNR_dehazing: 8.31 ssim: 0.681540
# 342 iter PSNR: 8.31 time: 0.018526
# 343 iter PSNR_dehazing: 11.98 ssim: 0.812309
# 343 iter PSNR: 11.98 time: 0.020225
# 344 iter PSNR_dehazing: 11.31 ssim: 0.793475
# 344 iter PSNR: 11.31 time: 0.018476
# 345 iter PSNR_dehazing: 10.72 ssim: 0.775388
# 345 iter PSNR: 10.72 time: 0.020912
# 346 iter PSNR_dehazing: 10.20 ssim: 0.758088
# 346 iter PSNR: 10.20 time: 0.018888
# 347 iter PSNR_dehazing: 9.74 ssim: 0.741599
# 347 iter PSNR: 9.74 time: 0.018536
# 348 iter PSNR_dehazing: 9.32 ssim: 0.725800
# 348 iter PSNR: 9.32 time: 0.018461
# 349 iter PSNR_dehazing: 8.94 ssim: 0.710307
# 349 iter PSNR: 8.94 time: 0.018752
# 350 iter PSNR_dehazing: 8.61 ssim: 0.695534
# 350 iter PSNR: 8.61 time: 0.018610
# 351 iter PSNR_dehazing: 12.56 ssim: 0.775096
# 351 iter PSNR: 12.56 time: 0.018677
# 352 iter PSNR_dehazing: 8.21 ssim: 0.611853
# 352 iter PSNR: 8.21 time: 0.018975
# 353 iter PSNR_dehazing: 11.79 ssim: 0.753599
# 353 iter PSNR: 11.79 time: 0.018385
# 354 iter PSNR_dehazing: 11.11 ssim: 0.732878
# 354 iter PSNR: 11.11 time: 0.019366
# 355 iter PSNR_dehazing: 10.53 ssim: 0.712921
# 355 iter PSNR: 10.53 time: 0.019347
# 356 iter PSNR_dehazing: 10.02 ssim: 0.693730
# 356 iter PSNR: 10.02 time: 0.019582
# 357 iter PSNR_dehazing: 9.57 ssim: 0.675156
# 357 iter PSNR: 9.57 time: 0.020156
# 358 iter PSNR_dehazing: 9.17 ssim: 0.657429
# 358 iter PSNR: 9.17 time: 0.020497
# 359 iter PSNR_dehazing: 8.81 ssim: 0.641042
# 359 iter PSNR: 8.81 time: 0.020406
# 360 iter PSNR_dehazing: 8.50 ssim: 0.625924
# 360 iter PSNR: 8.50 time: 0.018893
# 361 iter PSNR_dehazing: 14.90 ssim: 0.869519
# 361 iter PSNR: 14.90 time: 0.019847
# 362 iter PSNR_dehazing: 10.98 ssim: 0.770453
# 362 iter PSNR: 10.98 time: 0.019186
# 363 iter PSNR_dehazing: 14.27 ssim: 0.858336
# 363 iter PSNR: 14.27 time: 0.018515
# 364 iter PSNR_dehazing: 13.71 ssim: 0.847142
# 364 iter PSNR: 13.71 time: 0.019087
# 365 iter PSNR_dehazing: 13.20 ssim: 0.835836
# 365 iter PSNR: 13.20 time: 0.018581
# 366 iter PSNR_dehazing: 12.74 ssim: 0.824605
# 366 iter PSNR: 12.74 time: 0.018989
# 367 iter PSNR_dehazing: 12.32 ssim: 0.813509
# 367 iter PSNR: 12.32 time: 0.020231
# 368 iter PSNR_dehazing: 11.94 ssim: 0.802580
# 368 iter PSNR: 11.94 time: 0.019805
# 369 iter PSNR_dehazing: 11.59 ssim: 0.791706
# 369 iter PSNR: 11.59 time: 0.019437
# 370 iter PSNR_dehazing: 11.27 ssim: 0.781033
# 370 iter PSNR: 11.27 time: 0.018802
# 371 iter PSNR_dehazing: 11.42 ssim: 0.721486
# 371 iter PSNR: 11.42 time: 0.020310
# 372 iter PSNR_dehazing: 6.66 ssim: 0.522904
# 372 iter PSNR: 6.66 time: 0.020231
# 373 iter PSNR_dehazing: 10.56 ssim: 0.693172
# 373 iter PSNR: 10.56 time: 0.022464
# 374 iter PSNR_dehazing: 9.83 ssim: 0.666710
# 374 iter PSNR: 9.83 time: 0.020501
# 375 iter PSNR_dehazing: 9.19 ssim: 0.641979
# 375 iter PSNR: 9.19 time: 0.019866
# 376 iter PSNR_dehazing: 8.63 ssim: 0.618763
# 376 iter PSNR: 8.63 time: 0.018811
# 377 iter PSNR_dehazing: 8.14 ssim: 0.597031
# 377 iter PSNR: 8.14 time: 0.018973
# 378 iter PSNR_dehazing: 7.71 ssim: 0.576678
# 378 iter PSNR: 7.71 time: 0.019734
# 379 iter PSNR_dehazing: 7.32 ssim: 0.557592
# 379 iter PSNR: 7.32 time: 0.018870
# 380 iter PSNR_dehazing: 6.97 ssim: 0.539719
# 380 iter PSNR: 6.97 time: 0.019070
# 381 iter PSNR_dehazing: 14.09 ssim: 0.711810
# 381 iter PSNR: 14.09 time: 0.019848
# 382 iter PSNR_dehazing: 9.05 ssim: 0.602276
# 382 iter PSNR: 9.05 time: 0.019313
# 383 iter PSNR_dehazing: 13.23 ssim: 0.695911
# 383 iter PSNR: 13.23 time: 0.020830
# 384 iter PSNR_dehazing: 12.49 ssim: 0.681349
# 384 iter PSNR: 12.49 time: 0.022630
# 385 iter PSNR_dehazing: 11.83 ssim: 0.667870
# 385 iter PSNR: 11.83 time: 0.019098
# 386 iter PSNR_dehazing: 11.24 ssim: 0.655324
# 386 iter PSNR: 11.24 time: 0.020690
# 387 iter PSNR_dehazing: 10.71 ssim: 0.643520
# 387 iter PSNR: 10.71 time: 0.018759
# 388 iter PSNR_dehazing: 10.24 ssim: 0.632422
# 388 iter PSNR: 10.24 time: 0.018870
# 389 iter PSNR_dehazing: 9.81 ssim: 0.621861
# 389 iter PSNR: 9.81 time: 0.019042
# 390 iter PSNR_dehazing: 9.41 ssim: 0.611840
# 390 iter PSNR: 9.41 time: 0.019329
# 391 iter PSNR_dehazing: 14.35 ssim: 0.859004
# 391 iter PSNR: 14.35 time: 0.019025
# 392 iter PSNR_dehazing: 9.73 ssim: 0.722574
# 392 iter PSNR: 9.73 time: 0.020188
# 393 iter PSNR_dehazing: 13.57 ssim: 0.842695
# 393 iter PSNR: 13.57 time: 0.019500
# 394 iter PSNR_dehazing: 12.89 ssim: 0.826656
# 394 iter PSNR: 12.89 time: 0.020918
# 395 iter PSNR_dehazing: 12.29 ssim: 0.810927
# 395 iter PSNR: 12.29 time: 0.018603
# 396 iter PSNR_dehazing: 11.75 ssim: 0.795488
# 396 iter PSNR: 11.75 time: 0.019155
# 397 iter PSNR_dehazing: 11.26 ssim: 0.780366
# 397 iter PSNR: 11.26 time: 0.018689
# 398 iter PSNR_dehazing: 10.82 ssim: 0.765480
# 398 iter PSNR: 10.82 time: 0.020803
# 399 iter PSNR_dehazing: 10.42 ssim: 0.750907
# 399 iter PSNR: 10.42 time: 0.019776
# 400 iter PSNR_dehazing: 10.06 ssim: 0.736598
# 400 iter PSNR: 10.06 time: 0.019459
# 401 iter PSNR_dehazing: 10.91 ssim: 0.747412
# 401 iter PSNR: 10.91 time: 0.019197
# 402 iter PSNR_dehazing: 6.46 ssim: 0.563595
# 402 iter PSNR: 6.46 time: 0.020014
# 403 iter PSNR_dehazing: 10.07 ssim: 0.720276
# 403 iter PSNR: 10.07 time: 0.018999
# 404 iter PSNR_dehazing: 9.37 ssim: 0.695101
# 404 iter PSNR: 9.37 time: 0.019858
# 405 iter PSNR_dehazing: 8.77 ssim: 0.671835
# 405 iter PSNR: 8.77 time: 0.019591
# 406 iter PSNR_dehazing: 8.25 ssim: 0.650275
# 406 iter PSNR: 8.25 time: 0.022942
# 407 iter PSNR_dehazing: 7.79 ssim: 0.630431
# 407 iter PSNR: 7.79 time: 0.019593
# 408 iter PSNR_dehazing: 7.39 ssim: 0.611948
# 408 iter PSNR: 7.39 time: 0.019223
# 409 iter PSNR_dehazing: 7.04 ssim: 0.594682
# 409 iter PSNR: 7.04 time: 0.019739
# 410 iter PSNR_dehazing: 6.73 ssim: 0.578639
# 410 iter PSNR: 6.73 time: 0.019123
# 411 iter PSNR_dehazing: 14.30 ssim: 0.775486
# 411 iter PSNR: 14.30 time: 0.019706
# 412 iter PSNR_dehazing: 9.42 ssim: 0.653473
# 412 iter PSNR: 9.42 time: 0.020097
# 413 iter PSNR_dehazing: 13.49 ssim: 0.759080
# 413 iter PSNR: 13.49 time: 0.020768
# 414 iter PSNR_dehazing: 12.78 ssim: 0.743553
# 414 iter PSNR: 12.78 time: 0.018905
# 415 iter PSNR_dehazing: 12.14 ssim: 0.728820
# 415 iter PSNR: 12.14 time: 0.024885
# 416 iter PSNR_dehazing: 11.57 ssim: 0.714758
# 416 iter PSNR: 11.57 time: 0.019404
# 417 iter PSNR_dehazing: 11.06 ssim: 0.701387
# 417 iter PSNR: 11.06 time: 0.020628
# 418 iter PSNR_dehazing: 10.59 ssim: 0.688606
# 418 iter PSNR: 10.59 time: 0.019167
# 419 iter PSNR_dehazing: 10.16 ssim: 0.676365
# 419 iter PSNR: 10.16 time: 0.019410
# 420 iter PSNR_dehazing: 9.77 ssim: 0.664681
# 420 iter PSNR: 9.77 time: 0.018945
# 421 iter PSNR_dehazing: 11.57 ssim: 0.674648
# 421 iter PSNR: 11.57 time: 0.019606
# 422 iter PSNR_dehazing: 6.88 ssim: 0.500583
# 422 iter PSNR: 6.88 time: 0.019906
# 423 iter PSNR_dehazing: 10.73 ssim: 0.650087
# 423 iter PSNR: 10.73 time: 0.020656
# 424 iter PSNR_dehazing: 10.01 ssim: 0.627234
# 424 iter PSNR: 10.01 time: 0.021205
# 425 iter PSNR_dehazing: 9.39 ssim: 0.605739
# 425 iter PSNR: 9.39 time: 0.019385
# 426 iter PSNR_dehazing: 8.84 ssim: 0.585473
# 426 iter PSNR: 8.84 time: 0.019046
# 427 iter PSNR_dehazing: 8.35 ssim: 0.566390
# 427 iter PSNR: 8.35 time: 0.019359
# 428 iter PSNR_dehazing: 7.92 ssim: 0.548495
# 428 iter PSNR: 7.92 time: 0.021903
# 429 iter PSNR_dehazing: 7.54 ssim: 0.531630
# 429 iter PSNR: 7.54 time: 0.019175
# 430 iter PSNR_dehazing: 7.19 ssim: 0.515750
# 430 iter PSNR: 7.19 time: 0.021732
# 431 iter PSNR_dehazing: 14.27 ssim: 0.784245
# 431 iter PSNR: 14.27 time: 0.019705
# 432 iter PSNR_dehazing: 9.60 ssim: 0.654083
# 432 iter PSNR: 9.60 time: 0.019192
# 433 iter PSNR_dehazing: 13.50 ssim: 0.767519
# 433 iter PSNR: 13.50 time: 0.019330
# 434 iter PSNR_dehazing: 12.81 ssim: 0.751349
# 434 iter PSNR: 12.81 time: 0.019930
# 435 iter PSNR_dehazing: 12.21 ssim: 0.735777
# 435 iter PSNR: 12.21 time: 0.018934
# 436 iter PSNR_dehazing: 11.66 ssim: 0.720819
# 436 iter PSNR: 11.66 time: 0.019227
# 437 iter PSNR_dehazing: 11.17 ssim: 0.706380
# 437 iter PSNR: 11.17 time: 0.021595
# 438 iter PSNR_dehazing: 10.72 ssim: 0.692556
# 438 iter PSNR: 10.72 time: 0.019108
# 439 iter PSNR_dehazing: 10.31 ssim: 0.679226
# 439 iter PSNR: 10.31 time: 0.019221
# 440 iter PSNR_dehazing: 9.94 ssim: 0.666435
# 440 iter PSNR: 9.94 time: 0.018918
# 441 iter PSNR_dehazing: 11.14 ssim: 0.559444
# 441 iter PSNR: 11.14 time: 0.019375
# 442 iter PSNR_dehazing: 6.15 ssim: 0.368041
# 442 iter PSNR: 6.15 time: 0.018759
# 443 iter PSNR_dehazing: 10.25 ssim: 0.530663
# 443 iter PSNR: 10.25 time: 0.019549
# 444 iter PSNR_dehazing: 9.49 ssim: 0.504442
# 444 iter PSNR: 9.49 time: 0.018572
# 445 iter PSNR_dehazing: 8.83 ssim: 0.480324
# 445 iter PSNR: 8.83 time: 0.018967
# 446 iter PSNR_dehazing: 8.25 ssim: 0.458109
# 446 iter PSNR: 8.25 time: 0.019573
# 447 iter PSNR_dehazing: 7.73 ssim: 0.437446
# 447 iter PSNR: 7.73 time: 0.018893
# 448 iter PSNR_dehazing: 7.27 ssim: 0.418266
# 448 iter PSNR: 7.27 time: 0.019206
# 449 iter PSNR_dehazing: 6.86 ssim: 0.400369
# 449 iter PSNR: 6.86 time: 0.018866
# 450 iter PSNR_dehazing: 6.49 ssim: 0.383653
# 450 iter PSNR: 6.49 time: 0.019052
# 451 iter PSNR_dehazing: 13.41 ssim: 0.759411
# 451 iter PSNR: 13.41 time: 0.020942
# 452 iter PSNR_dehazing: 8.59 ssim: 0.579578
# 452 iter PSNR: 8.59 time: 0.020221
# 453 iter PSNR_dehazing: 12.60 ssim: 0.735732
# 453 iter PSNR: 12.60 time: 0.020085
# 454 iter PSNR_dehazing: 11.88 ssim: 0.713108
# 454 iter PSNR: 11.88 time: 0.020505
# 455 iter PSNR_dehazing: 11.25 ssim: 0.691471
# 455 iter PSNR: 11.25 time: 0.019600
# 456 iter PSNR_dehazing: 10.68 ssim: 0.670803
# 456 iter PSNR: 10.68 time: 0.019493
# 457 iter PSNR_dehazing: 10.18 ssim: 0.651051
# 457 iter PSNR: 10.18 time: 0.019641
# 458 iter PSNR_dehazing: 9.72 ssim: 0.632092
# 458 iter PSNR: 9.72 time: 0.018929
# 459 iter PSNR_dehazing: 9.31 ssim: 0.613915
# 459 iter PSNR: 9.31 time: 0.019032
# 460 iter PSNR_dehazing: 8.93 ssim: 0.596416
# 460 iter PSNR: 8.93 time: 0.018914
# 461 iter PSNR_dehazing: 12.81 ssim: 0.734168
# 461 iter PSNR: 12.81 time: 0.018971
# 462 iter PSNR_dehazing: 8.03 ssim: 0.523853
# 462 iter PSNR: 8.03 time: 0.019204
# 463 iter PSNR_dehazing: 11.98 ssim: 0.706577
# 463 iter PSNR: 11.98 time: 0.018878
# 464 iter PSNR_dehazing: 11.26 ssim: 0.680085
# 464 iter PSNR: 11.26 time: 0.019130
# 465 iter PSNR_dehazing: 10.63 ssim: 0.654759
# 465 iter PSNR: 10.63 time: 0.019367
# 466 iter PSNR_dehazing: 10.07 ssim: 0.630449
# 466 iter PSNR: 10.07 time: 0.020853
# 467 iter PSNR_dehazing: 9.57 ssim: 0.607155
# 467 iter PSNR: 9.57 time: 0.019068
# 468 iter PSNR_dehazing: 9.12 ssim: 0.584854
# 468 iter PSNR: 9.12 time: 0.019758
# 469 iter PSNR_dehazing: 8.72 ssim: 0.563495
# 469 iter PSNR: 8.72 time: 0.019019
# 470 iter PSNR_dehazing: 8.36 ssim: 0.543175
# 470 iter PSNR: 8.36 time: 0.023672
# 471 iter PSNR_dehazing: 13.18 ssim: 0.714212
# 471 iter PSNR: 13.18 time: 0.023956
# 472 iter PSNR_dehazing: 8.42 ssim: 0.505440
# 472 iter PSNR: 8.42 time: 0.019313
# 473 iter PSNR_dehazing: 12.36 ssim: 0.685945
# 473 iter PSNR: 12.36 time: 0.021590
# 474 iter PSNR_dehazing: 11.65 ssim: 0.659170
# 474 iter PSNR: 11.65 time: 0.018532
# 475 iter PSNR_dehazing: 11.02 ssim: 0.633792
# 475 iter PSNR: 11.02 time: 0.018984
# 476 iter PSNR_dehazing: 10.46 ssim: 0.609671
# 476 iter PSNR: 10.46 time: 0.019903
# 477 iter PSNR_dehazing: 9.96 ssim: 0.586625
# 477 iter PSNR: 9.96 time: 0.018829
# 478 iter PSNR_dehazing: 9.52 ssim: 0.564714
# 478 iter PSNR: 9.52 time: 0.018557
# 479 iter PSNR_dehazing: 9.11 ssim: 0.543775
# 479 iter PSNR: 9.11 time: 0.018427
# 480 iter PSNR_dehazing: 8.75 ssim: 0.523958
# 480 iter PSNR: 8.75 time: 0.019371
# 481 iter PSNR_dehazing: 13.69 ssim: 0.746978
# 481 iter PSNR: 13.69 time: 0.018606
# 482 iter PSNR_dehazing: 9.00 ssim: 0.564179
# 482 iter PSNR: 9.00 time: 0.021245
# 483 iter PSNR_dehazing: 12.89 ssim: 0.722801
# 483 iter PSNR: 12.89 time: 0.018682
# 484 iter PSNR_dehazing: 12.19 ssim: 0.699793
# 484 iter PSNR: 12.19 time: 0.025507
# 485 iter PSNR_dehazing: 11.57 ssim: 0.677858
# 485 iter PSNR: 11.57 time: 0.023229
# 486 iter PSNR_dehazing: 11.02 ssim: 0.656882
# 486 iter PSNR: 11.02 time: 0.019490
# 487 iter PSNR_dehazing: 10.53 ssim: 0.636831
# 487 iter PSNR: 10.53 time: 0.020842
# 488 iter PSNR_dehazing: 10.09 ssim: 0.617612
# 488 iter PSNR: 10.09 time: 0.023508
# 489 iter PSNR_dehazing: 9.69 ssim: 0.599041
# 489 iter PSNR: 9.69 time: 0.022953
# 490 iter PSNR_dehazing: 9.33 ssim: 0.581181
# 490 iter PSNR: 9.33 time: 0.019061
# 491 iter PSNR_dehazing: 13.16 ssim: 0.743542
# 491 iter PSNR: 13.16 time: 0.019530
# 492 iter PSNR_dehazing: 8.43 ssim: 0.527560
# 492 iter PSNR: 8.43 time: 0.018740
# 493 iter PSNR_dehazing: 12.34 ssim: 0.715361
# 493 iter PSNR: 12.34 time: 0.018616
# 494 iter PSNR_dehazing: 11.63 ssim: 0.688221
# 494 iter PSNR: 11.63 time: 0.018959
# 495 iter PSNR_dehazing: 11.00 ssim: 0.662215
# 495 iter PSNR: 11.00 time: 0.018991
# 496 iter PSNR_dehazing: 10.45 ssim: 0.637150
# 496 iter PSNR: 10.45 time: 0.018790
# 497 iter PSNR_dehazing: 9.96 ssim: 0.613064
# 497 iter PSNR: 9.96 time: 0.019216
# 498 iter PSNR_dehazing: 9.52 ssim: 0.590061
# 498 iter PSNR: 9.52 time: 0.019700
# 499 iter PSNR_dehazing: 9.12 ssim: 0.568160
# 499 iter PSNR: 9.12 time: 0.019247
# 500 iter PSNR_dehazing: 8.76 ssim: 0.547291
# 500 iter PSNR: 8.76 time: 0.019094
# ==========================================================
# The average PSNR is 10.26 dB
# The average SSIM is 0.64950 dB
# Average time: 0.020219

# %%
state_last = torch.load('/content/drive/MyDrive/MYresults/IRNeXt/ITS/model.pkl')
