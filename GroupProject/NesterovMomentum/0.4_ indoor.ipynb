# %% [markdown]
# Prep
# ==

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
# !pip install tensorboard einops scikit-image opencv-python pytorch_msssim warmup-scheduler
# Out:
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.10/dist-packages (2.14.1)
# Collecting einops
#   Downloading einops-0.7.0-py3-none-any.whl (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.6/44.6 kB 1.2 MB/s eta 0:00:00
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.10/dist-packages (0.19.3)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (4.8.0.76)
# Collecting pytorch_msssim
#   Downloading pytorch_msssim-1.0.0-py3-none-any.whl (7.7 kB)
# Collecting warmup-scheduler
#   Downloading warmup_scheduler-0.3.tar.gz (2.1 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (1.59.2)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (2.17.3)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (3.5.1)
# Requirement already satisfied: numpy>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (1.23.5)
# Requirement already satisfied: protobuf>=3.19.6 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (2.31.0)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (67.7.2)
# Requirement already satisfied: six>1.9 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (1.16.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (3.0.1)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image) (1.11.3)
# Requirement already satisfied: networkx>=2.2 in /usr/local/lib/python3.10/dist-packages (from scikit-image) (3.2.1)
# Requirement already satisfied: pillow!=7.1.0,!=7.1.1,!=8.3.0,>=6.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-image) (9.4.0)
# Requirement already satisfied: imageio>=2.4.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image) (2.31.6)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.10/dist-packages (from scikit-image) (2023.9.26)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image) (1.4.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from scikit-image) (23.2)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from pytorch_msssim) (2.1.0+cu118)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard) (2023.7.22)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard) (2.1.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->pytorch_msssim) (3.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch->pytorch_msssim) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->pytorch_msssim) (1.12)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->pytorch_msssim) (3.1.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch->pytorch_msssim) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch->pytorch_msssim) (2.1.0)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard) (3.2.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->pytorch_msssim) (1.3.0)
# Building wheels for collected packages: warmup-scheduler
#   Building wheel for warmup-scheduler (setup.py) ... done
#   Created wheel for warmup-scheduler: filename=warmup_scheduler-0.3-py3-none-any.whl size=2968 sha256=bf3a410c8b2d19500f8a373ea8963f14a8a0dfd697125b2fd214e51a36d8e0c1
#   Stored in directory: /root/.cache/pip/wheels/59/01/9e/d1820991c32916e9808c940f572b462f3e46427f3e76c4d852
# Successfully built warmup-scheduler
# Installing collected packages: warmup-scheduler, einops, pytorch_msssim
# Successfully installed einops-0.7.0 pytorch_msssim-1.0.0 warmup-scheduler-0.3

# %%
# !pip install pytorch-msssim
# Out:
# Requirement already satisfied: pytorch-msssim in /usr/local/lib/python3.10/dist-packages (1.0.0)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from pytorch-msssim) (2.1.0+cu118)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->pytorch-msssim) (3.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch->pytorch-msssim) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->pytorch-msssim) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->pytorch-msssim) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->pytorch-msssim) (3.1.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch->pytorch-msssim) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch->pytorch-msssim) (2.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->pytorch-msssim) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->pytorch-msssim) (1.3.0)

# %%
# !pip install warmup-scheduler
# Out:
# Requirement already satisfied: warmup-scheduler in /usr/local/lib/python3.10/dist-packages (0.3)

# %%
#path = "/content/drive/MyDrive/reside-indoor"
# !unzip  ./drive/MyDrive/reside-indoor/indoor_train.zip -d ./reside-indoorMY/ > trainlog.txt
# !unzip  ./drive/MyDrive/reside-indoor/indoor_test.zip -d ./reside-indoorMY/ >testlog.txt
#/content/reside-indoorMY/train/hazy

# %%
path = "/content/reside-indoorMY"
#/content/reside-indoorMY/train/hazy
#path = "/content/reside-indoorMY"
#path = "./reside-indoorMY"

# %% [markdown]
# Data Augment
# ==

# %%
import random
import torchvision.transforms as transforms
import torchvision.transforms.functional as FUNCTIONAL


class PairRandomCrop(transforms.RandomCrop):

    def __call__(self, image, label):

        if self.padding is not None:
            image = FUNCTIONAL.pad(image, self.padding, self.fill, self.padding_mode)
            label = FUNCTIONAL.pad(label, self.padding, self.fill, self.padding_mode)

        # pad the width if needed
        if self.pad_if_needed and image.size[0] < self.size[1]:
            image = FUNCTIONAL.pad(image, (self.size[1] - image.size[0], 0), self.fill, self.padding_mode)
            label = FUNCTIONAL.pad(label, (self.size[1] - label.size[0], 0), self.fill, self.padding_mode)
        # pad the height if needed
        if self.pad_if_needed and image.size[1] < self.size[0]:
            image = FUNCTIONAL.pad(image, (0, self.size[0] - image.size[1]), self.fill, self.padding_mode)
            label = FUNCTIONAL.pad(label, (0, self.size[0] - image.size[1]), self.fill, self.padding_mode)

        i, j, h, w = self.get_params(image, self.size)

        return FUNCTIONAL.crop(image, i, j, h, w), FUNCTIONAL.crop(label, i, j, h, w)


class PairCompose(transforms.Compose):
    def __call__(self, image, label):
        for t in self.transforms:
            image, label = t(image, label)
        return image, label


class PairRandomHorizontalFilp(transforms.RandomHorizontalFlip):
    def __call__(self, img, label):
        """
        Args:
            img (PIL Image): Image to be flipped.

        Returns:
            PIL Image: Randomly flipped image.
        """
        if random.random() < self.p:
            return FUNCTIONAL.hflip(img), FUNCTIONAL.hflip(label)
        return img, label


class PairToTensor(transforms.ToTensor):
    def __call__(self, pic, label):
        """
        Args:
            pic (PIL Image or numpy.ndarray): Image to be converted to tensor.

        Returns:
            Tensor: Converted image.
        """
        return FUNCTIONAL.to_tensor(pic), FUNCTIONAL.to_tensor(label)

# %% [markdown]
# Data Loader
# ==

# %%
import os
import torch
import numpy as np
from PIL import Image as Image
from torch.utils.data import Dataset, DataLoader


def train_dataloader(path, batch_size=1, num_workers=0, use_transform=True): # we change batch size = 1, but the original batch size = 64
    image_dir = os.path.join(path, 'train')

    transform = None
    if use_transform:
        transform = PairCompose(
            [
                PairRandomCrop(256),
                PairRandomHorizontalFilp(),
                PairToTensor()
            ]
        )
    dataloader = DataLoader(
        DeblurDataset(image_dir, transform=transform),
        batch_size=batch_size,
        shuffle=True,
        num_workers=num_workers,
        pin_memory=True
    )
    return dataloader


def test_dataloader(path, batch_size=1, num_workers=0):
    image_dir = os.path.join(path, 'test')
    dataloader = DataLoader(
        DeblurDataset(image_dir, is_test=True),
        batch_size=batch_size,
        shuffle=False,
        num_workers=num_workers,
        pin_memory=True
    )

    return dataloader


def valid_dataloader(path, batch_size=1, num_workers=0):
    dataloader = DataLoader(
        DeblurDataset(os.path.join(path, 'test')),
        batch_size=batch_size,
        shuffle=False,
        num_workers=num_workers
    )

    return dataloader


class DeblurDataset(Dataset):
    def __init__(self, image_dir, transform=None, is_test=False):
        self.image_dir = image_dir
        self.image_list = os.listdir(os.path.join(image_dir, 'hazy/'))
        self._check_image(self.image_list)
        self.image_list.sort()
        self.transform = transform
        self.is_test = is_test

    def __len__(self):
        return len(self.image_list)

    def __getitem__(self, idx):
        image = Image.open(os.path.join(self.image_dir, 'hazy', self.image_list[idx]))
        label = Image.open(os.path.join(self.image_dir, 'gt', self.image_list[idx].split('_')[0]+'.png'))

        if self.transform:
            image, label = self.transform(image, label)
        else:
            image = FUNCTIONAL.to_tensor(image)
            label = FUNCTIONAL.to_tensor(label)
        if self.is_test:
            name = self.image_list[idx]
            return image, label, name
        return image, label

    @staticmethod
    def _check_image(lst):
        for x in lst:
            splits = x.split('.')
            if splits[-1] not in ['png', 'jpg', 'jpeg']:
                raise ValueError

# %% [markdown]
# Utils
# ==

# %%
import time
import numpy as np


class Adder(object):
    def __init__(self):
        self.count = 0
        self.num = float(0)

    def reset(self):
        self.count = 0
        self.num = float(0)

    def __call__(self, num):
        self.count += 1
        self.num += num

    def average(self):
        return self.num / self.count


class Timer(object):
    def __init__(self, option='s'):
        self.tm = 0
        self.option = option
        if option == 's':
            self.devider = 1
        elif option == 'm':
            self.devider = 60
        else:
            self.devider = 3600

    def tic(self):
        self.tm = time.time()

    def toc(self):
        return (time.time() - self.tm) / self.devider


def check_lr(optimizer):
    for i, param_group in enumerate(optimizer.param_groups):
        lr = param_group['lr']
    return lr

# %% [markdown]
# Eval
# ==

# %%
from skimage.metrics import peak_signal_noise_ratio
from pytorch_msssim import ssim
import torch.nn.functional as fe

from skimage import img_as_ubyte
import cv2

def _eval(model, args):
    state_dict = torch.load(args.test_model)
    model.load_state_dict(state_dict['model'])
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    dataloader = test_dataloader(args.data_dir, batch_size=1, num_workers=0)
    torch.cuda.empty_cache()
    adder = Adder()
    model.eval()
    factor = 32
    with torch.no_grad():
        psnr_adder = Adder()
        ssim_adder = Adder()

        for iter_idx, data in enumerate(dataloader):
            input_img, label_img, name = data

            input_img = input_img.to(device)

            h, w = input_img.shape[2], input_img.shape[3]
            H, W = ((h+factor)//factor)*factor, ((w+factor)//factor*factor)
            padh = H-h if h%factor!=0 else 0
            padw = W-w if w%factor!=0 else 0
            input_img = fe.pad(input_img, (0, padw, 0, padh), 'reflect')

            tm = time.time()

            pred = model(input_img)[2]
            pred = pred[:,:,:h,:w]

            elapsed = time.time() - tm
            adder(elapsed)

            pred_clip = torch.clamp(pred, 0, 1)

            pred_numpy = pred_clip.squeeze(0).cpu().numpy()
            label_numpy = label_img.squeeze(0).cpu().numpy()


            label_img = (label_img).cuda()
            psnr_val = 10 * torch.log10(1 / fe.mse_loss(pred_clip, label_img))
            down_ratio = max(1, round(min(H, W) / 256))
            ssim_val = ssim(fe.adaptive_avg_pool2d(pred_clip, (int(H / down_ratio), int(W / down_ratio))),
                            fe.adaptive_avg_pool2d(label_img, (int(H / down_ratio), int(W / down_ratio))),
                            data_range=1, size_average=False)
            print('%d iter PSNR_dehazing: %.2f ssim: %f' % (iter_idx + 1, psnr_val, ssim_val))
            ssim_adder(ssim_val)

            if args.save_image:
                save_name = os.path.join(args.result_dir, name[0])
                pred_clip += 0.5 / 255
                pred = FUNCTIONAL.to_pil_image(pred_clip.squeeze(0).cpu(), 'RGB')
                pred.save(save_name)

            psnr_mimo = peak_signal_noise_ratio(pred_numpy, label_numpy, data_range=1)
            psnr_adder(psnr_val)

            print('%d iter PSNR: %.2f time: %f' % (iter_idx + 1, psnr_mimo, elapsed))

        print('==========================================================')
        print('The average PSNR is %.2f dB' % (psnr_adder.average()))
        print('The average SSIM is %.5f dB' % (ssim_adder.average()))

        print("Average time: %f" % adder.average())

# %% [markdown]
# Layers
# ==

# %%
import torch
import torch.nn as nn
import torch.nn.functional as fl
import math

class BasicConv(nn.Module):
    def __init__(self, in_channel, out_channel, kernel_size, stride, bias=True, norm=False, relu=True, transpose=False):
        super(BasicConv, self).__init__()
        if bias and norm:
            bias = False

        padding = kernel_size // 2
        layers = list()
        if transpose:
            padding = kernel_size // 2 -1
            layers.append(nn.ConvTranspose2d(in_channel, out_channel, kernel_size, padding=padding, stride=stride, bias=bias))
        else:
            layers.append(
                nn.Conv2d(in_channel, out_channel, kernel_size, padding=padding, stride=stride, bias=bias))
        if norm:
            layers.append(nn.BatchNorm2d(out_channel))
        if relu:
            layers.append(nn.GELU())
        self.main = nn.Sequential(*layers)

    def forward(self, x):
        return self.main(x)


class ResBlock(nn.Module):
    def __init__(self, in_channel, out_channel, filter=False):
        super(ResBlock, self).__init__()
        self.main = nn.Sequential(
            BasicConv(in_channel, out_channel, kernel_size=3, stride=1, relu=True),
            DeepPoolLayer(in_channel, out_channel) if filter else nn.Identity(),
            BasicConv(out_channel, out_channel, kernel_size=3, stride=1, relu=False)
        )

    def forward(self, x):
        return self.main(x) + x


class DeepPoolLayer(nn.Module):
    def __init__(self, k, k_out):
        super(DeepPoolLayer, self).__init__()
        self.pools_sizes = [8,4,2]
        pools, convs, dynas = [],[],[]
        for i in self.pools_sizes:
            pools.append(nn.AvgPool2d(kernel_size=i, stride=i))
            convs.append(nn.Conv2d(k, k, 3, 1, 1, bias=False))
            dynas.append(dynamic_filter(inchannels=k, kernel_size=3))
        self.pools = nn.ModuleList(pools)
        self.convs = nn.ModuleList(convs)
        self.dynas = nn.ModuleList(dynas)
        self.relu = nn.GELU()
        self.conv_sum = nn.Conv2d(k, k_out, 3, 1, 1, bias=False)

    def forward(self, x):
        x_size = x.size()
        resl = x
        for i in range(len(self.pools_sizes)):
            if i == 0:
                y = self.dynas[i](self.convs[i](self.pools[i](x)))
            else:
                y = self.dynas[i](self.convs[i](self.pools[i](x)+y_up))
            resl = torch.add(resl, fl.interpolate(y, x_size[2:], mode='bilinear', align_corners=True))
            if i != len(self.pools_sizes)-1:
                y_up = fl.interpolate(y, scale_factor=2, mode='bilinear', align_corners=True)
        resl = self.relu(resl)
        resl = self.conv_sum(resl)

        return resl

class dynamic_filter(nn.Module):
    def __init__(self, inchannels, kernel_size=3, stride=1, group=8):
        super(dynamic_filter, self).__init__()

        self.stride = stride
        self.kernel_size = kernel_size
        self.group = group

        self.conv = nn.Conv2d(inchannels, group*kernel_size**2, kernel_size=1, stride=1, bias=False)
        self.bn = nn.BatchNorm2d(group*kernel_size**2)
        self.act = nn.Tanh()

        nn.init.kaiming_normal_(self.conv.weight, mode='fan_out', nonlinearity='relu')
        self.lamb_l = nn.Parameter(torch.zeros(inchannels), requires_grad=True)
        self.lamb_h = nn.Parameter(torch.zeros(inchannels), requires_grad=True)
        self.pad = nn.ReflectionPad2d(kernel_size//2)

        self.ap = nn.AdaptiveAvgPool2d((1, 1))
        self.gap = nn.AdaptiveAvgPool2d(1)

        self.inside_all = nn.Parameter(torch.zeros(inchannels,1,1), requires_grad=True)

    def forward(self, x):
        identity_input = x
        # the Conv_{3x3} layer in eq.3 is included in DeepPoolLayer.convs
        low_filter = self.ap(x)
        low_filter = self.conv(low_filter)
        low_filter = self.bn(low_filter)

        n, c, h, w = x.shape
        x = fl.unfold(self.pad(x), kernel_size=self.kernel_size).reshape(n, self.group, c//self.group, self.kernel_size**2, h*w)

        n,c1,p,q = low_filter.shape
        low_filter = low_filter.reshape(n, c1//self.kernel_size**2, self.kernel_size**2, p*q).unsqueeze(2)
        low_filter = self.act(low_filter)
        low_part = torch.sum(x * low_filter, dim=3).reshape(n, c, h, w)

        # the variables here are slightly different from the paper: (code) --> (paper)
        # low_filter --> A (eq.3)
        # In Eq.7, X*A'= X*(A_{l} + WA_{h})
        #              = X*A_{l} + WX*(A - A_{l})
        #              = X*A_{l} + WX*A - WX*A_{l}
        #              = WX*A - X*A_{l}(W-1)
        # we substitute gap for A_{l} for simplicity, which is a coarser low-frequency filter
        out_low = low_part * (self.inside_all + 1.) - self.inside_all * self.gap(identity_input)

        out_low = out_low * self.lamb_l[None,:,None,None]
        out_high = (identity_input) * (self.lamb_h[None,:,None,None] + 1.)

        return out_low + out_high

# %% [markdown]
# IRNeXt
# ==

# %%
import torch
import torch.nn as nn
import torch.nn.functional as fwd

class EBlock(nn.Module):
    def __init__(self, out_channel, num_res=8):
        super(EBlock, self).__init__()

        layers = [ResBlock(out_channel, out_channel) for _ in range(num_res-1)]
        layers.append(ResBlock(out_channel, out_channel, filter=True))
        self.layers = nn.Sequential(*layers)

    def forward(self, x):
        return self.layers(x)


class DBlock(nn.Module):
    def __init__(self, channel, num_res=8):
        super(DBlock, self).__init__()

        layers = [ResBlock(channel, channel) for _ in range(num_res-1)]
        layers.append(ResBlock(channel, channel, filter=True))
        self.layers = nn.Sequential(*layers)

    def forward(self, x):
        return self.layers(x)


class SCM(nn.Module):
    def __init__(self, out_plane):
        super(SCM, self).__init__()

        self.main = nn.Sequential(
            BasicConv(3, out_plane//4, kernel_size=3, stride=1, relu=True),
            BasicConv(out_plane // 4, out_plane // 2, kernel_size=1, stride=1, relu=True),
            BasicConv(out_plane // 2, out_plane // 2, kernel_size=3, stride=1, relu=True),
            BasicConv(out_plane // 2, out_plane, kernel_size=1, stride=1, relu=False),
            nn.InstanceNorm2d(out_plane, affine=True)
        )

    def forward(self, x):
        x = self.main(x)
        return x

class FAM(nn.Module):
    def __init__(self, channel):
        super(FAM, self).__init__()

        self.merge = BasicConv(channel*2, channel, kernel_size=3, stride=1, relu=False)

    def forward(self, x1, x2):
        return self.merge(torch.cat([x1, x2], dim=1))

class IRNeXt(nn.Module):
    def __init__(self, num_res=4):
        super(IRNeXt, self).__init__()

        base_channel = 32
        self.Encoder = nn.ModuleList([
            EBlock(base_channel, num_res),
            EBlock(base_channel*2, num_res),
            EBlock(base_channel*4, num_res),
        ])

        self.feat_extract = nn.ModuleList([
            BasicConv(3, base_channel, kernel_size=3, relu=True, stride=1),
            BasicConv(base_channel, base_channel*2, kernel_size=3, relu=True, stride=2),
            BasicConv(base_channel*2, base_channel*4, kernel_size=3, relu=True, stride=2),
            BasicConv(base_channel*4, base_channel*2, kernel_size=4, relu=True, stride=2, transpose=True),
            BasicConv(base_channel*2, base_channel, kernel_size=4, relu=True, stride=2, transpose=True),
            BasicConv(base_channel, 3, kernel_size=3, relu=False, stride=1)
        ])

        self.Decoder = nn.ModuleList([
            DBlock(base_channel * 4, num_res),
            DBlock(base_channel * 2, num_res),
            DBlock(base_channel, num_res)
        ])

        self.Convs = nn.ModuleList([
            BasicConv(base_channel * 4, base_channel * 2, kernel_size=1, relu=True, stride=1),
            BasicConv(base_channel * 2, base_channel, kernel_size=1, relu=True, stride=1),
        ])

        self.ConvsOut = nn.ModuleList(
            [
                BasicConv(base_channel * 4, 3, kernel_size=3, relu=False, stride=1),
                BasicConv(base_channel * 2, 3, kernel_size=3, relu=False, stride=1),
            ]
        )

        self.FAM1 = FAM(base_channel * 4)
        self.SCM1 = SCM(base_channel * 4)
        self.FAM2 = FAM(base_channel * 2)
        self.SCM2 = SCM(base_channel * 2)

    def forward(self, x):
        x_2 = fwd.interpolate(x, scale_factor=0.5)
        x_4 = fwd.interpolate(x_2, scale_factor=0.5)
        z2 = self.SCM2(x_2)
        z4 = self.SCM1(x_4)

        outputs = list()
        # 256
        x_ = self.feat_extract[0](x)
        res1 = self.Encoder[0](x_)
        # 128
        z = self.feat_extract[1](res1)
        z = self.FAM2(z, z2)
        res2 = self.Encoder[1](z)
        # 64
        z = self.feat_extract[2](res2)
        z = self.FAM1(z, z4)
        z = self.Encoder[2](z)

        z = self.Decoder[0](z)
        z_ = self.ConvsOut[0](z)
        # 128
        z = self.feat_extract[3](z)
        outputs.append(z_+x_4)

        z = torch.cat([z, res2], dim=1)
        z = self.Convs[0](z)
        z = self.Decoder[1](z)
        z_ = self.ConvsOut[1](z)
        # 256
        z = self.feat_extract[4](z)
        outputs.append(z_+x_2)

        z = torch.cat([z, res1], dim=1)
        z = self.Convs[1](z)
        z = self.Decoder[2](z)
        z = self.feat_extract[5](z)
        outputs.append(z+x)

        return outputs


def build_net():
    return IRNeXt()

# %% [markdown]
# Valid
# ==

# %%
from skimage.metrics import peak_signal_noise_ratio
import torch.nn.functional as fv


def _valid(model, args, ep):
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    its = valid_dataloader(args.data_dir, batch_size=1, num_workers=0)
    model.eval()
    psnr_adder = Adder()

    with torch.no_grad():
        print('Start Evaluation')
        factor = 32
        for idx, data in enumerate(its):
            input_img, label_img = data
            input_img = input_img.to(device)

            h, w = input_img.shape[2], input_img.shape[3]
            H, W = ((h+factor)//factor)*factor, ((w+factor)//factor*factor)
            padh = H-h if h%factor!=0 else 0
            padw = W-w if w%factor!=0 else 0
            input_img = fv.pad(input_img, (0, padw, 0, padh), 'reflect')

            if not os.path.exists(os.path.join(args.result_dir, '%d' % (ep))):
                os.mkdir(os.path.join(args.result_dir, '%d' % (ep)))

            pred = model(input_img)[2]
            pred = pred[:,:,:h,:w]

            pred_clip = torch.clamp(pred, 0, 1)
            p_numpy = pred_clip.squeeze(0).cpu().numpy()
            label_numpy = label_img.squeeze(0).cpu().numpy()

            psnr = peak_signal_noise_ratio(p_numpy, label_numpy, data_range=1)

            psnr_adder(psnr)
            print('\r%03d'%idx, end=' ')

    print('\n')
    model.train()
    return psnr_adder.average()

# %% [markdown]
# SGLD
# ==

# %%
""" Custom optimizer implementations to track various runtime statistics """

from torch.optim import Optimizer


class SGLD(Optimizer):
    r"""Implements stochastic gradient descent (optionally with momentum).
    Nesterov momentum is based on the formula from
    `On the importance of initialization and momentum in deep learning`__.
    Args:
        params (iterable): iterable of parameters to optimize or dicts defining
            parameter groups
        lr (float): learning rate
        momentum (float, optional): momentum factor (default: 0)
        weight_decay (float, optional): weight decay (L2 penalty) (default: 0)
        dampening (float, optional): dampening for momentum (default: 0)
        nesterov (bool, optional): enables Nesterov momentum (default: False)
        noise_scale (float, optional): variance of isotropic noise for langevin
    Example:
        >>> optimizer = torch.optim.SGD(model.parameters(), lr=0.1, momentum=0.9)
        >>> optimizer.zero_grad()
        >>> loss_fn(model(input), target).backward()
        >>> optimizer.step()
    __ http://www.cs.toronto.edu/%7Ehinton/absps/momentum.pdf
    .. note::
        The implementation of SGD with Momentum/Nesterov subtly differs from
        Sutskever et. al. and implementations in some other frameworks.
        Considering the specific case of Momentum, the update can be written as
        .. math::
                  v = \rho * v + g \\
                  p = p - lr * v
        where p, g, v and :math:`\rho` denote the parameters, gradient,
        velocity, and momentum respectively.
        This is in contrast to Sutskever et. al. and
        other frameworks which employ an update of the form
        .. math::
             v = \rho * v + lr * g \\
             p = p - v
        The Nesterov version is analogously modified.
    """

    def __init__(self, params, lr, momentum=0, dampening=0,
                 weight_decay=0, nesterov=False,
                 noise_scale=0.01):
        if lr < 0.0:
            raise ValueError("Invalid learning rate: {}".format(lr))
        if momentum < 0.0:
            raise ValueError("Invalid momentum value: {}".format(momentum))
        if weight_decay < 0.0:
            raise ValueError("Invalid weight_decay value: {}".format(weight_decay))

        defaults = dict(lr=lr, momentum=momentum, dampening=dampening,
                        weight_decay=weight_decay, nesterov=nesterov)
        if nesterov and (momentum <= 0 or dampening != 0):
            raise ValueError("Nesterov momentum requires a momentum and zero dampening")
        super(SGLD, self).__init__(params, defaults)
        self.noise_scale = noise_scale

    def __setstate__(self, state):
        super(SGLD, self).__setstate__(state)
        for group in self.param_groups:
            group.setdefault('nesterov', False)

    def step(self, closure=None):
        """Performs a single optimization step.
        Arguments:
            closure (callable, optional): A closure that reevaluates the model
                and returns the loss.

        returns norm of the step we took for variance analysis later
        """
        loss = None
        if closure is not None:
            loss = closure()

        for group in self.param_groups:
            weight_decay = group['weight_decay']
            momentum = group['momentum']
            dampening = group['dampening']
            nesterov = group['nesterov']

            for p in group['params']:
                if p.grad is None:
                    continue
                d_p = p.grad.data

                if weight_decay != 0:
                    d_p.add_(weight_decay, p.data)
                if momentum != 0:
                    param_state = self.state[p]
                    if 'momentum_buffer' not in param_state:
                        buf = param_state['momentum_buffer'] = torch.zeros_like(p.data)
                        buf.mul_(momentum).add_(d_p)
                    else:
                        buf = param_state['momentum_buffer']
                        buf.mul_(momentum).add_(1 - dampening, d_p)
                    if nesterov:
                        d_p = d_p.add(momentum, buf)
                    else:
                        d_p = buf

                p.data.add_(-group['lr'], d_p)
                p.data.add_(np.sqrt(self.noise_scale), torch.randn_like(p.data))
        return loss

# %% [markdown]
# TRAIN
# ==

# %%
from torch.utils.tensorboard import SummaryWriter
import torch.nn.functional as ft
import torch.optim as optim


from warmup_scheduler import GradualWarmupScheduler

def _train(model, args):
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    model.to(device)
    criterion = torch.nn.L1Loss().to(device)
    optimizer = optim.SGD(model.parameters(), lr=args.learning_rate, momentum=args.momentum_value, nesterov=True)

    #optimizer = SGLD(params=model.parameters(), lr=args.learning_rate, weight_decay=args.weight_decay)
    dataloader = train_dataloader(args.data_dir, args.batch_size, args.num_worker)
    max_iter = len(dataloader)
    warmup_epochs=3
    scheduler_cosine = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=args.num_epoch-warmup_epochs, eta_min=1e-6)
    scheduler = GradualWarmupScheduler(optimizer, multiplier=1, total_epoch=warmup_epochs, after_scheduler=scheduler_cosine)
    scheduler.step()
    epoch = 1
    if args.resume:
        state = torch.load(args.resume)
        epoch = state['epoch']
        optimizer.load_state_dict(state['optimizer'])
        model.load_state_dict(state['model'])
        print('Resume from %d'%epoch)
        epoch += 1
        for i in range(epoch-1):
          scheduler.step()

    writer = SummaryWriter()
    epoch_pixel_adder = Adder()
    epoch_fft_adder = Adder()
    iter_pixel_adder = Adder()
    iter_fft_adder = Adder()
    epoch_timer = Timer('m')
    iter_timer = Timer('m')
    best_psnr=-1

    for epoch_idx in range(epoch, args.num_epoch + 1):

        epoch_timer.tic()
        iter_timer.tic()
        for iter_idx, batch_data in enumerate(dataloader):

            input_img, label_img = batch_data
            input_img = input_img.to(device)
            label_img = label_img.to(device)

            optimizer.zero_grad()
            pred_img = model(input_img)
            label_img2 = ft.interpolate(label_img, scale_factor=0.5, mode='bilinear')
            label_img4 = ft.interpolate(label_img, scale_factor=0.25, mode='bilinear')
            l1 = criterion(pred_img[0], label_img4)
            l2 = criterion(pred_img[1], label_img2)
            l3 = criterion(pred_img[2], label_img)
            loss_content = l1+l2+l3

            label_fft1 = torch.fft.fft2(label_img4, dim=(-2,-1))
            label_fft1 = torch.stack((label_fft1.real, label_fft1.imag), -1)

            pred_fft1 = torch.fft.fft2(pred_img[0], dim=(-2,-1))
            pred_fft1 = torch.stack((pred_fft1.real, pred_fft1.imag), -1)

            label_fft2 = torch.fft.fft2(label_img2, dim=(-2,-1))
            label_fft2 = torch.stack((label_fft2.real, label_fft2.imag), -1)

            pred_fft2 = torch.fft.fft2(pred_img[1], dim=(-2,-1))
            pred_fft2 = torch.stack((pred_fft2.real, pred_fft2.imag), -1)

            label_fft3 = torch.fft.fft2(label_img, dim=(-2,-1))
            label_fft3 = torch.stack((label_fft3.real, label_fft3.imag), -1)

            pred_fft3 = torch.fft.fft2(pred_img[2], dim=(-2,-1))
            pred_fft3 = torch.stack((pred_fft3.real, pred_fft3.imag), -1)

            f1 = criterion(pred_fft1, label_fft1)
            f2 = criterion(pred_fft2, label_fft2)
            f3 = criterion(pred_fft3, label_fft3)
            loss_fft = f1+f2+f3

            loss = loss_content + 0.1 * loss_fft
            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), 0.001)
            optimizer.step()

            iter_pixel_adder(loss_content.item())
            iter_fft_adder(loss_fft.item())

            epoch_pixel_adder(loss_content.item())
            epoch_fft_adder(loss_fft.item())

            if (iter_idx + 1) % args.print_freq == 0:
                print("Time: %7.4f Epoch: %03d Iter: %4d/%4d LR: %.10f Loss content: %7.4f Loss fft: %7.4f" % (
                    iter_timer.toc(), epoch_idx, iter_idx + 1, max_iter, scheduler.get_lr()[0], iter_pixel_adder.average(),
                    iter_fft_adder.average()))
                writer.add_scalar('Pixel Loss', iter_pixel_adder.average(), iter_idx + (epoch_idx-1)* max_iter)
                writer.add_scalar('FFT Loss', iter_fft_adder.average(), iter_idx + (epoch_idx - 1) * max_iter)

                iter_timer.tic()
                iter_pixel_adder.reset()
                iter_fft_adder.reset()
        overwrite_name = os.path.join(args.model_save_dir, 'model.pkl')
        torch.save({'model': model.state_dict(),
                    'optimizer': optimizer.state_dict(),
                    'epoch': epoch_idx}, overwrite_name)

        if epoch_idx % args.save_freq == 0:
            save_name = os.path.join(args.model_save_dir, 'model_%d.pkl' % epoch_idx)
            torch.save({'model': model.state_dict()}, save_name)
        print("EPOCH: %02d\nElapsed time: %4.2f Epoch Pixel Loss: %7.4f Epoch FFT Loss: %7.4f" % (
            epoch_idx, epoch_timer.toc(), epoch_pixel_adder.average(), epoch_fft_adder.average()))
        epoch_fft_adder.reset()
        epoch_pixel_adder.reset()
        scheduler.step()
        if epoch_idx % args.valid_freq == 0:
            val = _valid(model, args, epoch_idx)
            print('%03d epoch \n Average PSNR %.2f dB' % (epoch_idx, val))
            writer.add_scalar('PSNR', val, epoch_idx)
            if val >= best_psnr:
                torch.save({'model': model.state_dict()}, os.path.join(args.model_save_dir, 'Best.pkl'))
    save_name = os.path.join(args.model_save_dir, 'Final.pkl')
    torch.save({'model': model.state_dict()}, save_name)

# %% [markdown]
# Main (test model)
# ==

# %%
import os
import torch
import torchvision.transforms as transforms
# from torch.backends import cudnn # Uncomment if you need it

class Args:
    model_name = 'IRNeXt'
    mode = 'train'
    data_dir = path

    # Train
    batch_size = 4
    learning_rate = 1e-4
    weight_decay = 0
    num_epoch = 20
    print_freq = 100
    num_worker = 8
    save_freq = 10
    valid_freq = 10
    momentum_value = 0.4

    resume = ''
    #/content/drive/MyDrive/MYresults2/IRNeXt/ITS/model.pkl
    # Test
    test_model = '/content/drive/MyDrive/MYresults2_4/IRNeXt/ITS/Final.pkl'
    save_image = False

    # Directories (set these as per your requirement)
    model_save_dir = os.path.join('/content/drive/MyDrive/MYresults2_4/', 'IRNeXt', 'ITS/')
    result_dir = os.path.join('/content/drive/MyDrive/MYresults2_4/', model_name, 'test')

def main(args):
    # CUDNN
    # cudnn.benchmark = True # Uncomment if you need it

    if not os.path.exists('/content/drive/MyDrive/MYresults2_4/'):
        os.makedirs(args.model_save_dir)
    if not os.path.exists('/content/drive/MyDrive/MYresults2_4/' + args.model_name + '/'):
        os.makedirs('/content/drive/MyDrive/MYresults2_4/' + args.model_name + '/')
    if not os.path.exists(args.model_save_dir):
        os.makedirs(args.model_save_dir)
    if not os.path.exists(args.result_dir):
        os.makedirs(args.result_dir)

    model = build_net()  # Make sure to define build_net or import it if it's defined elsewhere
    print(model)

    if torch.cuda.is_available():
        model.cuda()
    if args.mode == 'train':
        _train(model, args)  # Make sure to define _train or import it if it's defined elsewhere

    elif args.mode == 'test':
        _eval(model, args)   # Make sure to define _eval or import it if it's defined elsewhere

# Replace parser.parse_args() with an instance of the Args class
args = Args()
if not os.path.exists(args.model_save_dir):
    os.makedirs(args.model_save_dir)
# Copying files (make sure these paths are correct)
command = 'cp ' + 'models/layers.py ' + args.model_save_dir
os.system(command)
command = 'cp ' + 'models/IRNeXt.py ' + args.model_save_dir
os.system(command)
command = 'cp ' + 'train.py ' + args.model_save_dir
os.system(command)
command = 'cp ' + 'main.py ' + args.model_save_dir
os.system(command)
print(args)
main(args)
# Out:
# <__main__.Args object at 0x7a0f9d4bad10>
# IRNeXt(
#   (Encoder): ModuleList(
#     (0): EBlock(
#       (layers): Sequential(
#         (0): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (1): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (2): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (3): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): DeepPoolLayer(
#               (pools): ModuleList(
#                 (0): AvgPool2d(kernel_size=8, stride=8, padding=0)
#                 (1): AvgPool2d(kernel_size=4, stride=4, padding=0)
#                 (2): AvgPool2d(kernel_size=2, stride=2, padding=0)
#               )
#               (convs): ModuleList(
#                 (0-2): 3 x Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#               (dynas): ModuleList(
#                 (0-2): 3 x dynamic_filter(
#                   (conv): Conv2d(32, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (bn): BatchNorm2d(72, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (act): Tanh()
#                   (pad): ReflectionPad2d((1, 1, 1, 1))
#                   (ap): AdaptiveAvgPool2d(output_size=(1, 1))
#                   (gap): AdaptiveAvgPool2d(output_size=1)
#                 )
#               )
#               (relu): GELU(approximate='none')
#               (conv_sum): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             )
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#       )
#     )
#     (1): EBlock(
#       (layers): Sequential(
#         (0): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (1): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (2): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (3): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): DeepPoolLayer(
#               (pools): ModuleList(
#                 (0): AvgPool2d(kernel_size=8, stride=8, padding=0)
#                 (1): AvgPool2d(kernel_size=4, stride=4, padding=0)
#                 (2): AvgPool2d(kernel_size=2, stride=2, padding=0)
#               )
#               (convs): ModuleList(
#                 (0-2): 3 x Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#               (dynas): ModuleList(
#                 (0-2): 3 x dynamic_filter(
#                   (conv): Conv2d(64, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (bn): BatchNorm2d(72, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (act): Tanh()
#                   (pad): ReflectionPad2d((1, 1, 1, 1))
#                   (ap): AdaptiveAvgPool2d(output_size=(1, 1))
#                   (gap): AdaptiveAvgPool2d(output_size=1)
#                 )
#               )
#               (relu): GELU(approximate='none')
#               (conv_sum): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             )
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#       )
#     )
#     (2): EBlock(
#       (layers): Sequential(
#         (0): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (1): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (2): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (3): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): DeepPoolLayer(
#               (pools): ModuleList(
#                 (0): AvgPool2d(kernel_size=8, stride=8, padding=0)
#                 (1): AvgPool2d(kernel_size=4, stride=4, padding=0)
#                 (2): AvgPool2d(kernel_size=2, stride=2, padding=0)
#               )
#               (convs): ModuleList(
#                 (0-2): 3 x Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#               (dynas): ModuleList(
#                 (0-2): 3 x dynamic_filter(
#                   (conv): Conv2d(128, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (bn): BatchNorm2d(72, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (act): Tanh()
#                   (pad): ReflectionPad2d((1, 1, 1, 1))
#                   (ap): AdaptiveAvgPool2d(output_size=(1, 1))
#                   (gap): AdaptiveAvgPool2d(output_size=1)
#                 )
#               )
#               (relu): GELU(approximate='none')
#               (conv_sum): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             )
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#       )
#     )
#   )
#   (feat_extract): ModuleList(
#     (0): BasicConv(
#       (main): Sequential(
#         (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): GELU(approximate='none')
#       )
#     )
#     (1): BasicConv(
#       (main): Sequential(
#         (0): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         (1): GELU(approximate='none')
#       )
#     )
#     (2): BasicConv(
#       (main): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         (1): GELU(approximate='none')
#       )
#     )
#     (3): BasicConv(
#       (main): Sequential(
#         (0): ConvTranspose2d(128, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#         (1): GELU(approximate='none')
#       )
#     )
#     (4): BasicConv(
#       (main): Sequential(
#         (0): ConvTranspose2d(64, 32, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#         (1): GELU(approximate='none')
#       )
#     )
#     (5): BasicConv(
#       (main): Sequential(
#         (0): Conv2d(32, 3, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#     )
#   )
#   (Decoder): ModuleList(
#     (0): DBlock(
#       (layers): Sequential(
#         (0): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (1): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (2): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (3): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): DeepPoolLayer(
#               (pools): ModuleList(
#                 (0): AvgPool2d(kernel_size=8, stride=8, padding=0)
#                 (1): AvgPool2d(kernel_size=4, stride=4, padding=0)
#                 (2): AvgPool2d(kernel_size=2, stride=2, padding=0)
#               )
#               (convs): ModuleList(
#                 (0-2): 3 x Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#               (dynas): ModuleList(
#                 (0-2): 3 x dynamic_filter(
#                   (conv): Conv2d(128, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (bn): BatchNorm2d(72, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (act): Tanh()
#                   (pad): ReflectionPad2d((1, 1, 1, 1))
#                   (ap): AdaptiveAvgPool2d(output_size=(1, 1))
#                   (gap): AdaptiveAvgPool2d(output_size=1)
#                 )
#               )
#               (relu): GELU(approximate='none')
#               (conv_sum): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             )
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#       )
#     )
#     (1): DBlock(
#       (layers): Sequential(
#         (0): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (1): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (2): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (3): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): DeepPoolLayer(
#               (pools): ModuleList(
#                 (0): AvgPool2d(kernel_size=8, stride=8, padding=0)
#                 (1): AvgPool2d(kernel_size=4, stride=4, padding=0)
#                 (2): AvgPool2d(kernel_size=2, stride=2, padding=0)
#               )
#               (convs): ModuleList(
#                 (0-2): 3 x Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#               (dynas): ModuleList(
#                 (0-2): 3 x dynamic_filter(
#                   (conv): Conv2d(64, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (bn): BatchNorm2d(72, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (act): Tanh()
#                   (pad): ReflectionPad2d((1, 1, 1, 1))
#                   (ap): AdaptiveAvgPool2d(output_size=(1, 1))
#                   (gap): AdaptiveAvgPool2d(output_size=1)
#                 )
#               )
#               (relu): GELU(approximate='none')
#               (conv_sum): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             )
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#       )
#     )
#     (2): DBlock(
#       (layers): Sequential(
#         (0): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (1): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (2): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (3): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): DeepPoolLayer(
#               (pools): ModuleList(
#                 (0): AvgPool2d(kernel_size=8, stride=8, padding=0)
#                 (1): AvgPool2d(kernel_size=4, stride=4, padding=0)
#                 (2): AvgPool2d(kernel_size=2, stride=2, padding=0)
#               )
#               (convs): ModuleList(
#                 (0-2): 3 x Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#               (dynas): ModuleList(
#                 (0-2): 3 x dynamic_filter(
#                   (conv): Conv2d(32, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (bn): BatchNorm2d(72, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (act): Tanh()
#                   (pad): ReflectionPad2d((1, 1, 1, 1))
#                   (ap): AdaptiveAvgPool2d(output_size=(1, 1))
#                   (gap): AdaptiveAvgPool2d(output_size=1)
#                 )
#               )
#               (relu): GELU(approximate='none')
#               (conv_sum): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             )
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#       )
#     )
#   )
#   (Convs): ModuleList(
#     (0): BasicConv(
#       (main): Sequential(
#         (0): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1))
#         (1): GELU(approximate='none')
#       )
#     )
#     (1): BasicConv(
#       (main): Sequential(
#         (0): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#         (1): GELU(approximate='none')
#       )
#     )
#   )
#   (ConvsOut): ModuleList(
#     (0): BasicConv(
#       (main): Sequential(
#         (0): Conv2d(128, 3, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#     )
#     (1): BasicConv(
#       (main): Sequential(
#         (0): Conv2d(64, 3, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#     )
#   )
#   (FAM1): FAM(
#     (merge): BasicConv(
#       (main): Sequential(
#         (0): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#     )
#   )
#   (SCM1): SCM(
#     (main): Sequential(
#       (0): BasicConv(
#         (main): Sequential(
#           (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): GELU(approximate='none')
#         )
#       )
#       (1): BasicConv(
#         (main): Sequential(
#           (0): Conv2d(32, 64, kernel_size=(1, 1), stride=(1, 1))
#           (1): GELU(approximate='none')
#         )
#       )
#       (2): BasicConv(
#         (main): Sequential(
#           (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): GELU(approximate='none')
#         )
#       )
#       (3): BasicConv(
#         (main): Sequential(
#           (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1))
#         )
#       )
#       (4): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#     )
#   )
#   (FAM2): FAM(
#     (merge): BasicConv(
#       (main): Sequential(
#         (0): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#     )
#   )
#   (SCM2): SCM(
#     (main): Sequential(
#       (0): BasicConv(
#         (main): Sequential(
#           (0): Conv2d(3, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): GELU(approximate='none')
#         )
#       )
#       (1): BasicConv(
#         (main): Sequential(
#           (0): Conv2d(16, 32, kernel_size=(1, 1), stride=(1, 1))
#           (1): GELU(approximate='none')
#         )
#       )
#       (2): BasicConv(
#         (main): Sequential(
#           (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): GELU(approximate='none')
#         )
#       )
#       (3): BasicConv(
#         (main): Sequential(
#           (0): Conv2d(32, 64, kernel_size=(1, 1), stride=(1, 1))
#         )
#       )
#       (4): InstanceNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#     )
#   )
# )
# /usr/local/lib/python3.10/dist-packages/torch/optim/lr_scheduler.py:136: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   warnings.warn("Detected call of `lr_scheduler.step()` before `optimizer.step()`. "
# Time:  0.2753 Epoch: 001 Iter:  100/3498 LR: 0.0000333333 Loss content:  0.6853 Loss fft:  9.7781
# Time:  0.1264 Epoch: 001 Iter:  200/3498 LR: 0.0000333333 Loss content:  0.7141 Loss fft: 10.1576
# Time:  0.1259 Epoch: 001 Iter:  300/3498 LR: 0.0000333333 Loss content:  0.7119 Loss fft:  9.9855
# Time:  0.1259 Epoch: 001 Iter:  400/3498 LR: 0.0000333333 Loss content:  0.7113 Loss fft: 10.2423
# Time:  0.1257 Epoch: 001 Iter:  500/3498 LR: 0.0000333333 Loss content:  0.7415 Loss fft:  9.9974
# Time:  0.1330 Epoch: 001 Iter:  600/3498 LR: 0.0000333333 Loss content:  0.7313 Loss fft: 10.2131
# Time:  0.1265 Epoch: 001 Iter:  700/3498 LR: 0.0000333333 Loss content:  0.7040 Loss fft: 10.1452
# Time:  0.1265 Epoch: 001 Iter:  800/3498 LR: 0.0000333333 Loss content:  0.7440 Loss fft: 10.0901
# Time:  0.1266 Epoch: 001 Iter:  900/3498 LR: 0.0000333333 Loss content:  0.7161 Loss fft:  9.9127
# Time:  0.1269 Epoch: 001 Iter: 1000/3498 LR: 0.0000333333 Loss content:  0.7025 Loss fft: 10.2348
# Time:  0.1269 Epoch: 001 Iter: 1100/3498 LR: 0.0000333333 Loss content:  0.7050 Loss fft: 10.5263
# Time:  0.1281 Epoch: 001 Iter: 1200/3498 LR: 0.0000333333 Loss content:  0.7513 Loss fft: 10.3610
# Time:  0.1259 Epoch: 001 Iter: 1300/3498 LR: 0.0000333333 Loss content:  0.7196 Loss fft: 10.0341
# Time:  0.1283 Epoch: 001 Iter: 1400/3498 LR: 0.0000333333 Loss content:  0.7424 Loss fft: 10.1857
# Time:  0.1263 Epoch: 001 Iter: 1500/3498 LR: 0.0000333333 Loss content:  0.7349 Loss fft: 10.2098
# Time:  0.1283 Epoch: 001 Iter: 1600/3498 LR: 0.0000333333 Loss content:  0.7282 Loss fft: 10.0484
# Time:  0.1272 Epoch: 001 Iter: 1700/3498 LR: 0.0000333333 Loss content:  0.7303 Loss fft: 10.0740
# Time:  0.1277 Epoch: 001 Iter: 1800/3498 LR: 0.0000333333 Loss content:  0.7548 Loss fft: 10.1275
# Time:  0.1279 Epoch: 001 Iter: 1900/3498 LR: 0.0000333333 Loss content:  0.7352 Loss fft: 10.1111
# Time:  0.1272 Epoch: 001 Iter: 2000/3498 LR: 0.0000333333 Loss content:  0.7110 Loss fft: 10.0080
# Time:  0.1272 Epoch: 001 Iter: 2100/3498 LR: 0.0000333333 Loss content:  0.7271 Loss fft: 10.2616
# Time:  0.1273 Epoch: 001 Iter: 2200/3498 LR: 0.0000333333 Loss content:  0.7186 Loss fft:  9.9135
# Time:  0.1268 Epoch: 001 Iter: 2300/3498 LR: 0.0000333333 Loss content:  0.7251 Loss fft: 10.2799
# Time:  0.1271 Epoch: 001 Iter: 2400/3498 LR: 0.0000333333 Loss content:  0.7016 Loss fft: 10.0567
# Time:  0.1279 Epoch: 001 Iter: 2500/3498 LR: 0.0000333333 Loss content:  0.7279 Loss fft: 10.3259
# Time:  0.1257 Epoch: 001 Iter: 2600/3498 LR: 0.0000333333 Loss content:  0.7347 Loss fft:  9.8540
# Time:  0.1276 Epoch: 001 Iter: 2700/3498 LR: 0.0000333333 Loss content:  0.7185 Loss fft:  9.9474
# Time:  0.1298 Epoch: 001 Iter: 2800/3498 LR: 0.0000333333 Loss content:  0.7139 Loss fft: 10.0484
# Time:  0.1274 Epoch: 001 Iter: 2900/3498 LR: 0.0000333333 Loss content:  0.7096 Loss fft:  9.8344
# Time:  0.1269 Epoch: 001 Iter: 3000/3498 LR: 0.0000333333 Loss content:  0.7187 Loss fft:  9.9877
# Time:  0.1271 Epoch: 001 Iter: 3100/3498 LR: 0.0000333333 Loss content:  0.6988 Loss fft:  9.9477
# Time:  0.1266 Epoch: 001 Iter: 3200/3498 LR: 0.0000333333 Loss content:  0.6995 Loss fft: 10.3180
# Time:  0.1272 Epoch: 001 Iter: 3300/3498 LR: 0.0000333333 Loss content:  0.7246 Loss fft: 10.1755
# Time:  0.1281 Epoch: 001 Iter: 3400/3498 LR: 0.0000333333 Loss content:  0.7127 Loss fft: 10.0867
# EPOCH: 01
# Elapsed time: 4.61 Epoch Pixel Loss:  0.7209 Epoch FFT Loss: 10.1082
# Time:  0.1366 Epoch: 002 Iter:  100/3498 LR: 0.0000666667 Loss content:  0.7214 Loss fft: 10.2753
# Time:  0.1291 Epoch: 002 Iter:  200/3498 LR: 0.0000666667 Loss content:  0.7017 Loss fft:  9.9861
# Time:  0.1273 Epoch: 002 Iter:  300/3498 LR: 0.0000666667 Loss content:  0.7212 Loss fft: 10.1549
# Time:  0.1273 Epoch: 002 Iter:  400/3498 LR: 0.0000666667 Loss content:  0.7086 Loss fft: 10.0154
# Time:  0.1283 Epoch: 002 Iter:  500/3498 LR: 0.0000666667 Loss content:  0.7370 Loss fft: 10.2895
# Time:  0.1288 Epoch: 002 Iter:  600/3498 LR: 0.0000666667 Loss content:  0.7220 Loss fft: 10.1876
# Time:  0.1288 Epoch: 002 Iter:  700/3498 LR: 0.0000666667 Loss content:  0.7152 Loss fft:  9.9611
# Time:  0.1274 Epoch: 002 Iter:  800/3498 LR: 0.0000666667 Loss content:  0.7265 Loss fft:  9.9319
# Time:  0.1273 Epoch: 002 Iter:  900/3498 LR: 0.0000666667 Loss content:  0.7338 Loss fft: 10.0414
# Time:  0.1271 Epoch: 002 Iter: 1000/3498 LR: 0.0000666667 Loss content:  0.7245 Loss fft: 10.2514
# Time:  0.1276 Epoch: 002 Iter: 1100/3498 LR: 0.0000666667 Loss content:  0.7240 Loss fft: 10.1730
# Time:  0.1276 Epoch: 002 Iter: 1200/3498 LR: 0.0000666667 Loss content:  0.7314 Loss fft: 10.0388
# Time:  0.1284 Epoch: 002 Iter: 1300/3498 LR: 0.0000666667 Loss content:  0.7009 Loss fft: 10.0759
# Time:  0.1271 Epoch: 002 Iter: 1400/3498 LR: 0.0000666667 Loss content:  0.7199 Loss fft:  9.8247
# Time:  0.1322 Epoch: 002 Iter: 1500/3498 LR: 0.0000666667 Loss content:  0.7406 Loss fft: 10.0234
# Time:  0.1274 Epoch: 002 Iter: 1600/3498 LR: 0.0000666667 Loss content:  0.7327 Loss fft: 10.0924

# %%
state_last = torch.load('/content/drive/MyDrive/MYresults/IRNeXt/ITS/model.pkl')

# %% [markdown]
# Test
# ==

# %%
import os
import torch
import torchvision.transforms as transforms
# from torch.backends import cudnn # Uncomment if you need it

class Args:
    model_name = 'IRNeXt'
    mode = 'test'
    data_dir = path

    # Train
    batch_size = 4
    learning_rate = 1e-4
    weight_decay = 0
    num_epoch = 20
    print_freq = 100
    num_worker = 8
    save_freq = 10
    valid_freq = 10
    momentum_value = 0.4

    resume = ''
    #/content/drive/MyDrive/MYresults2/IRNeXt/ITS/model.pkl
    # Test
    test_model = '/content/drive/MyDrive/MYresults2_4/IRNeXt/ITS/Final.pkl'
    save_image = False

    # Directories (set these as per your requirement)
    model_save_dir = os.path.join('/content/drive/MyDrive/MYresults2_4/', 'IRNeXt', 'ITS/')
    result_dir = os.path.join('/content/drive/MyDrive/MYresults2_4/', model_name, 'test')

def main(args):
    # CUDNN
    # cudnn.benchmark = True # Uncomment if you need it

    if not os.path.exists('/content/drive/MyDrive/MYresults2_4/'):
        os.makedirs(args.model_save_dir)
    if not os.path.exists('/content/drive/MyDrive/MYresults2_4/' + args.model_name + '/'):
        os.makedirs('/content/drive/MyDrive/MYresults2_4/' + args.model_name + '/')
    if not os.path.exists(args.model_save_dir):
        os.makedirs(args.model_save_dir)
    if not os.path.exists(args.result_dir):
        os.makedirs(args.result_dir)

    model = build_net()  # Make sure to define build_net or import it if it's defined elsewhere
    print(model)

    if torch.cuda.is_available():
        model.cuda()
    if args.mode == 'train':
        _train(model, args)  # Make sure to define _train or import it if it's defined elsewhere

    elif args.mode == 'test':
        _eval(model, args)   # Make sure to define _eval or import it if it's defined elsewhere

# Replace parser.parse_args() with an instance of the Args class
args = Args()
if not os.path.exists(args.model_save_dir):
    os.makedirs(args.model_save_dir)
# Copying files (make sure these paths are correct)
command = 'cp ' + 'models/layers.py ' + args.model_save_dir
os.system(command)
command = 'cp ' + 'models/IRNeXt.py ' + args.model_save_dir
os.system(command)
command = 'cp ' + 'train.py ' + args.model_save_dir
os.system(command)
command = 'cp ' + 'main.py ' + args.model_save_dir
os.system(command)
print(args)
main(args)
# Out:
# <__main__.Args object at 0x7ca77ddfc820>
# IRNeXt(
#   (Encoder): ModuleList(
#     (0): EBlock(
#       (layers): Sequential(
#         (0): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (1): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (2): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (3): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): DeepPoolLayer(
#               (pools): ModuleList(
#                 (0): AvgPool2d(kernel_size=8, stride=8, padding=0)
#                 (1): AvgPool2d(kernel_size=4, stride=4, padding=0)
#                 (2): AvgPool2d(kernel_size=2, stride=2, padding=0)
#               )
#               (convs): ModuleList(
#                 (0-2): 3 x Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#               (dynas): ModuleList(
#                 (0-2): 3 x dynamic_filter(
#                   (conv): Conv2d(32, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (bn): BatchNorm2d(72, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (act): Tanh()
#                   (pad): ReflectionPad2d((1, 1, 1, 1))
#                   (ap): AdaptiveAvgPool2d(output_size=(1, 1))
#                   (gap): AdaptiveAvgPool2d(output_size=1)
#                 )
#               )
#               (relu): GELU(approximate='none')
#               (conv_sum): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             )
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#       )
#     )
#     (1): EBlock(
#       (layers): Sequential(
#         (0): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (1): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (2): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (3): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): DeepPoolLayer(
#               (pools): ModuleList(
#                 (0): AvgPool2d(kernel_size=8, stride=8, padding=0)
#                 (1): AvgPool2d(kernel_size=4, stride=4, padding=0)
#                 (2): AvgPool2d(kernel_size=2, stride=2, padding=0)
#               )
#               (convs): ModuleList(
#                 (0-2): 3 x Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#               (dynas): ModuleList(
#                 (0-2): 3 x dynamic_filter(
#                   (conv): Conv2d(64, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (bn): BatchNorm2d(72, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (act): Tanh()
#                   (pad): ReflectionPad2d((1, 1, 1, 1))
#                   (ap): AdaptiveAvgPool2d(output_size=(1, 1))
#                   (gap): AdaptiveAvgPool2d(output_size=1)
#                 )
#               )
#               (relu): GELU(approximate='none')
#               (conv_sum): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             )
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#       )
#     )
#     (2): EBlock(
#       (layers): Sequential(
#         (0): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (1): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (2): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (3): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): DeepPoolLayer(
#               (pools): ModuleList(
#                 (0): AvgPool2d(kernel_size=8, stride=8, padding=0)
#                 (1): AvgPool2d(kernel_size=4, stride=4, padding=0)
#                 (2): AvgPool2d(kernel_size=2, stride=2, padding=0)
#               )
#               (convs): ModuleList(
#                 (0-2): 3 x Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#               (dynas): ModuleList(
#                 (0-2): 3 x dynamic_filter(
#                   (conv): Conv2d(128, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (bn): BatchNorm2d(72, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (act): Tanh()
#                   (pad): ReflectionPad2d((1, 1, 1, 1))
#                   (ap): AdaptiveAvgPool2d(output_size=(1, 1))
#                   (gap): AdaptiveAvgPool2d(output_size=1)
#                 )
#               )
#               (relu): GELU(approximate='none')
#               (conv_sum): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             )
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#       )
#     )
#   )
#   (feat_extract): ModuleList(
#     (0): BasicConv(
#       (main): Sequential(
#         (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): GELU(approximate='none')
#       )
#     )
#     (1): BasicConv(
#       (main): Sequential(
#         (0): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         (1): GELU(approximate='none')
#       )
#     )
#     (2): BasicConv(
#       (main): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         (1): GELU(approximate='none')
#       )
#     )
#     (3): BasicConv(
#       (main): Sequential(
#         (0): ConvTranspose2d(128, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#         (1): GELU(approximate='none')
#       )
#     )
#     (4): BasicConv(
#       (main): Sequential(
#         (0): ConvTranspose2d(64, 32, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#         (1): GELU(approximate='none')
#       )
#     )
#     (5): BasicConv(
#       (main): Sequential(
#         (0): Conv2d(32, 3, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#     )
#   )
#   (Decoder): ModuleList(
#     (0): DBlock(
#       (layers): Sequential(
#         (0): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (1): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (2): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (3): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): DeepPoolLayer(
#               (pools): ModuleList(
#                 (0): AvgPool2d(kernel_size=8, stride=8, padding=0)
#                 (1): AvgPool2d(kernel_size=4, stride=4, padding=0)
#                 (2): AvgPool2d(kernel_size=2, stride=2, padding=0)
#               )
#               (convs): ModuleList(
#                 (0-2): 3 x Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#               (dynas): ModuleList(
#                 (0-2): 3 x dynamic_filter(
#                   (conv): Conv2d(128, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (bn): BatchNorm2d(72, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (act): Tanh()
#                   (pad): ReflectionPad2d((1, 1, 1, 1))
#                   (ap): AdaptiveAvgPool2d(output_size=(1, 1))
#                   (gap): AdaptiveAvgPool2d(output_size=1)
#                 )
#               )
#               (relu): GELU(approximate='none')
#               (conv_sum): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             )
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#       )
#     )
#     (1): DBlock(
#       (layers): Sequential(
#         (0): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (1): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (2): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (3): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): DeepPoolLayer(
#               (pools): ModuleList(
#                 (0): AvgPool2d(kernel_size=8, stride=8, padding=0)
#                 (1): AvgPool2d(kernel_size=4, stride=4, padding=0)
#                 (2): AvgPool2d(kernel_size=2, stride=2, padding=0)
#               )
#               (convs): ModuleList(
#                 (0-2): 3 x Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#               (dynas): ModuleList(
#                 (0-2): 3 x dynamic_filter(
#                   (conv): Conv2d(64, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (bn): BatchNorm2d(72, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (act): Tanh()
#                   (pad): ReflectionPad2d((1, 1, 1, 1))
#                   (ap): AdaptiveAvgPool2d(output_size=(1, 1))
#                   (gap): AdaptiveAvgPool2d(output_size=1)
#                 )
#               )
#               (relu): GELU(approximate='none')
#               (conv_sum): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             )
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#       )
#     )
#     (2): DBlock(
#       (layers): Sequential(
#         (0): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (1): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (2): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (3): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): DeepPoolLayer(
#               (pools): ModuleList(
#                 (0): AvgPool2d(kernel_size=8, stride=8, padding=0)
#                 (1): AvgPool2d(kernel_size=4, stride=4, padding=0)
#                 (2): AvgPool2d(kernel_size=2, stride=2, padding=0)
#               )
#               (convs): ModuleList(
#                 (0-2): 3 x Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#               (dynas): ModuleList(
#                 (0-2): 3 x dynamic_filter(
#                   (conv): Conv2d(32, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (bn): BatchNorm2d(72, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (act): Tanh()
#                   (pad): ReflectionPad2d((1, 1, 1, 1))
#                   (ap): AdaptiveAvgPool2d(output_size=(1, 1))
#                   (gap): AdaptiveAvgPool2d(output_size=1)
#                 )
#               )
#               (relu): GELU(approximate='none')
#               (conv_sum): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             )
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#       )
#     )
#   )
#   (Convs): ModuleList(
#     (0): BasicConv(
#       (main): Sequential(
#         (0): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1))
#         (1): GELU(approximate='none')
#       )
#     )
#     (1): BasicConv(
#       (main): Sequential(
#         (0): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#         (1): GELU(approximate='none')
#       )
#     )
#   )
#   (ConvsOut): ModuleList(
#     (0): BasicConv(
#       (main): Sequential(
#         (0): Conv2d(128, 3, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#     )
#     (1): BasicConv(
#       (main): Sequential(
#         (0): Conv2d(64, 3, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#     )
#   )
#   (FAM1): FAM(
#     (merge): BasicConv(
#       (main): Sequential(
#         (0): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#     )
#   )
#   (SCM1): SCM(
#     (main): Sequential(
#       (0): BasicConv(
#         (main): Sequential(
#           (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): GELU(approximate='none')
#         )
#       )
#       (1): BasicConv(
#         (main): Sequential(
#           (0): Conv2d(32, 64, kernel_size=(1, 1), stride=(1, 1))
#           (1): GELU(approximate='none')
#         )
#       )
#       (2): BasicConv(
#         (main): Sequential(
#           (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): GELU(approximate='none')
#         )
#       )
#       (3): BasicConv(
#         (main): Sequential(
#           (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1))
#         )
#       )
#       (4): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#     )
#   )
#   (FAM2): FAM(
#     (merge): BasicConv(
#       (main): Sequential(
#         (0): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#     )
#   )
#   (SCM2): SCM(
#     (main): Sequential(
#       (0): BasicConv(
#         (main): Sequential(
#           (0): Conv2d(3, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): GELU(approximate='none')
#         )
#       )
#       (1): BasicConv(
#         (main): Sequential(
#           (0): Conv2d(16, 32, kernel_size=(1, 1), stride=(1, 1))
#           (1): GELU(approximate='none')
#         )
#       )
#       (2): BasicConv(
#         (main): Sequential(
#           (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): GELU(approximate='none')
#         )
#       )
#       (3): BasicConv(
#         (main): Sequential(
#           (0): Conv2d(32, 64, kernel_size=(1, 1), stride=(1, 1))
#         )
#       )
#       (4): InstanceNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#     )
#   )
# )
# 1 iter PSNR_dehazing: 13.56 ssim: 0.782210
# 1 iter PSNR: 13.56 time: 0.021888
# 2 iter PSNR_dehazing: 8.59 ssim: 0.622711
# 2 iter PSNR: 8.59 time: 0.019607
# 3 iter PSNR_dehazing: 12.68 ssim: 0.760774
# 3 iter PSNR: 12.68 time: 0.019196
# 4 iter PSNR_dehazing: 11.92 ssim: 0.740624
# 4 iter PSNR: 11.92 time: 0.020180
# 5 iter PSNR_dehazing: 11.26 ssim: 0.721481
# 5 iter PSNR: 11.26 time: 0.019237
# 6 iter PSNR_dehazing: 10.68 ssim: 0.703185
# 6 iter PSNR: 10.68 time: 0.019125
# 7 iter PSNR_dehazing: 10.16 ssim: 0.685707
# 7 iter PSNR: 10.16 time: 0.020144
# 8 iter PSNR_dehazing: 9.71 ssim: 0.668991
# 8 iter PSNR: 9.71 time: 0.019958
# 9 iter PSNR_dehazing: 9.30 ssim: 0.652936
# 9 iter PSNR: 9.30 time: 0.020032
# 10 iter PSNR_dehazing: 8.93 ssim: 0.637521
# 10 iter PSNR: 8.93 time: 0.021199
# 11 iter PSNR_dehazing: 15.91 ssim: 0.806268
# 11 iter PSNR: 15.91 time: 0.020155
# 12 iter PSNR_dehazing: 10.89 ssim: 0.675899
# 12 iter PSNR: 10.89 time: 0.020386
# 13 iter PSNR_dehazing: 15.10 ssim: 0.786913
# 13 iter PSNR: 15.10 time: 0.020445
# 14 iter PSNR_dehazing: 14.37 ssim: 0.769683
# 14 iter PSNR: 14.37 time: 0.019515
# 15 iter PSNR_dehazing: 13.72 ssim: 0.753918
# 15 iter PSNR: 13.72 time: 0.019598
# 16 iter PSNR_dehazing: 13.13 ssim: 0.739213
# 16 iter PSNR: 13.13 time: 0.021467
# 17 iter PSNR_dehazing: 12.59 ssim: 0.725337
# 17 iter PSNR: 12.59 time: 0.022880
# 18 iter PSNR_dehazing: 12.11 ssim: 0.712150
# 18 iter PSNR: 12.11 time: 0.020969
# 19 iter PSNR_dehazing: 11.67 ssim: 0.699552
# 19 iter PSNR: 11.67 time: 0.021701
# 20 iter PSNR_dehazing: 11.26 ssim: 0.687475
# 20 iter PSNR: 11.26 time: 0.021832
# 21 iter PSNR_dehazing: 14.66 ssim: 0.704648
# 21 iter PSNR: 14.66 time: 0.020388
# 22 iter PSNR_dehazing: 9.34 ssim: 0.534752
# 22 iter PSNR: 9.34 time: 0.019729
# 23 iter PSNR_dehazing: 13.77 ssim: 0.676669
# 23 iter PSNR: 13.77 time: 0.020796
# 24 iter PSNR_dehazing: 12.98 ssim: 0.652449
# 24 iter PSNR: 12.98 time: 0.022024
# 25 iter PSNR_dehazing: 12.28 ssim: 0.630872
# 25 iter PSNR: 12.28 time: 0.019971
# 26 iter PSNR_dehazing: 11.66 ssim: 0.611389
# 26 iter PSNR: 11.66 time: 0.019435
# 27 iter PSNR_dehazing: 11.10 ssim: 0.593586
# 27 iter PSNR: 11.10 time: 0.020754
# 28 iter PSNR_dehazing: 10.60 ssim: 0.577203
# 28 iter PSNR: 10.60 time: 0.019860
# 29 iter PSNR_dehazing: 10.14 ssim: 0.562073
# 29 iter PSNR: 10.14 time: 0.019403
# 30 iter PSNR_dehazing: 9.72 ssim: 0.547961
# 30 iter PSNR: 9.72 time: 0.021441
# 31 iter PSNR_dehazing: 12.39 ssim: 0.645397
# 31 iter PSNR: 12.39 time: 0.022896
# 32 iter PSNR_dehazing: 7.01 ssim: 0.458376
# 32 iter PSNR: 7.01 time: 0.020661
# 33 iter PSNR_dehazing: 11.44 ssim: 0.616548
# 33 iter PSNR: 11.44 time: 0.020202
# 34 iter PSNR_dehazing: 10.62 ssim: 0.590560
# 34 iter PSNR: 10.62 time: 0.023398
# 35 iter PSNR_dehazing: 9.91 ssim: 0.566917
# 35 iter PSNR: 9.91 time: 0.020404
# 36 iter PSNR_dehazing: 9.28 ssim: 0.545230
# 36 iter PSNR: 9.28 time: 0.019934
# 37 iter PSNR_dehazing: 8.72 ssim: 0.525217
# 37 iter PSNR: 8.72 time: 0.022533
# 38 iter PSNR_dehazing: 8.22 ssim: 0.506668
# 38 iter PSNR: 8.22 time: 0.021010
# 39 iter PSNR_dehazing: 7.78 ssim: 0.489448
# 39 iter PSNR: 7.78 time: 0.021096
# 40 iter PSNR_dehazing: 7.37 ssim: 0.473361
# 40 iter PSNR: 7.37 time: 0.024056
# 41 iter PSNR_dehazing: 14.73 ssim: 0.811249
# 41 iter PSNR: 14.73 time: 0.020594
# 42 iter PSNR_dehazing: 9.59 ssim: 0.623657
# 42 iter PSNR: 9.59 time: 0.019932
# 43 iter PSNR_dehazing: 13.86 ssim: 0.786305
# 43 iter PSNR: 13.86 time: 0.020479
# 44 iter PSNR_dehazing: 13.09 ssim: 0.762451
# 44 iter PSNR: 13.09 time: 0.019816
# 45 iter PSNR_dehazing: 12.42 ssim: 0.739671
# 45 iter PSNR: 12.42 time: 0.019336
# 46 iter PSNR_dehazing: 11.82 ssim: 0.717951
# 46 iter PSNR: 11.82 time: 0.019694
# 47 iter PSNR_dehazing: 11.28 ssim: 0.697238
# 47 iter PSNR: 11.28 time: 0.019162
# 48 iter PSNR_dehazing: 10.79 ssim: 0.677489
# 48 iter PSNR: 10.79 time: 0.019552
# 49 iter PSNR_dehazing: 10.36 ssim: 0.658659
# 49 iter PSNR: 10.36 time: 0.020675
# 50 iter PSNR_dehazing: 9.96 ssim: 0.640734
# 50 iter PSNR: 9.96 time: 0.019641
# 51 iter PSNR_dehazing: 14.44 ssim: 0.834236
# 51 iter PSNR: 14.44 time: 0.020644
# 52 iter PSNR_dehazing: 9.45 ssim: 0.655551
# 52 iter PSNR: 9.45 time: 0.021160
# 53 iter PSNR_dehazing: 13.58 ssim: 0.810298
# 53 iter PSNR: 13.58 time: 0.021879
# 54 iter PSNR_dehazing: 12.83 ssim: 0.787433
# 54 iter PSNR: 12.83 time: 0.020098
# 55 iter PSNR_dehazing: 12.17 ssim: 0.765662
# 55 iter PSNR: 12.17 time: 0.020705
# 56 iter PSNR_dehazing: 11.59 ssim: 0.745010
# 56 iter PSNR: 11.59 time: 0.020520
# 57 iter PSNR_dehazing: 11.07 ssim: 0.725360
# 57 iter PSNR: 11.07 time: 0.022187
# 58 iter PSNR_dehazing: 10.60 ssim: 0.706669
# 58 iter PSNR: 10.60 time: 0.019611
# 59 iter PSNR_dehazing: 10.18 ssim: 0.688823
# 59 iter PSNR: 10.18 time: 0.019385
# 60 iter PSNR_dehazing: 9.79 ssim: 0.671814
# 60 iter PSNR: 9.79 time: 0.019738
# 61 iter PSNR_dehazing: 15.65 ssim: 0.859626
# 61 iter PSNR: 15.65 time: 0.019910
# 62 iter PSNR_dehazing: 10.79 ssim: 0.695731
# 62 iter PSNR: 10.79 time: 0.019827
# 63 iter PSNR_dehazing: 14.85 ssim: 0.839340
# 63 iter PSNR: 14.85 time: 0.019870
# 64 iter PSNR_dehazing: 14.14 ssim: 0.819134
# 64 iter PSNR: 14.14 time: 0.018852
# 65 iter PSNR_dehazing: 13.50 ssim: 0.799390
# 65 iter PSNR: 13.50 time: 0.020238
# 66 iter PSNR_dehazing: 12.93 ssim: 0.780305
# 66 iter PSNR: 12.93 time: 0.019628
# 67 iter PSNR_dehazing: 12.42 ssim: 0.761971
# 67 iter PSNR: 12.42 time: 0.019728
# 68 iter PSNR_dehazing: 11.96 ssim: 0.744327
# 68 iter PSNR: 11.96 time: 0.019248
# 69 iter PSNR_dehazing: 11.53 ssim: 0.727414
# 69 iter PSNR: 11.53 time: 0.020430
# 70 iter PSNR_dehazing: 11.15 ssim: 0.711243
# 70 iter PSNR: 11.15 time: 0.020728
# 71 iter PSNR_dehazing: 15.43 ssim: 0.884902
# 71 iter PSNR: 15.43 time: 0.019652
# 72 iter PSNR_dehazing: 10.61 ssim: 0.733228
# 72 iter PSNR: 10.61 time: 0.020708
# 73 iter PSNR_dehazing: 14.63 ssim: 0.867513
# 73 iter PSNR: 14.63 time: 0.022713
# 74 iter PSNR_dehazing: 13.91 ssim: 0.850076
# 74 iter PSNR: 13.91 time: 0.020170
# 75 iter PSNR_dehazing: 13.28 ssim: 0.832735
# 75 iter PSNR: 13.28 time: 0.020141
# 76 iter PSNR_dehazing: 12.71 ssim: 0.815523
# 76 iter PSNR: 12.71 time: 0.022738
# 77 iter PSNR_dehazing: 12.20 ssim: 0.798542
# 77 iter PSNR: 12.20 time: 0.019357
# 78 iter PSNR_dehazing: 11.74 ssim: 0.781803
# 78 iter PSNR: 11.74 time: 0.019875
# 79 iter PSNR_dehazing: 11.33 ssim: 0.765271
# 79 iter PSNR: 11.33 time: 0.019846
# 80 iter PSNR_dehazing: 10.95 ssim: 0.749122
# 80 iter PSNR: 10.95 time: 0.021251
# 81 iter PSNR_dehazing: 15.69 ssim: 0.893387
# 81 iter PSNR: 15.69 time: 0.024039
# 82 iter PSNR_dehazing: 10.90 ssim: 0.732830
# 82 iter PSNR: 10.90 time: 0.020329
# 83 iter PSNR_dehazing: 14.90 ssim: 0.876132
# 83 iter PSNR: 14.90 time: 0.019887
# 84 iter PSNR_dehazing: 14.19 ssim: 0.858336
# 84 iter PSNR: 14.19 time: 0.021521
# 85 iter PSNR_dehazing: 13.57 ssim: 0.840259
# 85 iter PSNR: 13.57 time: 0.019267
# 86 iter PSNR_dehazing: 13.00 ssim: 0.822080
# 86 iter PSNR: 13.00 time: 0.019848
# 87 iter PSNR_dehazing: 12.50 ssim: 0.803921
# 87 iter PSNR: 12.50 time: 0.018938
# 88 iter PSNR_dehazing: 12.04 ssim: 0.785810
# 88 iter PSNR: 12.04 time: 0.019737
# 89 iter PSNR_dehazing: 11.63 ssim: 0.767848
# 89 iter PSNR: 11.63 time: 0.019047
# 90 iter PSNR_dehazing: 11.25 ssim: 0.750175
# 90 iter PSNR: 11.25 time: 0.020173
# 91 iter PSNR_dehazing: 15.90 ssim: 0.873805
# 91 iter PSNR: 15.90 time: 0.019516
# 92 iter PSNR_dehazing: 11.36 ssim: 0.700963
# 92 iter PSNR: 11.36 time: 0.019506
# 93 iter PSNR_dehazing: 15.14 ssim: 0.856128
# 93 iter PSNR: 15.14 time: 0.019465
# 94 iter PSNR_dehazing: 14.47 ssim: 0.836794
# 94 iter PSNR: 14.47 time: 0.018925
# 95 iter PSNR_dehazing: 13.87 ssim: 0.816296
# 95 iter PSNR: 13.87 time: 0.019959
# 96 iter PSNR_dehazing: 13.34 ssim: 0.795762
# 96 iter PSNR: 13.34 time: 0.019533
# 97 iter PSNR_dehazing: 12.85 ssim: 0.775655
# 97 iter PSNR: 12.85 time: 0.019402
# 98 iter PSNR_dehazing: 12.42 ssim: 0.756102
# 98 iter PSNR: 12.42 time: 0.021922
# 99 iter PSNR_dehazing: 12.03 ssim: 0.737113
# 99 iter PSNR: 12.03 time: 0.019238
# 100 iter PSNR_dehazing: 11.68 ssim: 0.718732
# 100 iter PSNR: 11.68 time: 0.020974
# 101 iter PSNR_dehazing: 15.28 ssim: 0.880872
# 101 iter PSNR: 15.28 time: 0.020354
# 102 iter PSNR_dehazing: 10.41 ssim: 0.748063
# 102 iter PSNR: 10.41 time: 0.020385
# 103 iter PSNR_dehazing: 14.47 ssim: 0.865067
# 103 iter PSNR: 14.47 time: 0.019996
# 104 iter PSNR_dehazing: 13.75 ssim: 0.849342
# 104 iter PSNR: 13.75 time: 0.019882
# 105 iter PSNR_dehazing: 13.11 ssim: 0.833857
# 105 iter PSNR: 13.11 time: 0.020444
# 106 iter PSNR_dehazing: 12.54 ssim: 0.818641
# 106 iter PSNR: 12.54 time: 0.020066
# 107 iter PSNR_dehazing: 12.03 ssim: 0.803775
# 107 iter PSNR: 12.03 time: 0.020200
# 108 iter PSNR_dehazing: 11.56 ssim: 0.789262
# 108 iter PSNR: 11.56 time: 0.019408
# 109 iter PSNR_dehazing: 11.14 ssim: 0.775162
# 109 iter PSNR: 11.14 time: 0.020156
# 110 iter PSNR_dehazing: 10.76 ssim: 0.761460
# 110 iter PSNR: 10.76 time: 0.019823
# 111 iter PSNR_dehazing: 12.99 ssim: 0.740664
# 111 iter PSNR: 12.99 time: 0.021069
# 112 iter PSNR_dehazing: 7.93 ssim: 0.568743
# 112 iter PSNR: 7.93 time: 0.021175
# 113 iter PSNR_dehazing: 12.07 ssim: 0.715521
# 113 iter PSNR: 12.07 time: 0.020135
# 114 iter PSNR_dehazing: 11.29 ssim: 0.692421
# 114 iter PSNR: 11.29 time: 0.020872
# 115 iter PSNR_dehazing: 10.62 ssim: 0.670990
# 115 iter PSNR: 10.62 time: 0.020125
# 116 iter PSNR_dehazing: 10.02 ssim: 0.650973
# 116 iter PSNR: 10.02 time: 0.019810
# 117 iter PSNR_dehazing: 9.50 ssim: 0.632278
# 117 iter PSNR: 9.50 time: 0.020023
# 118 iter PSNR_dehazing: 9.04 ssim: 0.614794
# 118 iter PSNR: 9.04 time: 0.019616
# 119 iter PSNR_dehazing: 8.63 ssim: 0.598409
# 119 iter PSNR: 8.63 time: 0.019514
# 120 iter PSNR_dehazing: 8.26 ssim: 0.583106
# 120 iter PSNR: 8.26 time: 0.019509
# 121 iter PSNR_dehazing: 14.27 ssim: 0.804753
# 121 iter PSNR: 14.27 time: 0.019381
# 122 iter PSNR_dehazing: 9.28 ssim: 0.639016
# 122 iter PSNR: 9.28 time: 0.020286
# 123 iter PSNR_dehazing: 13.41 ssim: 0.782267
# 123 iter PSNR: 13.41 time: 0.019669
# 124 iter PSNR_dehazing: 12.65 ssim: 0.761136
# 124 iter PSNR: 12.65 time: 0.020705
# 125 iter PSNR_dehazing: 11.99 ssim: 0.741109
# 125 iter PSNR: 11.99 time: 0.021146
# 126 iter PSNR_dehazing: 11.41 ssim: 0.722055
# 126 iter PSNR: 11.41 time: 0.019358
# 127 iter PSNR_dehazing: 10.89 ssim: 0.703935
# 127 iter PSNR: 10.89 time: 0.020464
# 128 iter PSNR_dehazing: 10.43 ssim: 0.686611
# 128 iter PSNR: 10.43 time: 0.019173
# 129 iter PSNR_dehazing: 10.01 ssim: 0.670048
# 129 iter PSNR: 10.01 time: 0.021006
# 130 iter PSNR_dehazing: 9.63 ssim: 0.654211
# 130 iter PSNR: 9.63 time: 0.019172
# 131 iter PSNR_dehazing: 11.38 ssim: 0.720599
# 131 iter PSNR: 11.38 time: 0.019635
# 132 iter PSNR_dehazing: 6.70 ssim: 0.504015
# 132 iter PSNR: 6.70 time: 0.019296
# 133 iter PSNR_dehazing: 10.50 ssim: 0.688128
# 133 iter PSNR: 10.50 time: 0.019328
# 134 iter PSNR_dehazing: 9.75 ssim: 0.658088
# 134 iter PSNR: 9.75 time: 0.019929
# 135 iter PSNR_dehazing: 9.12 ssim: 0.630551
# 135 iter PSNR: 9.12 time: 0.019479
# 136 iter PSNR_dehazing: 8.57 ssim: 0.604838
# 136 iter PSNR: 8.57 time: 0.019351
# 137 iter PSNR_dehazing: 8.09 ssim: 0.581173
# 137 iter PSNR: 8.09 time: 0.019479
# 138 iter PSNR_dehazing: 7.68 ssim: 0.559407
# 138 iter PSNR: 7.68 time: 0.019413
# 139 iter PSNR_dehazing: 7.31 ssim: 0.539325
# 139 iter PSNR: 7.31 time: 0.019066
# 140 iter PSNR_dehazing: 6.99 ssim: 0.520922
# 140 iter PSNR: 6.99 time: 0.019372
# 141 iter PSNR_dehazing: 12.81 ssim: 0.720126
# 141 iter PSNR: 12.81 time: 0.019853
# 142 iter PSNR_dehazing: 7.89 ssim: 0.514370
# 142 iter PSNR: 7.89 time: 0.018898
# 143 iter PSNR_dehazing: 11.91 ssim: 0.691154
# 143 iter PSNR: 11.91 time: 0.021759
# 144 iter PSNR_dehazing: 11.15 ssim: 0.663896
# 144 iter PSNR: 11.15 time: 0.019926
# 145 iter PSNR_dehazing: 10.49 ssim: 0.638288
# 145 iter PSNR: 10.49 time: 0.018696
# 146 iter PSNR_dehazing: 9.91 ssim: 0.614066
# 146 iter PSNR: 9.91 time: 0.019322
# 147 iter PSNR_dehazing: 9.41 ssim: 0.591229
# 147 iter PSNR: 9.41 time: 0.018234
# 148 iter PSNR_dehazing: 8.96 ssim: 0.569905
# 148 iter PSNR: 8.96 time: 0.018748
# 149 iter PSNR_dehazing: 8.56 ssim: 0.550038
# 149 iter PSNR: 8.56 time: 0.019096
# 150 iter PSNR_dehazing: 8.21 ssim: 0.531544
# 150 iter PSNR: 8.21 time: 0.019228
# 151 iter PSNR_dehazing: 14.16 ssim: 0.831464
# 151 iter PSNR: 14.16 time: 0.020627
# 152 iter PSNR_dehazing: 9.03 ssim: 0.654812
# 152 iter PSNR: 9.03 time: 0.020445
# 153 iter PSNR_dehazing: 13.28 ssim: 0.807573
# 153 iter PSNR: 13.28 time: 0.020038
# 154 iter PSNR_dehazing: 12.51 ssim: 0.784655
# 154 iter PSNR: 12.51 time: 0.019246
# 155 iter PSNR_dehazing: 11.83 ssim: 0.762855
# 155 iter PSNR: 11.83 time: 0.021424
# 156 iter PSNR_dehazing: 11.23 ssim: 0.742224
# 156 iter PSNR: 11.23 time: 0.019767
# 157 iter PSNR_dehazing: 10.70 ssim: 0.722692
# 157 iter PSNR: 10.70 time: 0.019386
# 158 iter PSNR_dehazing: 10.22 ssim: 0.704281
# 158 iter PSNR: 10.22 time: 0.021945
# 159 iter PSNR_dehazing: 9.78 ssim: 0.686849
# 159 iter PSNR: 9.78 time: 0.019827
# 160 iter PSNR_dehazing: 9.39 ssim: 0.670411
# 160 iter PSNR: 9.39 time: 0.019039
# 161 iter PSNR_dehazing: 16.28 ssim: 0.911014
# 161 iter PSNR: 16.28 time: 0.020811
# 162 iter PSNR_dehazing: 11.85 ssim: 0.824899
# 162 iter PSNR: 11.85 time: 0.019234
# 163 iter PSNR_dehazing: 15.57 ssim: 0.900157
# 163 iter PSNR: 15.57 time: 0.020537
# 164 iter PSNR_dehazing: 14.92 ssim: 0.889653
# 164 iter PSNR: 14.92 time: 0.020267
# 165 iter PSNR_dehazing: 14.34 ssim: 0.879498
# 165 iter PSNR: 14.34 time: 0.019246
# 166 iter PSNR_dehazing: 13.82 ssim: 0.869661
# 166 iter PSNR: 13.82 time: 0.019797
# 167 iter PSNR_dehazing: 13.35 ssim: 0.860127
# 167 iter PSNR: 13.35 time: 0.019423
# 168 iter PSNR_dehazing: 12.92 ssim: 0.850898
# 168 iter PSNR: 12.92 time: 0.019577
# 169 iter PSNR_dehazing: 12.53 ssim: 0.841960
# 169 iter PSNR: 12.53 time: 0.020637
# 170 iter PSNR_dehazing: 12.17 ssim: 0.833301
# 170 iter PSNR: 12.17 time: 0.019194
# 171 iter PSNR_dehazing: 14.21 ssim: 0.811340
# 171 iter PSNR: 14.21 time: 0.019348
# 172 iter PSNR_dehazing: 9.35 ssim: 0.576900
# 172 iter PSNR: 9.35 time: 0.020376
# 173 iter PSNR_dehazing: 13.36 ssim: 0.780437
# 173 iter PSNR: 13.36 time: 0.022648
# 174 iter PSNR_dehazing: 12.62 ssim: 0.750553
# 174 iter PSNR: 12.62 time: 0.019297
# 175 iter PSNR_dehazing: 11.97 ssim: 0.721675
# 175 iter PSNR: 11.97 time: 0.020919
# 176 iter PSNR_dehazing: 11.40 ssim: 0.693929
# 176 iter PSNR: 11.40 time: 0.020424
# 177 iter PSNR_dehazing: 10.90 ssim: 0.667562
# 177 iter PSNR: 10.90 time: 0.019061
# 178 iter PSNR_dehazing: 10.45 ssim: 0.642703
# 178 iter PSNR: 10.45 time: 0.019858
# 179 iter PSNR_dehazing: 10.04 ssim: 0.619372
# 179 iter PSNR: 10.04 time: 0.019373
# 180 iter PSNR_dehazing: 9.68 ssim: 0.597461
# 180 iter PSNR: 9.68 time: 0.019941
# 181 iter PSNR_dehazing: 14.67 ssim: 0.802940
# 181 iter PSNR: 14.67 time: 0.020957
# 182 iter PSNR_dehazing: 9.69 ssim: 0.589979
# 182 iter PSNR: 9.69 time: 0.021141
# 183 iter PSNR_dehazing: 13.82 ssim: 0.776009
# 183 iter PSNR: 13.82 time: 0.019449
# 184 iter PSNR_dehazing: 13.08 ssim: 0.749833
# 184 iter PSNR: 13.08 time: 0.021214
# 185 iter PSNR_dehazing: 12.42 ssim: 0.724503
# 185 iter PSNR: 12.42 time: 0.019720
# 186 iter PSNR_dehazing: 11.84 ssim: 0.699941
# 186 iter PSNR: 11.84 time: 0.019732
# 187 iter PSNR_dehazing: 11.31 ssim: 0.676204
# 187 iter PSNR: 11.31 time: 0.020968
# 188 iter PSNR_dehazing: 10.85 ssim: 0.653390
# 188 iter PSNR: 10.85 time: 0.020444
# 189 iter PSNR_dehazing: 10.42 ssim: 0.631372
# 189 iter PSNR: 10.42 time: 0.019708
# 190 iter PSNR_dehazing: 10.04 ssim: 0.610262
# 190 iter PSNR: 10.04 time: 0.019337
# 191 iter PSNR_dehazing: 14.61 ssim: 0.826207
# 191 iter PSNR: 14.61 time: 0.019120
# 192 iter PSNR_dehazing: 9.69 ssim: 0.626422
# 192 iter PSNR: 9.69 time: 0.019999
# 193 iter PSNR_dehazing: 13.77 ssim: 0.801058
# 193 iter PSNR: 13.77 time: 0.019289
# 194 iter PSNR_dehazing: 13.03 ssim: 0.776620
# 194 iter PSNR: 13.03 time: 0.019169
# 195 iter PSNR_dehazing: 12.38 ssim: 0.752987
# 195 iter PSNR: 12.38 time: 0.018843
# 196 iter PSNR_dehazing: 11.81 ssim: 0.730077
# 196 iter PSNR: 11.81 time: 0.019397
# 197 iter PSNR_dehazing: 11.29 ssim: 0.707908
# 197 iter PSNR: 11.29 time: 0.019134
# 198 iter PSNR_dehazing: 10.83 ssim: 0.686491
# 198 iter PSNR: 10.83 time: 0.022195
# 199 iter PSNR_dehazing: 10.41 ssim: 0.665814
# 199 iter PSNR: 10.41 time: 0.019220
# 200 iter PSNR_dehazing: 10.04 ssim: 0.645820
# 200 iter PSNR: 10.04 time: 0.018997
# 201 iter PSNR_dehazing: 11.77 ssim: 0.723226
# 201 iter PSNR: 11.77 time: 0.021098
# 202 iter PSNR_dehazing: 6.96 ssim: 0.467284
# 202 iter PSNR: 6.96 time: 0.019760
# 203 iter PSNR_dehazing: 10.88 ssim: 0.688268
# 203 iter PSNR: 10.88 time: 0.019696
# 204 iter PSNR_dehazing: 10.12 ssim: 0.654966
# 204 iter PSNR: 10.12 time: 0.019681
# 205 iter PSNR_dehazing: 9.47 ssim: 0.623307
# 205 iter PSNR: 9.47 time: 0.019639
# 206 iter PSNR_dehazing: 8.91 ssim: 0.593223
# 206 iter PSNR: 8.91 time: 0.021320
# 207 iter PSNR_dehazing: 8.41 ssim: 0.564690
# 207 iter PSNR: 8.41 time: 0.020853
# 208 iter PSNR_dehazing: 7.98 ssim: 0.537750
# 208 iter PSNR: 7.98 time: 0.019875
# 209 iter PSNR_dehazing: 7.60 ssim: 0.512625
# 209 iter PSNR: 7.60 time: 0.020066
# 210 iter PSNR_dehazing: 7.26 ssim: 0.489222
# 210 iter PSNR: 7.26 time: 0.019305
# 211 iter PSNR_dehazing: 14.95 ssim: 0.819553
# 211 iter PSNR: 14.95 time: 0.019864
# 212 iter PSNR_dehazing: 9.73 ssim: 0.669244
# 212 iter PSNR: 9.73 time: 0.020743
# 213 iter PSNR_dehazing: 14.09 ssim: 0.799390
# 213 iter PSNR: 14.09 time: 0.019174
# 214 iter PSNR_dehazing: 13.33 ssim: 0.780368
# 214 iter PSNR: 13.33 time: 0.019291
# 215 iter PSNR_dehazing: 12.65 ssim: 0.762329
# 215 iter PSNR: 12.65 time: 0.019678
# 216 iter PSNR_dehazing: 12.04 ssim: 0.745111
# 216 iter PSNR: 12.04 time: 0.020676
# 217 iter PSNR_dehazing: 11.48 ssim: 0.728700
# 217 iter PSNR: 11.48 time: 0.019531
# 218 iter PSNR_dehazing: 10.99 ssim: 0.712956
# 218 iter PSNR: 10.99 time: 0.019394
# 219 iter PSNR_dehazing: 10.53 ssim: 0.697850
# 219 iter PSNR: 10.53 time: 0.019304
# 220 iter PSNR_dehazing: 10.12 ssim: 0.683261
# 220 iter PSNR: 10.12 time: 0.019415
# 221 iter PSNR_dehazing: 13.31 ssim: 0.664865
# 221 iter PSNR: 13.31 time: 0.019475
# 222 iter PSNR_dehazing: 8.00 ssim: 0.516101
# 222 iter PSNR: 8.00 time: 0.019021
# 223 iter PSNR_dehazing: 12.39 ssim: 0.641713
# 223 iter PSNR: 12.39 time: 0.019216
# 224 iter PSNR_dehazing: 11.59 ssim: 0.621215
# 224 iter PSNR: 11.59 time: 0.019420
# 225 iter PSNR_dehazing: 10.89 ssim: 0.602636
# 225 iter PSNR: 10.89 time: 0.018660
# 226 iter PSNR_dehazing: 10.27 ssim: 0.585598
# 226 iter PSNR: 10.27 time: 0.018904
# 227 iter PSNR_dehazing: 9.72 ssim: 0.569802
# 227 iter PSNR: 9.72 time: 0.019577
# 228 iter PSNR_dehazing: 9.22 ssim: 0.555080
# 228 iter PSNR: 9.22 time: 0.021241
# 229 iter PSNR_dehazing: 8.78 ssim: 0.541286
# 229 iter PSNR: 8.78 time: 0.020778
# 230 iter PSNR_dehazing: 8.37 ssim: 0.528339
# 230 iter PSNR: 8.37 time: 0.020441
# 231 iter PSNR_dehazing: 11.64 ssim: 0.613450
# 231 iter PSNR: 11.64 time: 0.020946
# 232 iter PSNR_dehazing: 6.51 ssim: 0.449995
# 232 iter PSNR: 6.51 time: 0.022571
# 233 iter PSNR_dehazing: 10.71 ssim: 0.586917
# 233 iter PSNR: 10.71 time: 0.020170
# 234 iter PSNR_dehazing: 9.92 ssim: 0.563513
# 234 iter PSNR: 9.92 time: 0.020287
# 235 iter PSNR_dehazing: 9.23 ssim: 0.542560
# 235 iter PSNR: 9.23 time: 0.020042
# 236 iter PSNR_dehazing: 8.64 ssim: 0.523597
# 236 iter PSNR: 8.64 time: 0.020412
# 237 iter PSNR_dehazing: 8.11 ssim: 0.506333
# 237 iter PSNR: 8.11 time: 0.020372
# 238 iter PSNR_dehazing: 7.64 ssim: 0.490511
# 238 iter PSNR: 7.64 time: 0.019934
# 239 iter PSNR_dehazing: 7.22 ssim: 0.475924
# 239 iter PSNR: 7.22 time: 0.019596
# 240 iter PSNR_dehazing: 6.85 ssim: 0.462466
# 240 iter PSNR: 6.85 time: 0.022782
# 241 iter PSNR_dehazing: 13.64 ssim: 0.775000
# 241 iter PSNR: 13.64 time: 0.019714
# 242 iter PSNR_dehazing: 8.57 ssim: 0.595784
# 242 iter PSNR: 8.57 time: 0.019326
# 243 iter PSNR_dehazing: 12.76 ssim: 0.750170
# 243 iter PSNR: 12.76 time: 0.020301
# 244 iter PSNR_dehazing: 11.99 ssim: 0.726881
# 244 iter PSNR: 11.99 time: 0.019796
# 245 iter PSNR_dehazing: 11.32 ssim: 0.704946
# 245 iter PSNR: 11.32 time: 0.021009
# 246 iter PSNR_dehazing: 10.73 ssim: 0.684238
# 246 iter PSNR: 10.73 time: 0.019979
# 247 iter PSNR_dehazing: 10.20 ssim: 0.664633
# 247 iter PSNR: 10.20 time: 0.021429
# 248 iter PSNR_dehazing: 9.73 ssim: 0.646035
# 248 iter PSNR: 9.73 time: 0.021283
# 249 iter PSNR_dehazing: 9.30 ssim: 0.628412
# 249 iter PSNR: 9.30 time: 0.021837
# 250 iter PSNR_dehazing: 8.92 ssim: 0.611659
# 250 iter PSNR: 8.92 time: 0.022249
# 251 iter PSNR_dehazing: 11.47 ssim: 0.676749
# 251 iter PSNR: 11.47 time: 0.019873
# 252 iter PSNR_dehazing: 6.53 ssim: 0.465190
# 252 iter PSNR: 6.53 time: 0.020956
# 253 iter PSNR_dehazing: 10.56 ssim: 0.646330
# 253 iter PSNR: 10.56 time: 0.020648
# 254 iter PSNR_dehazing: 9.78 ssim: 0.618225
# 254 iter PSNR: 9.78 time: 0.019879
# 255 iter PSNR_dehazing: 9.12 ssim: 0.592169
# 255 iter PSNR: 9.12 time: 0.019630
# 256 iter PSNR_dehazing: 8.54 ssim: 0.567732
# 256 iter PSNR: 8.54 time: 0.019405
# 257 iter PSNR_dehazing: 8.04 ssim: 0.544788
# 257 iter PSNR: 8.04 time: 0.019663
# 258 iter PSNR_dehazing: 7.59 ssim: 0.523170
# 258 iter PSNR: 7.59 time: 0.019453
# 259 iter PSNR_dehazing: 7.20 ssim: 0.502705
# 259 iter PSNR: 7.20 time: 0.019455
# 260 iter PSNR_dehazing: 6.85 ssim: 0.483412
# 260 iter PSNR: 6.85 time: 0.019423
# 261 iter PSNR_dehazing: 13.06 ssim: 0.693246
# 261 iter PSNR: 13.06 time: 0.019691
# 262 iter PSNR_dehazing: 7.80 ssim: 0.518120
# 262 iter PSNR: 7.80 time: 0.019335
# 263 iter PSNR_dehazing: 12.14 ssim: 0.668038
# 263 iter PSNR: 12.14 time: 0.019375
# 264 iter PSNR_dehazing: 11.34 ssim: 0.644955
# 264 iter PSNR: 11.34 time: 0.019111
# 265 iter PSNR_dehazing: 10.64 ssim: 0.623468
# 265 iter PSNR: 10.64 time: 0.021216
# 266 iter PSNR_dehazing: 10.03 ssim: 0.603385
# 266 iter PSNR: 10.03 time: 0.019668
# 267 iter PSNR_dehazing: 9.48 ssim: 0.584474
# 267 iter PSNR: 9.48 time: 0.018964
# 268 iter PSNR_dehazing: 8.99 ssim: 0.566593
# 268 iter PSNR: 8.99 time: 0.019920
# 269 iter PSNR_dehazing: 8.55 ssim: 0.549621
# 269 iter PSNR: 8.55 time: 0.019500
# 270 iter PSNR_dehazing: 8.16 ssim: 0.533527
# 270 iter PSNR: 8.16 time: 0.019813
# 271 iter PSNR_dehazing: 16.24 ssim: 0.789992
# 271 iter PSNR: 16.24 time: 0.019388
# 272 iter PSNR_dehazing: 11.05 ssim: 0.661950
# 272 iter PSNR: 11.05 time: 0.020577
# 273 iter PSNR_dehazing: 15.42 ssim: 0.768598
# 273 iter PSNR: 15.42 time: 0.019660
# 274 iter PSNR_dehazing: 14.68 ssim: 0.751042
# 274 iter PSNR: 14.68 time: 0.020207
# 275 iter PSNR_dehazing: 14.02 ssim: 0.735521
# 275 iter PSNR: 14.02 time: 0.020611
# 276 iter PSNR_dehazing: 13.41 ssim: 0.721302
# 276 iter PSNR: 13.41 time: 0.020027
# 277 iter PSNR_dehazing: 12.85 ssim: 0.708034
# 277 iter PSNR: 12.85 time: 0.020271
# 278 iter PSNR_dehazing: 12.34 ssim: 0.695567
# 278 iter PSNR: 12.34 time: 0.020707
# 279 iter PSNR_dehazing: 11.88 ssim: 0.683784
# 279 iter PSNR: 11.88 time: 0.019556
# 280 iter PSNR_dehazing: 11.45 ssim: 0.672620
# 280 iter PSNR: 11.45 time: 0.020159
# 281 iter PSNR_dehazing: 13.41 ssim: 0.739346
# 281 iter PSNR: 13.41 time: 0.019341
# 282 iter PSNR_dehazing: 8.25 ssim: 0.577942
# 282 iter PSNR: 8.25 time: 0.020047
# 283 iter PSNR_dehazing: 12.51 ssim: 0.717071
# 283 iter PSNR: 12.51 time: 0.021155
# 284 iter PSNR_dehazing: 11.72 ssim: 0.696311
# 284 iter PSNR: 11.72 time: 0.019313
# 285 iter PSNR_dehazing: 11.04 ssim: 0.676775
# 285 iter PSNR: 11.04 time: 0.019336
# 286 iter PSNR_dehazing: 10.43 ssim: 0.658240
# 286 iter PSNR: 10.43 time: 0.019330
# 287 iter PSNR_dehazing: 9.90 ssim: 0.640673
# 287 iter PSNR: 9.90 time: 0.019118
# 288 iter PSNR_dehazing: 9.42 ssim: 0.623910
# 288 iter PSNR: 9.42 time: 0.019356
# 289 iter PSNR_dehazing: 8.99 ssim: 0.607893
# 289 iter PSNR: 8.99 time: 0.019487
# 290 iter PSNR_dehazing: 8.60 ssim: 0.592597
# 290 iter PSNR: 8.60 time: 0.019199
# 291 iter PSNR_dehazing: 11.28 ssim: 0.609968
# 291 iter PSNR: 11.28 time: 0.019099
# 292 iter PSNR_dehazing: 6.28 ssim: 0.422556
# 292 iter PSNR: 6.28 time: 0.019692
# 293 iter PSNR_dehazing: 10.35 ssim: 0.580897
# 293 iter PSNR: 10.35 time: 0.018797
# 294 iter PSNR_dehazing: 9.57 ssim: 0.554945
# 294 iter PSNR: 9.57 time: 0.019585
# 295 iter PSNR_dehazing: 8.90 ssim: 0.531421
# 295 iter PSNR: 8.90 time: 0.019713
# 296 iter PSNR_dehazing: 8.32 ssim: 0.509789
# 296 iter PSNR: 8.32 time: 0.019018
# 297 iter PSNR_dehazing: 7.81 ssim: 0.489839
# 297 iter PSNR: 7.81 time: 0.019973
# 298 iter PSNR_dehazing: 7.36 ssim: 0.471255
# 298 iter PSNR: 7.36 time: 0.019805
# 299 iter PSNR_dehazing: 6.96 ssim: 0.453950
# 299 iter PSNR: 6.96 time: 0.019394
# 300 iter PSNR_dehazing: 6.60 ssim: 0.437741
# 300 iter PSNR: 6.60 time: 0.018915
# 301 iter PSNR_dehazing: 12.56 ssim: 0.548497
# 301 iter PSNR: 12.56 time: 0.019145
# 302 iter PSNR_dehazing: 7.05 ssim: 0.388759
# 302 iter PSNR: 7.05 time: 0.019169
# 303 iter PSNR_dehazing: 11.60 ssim: 0.522115
# 303 iter PSNR: 11.60 time: 0.019483
# 304 iter PSNR_dehazing: 10.77 ssim: 0.499108
# 304 iter PSNR: 10.77 time: 0.019723
# 305 iter PSNR_dehazing: 10.04 ssim: 0.478629
# 305 iter PSNR: 10.04 time: 0.019861
# 306 iter PSNR_dehazing: 9.40 ssim: 0.460195
# 306 iter PSNR: 9.40 time: 0.020041
# 307 iter PSNR_dehazing: 8.82 ssim: 0.443387
# 307 iter PSNR: 8.82 time: 0.019920
# 308 iter PSNR_dehazing: 8.31 ssim: 0.428073
# 308 iter PSNR: 8.31 time: 0.019618
# 309 iter PSNR_dehazing: 7.85 ssim: 0.413905
# 309 iter PSNR: 7.85 time: 0.019608
# 310 iter PSNR_dehazing: 7.43 ssim: 0.400876
# 310 iter PSNR: 7.43 time: 0.020101
# 311 iter PSNR_dehazing: 12.94 ssim: 0.654617
# 311 iter PSNR: 12.94 time: 0.020040
# 312 iter PSNR_dehazing: 7.62 ssim: 0.449820
# 312 iter PSNR: 7.62 time: 0.020464
# 313 iter PSNR_dehazing: 12.00 ssim: 0.624673
# 313 iter PSNR: 12.00 time: 0.020076
# 314 iter PSNR_dehazing: 11.19 ssim: 0.594166
# 314 iter PSNR: 11.19 time: 0.018937
# 315 iter PSNR_dehazing: 10.48 ssim: 0.566799
# 315 iter PSNR: 10.48 time: 0.019112
# 316 iter PSNR_dehazing: 9.86 ssim: 0.542504
# 316 iter PSNR: 9.86 time: 0.019017
# 317 iter PSNR_dehazing: 9.31 ssim: 0.520614
# 317 iter PSNR: 9.31 time: 0.019126
# 318 iter PSNR_dehazing: 8.82 ssim: 0.500669
# 318 iter PSNR: 8.82 time: 0.019484
# 319 iter PSNR_dehazing: 8.38 ssim: 0.482356
# 319 iter PSNR: 8.38 time: 0.019250
# 320 iter PSNR_dehazing: 7.98 ssim: 0.465461
# 320 iter PSNR: 7.98 time: 0.022712
# 321 iter PSNR_dehazing: 15.52 ssim: 0.712100
# 321 iter PSNR: 15.52 time: 0.019136
# 322 iter PSNR_dehazing: 10.22 ssim: 0.529528
# 322 iter PSNR: 10.22 time: 0.018788
# 323 iter PSNR_dehazing: 14.66 ssim: 0.687120
# 323 iter PSNR: 14.66 time: 0.019911
# 324 iter PSNR_dehazing: 13.88 ssim: 0.663585
# 324 iter PSNR: 13.88 time: 0.019031
# 325 iter PSNR_dehazing: 13.19 ssim: 0.642409
# 325 iter PSNR: 13.19 time: 0.019315
# 326 iter PSNR_dehazing: 12.57 ssim: 0.623489
# 326 iter PSNR: 12.57 time: 0.020822
# 327 iter PSNR_dehazing: 12.01 ssim: 0.605893
# 327 iter PSNR: 12.01 time: 0.019501
# 328 iter PSNR_dehazing: 11.50 ssim: 0.588551
# 328 iter PSNR: 11.50 time: 0.019644
# 329 iter PSNR_dehazing: 11.04 ssim: 0.568820
# 329 iter PSNR: 11.04 time: 0.020838
# 330 iter PSNR_dehazing: 10.61 ssim: 0.548563
# 330 iter PSNR: 10.61 time: 0.020234
# 331 iter PSNR_dehazing: 14.69 ssim: 0.732430
# 331 iter PSNR: 14.69 time: 0.021404
# 332 iter PSNR_dehazing: 9.38 ssim: 0.528785
# 332 iter PSNR: 9.38 time: 0.019274
# 333 iter PSNR_dehazing: 13.80 ssim: 0.703464
# 333 iter PSNR: 13.80 time: 0.019796
# 334 iter PSNR_dehazing: 13.02 ssim: 0.675545
# 334 iter PSNR: 13.02 time: 0.019328
# 335 iter PSNR_dehazing: 12.32 ssim: 0.649122
# 335 iter PSNR: 12.32 time: 0.020386
# 336 iter PSNR_dehazing: 11.70 ssim: 0.624993
# 336 iter PSNR: 11.70 time: 0.019212
# 337 iter PSNR_dehazing: 11.14 ssim: 0.602811
# 337 iter PSNR: 11.14 time: 0.019590
# 338 iter PSNR_dehazing: 10.64 ssim: 0.582341
# 338 iter PSNR: 10.64 time: 0.020883
# 339 iter PSNR_dehazing: 10.18 ssim: 0.563268
# 339 iter PSNR: 10.18 time: 0.019870
# 340 iter PSNR_dehazing: 9.77 ssim: 0.545470
# 340 iter PSNR: 9.77 time: 0.020960
# 341 iter PSNR_dehazing: 14.05 ssim: 0.854071
# 341 iter PSNR: 14.05 time: 0.020092
# 342 iter PSNR_dehazing: 9.17 ssim: 0.702651
# 342 iter PSNR: 9.17 time: 0.020186
# 343 iter PSNR_dehazing: 13.20 ssim: 0.834524
# 343 iter PSNR: 13.20 time: 0.019749
# 344 iter PSNR_dehazing: 12.47 ssim: 0.815474
# 344 iter PSNR: 12.47 time: 0.019724
# 345 iter PSNR_dehazing: 11.82 ssim: 0.797093
# 345 iter PSNR: 11.82 time: 0.019687
# 346 iter PSNR_dehazing: 11.25 ssim: 0.779451
# 346 iter PSNR: 11.25 time: 0.019795
# 347 iter PSNR_dehazing: 10.74 ssim: 0.762565
# 347 iter PSNR: 10.74 time: 0.019295
# 348 iter PSNR_dehazing: 10.29 ssim: 0.746445
# 348 iter PSNR: 10.29 time: 0.020244
# 349 iter PSNR_dehazing: 9.88 ssim: 0.731074
# 349 iter PSNR: 9.88 time: 0.020183
# 350 iter PSNR_dehazing: 9.50 ssim: 0.716510
# 350 iter PSNR: 9.50 time: 0.022416
# 351 iter PSNR_dehazing: 13.63 ssim: 0.795515
# 351 iter PSNR: 13.63 time: 0.020312
# 352 iter PSNR_dehazing: 8.89 ssim: 0.629531
# 352 iter PSNR: 8.89 time: 0.019869
# 353 iter PSNR_dehazing: 12.78 ssim: 0.773399
# 353 iter PSNR: 12.78 time: 0.019030
# 354 iter PSNR_dehazing: 12.06 ssim: 0.752308
# 354 iter PSNR: 12.06 time: 0.019478
# 355 iter PSNR_dehazing: 11.42 ssim: 0.732240
# 355 iter PSNR: 11.42 time: 0.021110
# 356 iter PSNR_dehazing: 10.87 ssim: 0.713051
# 356 iter PSNR: 10.87 time: 0.019437
# 357 iter PSNR_dehazing: 10.38 ssim: 0.694739
# 357 iter PSNR: 10.38 time: 0.021012
# 358 iter PSNR_dehazing: 9.94 ssim: 0.677301
# 358 iter PSNR: 9.94 time: 0.020066
# 359 iter PSNR_dehazing: 9.55 ssim: 0.660636
# 359 iter PSNR: 9.55 time: 0.018753
# 360 iter PSNR_dehazing: 9.21 ssim: 0.644814
# 360 iter PSNR: 9.21 time: 0.019272
# 361 iter PSNR_dehazing: 16.59 ssim: 0.889082
# 361 iter PSNR: 16.59 time: 0.018753
# 362 iter PSNR_dehazing: 12.17 ssim: 0.793259
# 362 iter PSNR: 12.17 time: 0.020236
# 363 iter PSNR_dehazing: 15.90 ssim: 0.878056
# 363 iter PSNR: 15.90 time: 0.020177
# 364 iter PSNR_dehazing: 15.27 ssim: 0.867069
# 364 iter PSNR: 15.27 time: 0.019575
# 365 iter PSNR_dehazing: 14.70 ssim: 0.856163
# 365 iter PSNR: 14.70 time: 0.019430
# 366 iter PSNR_dehazing: 14.18 ssim: 0.845393
# 366 iter PSNR: 14.18 time: 0.018884
# 367 iter PSNR_dehazing: 13.70 ssim: 0.834743
# 367 iter PSNR: 13.70 time: 0.019382
# 368 iter PSNR_dehazing: 13.27 ssim: 0.824203
# 368 iter PSNR: 13.27 time: 0.018790
# 369 iter PSNR_dehazing: 12.87 ssim: 0.813702
# 369 iter PSNR: 12.87 time: 0.020808
# 370 iter PSNR_dehazing: 12.51 ssim: 0.803406
# 370 iter PSNR: 12.51 time: 0.020601
# 371 iter PSNR_dehazing: 12.29 ssim: 0.746421
# 371 iter PSNR: 12.29 time: 0.020413
# 372 iter PSNR_dehazing: 7.23 ssim: 0.539418
# 372 iter PSNR: 7.23 time: 0.020218
# 373 iter PSNR_dehazing: 11.38 ssim: 0.716351
# 373 iter PSNR: 11.38 time: 0.019945
# 374 iter PSNR_dehazing: 10.59 ssim: 0.688424
# 374 iter PSNR: 10.59 time: 0.020293
# 375 iter PSNR_dehazing: 9.92 ssim: 0.662509
# 375 iter PSNR: 9.92 time: 0.020321
# 376 iter PSNR_dehazing: 9.33 ssim: 0.638320
# 376 iter PSNR: 9.33 time: 0.019583
# 377 iter PSNR_dehazing: 8.81 ssim: 0.615771
# 377 iter PSNR: 8.81 time: 0.019658
# 378 iter PSNR_dehazing: 8.34 ssim: 0.594699
# 378 iter PSNR: 8.34 time: 0.020046
# 379 iter PSNR_dehazing: 7.93 ssim: 0.574994
# 379 iter PSNR: 7.93 time: 0.020383
# 380 iter PSNR_dehazing: 7.56 ssim: 0.556603
# 380 iter PSNR: 7.56 time: 0.019757
# 381 iter PSNR_dehazing: 14.89 ssim: 0.743830
# 381 iter PSNR: 14.89 time: 0.020370
# 382 iter PSNR_dehazing: 9.64 ssim: 0.620423
# 382 iter PSNR: 9.64 time: 0.019704
# 383 iter PSNR_dehazing: 14.01 ssim: 0.724736
# 383 iter PSNR: 14.01 time: 0.020428
# 384 iter PSNR_dehazing: 13.23 ssim: 0.707656
# 384 iter PSNR: 13.23 time: 0.019503
# 385 iter PSNR_dehazing: 12.55 ssim: 0.692234
# 385 iter PSNR: 12.55 time: 0.020013
# 386 iter PSNR_dehazing: 11.93 ssim: 0.678121
# 386 iter PSNR: 11.93 time: 0.020293
# 387 iter PSNR_dehazing: 11.38 ssim: 0.665045
# 387 iter PSNR: 11.38 time: 0.019258
# 388 iter PSNR_dehazing: 10.88 ssim: 0.652889
# 388 iter PSNR: 10.88 time: 0.019835
# 389 iter PSNR_dehazing: 10.43 ssim: 0.641438
# 389 iter PSNR: 10.43 time: 0.019801
# 390 iter PSNR_dehazing: 10.02 ssim: 0.630652
# 390 iter PSNR: 10.02 time: 0.019539
# 391 iter PSNR_dehazing: 15.36 ssim: 0.877356
# 391 iter PSNR: 15.36 time: 0.019468
# 392 iter PSNR_dehazing: 10.47 ssim: 0.742511
# 392 iter PSNR: 10.47 time: 0.019342
# 393 iter PSNR_dehazing: 14.55 ssim: 0.862121
# 393 iter PSNR: 14.55 time: 0.019674
# 394 iter PSNR_dehazing: 13.83 ssim: 0.846836
# 394 iter PSNR: 13.83 time: 0.019535
# 395 iter PSNR_dehazing: 13.19 ssim: 0.831465
# 395 iter PSNR: 13.19 time: 0.019107
# 396 iter PSNR_dehazing: 12.61 ssim: 0.816077
# 396 iter PSNR: 12.61 time: 0.019495
# 397 iter PSNR_dehazing: 12.10 ssim: 0.800868
# 397 iter PSNR: 12.10 time: 0.019886
# 398 iter PSNR_dehazing: 11.63 ssim: 0.785868
# 398 iter PSNR: 11.63 time: 0.020410
# 399 iter PSNR_dehazing: 11.21 ssim: 0.771144
# 399 iter PSNR: 11.21 time: 0.019303
# 400 iter PSNR_dehazing: 10.83 ssim: 0.756693
# 400 iter PSNR: 10.83 time: 0.019309
# 401 iter PSNR_dehazing: 11.70 ssim: 0.771921
# 401 iter PSNR: 11.70 time: 0.019326
# 402 iter PSNR_dehazing: 6.99 ssim: 0.581255
# 402 iter PSNR: 6.99 time: 0.019670
# 403 iter PSNR_dehazing: 10.82 ssim: 0.743544
# 403 iter PSNR: 10.82 time: 0.019845
# 404 iter PSNR_dehazing: 10.07 ssim: 0.717223
# 404 iter PSNR: 10.07 time: 0.020089
# 405 iter PSNR_dehazing: 9.43 ssim: 0.692918
# 405 iter PSNR: 9.43 time: 0.020338
# 406 iter PSNR_dehazing: 8.88 ssim: 0.670440
# 406 iter PSNR: 8.88 time: 0.019875
# 407 iter PSNR_dehazing: 8.40 ssim: 0.649787
# 407 iter PSNR: 8.40 time: 0.020162
# 408 iter PSNR_dehazing: 7.98 ssim: 0.630607
# 408 iter PSNR: 7.98 time: 0.020348
# 409 iter PSNR_dehazing: 7.61 ssim: 0.612862
# 409 iter PSNR: 7.61 time: 0.019593
# 410 iter PSNR_dehazing: 7.28 ssim: 0.596448
# 410 iter PSNR: 7.28 time: 0.020263
# 411 iter PSNR_dehazing: 15.44 ssim: 0.808314
# 411 iter PSNR: 15.44 time: 0.019411
# 412 iter PSNR_dehazing: 10.22 ssim: 0.680274
# 412 iter PSNR: 10.22 time: 0.019894
# 413 iter PSNR_dehazing: 14.58 ssim: 0.792262
# 413 iter PSNR: 14.58 time: 0.019992
# 414 iter PSNR_dehazing: 13.82 ssim: 0.776772
# 414 iter PSNR: 13.82 time: 0.019665
# 415 iter PSNR_dehazing: 13.14 ssim: 0.761415
# 415 iter PSNR: 13.14 time: 0.019729
# 416 iter PSNR_dehazing: 12.53 ssim: 0.746430
# 416 iter PSNR: 12.53 time: 0.019751
# 417 iter PSNR_dehazing: 11.98 ssim: 0.732017
# 417 iter PSNR: 11.98 time: 0.020083
# 418 iter PSNR_dehazing: 11.48 ssim: 0.718239
# 418 iter PSNR: 11.48 time: 0.019720
# 419 iter PSNR_dehazing: 11.02 ssim: 0.704999
# 419 iter PSNR: 11.02 time: 0.019380
# 420 iter PSNR_dehazing: 10.60 ssim: 0.692387
# 420 iter PSNR: 10.60 time: 0.019561
# 421 iter PSNR_dehazing: 12.58 ssim: 0.702864
# 421 iter PSNR: 12.58 time: 0.019559
# 422 iter PSNR_dehazing: 7.54 ssim: 0.517736
# 422 iter PSNR: 7.54 time: 0.021547
# 423 iter PSNR_dehazing: 11.67 ssim: 0.675204
# 423 iter PSNR: 11.67 time: 0.020126
# 424 iter PSNR_dehazing: 10.90 ssim: 0.650307
# 424 iter PSNR: 10.90 time: 0.022075
# 425 iter PSNR_dehazing: 10.22 ssim: 0.627480
# 425 iter PSNR: 10.22 time: 0.020930
# 426 iter PSNR_dehazing: 9.63 ssim: 0.606334
# 426 iter PSNR: 9.63 time: 0.019296
# 427 iter PSNR_dehazing: 9.12 ssim: 0.586458
# 427 iter PSNR: 9.12 time: 0.020723
# 428 iter PSNR_dehazing: 8.65 ssim: 0.567672
# 428 iter PSNR: 8.65 time: 0.019955
# 429 iter PSNR_dehazing: 8.24 ssim: 0.549932
# 429 iter PSNR: 8.24 time: 0.019190
# 430 iter PSNR_dehazing: 7.87 ssim: 0.533360
# 430 iter PSNR: 7.87 time: 0.019388
# 431 iter PSNR_dehazing: 15.50 ssim: 0.833000
# 431 iter PSNR: 15.50 time: 0.020715
# 432 iter PSNR_dehazing: 10.47 ssim: 0.674138
# 432 iter PSNR: 10.47 time: 0.020037
# 433 iter PSNR_dehazing: 14.67 ssim: 0.810431
# 433 iter PSNR: 14.67 time: 0.019217
# 434 iter PSNR_dehazing: 13.93 ssim: 0.788910
# 434 iter PSNR: 13.93 time: 0.019041
# 435 iter PSNR_dehazing: 13.28 ssim: 0.767828
# 435 iter PSNR: 13.28 time: 0.019362
# 436 iter PSNR_dehazing: 12.69 ssim: 0.749076
# 436 iter PSNR: 12.69 time: 0.019696
# 437 iter PSNR_dehazing: 12.16 ssim: 0.731962
# 437 iter PSNR: 12.16 time: 0.019556
# 438 iter PSNR_dehazing: 11.68 ssim: 0.716227
# 438 iter PSNR: 11.68 time: 0.020014
# 439 iter PSNR_dehazing: 11.24 ssim: 0.701411
# 439 iter PSNR: 11.24 time: 0.020531
# 440 iter PSNR_dehazing: 10.84 ssim: 0.687419
# 440 iter PSNR: 10.84 time: 0.020547
# 441 iter PSNR_dehazing: 12.03 ssim: 0.588777
# 441 iter PSNR: 12.03 time: 0.020141
# 442 iter PSNR_dehazing: 6.73 ssim: 0.382242
# 442 iter PSNR: 6.73 time: 0.020634
# 443 iter PSNR_dehazing: 11.09 ssim: 0.556641
# 443 iter PSNR: 11.09 time: 0.020379
# 444 iter PSNR_dehazing: 10.27 ssim: 0.527820
# 444 iter PSNR: 10.27 time: 0.019741
# 445 iter PSNR_dehazing: 9.57 ssim: 0.501610
# 445 iter PSNR: 9.57 time: 0.020634
# 446 iter PSNR_dehazing: 8.95 ssim: 0.477679
# 446 iter PSNR: 8.95 time: 0.019976
# 447 iter PSNR_dehazing: 8.40 ssim: 0.455574
# 447 iter PSNR: 8.40 time: 0.019233
# 448 iter PSNR_dehazing: 7.92 ssim: 0.435176
# 448 iter PSNR: 7.92 time: 0.019594
# 449 iter PSNR_dehazing: 7.48 ssim: 0.416237
# 449 iter PSNR: 7.48 time: 0.020151
# 450 iter PSNR_dehazing: 7.09 ssim: 0.398627
# 450 iter PSNR: 7.09 time: 0.020078
# 451 iter PSNR_dehazing: 14.53 ssim: 0.796191
# 451 iter PSNR: 14.53 time: 0.019558
# 452 iter PSNR_dehazing: 9.35 ssim: 0.604029
# 452 iter PSNR: 9.35 time: 0.020555
# 453 iter PSNR_dehazing: 13.65 ssim: 0.770551
# 453 iter PSNR: 13.65 time: 0.020904
# 454 iter PSNR_dehazing: 12.88 ssim: 0.745848
# 454 iter PSNR: 12.88 time: 0.019940
# 455 iter PSNR_dehazing: 12.20 ssim: 0.722408
# 455 iter PSNR: 12.20 time: 0.020554
# 456 iter PSNR_dehazing: 11.60 ssim: 0.700176
# 456 iter PSNR: 11.60 time: 0.025197
# 457 iter PSNR_dehazing: 11.05 ssim: 0.679083
# 457 iter PSNR: 11.05 time: 0.020229
# 458 iter PSNR_dehazing: 10.57 ssim: 0.658943
# 458 iter PSNR: 10.57 time: 0.020155
# 459 iter PSNR_dehazing: 10.12 ssim: 0.639778
# 459 iter PSNR: 10.12 time: 0.020766
# 460 iter PSNR_dehazing: 9.72 ssim: 0.621507
# 460 iter PSNR: 9.72 time: 0.020000
# 461 iter PSNR_dehazing: 13.85 ssim: 0.764752
# 461 iter PSNR: 13.85 time: 0.019543
# 462 iter PSNR_dehazing: 8.72 ssim: 0.545855
# 462 iter PSNR: 8.72 time: 0.020063
# 463 iter PSNR_dehazing: 12.96 ssim: 0.737145
# 463 iter PSNR: 12.96 time: 0.019753
# 464 iter PSNR_dehazing: 12.18 ssim: 0.710006
# 464 iter PSNR: 12.18 time: 0.021947
# 465 iter PSNR_dehazing: 11.50 ssim: 0.682986
# 465 iter PSNR: 11.50 time: 0.020911
# 466 iter PSNR_dehazing: 10.90 ssim: 0.657028
# 466 iter PSNR: 10.90 time: 0.021741
# 467 iter PSNR_dehazing: 10.37 ssim: 0.632478
# 467 iter PSNR: 10.37 time: 0.019943
# 468 iter PSNR_dehazing: 9.89 ssim: 0.609187
# 468 iter PSNR: 9.89 time: 0.021894
# 469 iter PSNR_dehazing: 9.46 ssim: 0.586973
# 469 iter PSNR: 9.46 time: 0.023761
# 470 iter PSNR_dehazing: 9.07 ssim: 0.565906
# 470 iter PSNR: 9.07 time: 0.020565
# 471 iter PSNR_dehazing: 14.27 ssim: 0.758818
# 471 iter PSNR: 14.27 time: 0.021101
# 472 iter PSNR_dehazing: 9.15 ssim: 0.532064
# 472 iter PSNR: 9.15 time: 0.023371
# 473 iter PSNR_dehazing: 13.39 ssim: 0.726188
# 473 iter PSNR: 13.39 time: 0.020215
# 474 iter PSNR_dehazing: 12.63 ssim: 0.696077
# 474 iter PSNR: 12.63 time: 0.020070
# 475 iter PSNR_dehazing: 11.95 ssim: 0.668053
# 475 iter PSNR: 11.95 time: 0.021654
# 476 iter PSNR_dehazing: 11.35 ssim: 0.641874
# 476 iter PSNR: 11.35 time: 0.019260
# 477 iter PSNR_dehazing: 10.82 ssim: 0.617219
# 477 iter PSNR: 10.82 time: 0.019912
# 478 iter PSNR_dehazing: 10.34 ssim: 0.594076
# 478 iter PSNR: 10.34 time: 0.019496
# 479 iter PSNR_dehazing: 9.90 ssim: 0.572208
# 479 iter PSNR: 9.90 time: 0.019857
# 480 iter PSNR_dehazing: 9.51 ssim: 0.551523
# 480 iter PSNR: 9.51 time: 0.019410
# 481 iter PSNR_dehazing: 14.80 ssim: 0.783395
# 481 iter PSNR: 14.80 time: 0.019099
# 482 iter PSNR_dehazing: 9.77 ssim: 0.591493
# 482 iter PSNR: 9.77 time: 0.020001
# 483 iter PSNR_dehazing: 13.94 ssim: 0.766658
# 483 iter PSNR: 13.94 time: 0.020153
# 484 iter PSNR_dehazing: 13.19 ssim: 0.745232
# 484 iter PSNR: 13.19 time: 0.020394
# 485 iter PSNR_dehazing: 12.53 ssim: 0.719637
# 485 iter PSNR: 12.53 time: 0.020429
# 486 iter PSNR_dehazing: 11.94 ssim: 0.694594
# 486 iter PSNR: 11.94 time: 0.019442
# 487 iter PSNR_dehazing: 11.42 ssim: 0.671154
# 487 iter PSNR: 11.42 time: 0.019678
# 488 iter PSNR_dehazing: 10.95 ssim: 0.649423
# 488 iter PSNR: 10.95 time: 0.019368
# 489 iter PSNR_dehazing: 10.52 ssim: 0.628964
# 489 iter PSNR: 10.52 time: 0.021570
# 490 iter PSNR_dehazing: 10.13 ssim: 0.609709
# 490 iter PSNR: 10.13 time: 0.019201
# 491 iter PSNR_dehazing: 14.23 ssim: 0.783271
# 491 iter PSNR: 14.23 time: 0.019528
# 492 iter PSNR_dehazing: 9.15 ssim: 0.552092
# 492 iter PSNR: 9.15 time: 0.019315
# 493 iter PSNR_dehazing: 13.36 ssim: 0.753116
# 493 iter PSNR: 13.36 time: 0.019351
# 494 iter PSNR_dehazing: 12.59 ssim: 0.723575
# 494 iter PSNR: 12.59 time: 0.019853
# 495 iter PSNR_dehazing: 11.92 ssim: 0.695299
# 495 iter PSNR: 11.92 time: 0.020021
# 496 iter PSNR_dehazing: 11.33 ssim: 0.668318
# 496 iter PSNR: 11.33 time: 0.021960
# 497 iter PSNR_dehazing: 10.80 ssim: 0.642648
# 497 iter PSNR: 10.80 time: 0.020063
# 498 iter PSNR_dehazing: 10.32 ssim: 0.618339
# 498 iter PSNR: 10.32 time: 0.020236
# 499 iter PSNR_dehazing: 9.89 ssim: 0.595181
# 499 iter PSNR: 9.89 time: 0.021063
# 500 iter PSNR_dehazing: 9.50 ssim: 0.573091
# 500 iter PSNR: 9.50 time: 0.020566
# ==========================================================
# The average PSNR is 11.13 dB
# The average SSIM is 0.67365 dB
# Average time: 0.020065
