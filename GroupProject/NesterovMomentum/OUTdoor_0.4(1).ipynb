# %% [markdown]
# Prep
# ==

# %%
from google.colab import drive
drive.mount('/content/drive/')

# %%
# !pip install tensorboard einops scikit-image opencv-python pytorch_msssim warmup-scheduler

# %%
# !pip install pytorch-msssim

# %%
# !pip install warmup-scheduler

# %%
#path = "/content/drive/MyDrive/reside-indoor"
# !unzip  ./drive/MyDrive/reside-indoor.zip -d ./reside-outdoorMY/ > trainlog.txt
# !unzip  ./drive/MyDrive/reside-indoor.zip -d ./reside-outdoorMY/ >testlog.txt
#/content/reside-indoorMY/train/hazy

# %%
path = "/content/reside-outdoorMY"
#/content/reside-indoorMY/train/hazy
#path = "/content/reside-indoorMY"
#path = "./reside-indoorMY"

# %% [markdown]
# Data Augment
# ==

# %%
import random
import torchvision.transforms as transforms
import torchvision.transforms.functional as FUNCTIONAL


class PairRandomCrop(transforms.RandomCrop):

    def __call__(self, image, label):

        if self.padding is not None:
            image = FUNCTIONAL.pad(image, self.padding, self.fill, self.padding_mode)
            label = FUNCTIONAL.pad(label, self.padding, self.fill, self.padding_mode)

        # pad the width if needed
        if self.pad_if_needed and image.size[0] < self.size[1]:
            image = FUNCTIONAL.pad(image, (self.size[1] - image.size[0], 0), self.fill, self.padding_mode)
            label = FUNCTIONAL.pad(label, (self.size[1] - label.size[0], 0), self.fill, self.padding_mode)
        # pad the height if needed
        if self.pad_if_needed and image.size[1] < self.size[0]:
            image = FUNCTIONAL.pad(image, (0, self.size[0] - image.size[1]), self.fill, self.padding_mode)
            label = FUNCTIONAL.pad(label, (0, self.size[0] - image.size[1]), self.fill, self.padding_mode)

        i, j, h, w = self.get_params(image, self.size)

        return FUNCTIONAL.crop(image, i, j, h, w), FUNCTIONAL.crop(label, i, j, h, w)


class PairCompose(transforms.Compose):
    def __call__(self, image, label):
        for t in self.transforms:
            image, label = t(image, label)
        return image, label


class PairRandomHorizontalFilp(transforms.RandomHorizontalFlip):
    def __call__(self, img, label):
        """
        Args:
            img (PIL Image): Image to be flipped.

        Returns:
            PIL Image: Randomly flipped image.
        """
        if random.random() < self.p:
            return FUNCTIONAL.hflip(img), FUNCTIONAL.hflip(label)
        return img, label


class PairToTensor(transforms.ToTensor):
    def __call__(self, pic, label):
        """
        Args:
            pic (PIL Image or numpy.ndarray): Image to be converted to tensor.

        Returns:
            Tensor: Converted image.
        """
        return FUNCTIONAL.to_tensor(pic), FUNCTIONAL.to_tensor(label)

# %% [markdown]
# Data Loader
# ==

# %%
import os
import torch
import numpy as np
from PIL import Image as Image
from torch.utils.data import Dataset, DataLoader


def train_dataloader(path, batch_size=1, num_workers=0, use_transform=True): # we change batch size = 1, but the original batch size = 64
    image_dir = os.path.join(path, 'train')

    transform = None
    if use_transform:
        transform = PairCompose(
            [
                PairRandomCrop(256),
                PairRandomHorizontalFilp(),
                PairToTensor()
            ]
        )
    dataloader = DataLoader(
        DeblurDataset(image_dir, transform=transform),
        batch_size=batch_size,
        shuffle=True,
        num_workers=num_workers,
        pin_memory=True
    )
    return dataloader


def test_dataloader(path, batch_size=1, num_workers=0):
    image_dir = os.path.join(path, 'test')
    dataloader = DataLoader(
        DeblurDataset(image_dir, is_test=True),
        batch_size=batch_size,
        shuffle=False,
        num_workers=num_workers,
        pin_memory=True
    )

    return dataloader


def valid_dataloader(path, batch_size=1, num_workers=0):
    dataloader = DataLoader(
        DeblurDataset(os.path.join(path, 'test')),
        batch_size=batch_size,
        shuffle=False,
        num_workers=num_workers
    )

    return dataloader


class DeblurDataset(Dataset):
    def __init__(self, image_dir, transform=None, is_test=False):
        self.image_dir = image_dir
        self.image_list = os.listdir(os.path.join(image_dir, 'hazy/'))
        self._check_image(self.image_list)
        self.image_list.sort()
        self.transform = transform
        self.is_test = is_test

    def __len__(self):
        return len(self.image_list)

    def __getitem__(self, idx):
        image = Image.open(os.path.join(self.image_dir, 'hazy', self.image_list[idx]))
        label = Image.open(os.path.join(self.image_dir, 'gt', self.image_list[idx].split('_')[0]+'.png'))

        if self.transform:
            image, label = self.transform(image, label)
        else:
            image = FUNCTIONAL.to_tensor(image)
            label = FUNCTIONAL.to_tensor(label)
        if self.is_test:
            name = self.image_list[idx]
            return image, label, name
        return image, label

    @staticmethod
    def _check_image(lst):
        for x in lst:
            splits = x.split('.')
            if splits[-1] not in ['png', 'jpg', 'jpeg']:
                raise ValueError

# %% [markdown]
# Utils
# ==

# %%
import time
import numpy as np


class Adder(object):
    def __init__(self):
        self.count = 0
        self.num = float(0)

    def reset(self):
        self.count = 0
        self.num = float(0)

    def __call__(self, num):
        self.count += 1
        self.num += num

    def average(self):
        return self.num / self.count


class Timer(object):
    def __init__(self, option='s'):
        self.tm = 0
        self.option = option
        if option == 's':
            self.devider = 1
        elif option == 'm':
            self.devider = 60
        else:
            self.devider = 3600

    def tic(self):
        self.tm = time.time()

    def toc(self):
        return (time.time() - self.tm) / self.devider


def check_lr(optimizer):
    for i, param_group in enumerate(optimizer.param_groups):
        lr = param_group['lr']
    return lr

# %% [markdown]
# Eval
# ==

# %%
from skimage.metrics import peak_signal_noise_ratio
from pytorch_msssim import ssim
import torch.nn.functional as fe

from skimage import img_as_ubyte
import cv2

def _eval(model, args):
    state_dict = torch.load(args.test_model)
    model.load_state_dict(state_dict['model'])
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    dataloader = test_dataloader(args.data_dir, batch_size=1, num_workers=0)
    torch.cuda.empty_cache()
    adder = Adder()
    model.eval()
    factor = 32
    with torch.no_grad():
        psnr_adder = Adder()
        ssim_adder = Adder()

        for iter_idx, data in enumerate(dataloader):
            input_img, label_img, name = data

            input_img = input_img.to(device)

            h, w = input_img.shape[2], input_img.shape[3]
            H, W = ((h+factor)//factor)*factor, ((w+factor)//factor*factor)
            padh = H-h if h%factor!=0 else 0
            padw = W-w if w%factor!=0 else 0
            input_img = fe.pad(input_img, (0, padw, 0, padh), 'reflect')

            tm = time.time()

            pred = model(input_img)[2]
            pred = pred[:,:,:h,:w]

            elapsed = time.time() - tm
            adder(elapsed)

            pred_clip = torch.clamp(pred, 0, 1)

            pred_numpy = pred_clip.squeeze(0).cpu().numpy()
            label_numpy = label_img.squeeze(0).cpu().numpy()


            label_img = (label_img).cuda()
            psnr_val = 10 * torch.log10(1 / fe.mse_loss(pred_clip, label_img))
            down_ratio = max(1, round(min(H, W) / 256))
            ssim_val = ssim(fe.adaptive_avg_pool2d(pred_clip, (int(H / down_ratio), int(W / down_ratio))),
                            fe.adaptive_avg_pool2d(label_img, (int(H / down_ratio), int(W / down_ratio))),
                            data_range=1, size_average=False)
            print('%d iter PSNR_dehazing: %.2f ssim: %f' % (iter_idx + 1, psnr_val, ssim_val))
            ssim_adder(ssim_val)

            if args.save_image:
                save_name = os.path.join(args.result_dir, name[0])
                pred_clip += 0.5 / 255
                pred = FUNCTIONAL.to_pil_image(pred_clip.squeeze(0).cpu(), 'RGB')
                pred.save(save_name)

            psnr_mimo = peak_signal_noise_ratio(pred_numpy, label_numpy, data_range=1)
            psnr_adder(psnr_val)

            print('%d iter PSNR: %.2f time: %f' % (iter_idx + 1, psnr_mimo, elapsed))

        print('==========================================================')
        print('The average PSNR is %.2f dB' % (psnr_adder.average()))
        print('The average SSIM is %.5f dB' % (ssim_adder.average()))

        print("Average time: %f" % adder.average())

# %% [markdown]
# Layers
# ==

# %%
import torch
import torch.nn as nn
import torch.nn.functional as fl
import math

class BasicConv(nn.Module):
    def __init__(self, in_channel, out_channel, kernel_size, stride, bias=True, norm=False, relu=True, transpose=False):
        super(BasicConv, self).__init__()
        if bias and norm:
            bias = False

        padding = kernel_size // 2
        layers = list()
        if transpose:
            padding = kernel_size // 2 -1
            layers.append(nn.ConvTranspose2d(in_channel, out_channel, kernel_size, padding=padding, stride=stride, bias=bias))
        else:
            layers.append(
                nn.Conv2d(in_channel, out_channel, kernel_size, padding=padding, stride=stride, bias=bias))
        if norm:
            layers.append(nn.BatchNorm2d(out_channel))
        if relu:
            layers.append(nn.GELU())
        self.main = nn.Sequential(*layers)

    def forward(self, x):
        return self.main(x)


class ResBlock(nn.Module):
    def __init__(self, in_channel, out_channel, filter=False):
        super(ResBlock, self).__init__()
        self.main = nn.Sequential(
            BasicConv(in_channel, out_channel, kernel_size=3, stride=1, relu=True),
            DeepPoolLayer(in_channel, out_channel) if filter else nn.Identity(),
            BasicConv(out_channel, out_channel, kernel_size=3, stride=1, relu=False)
        )

    def forward(self, x):
        return self.main(x) + x


class DeepPoolLayer(nn.Module):
    def __init__(self, k, k_out):
        super(DeepPoolLayer, self).__init__()
        self.pools_sizes = [8,4,2]
        pools, convs, dynas = [],[],[]
        for i in self.pools_sizes:
            pools.append(nn.AvgPool2d(kernel_size=i, stride=i))
            convs.append(nn.Conv2d(k, k, 3, 1, 1, bias=False))
            dynas.append(dynamic_filter(inchannels=k, kernel_size=3))
        self.pools = nn.ModuleList(pools)
        self.convs = nn.ModuleList(convs)
        self.dynas = nn.ModuleList(dynas)
        self.relu = nn.GELU()
        self.conv_sum = nn.Conv2d(k, k_out, 3, 1, 1, bias=False)

    def forward(self, x):
        x_size = x.size()
        resl = x
        for i in range(len(self.pools_sizes)):
            if i == 0:
                y = self.dynas[i](self.convs[i](self.pools[i](x)))
            else:
                y = self.dynas[i](self.convs[i](self.pools[i](x)+y_up))
            resl = torch.add(resl, fl.interpolate(y, x_size[2:], mode='bilinear', align_corners=True))
            if i != len(self.pools_sizes)-1:
                y_up = fl.interpolate(y, scale_factor=2, mode='bilinear', align_corners=True)
        resl = self.relu(resl)
        resl = self.conv_sum(resl)

        return resl

class dynamic_filter(nn.Module):
    def __init__(self, inchannels, kernel_size=3, stride=1, group=8):
        super(dynamic_filter, self).__init__()

        self.stride = stride
        self.kernel_size = kernel_size
        self.group = group

        self.conv = nn.Conv2d(inchannels, group*kernel_size**2, kernel_size=1, stride=1, bias=False)
        self.bn = nn.BatchNorm2d(group*kernel_size**2)
        self.act = nn.Tanh()

        nn.init.kaiming_normal_(self.conv.weight, mode='fan_out', nonlinearity='relu')
        self.lamb_l = nn.Parameter(torch.zeros(inchannels), requires_grad=True)
        self.lamb_h = nn.Parameter(torch.zeros(inchannels), requires_grad=True)
        self.pad = nn.ReflectionPad2d(kernel_size//2)

        self.ap = nn.AdaptiveAvgPool2d((1, 1))
        self.gap = nn.AdaptiveAvgPool2d(1)

        self.inside_all = nn.Parameter(torch.zeros(inchannels,1,1), requires_grad=True)

    def forward(self, x):
        identity_input = x
        # the Conv_{3x3} layer in eq.3 is included in DeepPoolLayer.convs
        low_filter = self.ap(x)
        low_filter = self.conv(low_filter)
        low_filter = self.bn(low_filter)

        n, c, h, w = x.shape
        x = fl.unfold(self.pad(x), kernel_size=self.kernel_size).reshape(n, self.group, c//self.group, self.kernel_size**2, h*w)

        n,c1,p,q = low_filter.shape
        low_filter = low_filter.reshape(n, c1//self.kernel_size**2, self.kernel_size**2, p*q).unsqueeze(2)
        low_filter = self.act(low_filter)
        low_part = torch.sum(x * low_filter, dim=3).reshape(n, c, h, w)

        # the variables here are slightly different from the paper: (code) --> (paper)
        # low_filter --> A (eq.3)
        # In Eq.7, X*A'= X*(A_{l} + WA_{h})
        #              = X*A_{l} + WX*(A - A_{l})
        #              = X*A_{l} + WX*A - WX*A_{l}
        #              = WX*A - X*A_{l}(W-1)
        # we substitute gap for A_{l} for simplicity, which is a coarser low-frequency filter
        out_low = low_part * (self.inside_all + 1.) - self.inside_all * self.gap(identity_input)

        out_low = out_low * self.lamb_l[None,:,None,None]
        out_high = (identity_input) * (self.lamb_h[None,:,None,None] + 1.)

        return out_low + out_high

# %% [markdown]
# IRNeXt
# ==

# %%
import torch
import torch.nn as nn
import torch.nn.functional as fwd

class EBlock(nn.Module):
    def __init__(self, out_channel, num_res=8):
        super(EBlock, self).__init__()

        layers = [ResBlock(out_channel, out_channel) for _ in range(num_res-1)]
        layers.append(ResBlock(out_channel, out_channel, filter=True))
        self.layers = nn.Sequential(*layers)

    def forward(self, x):
        return self.layers(x)


class DBlock(nn.Module):
    def __init__(self, channel, num_res=8):
        super(DBlock, self).__init__()

        layers = [ResBlock(channel, channel) for _ in range(num_res-1)]
        layers.append(ResBlock(channel, channel, filter=True))
        self.layers = nn.Sequential(*layers)

    def forward(self, x):
        return self.layers(x)


class SCM(nn.Module):
    def __init__(self, out_plane):
        super(SCM, self).__init__()

        self.main = nn.Sequential(
            BasicConv(3, out_plane//4, kernel_size=3, stride=1, relu=True),
            BasicConv(out_plane // 4, out_plane // 2, kernel_size=1, stride=1, relu=True),
            BasicConv(out_plane // 2, out_plane // 2, kernel_size=3, stride=1, relu=True),
            BasicConv(out_plane // 2, out_plane, kernel_size=1, stride=1, relu=False),
            nn.InstanceNorm2d(out_plane, affine=True)
        )

    def forward(self, x):
        x = self.main(x)
        return x

class FAM(nn.Module):
    def __init__(self, channel):
        super(FAM, self).__init__()

        self.merge = BasicConv(channel*2, channel, kernel_size=3, stride=1, relu=False)

    def forward(self, x1, x2):
        return self.merge(torch.cat([x1, x2], dim=1))

class IRNeXt(nn.Module):
    def __init__(self, num_res=4):
        super(IRNeXt, self).__init__()

        base_channel = 32
        self.Encoder = nn.ModuleList([
            EBlock(base_channel, num_res),
            EBlock(base_channel*2, num_res),
            EBlock(base_channel*4, num_res),
        ])

        self.feat_extract = nn.ModuleList([
            BasicConv(3, base_channel, kernel_size=3, relu=True, stride=1),
            BasicConv(base_channel, base_channel*2, kernel_size=3, relu=True, stride=2),
            BasicConv(base_channel*2, base_channel*4, kernel_size=3, relu=True, stride=2),
            BasicConv(base_channel*4, base_channel*2, kernel_size=4, relu=True, stride=2, transpose=True),
            BasicConv(base_channel*2, base_channel, kernel_size=4, relu=True, stride=2, transpose=True),
            BasicConv(base_channel, 3, kernel_size=3, relu=False, stride=1)
        ])

        self.Decoder = nn.ModuleList([
            DBlock(base_channel * 4, num_res),
            DBlock(base_channel * 2, num_res),
            DBlock(base_channel, num_res)
        ])

        self.Convs = nn.ModuleList([
            BasicConv(base_channel * 4, base_channel * 2, kernel_size=1, relu=True, stride=1),
            BasicConv(base_channel * 2, base_channel, kernel_size=1, relu=True, stride=1),
        ])

        self.ConvsOut = nn.ModuleList(
            [
                BasicConv(base_channel * 4, 3, kernel_size=3, relu=False, stride=1),
                BasicConv(base_channel * 2, 3, kernel_size=3, relu=False, stride=1),
            ]
        )

        self.FAM1 = FAM(base_channel * 4)
        self.SCM1 = SCM(base_channel * 4)
        self.FAM2 = FAM(base_channel * 2)
        self.SCM2 = SCM(base_channel * 2)

    def forward(self, x):
        x_2 = fwd.interpolate(x, scale_factor=0.5)
        x_4 = fwd.interpolate(x_2, scale_factor=0.5)
        z2 = self.SCM2(x_2)
        z4 = self.SCM1(x_4)

        outputs = list()
        # 256
        x_ = self.feat_extract[0](x)
        res1 = self.Encoder[0](x_)
        # 128
        z = self.feat_extract[1](res1)
        z = self.FAM2(z, z2)
        res2 = self.Encoder[1](z)
        # 64
        z = self.feat_extract[2](res2)
        z = self.FAM1(z, z4)
        z = self.Encoder[2](z)

        z = self.Decoder[0](z)
        z_ = self.ConvsOut[0](z)
        # 128
        z = self.feat_extract[3](z)
        outputs.append(z_+x_4)

        z = torch.cat([z, res2], dim=1)
        z = self.Convs[0](z)
        z = self.Decoder[1](z)
        z_ = self.ConvsOut[1](z)
        # 256
        z = self.feat_extract[4](z)
        outputs.append(z_+x_2)

        z = torch.cat([z, res1], dim=1)
        z = self.Convs[1](z)
        z = self.Decoder[2](z)
        z = self.feat_extract[5](z)
        outputs.append(z+x)

        return outputs


def build_net():
    return IRNeXt()

# %% [markdown]
# Valid
# ==

# %%
from skimage.metrics import peak_signal_noise_ratio
import torch.nn.functional as fv


def _valid(model, args, ep):
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    its = valid_dataloader(args.data_dir, batch_size=1, num_workers=0)
    model.eval()
    psnr_adder = Adder()

    with torch.no_grad():
        print('Start Evaluation')
        factor = 32
        for idx, data in enumerate(its):
            input_img, label_img = data
            input_img = input_img.to(device)

            h, w = input_img.shape[2], input_img.shape[3]
            H, W = ((h+factor)//factor)*factor, ((w+factor)//factor*factor)
            padh = H-h if h%factor!=0 else 0
            padw = W-w if w%factor!=0 else 0
            input_img = fv.pad(input_img, (0, padw, 0, padh), 'reflect')

            if not os.path.exists(os.path.join(args.result_dir, '%d' % (ep))):
                os.mkdir(os.path.join(args.result_dir, '%d' % (ep)))

            pred = model(input_img)[2]
            pred = pred[:,:,:h,:w]

            pred_clip = torch.clamp(pred, 0, 1)
            p_numpy = pred_clip.squeeze(0).cpu().numpy()
            label_numpy = label_img.squeeze(0).cpu().numpy()

            psnr = peak_signal_noise_ratio(p_numpy, label_numpy, data_range=1)

            psnr_adder(psnr)
            print('\r%03d'%idx, end=' ')

    print('\n')
    model.train()
    return psnr_adder.average()

# %% [markdown]
# SGLD
# ==

# %%
""" Custom optimizer implementations to track various runtime statistics """

from torch.optim import Optimizer


class SGLD(Optimizer):
    r"""Implements stochastic gradient descent (optionally with momentum).
    Nesterov momentum is based on the formula from
    `On the importance of initialization and momentum in deep learning`__.
    Args:
        params (iterable): iterable of parameters to optimize or dicts defining
            parameter groups
        lr (float): learning rate
        momentum (float, optional): momentum factor (default: 0)
        weight_decay (float, optional): weight decay (L2 penalty) (default: 0)
        dampening (float, optional): dampening for momentum (default: 0)
        nesterov (bool, optional): enables Nesterov momentum (default: False)
        noise_scale (float, optional): variance of isotropic noise for langevin
    Example:
        >>> optimizer = torch.optim.SGD(model.parameters(), lr=0.1, momentum=0.9)
        >>> optimizer.zero_grad()
        >>> loss_fn(model(input), target).backward()
        >>> optimizer.step()
    __ http://www.cs.toronto.edu/%7Ehinton/absps/momentum.pdf
    .. note::
        The implementation of SGD with Momentum/Nesterov subtly differs from
        Sutskever et. al. and implementations in some other frameworks.
        Considering the specific case of Momentum, the update can be written as
        .. math::
                  v = \rho * v + g \\
                  p = p - lr * v
        where p, g, v and :math:`\rho` denote the parameters, gradient,
        velocity, and momentum respectively.
        This is in contrast to Sutskever et. al. and
        other frameworks which employ an update of the form
        .. math::
             v = \rho * v + lr * g \\
             p = p - v
        The Nesterov version is analogously modified.
    """

    def __init__(self, params, lr, momentum=0, dampening=0,
                 weight_decay=0, nesterov=False,
                 noise_scale=0.01):
        if lr < 0.0:
            raise ValueError("Invalid learning rate: {}".format(lr))
        if momentum < 0.0:
            raise ValueError("Invalid momentum value: {}".format(momentum))
        if weight_decay < 0.0:
            raise ValueError("Invalid weight_decay value: {}".format(weight_decay))

        defaults = dict(lr=lr, momentum=momentum, dampening=dampening,
                        weight_decay=weight_decay, nesterov=nesterov)
        if nesterov and (momentum <= 0 or dampening != 0):
            raise ValueError("Nesterov momentum requires a momentum and zero dampening")
        super(SGLD, self).__init__(params, defaults)
        self.noise_scale = noise_scale

    def __setstate__(self, state):
        super(SGLD, self).__setstate__(state)
        for group in self.param_groups:
            group.setdefault('nesterov', False)

    def step(self, closure=None):
        """Performs a single optimization step.
        Arguments:
            closure (callable, optional): A closure that reevaluates the model
                and returns the loss.

        returns norm of the step we took for variance analysis later
        """
        loss = None
        if closure is not None:
            loss = closure()

        for group in self.param_groups:
            weight_decay = group['weight_decay']
            momentum = group['momentum']
            dampening = group['dampening']
            nesterov = group['nesterov']

            for p in group['params']:
                if p.grad is None:
                    continue
                d_p = p.grad.data

                if weight_decay != 0:
                    d_p.add_(weight_decay, p.data)
                if momentum != 0:
                    param_state = self.state[p]
                    if 'momentum_buffer' not in param_state:
                        buf = param_state['momentum_buffer'] = torch.zeros_like(p.data)
                        buf.mul_(momentum).add_(d_p)
                    else:
                        buf = param_state['momentum_buffer']
                        buf.mul_(momentum).add_(1 - dampening, d_p)
                    if nesterov:
                        d_p = d_p.add(momentum, buf)
                    else:
                        d_p = buf

                p.data.add_(-group['lr'], d_p)
                p.data.add_(np.sqrt(self.noise_scale), torch.randn_like(p.data))
        return loss

# %% [markdown]
# TRAIN
# ==

# %%
from torch.utils.tensorboard import SummaryWriter
import torch.nn.functional as ft
import torch.optim as optim


from warmup_scheduler import GradualWarmupScheduler

def _train(model, args):
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    model.to(device)
    criterion = torch.nn.L1Loss().to(device)
    optimizer = optim.SGD(model.parameters(), lr=args.learning_rate, momentum=args.momentum_value, nesterov=True)

    #optimizer = SGLD(params=model.parameters(), lr=args.learning_rate, weight_decay=args.weight_decay)
    dataloader = train_dataloader(args.data_dir, args.batch_size, args.num_worker)
    max_iter = len(dataloader)
    warmup_epochs=3
    scheduler_cosine = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=args.num_epoch-warmup_epochs, eta_min=1e-6)
    scheduler = GradualWarmupScheduler(optimizer, multiplier=1, total_epoch=warmup_epochs, after_scheduler=scheduler_cosine)
    scheduler.step()
    epoch = 1
    if args.resume:
        state = torch.load(args.resume)
        epoch = state['epoch']
        optimizer.load_state_dict(state['optimizer'])
        model.load_state_dict(state['model'])
        print('Resume from %d'%epoch)
        epoch += 1
        for i in range(epoch-1):
          scheduler.step()

    writer = SummaryWriter()
    epoch_pixel_adder = Adder()
    epoch_fft_adder = Adder()
    iter_pixel_adder = Adder()
    iter_fft_adder = Adder()
    epoch_timer = Timer('m')
    iter_timer = Timer('m')
    best_psnr=-1

    for epoch_idx in range(epoch, args.num_epoch + 1):

        epoch_timer.tic()
        iter_timer.tic()
        for iter_idx, batch_data in enumerate(dataloader):

            input_img, label_img = batch_data
            input_img = input_img.to(device)
            label_img = label_img.to(device)

            optimizer.zero_grad()
            pred_img = model(input_img)
            label_img2 = ft.interpolate(label_img, scale_factor=0.5, mode='bilinear')
            label_img4 = ft.interpolate(label_img, scale_factor=0.25, mode='bilinear')
            l1 = criterion(pred_img[0], label_img4)
            l2 = criterion(pred_img[1], label_img2)
            l3 = criterion(pred_img[2], label_img)
            loss_content = l1+l2+l3

            label_fft1 = torch.fft.fft2(label_img4, dim=(-2,-1))
            label_fft1 = torch.stack((label_fft1.real, label_fft1.imag), -1)

            pred_fft1 = torch.fft.fft2(pred_img[0], dim=(-2,-1))
            pred_fft1 = torch.stack((pred_fft1.real, pred_fft1.imag), -1)

            label_fft2 = torch.fft.fft2(label_img2, dim=(-2,-1))
            label_fft2 = torch.stack((label_fft2.real, label_fft2.imag), -1)

            pred_fft2 = torch.fft.fft2(pred_img[1], dim=(-2,-1))
            pred_fft2 = torch.stack((pred_fft2.real, pred_fft2.imag), -1)

            label_fft3 = torch.fft.fft2(label_img, dim=(-2,-1))
            label_fft3 = torch.stack((label_fft3.real, label_fft3.imag), -1)

            pred_fft3 = torch.fft.fft2(pred_img[2], dim=(-2,-1))
            pred_fft3 = torch.stack((pred_fft3.real, pred_fft3.imag), -1)

            f1 = criterion(pred_fft1, label_fft1)
            f2 = criterion(pred_fft2, label_fft2)
            f3 = criterion(pred_fft3, label_fft3)
            loss_fft = f1+f2+f3

            loss = loss_content + 0.1 * loss_fft
            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), 0.001)
            optimizer.step()

            iter_pixel_adder(loss_content.item())
            iter_fft_adder(loss_fft.item())

            epoch_pixel_adder(loss_content.item())
            epoch_fft_adder(loss_fft.item())

            if (iter_idx + 1) % args.print_freq == 0:
                print("Time: %7.4f Epoch: %03d Iter: %4d/%4d LR: %.10f Loss content: %7.4f Loss fft: %7.4f" % (
                    iter_timer.toc(), epoch_idx, iter_idx + 1, max_iter, scheduler.get_lr()[0], iter_pixel_adder.average(),
                    iter_fft_adder.average()))
                writer.add_scalar('Pixel Loss', iter_pixel_adder.average(), iter_idx + (epoch_idx-1)* max_iter)
                writer.add_scalar('FFT Loss', iter_fft_adder.average(), iter_idx + (epoch_idx - 1) * max_iter)

                iter_timer.tic()
                iter_pixel_adder.reset()
                iter_fft_adder.reset()
        overwrite_name = os.path.join(args.model_save_dir, 'model.pkl')
        torch.save({'model': model.state_dict(),
                    'optimizer': optimizer.state_dict(),
                    'epoch': epoch_idx}, overwrite_name)

        if epoch_idx % args.save_freq == 0:
            save_name = os.path.join(args.model_save_dir, 'model_%d.pkl' % epoch_idx)
            torch.save({'model': model.state_dict()}, save_name)
        print("EPOCH: %02d\nElapsed time: %4.2f Epoch Pixel Loss: %7.4f Epoch FFT Loss: %7.4f" % (
            epoch_idx, epoch_timer.toc(), epoch_pixel_adder.average(), epoch_fft_adder.average()))
        epoch_fft_adder.reset()
        epoch_pixel_adder.reset()
        scheduler.step()
        if epoch_idx % args.valid_freq == 0:
            val = _valid(model, args, epoch_idx)
            print('%03d epoch \n Average PSNR %.2f dB' % (epoch_idx, val))
            writer.add_scalar('PSNR', val, epoch_idx)
            if val >= best_psnr:
                torch.save({'model': model.state_dict()}, os.path.join(args.model_save_dir, 'Best.pkl'))
    save_name = os.path.join(args.model_save_dir, 'Final.pkl')
    torch.save({'model': model.state_dict()}, save_name)

# %% [markdown]
# Main (Train)
# ==

# %%
import os
import torch
import torchvision.transforms as transforms
# from torch.backends import cudnn # Uncomment if you need it

class Args:
    model_name = 'IRNeXt'
    mode = 'train'
    data_dir = path

    # Train
    batch_size = 4
    learning_rate = 1e-4
    weight_decay = 0
    num_epoch = 20
    print_freq = 100
    num_worker = 8
    save_freq = 10
    valid_freq = 10
    momentum_value = 0.4

    resume = '/content/drive/MyDrive/OUTMYresults0_4/IRNeXt/ITS/model.pkl'
    #/content/drive/MyDrive/MYresults2/IRNeXt/ITS/model.pkl
    # Test
    test_model = '/content/drive/MyDrive/OUTMYresults0_4/IRNeXt/ITS/Final.pkl'
    save_image = False

    # Directories (set these as per your requirement)
    model_save_dir = os.path.join('/content/drive/MyDrive/OUTMYresults0_4/', 'IRNeXt', 'ITS/')
    result_dir = os.path.join('/content/drive/MyDrive/OUTMYresults0_4/', model_name, 'test')

def main(args):
    # CUDNN
    # cudnn.benchmark = True # Uncomment if you need it

    if not os.path.exists('/content/drive/MyDrive/OUTMYresults0_4/'):
        os.makedirs(args.model_save_dir)
    if not os.path.exists('/content/drive/MyDrive/OUTMYresults0_4/' + args.model_name + '/'):
        os.makedirs('/content/drive/MyDrive/OUTMYresults0_4/' + args.model_name + '/')
    if not os.path.exists(args.model_save_dir):
        os.makedirs(args.model_save_dir)
    if not os.path.exists(args.result_dir):
        os.makedirs(args.result_dir)

    model = build_net()  # Make sure to define build_net or import it if it's defined elsewhere
    print(model)

    if torch.cuda.is_available():
        model.cuda()
    if args.mode == 'train':
        _train(model, args)  # Make sure to define _train or import it if it's defined elsewhere

    elif args.mode == 'test':
        _eval(model, args)   # Make sure to define _eval or import it if it's defined elsewhere

# Replace parser.parse_args() with an instance of the Args class
args = Args()
if not os.path.exists(args.model_save_dir):
    os.makedirs(args.model_save_dir)
# Copying files (make sure these paths are correct)
command = 'cp ' + 'models/layers.py ' + args.model_save_dir
os.system(command)
command = 'cp ' + 'models/IRNeXt.py ' + args.model_save_dir
os.system(command)
command = 'cp ' + 'train.py ' + args.model_save_dir
os.system(command)
command = 'cp ' + 'main.py ' + args.model_save_dir
os.system(command)
print(args)
main(args)
# Out:
# <__main__.Args object at 0x7a0feadb2080>
# IRNeXt(
#   (Encoder): ModuleList(
#     (0): EBlock(
#       (layers): Sequential(
#         (0): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (1): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (2): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (3): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): DeepPoolLayer(
#               (pools): ModuleList(
#                 (0): AvgPool2d(kernel_size=8, stride=8, padding=0)
#                 (1): AvgPool2d(kernel_size=4, stride=4, padding=0)
#                 (2): AvgPool2d(kernel_size=2, stride=2, padding=0)
#               )
#               (convs): ModuleList(
#                 (0-2): 3 x Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#               (dynas): ModuleList(
#                 (0-2): 3 x dynamic_filter(
#                   (conv): Conv2d(32, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (bn): BatchNorm2d(72, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (act): Tanh()
#                   (pad): ReflectionPad2d((1, 1, 1, 1))
#                   (ap): AdaptiveAvgPool2d(output_size=(1, 1))
#                   (gap): AdaptiveAvgPool2d(output_size=1)
#                 )
#               )
#               (relu): GELU(approximate='none')
#               (conv_sum): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             )
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#       )
#     )
#     (1): EBlock(
#       (layers): Sequential(
#         (0): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (1): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (2): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (3): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): DeepPoolLayer(
#               (pools): ModuleList(
#                 (0): AvgPool2d(kernel_size=8, stride=8, padding=0)
#                 (1): AvgPool2d(kernel_size=4, stride=4, padding=0)
#                 (2): AvgPool2d(kernel_size=2, stride=2, padding=0)
#               )
#               (convs): ModuleList(
#                 (0-2): 3 x Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#               (dynas): ModuleList(
#                 (0-2): 3 x dynamic_filter(
#                   (conv): Conv2d(64, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (bn): BatchNorm2d(72, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (act): Tanh()
#                   (pad): ReflectionPad2d((1, 1, 1, 1))
#                   (ap): AdaptiveAvgPool2d(output_size=(1, 1))
#                   (gap): AdaptiveAvgPool2d(output_size=1)
#                 )
#               )
#               (relu): GELU(approximate='none')
#               (conv_sum): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             )
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#       )
#     )
#     (2): EBlock(
#       (layers): Sequential(
#         (0): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (1): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (2): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (3): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): DeepPoolLayer(
#               (pools): ModuleList(
#                 (0): AvgPool2d(kernel_size=8, stride=8, padding=0)
#                 (1): AvgPool2d(kernel_size=4, stride=4, padding=0)
#                 (2): AvgPool2d(kernel_size=2, stride=2, padding=0)
#               )
#               (convs): ModuleList(
#                 (0-2): 3 x Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#               (dynas): ModuleList(
#                 (0-2): 3 x dynamic_filter(
#                   (conv): Conv2d(128, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (bn): BatchNorm2d(72, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (act): Tanh()
#                   (pad): ReflectionPad2d((1, 1, 1, 1))
#                   (ap): AdaptiveAvgPool2d(output_size=(1, 1))
#                   (gap): AdaptiveAvgPool2d(output_size=1)
#                 )
#               )
#               (relu): GELU(approximate='none')
#               (conv_sum): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             )
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#       )
#     )
#   )
#   (feat_extract): ModuleList(
#     (0): BasicConv(
#       (main): Sequential(
#         (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): GELU(approximate='none')
#       )
#     )
#     (1): BasicConv(
#       (main): Sequential(
#         (0): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         (1): GELU(approximate='none')
#       )
#     )
#     (2): BasicConv(
#       (main): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         (1): GELU(approximate='none')
#       )
#     )
#     (3): BasicConv(
#       (main): Sequential(
#         (0): ConvTranspose2d(128, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#         (1): GELU(approximate='none')
#       )
#     )
#     (4): BasicConv(
#       (main): Sequential(
#         (0): ConvTranspose2d(64, 32, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#         (1): GELU(approximate='none')
#       )
#     )
#     (5): BasicConv(
#       (main): Sequential(
#         (0): Conv2d(32, 3, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#     )
#   )
#   (Decoder): ModuleList(
#     (0): DBlock(
#       (layers): Sequential(
#         (0): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (1): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (2): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (3): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): DeepPoolLayer(
#               (pools): ModuleList(
#                 (0): AvgPool2d(kernel_size=8, stride=8, padding=0)
#                 (1): AvgPool2d(kernel_size=4, stride=4, padding=0)
#                 (2): AvgPool2d(kernel_size=2, stride=2, padding=0)
#               )
#               (convs): ModuleList(
#                 (0-2): 3 x Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#               (dynas): ModuleList(
#                 (0-2): 3 x dynamic_filter(
#                   (conv): Conv2d(128, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (bn): BatchNorm2d(72, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (act): Tanh()
#                   (pad): ReflectionPad2d((1, 1, 1, 1))
#                   (ap): AdaptiveAvgPool2d(output_size=(1, 1))
#                   (gap): AdaptiveAvgPool2d(output_size=1)
#                 )
#               )
#               (relu): GELU(approximate='none')
#               (conv_sum): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             )
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#       )
#     )
#     (1): DBlock(
#       (layers): Sequential(
#         (0): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (1): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (2): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (3): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): DeepPoolLayer(
#               (pools): ModuleList(
#                 (0): AvgPool2d(kernel_size=8, stride=8, padding=0)
#                 (1): AvgPool2d(kernel_size=4, stride=4, padding=0)
#                 (2): AvgPool2d(kernel_size=2, stride=2, padding=0)
#               )
#               (convs): ModuleList(
#                 (0-2): 3 x Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#               (dynas): ModuleList(
#                 (0-2): 3 x dynamic_filter(
#                   (conv): Conv2d(64, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (bn): BatchNorm2d(72, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (act): Tanh()
#                   (pad): ReflectionPad2d((1, 1, 1, 1))
#                   (ap): AdaptiveAvgPool2d(output_size=(1, 1))
#                   (gap): AdaptiveAvgPool2d(output_size=1)
#                 )
#               )
#               (relu): GELU(approximate='none')
#               (conv_sum): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             )
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#       )
#     )
#     (2): DBlock(
#       (layers): Sequential(
#         (0): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (1): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (2): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (3): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): DeepPoolLayer(
#               (pools): ModuleList(
#                 (0): AvgPool2d(kernel_size=8, stride=8, padding=0)
#                 (1): AvgPool2d(kernel_size=4, stride=4, padding=0)
#                 (2): AvgPool2d(kernel_size=2, stride=2, padding=0)
#               )
#               (convs): ModuleList(
#                 (0-2): 3 x Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#               (dynas): ModuleList(
#                 (0-2): 3 x dynamic_filter(
#                   (conv): Conv2d(32, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (bn): BatchNorm2d(72, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (act): Tanh()
#                   (pad): ReflectionPad2d((1, 1, 1, 1))
#                   (ap): AdaptiveAvgPool2d(output_size=(1, 1))
#                   (gap): AdaptiveAvgPool2d(output_size=1)
#                 )
#               )
#               (relu): GELU(approximate='none')
#               (conv_sum): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             )
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#       )
#     )
#   )
#   (Convs): ModuleList(
#     (0): BasicConv(
#       (main): Sequential(
#         (0): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1))
#         (1): GELU(approximate='none')
#       )
#     )
#     (1): BasicConv(
#       (main): Sequential(
#         (0): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#         (1): GELU(approximate='none')
#       )
#     )
#   )
#   (ConvsOut): ModuleList(
#     (0): BasicConv(
#       (main): Sequential(
#         (0): Conv2d(128, 3, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#     )
#     (1): BasicConv(
#       (main): Sequential(
#         (0): Conv2d(64, 3, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#     )
#   )
#   (FAM1): FAM(
#     (merge): BasicConv(
#       (main): Sequential(
#         (0): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#     )
#   )
#   (SCM1): SCM(
#     (main): Sequential(
#       (0): BasicConv(
#         (main): Sequential(
#           (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): GELU(approximate='none')
#         )
#       )
#       (1): BasicConv(
#         (main): Sequential(
#           (0): Conv2d(32, 64, kernel_size=(1, 1), stride=(1, 1))
#           (1): GELU(approximate='none')
#         )
#       )
#       (2): BasicConv(
#         (main): Sequential(
#           (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): GELU(approximate='none')
#         )
#       )
#       (3): BasicConv(
#         (main): Sequential(
#           (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1))
#         )
#       )
#       (4): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#     )
#   )
#   (FAM2): FAM(
#     (merge): BasicConv(
#       (main): Sequential(
#         (0): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#     )
#   )
#   (SCM2): SCM(
#     (main): Sequential(
#       (0): BasicConv(
#         (main): Sequential(
#           (0): Conv2d(3, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): GELU(approximate='none')
#         )
#       )
#       (1): BasicConv(
#         (main): Sequential(
#           (0): Conv2d(16, 32, kernel_size=(1, 1), stride=(1, 1))
#           (1): GELU(approximate='none')
#         )
#       )
#       (2): BasicConv(
#         (main): Sequential(
#           (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): GELU(approximate='none')
#         )
#       )
#       (3): BasicConv(
#         (main): Sequential(
#           (0): Conv2d(32, 64, kernel_size=(1, 1), stride=(1, 1))
#         )
#       )
#       (4): InstanceNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#     )
#   )
# )
# Resume from 20
# /usr/local/lib/python3.10/dist-packages/torch/optim/lr_scheduler.py:136: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   warnings.warn("Detected call of `lr_scheduler.step()` before `optimizer.step()`. "
# /usr/local/lib/python3.10/dist-packages/torch/optim/lr_scheduler.py:809: UserWarning: To get the last learning rate computed by the scheduler, please use `get_last_lr()`.
#   warnings.warn("To get the last learning rate computed by the scheduler, "
# Time:  0.1385 Epoch: 021 Iter:  100/3498 LR: 0.0000991110 Loss content:  0.7389 Loss fft:  9.9737
# Time:  0.1277 Epoch: 021 Iter:  200/3498 LR: 0.0000991110 Loss content:  0.7403 Loss fft: 10.1717
# Time:  0.1277 Epoch: 021 Iter:  300/3498 LR: 0.0000991110 Loss content:  0.7708 Loss fft: 10.0517
# Time:  0.1283 Epoch: 021 Iter:  400/3498 LR: 0.0000991110 Loss content:  0.7364 Loss fft: 10.0441
# Time:  0.1267 Epoch: 021 Iter:  500/3498 LR: 0.0000991110 Loss content:  0.7416 Loss fft:  9.9040
# Time:  0.1275 Epoch: 021 Iter:  600/3498 LR: 0.0000991110 Loss content:  0.7580 Loss fft: 10.2176
# Time:  0.1270 Epoch: 021 Iter:  700/3498 LR: 0.0000991110 Loss content:  0.7493 Loss fft:  9.8557
# Time:  0.1299 Epoch: 021 Iter:  800/3498 LR: 0.0000991110 Loss content:  0.7702 Loss fft:  9.7747
# Time:  0.1287 Epoch: 021 Iter:  900/3498 LR: 0.0000991110 Loss content:  0.7607 Loss fft: 10.0172
# Time:  0.1286 Epoch: 021 Iter: 1000/3498 LR: 0.0000991110 Loss content:  0.7555 Loss fft: 10.0847
# Time:  0.1277 Epoch: 021 Iter: 1100/3498 LR: 0.0000991110 Loss content:  0.7497 Loss fft:  9.9002
# Time:  0.1271 Epoch: 021 Iter: 1200/3498 LR: 0.0000991110 Loss content:  0.7404 Loss fft:  9.6607
# Time:  0.1297 Epoch: 021 Iter: 1300/3498 LR: 0.0000991110 Loss content:  0.7262 Loss fft:  9.8998
# Time:  0.1286 Epoch: 021 Iter: 1400/3498 LR: 0.0000991110 Loss content:  0.7469 Loss fft:  9.8310
# Time:  0.1281 Epoch: 021 Iter: 1500/3498 LR: 0.0000991110 Loss content:  0.7390 Loss fft: 10.1151
# Time:  0.1289 Epoch: 021 Iter: 1600/3498 LR: 0.0000991110 Loss content:  0.7650 Loss fft: 10.2073
# Time:  0.1282 Epoch: 021 Iter: 1700/3498 LR: 0.0000991110 Loss content:  0.7503 Loss fft:  9.8398
# Time:  0.1276 Epoch: 021 Iter: 1800/3498 LR: 0.0000991110 Loss content:  0.7619 Loss fft:  9.7694
# Time:  0.1343 Epoch: 021 Iter: 1900/3498 LR: 0.0000991110 Loss content:  0.7258 Loss fft: 10.0276
# Time:  0.1285 Epoch: 021 Iter: 2000/3498 LR: 0.0000991110 Loss content:  0.7617 Loss fft:  9.8353
# Time:  0.1279 Epoch: 021 Iter: 2100/3498 LR: 0.0000991110 Loss content:  0.7412 Loss fft:  9.8429
# Time:  0.1293 Epoch: 021 Iter: 2200/3498 LR: 0.0000991110 Loss content:  0.7352 Loss fft:  9.9153
# Time:  0.1283 Epoch: 021 Iter: 2300/3498 LR: 0.0000991110 Loss content:  0.7508 Loss fft: 10.1679
# Time:  0.1308 Epoch: 021 Iter: 2400/3498 LR: 0.0000991110 Loss content:  0.7673 Loss fft: 10.0353
# Time:  0.1279 Epoch: 021 Iter: 2500/3498 LR: 0.0000991110 Loss content:  0.7758 Loss fft:  9.6010
# Time:  0.1290 Epoch: 021 Iter: 2600/3498 LR: 0.0000991110 Loss content:  0.7218 Loss fft:  9.8939
# Time:  0.1287 Epoch: 021 Iter: 2700/3498 LR: 0.0000991110 Loss content:  0.7505 Loss fft:  9.8189
# Time:  0.1282 Epoch: 021 Iter: 2800/3498 LR: 0.0000991110 Loss content:  0.7575 Loss fft:  9.8872
# Time:  0.1286 Epoch: 021 Iter: 2900/3498 LR: 0.0000991110 Loss content:  0.7352 Loss fft:  9.9469
# Time:  0.1297 Epoch: 021 Iter: 3000/3498 LR: 0.0000991110 Loss content:  0.7557 Loss fft:  9.8382
# Time:  0.1295 Epoch: 021 Iter: 3100/3498 LR: 0.0000991110 Loss content:  0.7338 Loss fft:  9.6804
# Time:  0.1283 Epoch: 021 Iter: 3200/3498 LR: 0.0000991110 Loss content:  0.7573 Loss fft: 10.0828
# Time:  0.1289 Epoch: 021 Iter: 3300/3498 LR: 0.0000991110 Loss content:  0.7319 Loss fft:  9.8633
# Time:  0.1296 Epoch: 021 Iter: 3400/3498 LR: 0.0000991110 Loss content:  0.7510 Loss fft:  9.8780
# EPOCH: 21
# Elapsed time: 4.52 Epoch Pixel Loss:  0.7486 Epoch FFT Loss:  9.9291
# Time:  0.1400 Epoch: 022 Iter:  100/3498 LR: 0.0000990092 Loss content:  0.7440 Loss fft:  9.8929
# Time:  0.1294 Epoch: 022 Iter:  200/3498 LR: 0.0000990092 Loss content:  0.7429 Loss fft:  9.9652
# Time:  0.1302 Epoch: 022 Iter:  300/3498 LR: 0.0000990092 Loss content:  0.7450 Loss fft:  9.8430
# Time:  0.1292 Epoch: 022 Iter:  400/3498 LR: 0.0000990092 Loss content:  0.7652 Loss fft: 10.1082
# Time:  0.1293 Epoch: 022 Iter:  500/3498 LR: 0.0000990092 Loss content:  0.7350 Loss fft:  9.8719
# Time:  0.1303 Epoch: 022 Iter:  600/3498 LR: 0.0000990092 Loss content:  0.7459 Loss fft:  9.7968
# Time:  0.1370 Epoch: 022 Iter:  700/3498 LR: 0.0000990092 Loss content:  0.7532 Loss fft:  9.8108
# Time:  0.1306 Epoch: 022 Iter:  800/3498 LR: 0.0000990092 Loss content:  0.7704 Loss fft:  9.8096
# Time:  0.1292 Epoch: 022 Iter:  900/3498 LR: 0.0000990092 Loss content:  0.7419 Loss fft: 10.0275
# Time:  0.1299 Epoch: 022 Iter: 1000/3498 LR: 0.0000990092 Loss content:  0.7302 Loss fft:  9.8093
# Time:  0.1302 Epoch: 022 Iter: 1100/3498 LR: 0.0000990092 Loss content:  0.7310 Loss fft:  9.6322
# Time:  0.1297 Epoch: 022 Iter: 1200/3498 LR: 0.0000990092 Loss content:  0.7585 Loss fft:  9.9517
# Time:  0.1302 Epoch: 022 Iter: 1300/3498 LR: 0.0000990092 Loss content:  0.7284 Loss fft:  9.7887
# Time:  0.1285 Epoch: 022 Iter: 1400/3498 LR: 0.0000990092 Loss content:  0.7826 Loss fft: 10.3550
# Time:  0.1301 Epoch: 022 Iter: 1500/3498 LR: 0.0000990092 Loss content:  0.7346 Loss fft:  9.6086
# Time:  0.1293 Epoch: 022 Iter: 1600/3498 LR: 0.0000990092 Loss content:  0.7588 Loss fft:  9.7132
# Time:  0.1319 Epoch: 022 Iter: 1700/3498 LR: 0.0000990092 Loss content:  0.7639 Loss fft: 10.0166
# Time:  0.1307 Epoch: 022 Iter: 1800/3498 LR: 0.0000990092 Loss content:  0.7352 Loss fft: 10.0102
# Time:  0.1294 Epoch: 022 Iter: 1900/3498 LR: 0.0000990092 Loss content:  0.7473 Loss fft: 10.1143
# Time:  0.1295 Epoch: 022 Iter: 2000/3498 LR: 0.0000990092 Loss content:  0.7172 Loss fft:  9.8495
# Time:  0.1305 Epoch: 022 Iter: 2100/3498 LR: 0.0000990092 Loss content:  0.7453 Loss fft:  9.9287
# Time:  0.1286 Epoch: 022 Iter: 2200/3498 LR: 0.0000990092 Loss content:  0.7389 Loss fft:  9.9867
# Time:  0.1286 Epoch: 022 Iter: 2300/3498 LR: 0.0000990092 Loss content:  0.7606 Loss fft:  9.8038
# Time:  0.1300 Epoch: 022 Iter: 2400/3498 LR: 0.0000990092 Loss content:  0.7636 Loss fft:  9.9534
# Time:  0.1300 Epoch: 022 Iter: 2500/3498 LR: 0.0000990092 Loss content:  0.7431 Loss fft:  9.9862
# Time:  0.1288 Epoch: 022 Iter: 2600/3498 LR: 0.0000990092 Loss content:  0.7557 Loss fft: 10.1654
# Time:  0.1289 Epoch: 022 Iter: 2700/3498 LR: 0.0000990092 Loss content:  0.7549 Loss fft: 10.2294
# Time:  0.1287 Epoch: 022 Iter: 2800/3498 LR: 0.0000990092 Loss content:  0.7534 Loss fft:  9.8583
# Time:  0.1297 Epoch: 022 Iter: 2900/3498 LR: 0.0000990092 Loss content:  0.7380 Loss fft:  9.9070
# Time:  0.1334 Epoch: 022 Iter: 3000/3498 LR: 0.0000990092 Loss content:  0.7489 Loss fft: 10.0763
# Time:  0.1283 Epoch: 022 Iter: 3100/3498 LR: 0.0000990092 Loss content:  0.7525 Loss fft: 10.0287
# Time:  0.1293 Epoch: 022 Iter: 3200/3498 LR: 0.0000990092 Loss content:  0.7388 Loss fft: 10.1526
# Time:  0.1285 Epoch: 022 Iter: 3300/3498 LR: 0.0000990092 Loss content:  0.7368 Loss fft:  9.9140
# Time:  0.1299 Epoch: 022 Iter: 3400/3498 LR: 0.0000990092 Loss content:  0.7339 Loss fft:  9.8316
# EPOCH: 22
# Elapsed time: 4.56 Epoch Pixel Loss:  0.7472 Epoch FFT Loss:  9.9380
# Time:  0.1390 Epoch: 023 Iter:  100/3498 LR: 0.0000989020 Loss content:  0.7439 Loss fft:  9.9918
# Time:  0.1287 Epoch: 023 Iter:  200/3498 LR: 0.0000989020 Loss content:  0.7401 Loss fft:  9.8064
# Time:  0.1285 Epoch: 023 Iter:  300/3498 LR: 0.0000989020 Loss content:  0.7518 Loss fft: 10.0925
# Time:  0.1295 Epoch: 023 Iter:  400/3498 LR: 0.0000989020 Loss content:  0.7458 Loss fft:  9.9813
# Time:  0.1275 Epoch: 023 Iter:  500/3498 LR: 0.0000989020 Loss content:  0.7390 Loss fft: 10.1408
# Time:  0.1279 Epoch: 023 Iter:  600/3498 LR: 0.0000989020 Loss content:  0.7544 Loss fft:  9.7857
# Time:  0.1278 Epoch: 023 Iter:  700/3498 LR: 0.0000989020 Loss content:  0.7502 Loss fft:  9.8237
# Time:  0.1283 Epoch: 023 Iter:  800/3498 LR: 0.0000989020 Loss content:  0.7643 Loss fft:  9.6986
# Time:  0.1295 Epoch: 023 Iter:  900/3498 LR: 0.0000989020 Loss content:  0.7244 Loss fft:  9.8553
# Time:  0.1294 Epoch: 023 Iter: 1000/3498 LR: 0.0000989020 Loss content:  0.7461 Loss fft: 10.0081
# Time:  0.1303 Epoch: 023 Iter: 1100/3498 LR: 0.0000989020 Loss content:  0.7515 Loss fft:  9.9178
# Time:  0.1295 Epoch: 023 Iter: 1200/3498 LR: 0.0000989020 Loss content:  0.7501 Loss fft:  9.8525
# Time:  0.1299 Epoch: 023 Iter: 1300/3498 LR: 0.0000989020 Loss content:  0.7407 Loss fft: 10.0112
# Time:  0.1290 Epoch: 023 Iter: 1400/3498 LR: 0.0000989020 Loss content:  0.7456 Loss fft: 10.2243
# Time:  0.1300 Epoch: 023 Iter: 1500/3498 LR: 0.0000989020 Loss content:  0.7534 Loss fft:  9.7622
# Time:  0.1310 Epoch: 023 Iter: 1600/3498 LR: 0.0000989020 Loss content:  0.7344 Loss fft:  9.9332

# %%
state_last = torch.load('/content/drive/MyDrive/MYresults/IRNeXt/ITS/model.pkl')

# %% [markdown]
# Test
# ==

# %%
import os
import torch
import torchvision.transforms as transforms
# from torch.backends import cudnn # Uncomment if you need it

class Args:
    model_name = 'IRNeXt'
    mode = 'test'
    data_dir = path

    # Train
    batch_size = 4
    learning_rate = 1e-4
    weight_decay = 0
    num_epoch = 300
    print_freq = 100
    num_worker = 8
    save_freq = 10
    valid_freq = 10
    momentum_value = 0.2

    resume = ''
    #/content/drive/MyDrive/MYresults2/IRNeXt/ITS/model.pkl
    # Test
    test_model = '/content/drive/MyDrive/OUTMYresults0_4/IRNeXt/ITS/Final.pkl'
    save_image = False

    # Directories (set these as per your requirement)
    model_save_dir = os.path.join('/content/drive/MyDrive/OUTMYresults0_4/', 'IRNeXt', 'ITS/')
    result_dir = os.path.join('/content/drive/MyDrive/OUTMYresults0_4/', model_name, 'test')

def main(args):
    # CUDNN
    # cudnn.benchmark = True # Uncomment if you need it

    if not os.path.exists('/content/drive/MyDrive/OUTMYresults0_4/'):
        os.makedirs(args.model_save_dir)
    if not os.path.exists('/content/drive/MyDrive/OUTMYresults0_4/' + args.model_name + '/'):
        os.makedirs('/content/drive/MyDrive/OUTMYresults0_4/' + args.model_name + '/')
    if not os.path.exists(args.model_save_dir):
        os.makedirs(args.model_save_dir)
    if not os.path.exists(args.result_dir):
        os.makedirs(args.result_dir)

    model = build_net()  # Make sure to define build_net or import it if it's defined elsewhere
    print(model)

    if torch.cuda.is_available():
        model.cuda()
    if args.mode == 'train':
        _train(model, args)  # Make sure to define _train or import it if it's defined elsewhere

    elif args.mode == 'test':
        _eval(model, args)   # Make sure to define _eval or import it if it's defined elsewhere

# Replace parser.parse_args() with an instance of the Args class
args = Args()
if not os.path.exists(args.model_save_dir):
    os.makedirs(args.model_save_dir)
# Copying files (make sure these paths are correct)
command = 'cp ' + 'models/layers.py ' + args.model_save_dir
os.system(command)
command = 'cp ' + 'models/IRNeXt.py ' + args.model_save_dir
os.system(command)
command = 'cp ' + 'train.py ' + args.model_save_dir
os.system(command)
command = 'cp ' + 'main.py ' + args.model_save_dir
os.system(command)
print(args)
main(args)
# Out:
# <__main__.Args object at 0x7a0f9733dc60>
# IRNeXt(
#   (Encoder): ModuleList(
#     (0): EBlock(
#       (layers): Sequential(
#         (0): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (1): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (2): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (3): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): DeepPoolLayer(
#               (pools): ModuleList(
#                 (0): AvgPool2d(kernel_size=8, stride=8, padding=0)
#                 (1): AvgPool2d(kernel_size=4, stride=4, padding=0)
#                 (2): AvgPool2d(kernel_size=2, stride=2, padding=0)
#               )
#               (convs): ModuleList(
#                 (0-2): 3 x Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#               (dynas): ModuleList(
#                 (0-2): 3 x dynamic_filter(
#                   (conv): Conv2d(32, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (bn): BatchNorm2d(72, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (act): Tanh()
#                   (pad): ReflectionPad2d((1, 1, 1, 1))
#                   (ap): AdaptiveAvgPool2d(output_size=(1, 1))
#                   (gap): AdaptiveAvgPool2d(output_size=1)
#                 )
#               )
#               (relu): GELU(approximate='none')
#               (conv_sum): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             )
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#       )
#     )
#     (1): EBlock(
#       (layers): Sequential(
#         (0): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (1): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (2): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (3): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): DeepPoolLayer(
#               (pools): ModuleList(
#                 (0): AvgPool2d(kernel_size=8, stride=8, padding=0)
#                 (1): AvgPool2d(kernel_size=4, stride=4, padding=0)
#                 (2): AvgPool2d(kernel_size=2, stride=2, padding=0)
#               )
#               (convs): ModuleList(
#                 (0-2): 3 x Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#               (dynas): ModuleList(
#                 (0-2): 3 x dynamic_filter(
#                   (conv): Conv2d(64, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (bn): BatchNorm2d(72, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (act): Tanh()
#                   (pad): ReflectionPad2d((1, 1, 1, 1))
#                   (ap): AdaptiveAvgPool2d(output_size=(1, 1))
#                   (gap): AdaptiveAvgPool2d(output_size=1)
#                 )
#               )
#               (relu): GELU(approximate='none')
#               (conv_sum): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             )
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#       )
#     )
#     (2): EBlock(
#       (layers): Sequential(
#         (0): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (1): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (2): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (3): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): DeepPoolLayer(
#               (pools): ModuleList(
#                 (0): AvgPool2d(kernel_size=8, stride=8, padding=0)
#                 (1): AvgPool2d(kernel_size=4, stride=4, padding=0)
#                 (2): AvgPool2d(kernel_size=2, stride=2, padding=0)
#               )
#               (convs): ModuleList(
#                 (0-2): 3 x Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#               (dynas): ModuleList(
#                 (0-2): 3 x dynamic_filter(
#                   (conv): Conv2d(128, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (bn): BatchNorm2d(72, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (act): Tanh()
#                   (pad): ReflectionPad2d((1, 1, 1, 1))
#                   (ap): AdaptiveAvgPool2d(output_size=(1, 1))
#                   (gap): AdaptiveAvgPool2d(output_size=1)
#                 )
#               )
#               (relu): GELU(approximate='none')
#               (conv_sum): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             )
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#       )
#     )
#   )
#   (feat_extract): ModuleList(
#     (0): BasicConv(
#       (main): Sequential(
#         (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): GELU(approximate='none')
#       )
#     )
#     (1): BasicConv(
#       (main): Sequential(
#         (0): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         (1): GELU(approximate='none')
#       )
#     )
#     (2): BasicConv(
#       (main): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         (1): GELU(approximate='none')
#       )
#     )
#     (3): BasicConv(
#       (main): Sequential(
#         (0): ConvTranspose2d(128, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#         (1): GELU(approximate='none')
#       )
#     )
#     (4): BasicConv(
#       (main): Sequential(
#         (0): ConvTranspose2d(64, 32, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#         (1): GELU(approximate='none')
#       )
#     )
#     (5): BasicConv(
#       (main): Sequential(
#         (0): Conv2d(32, 3, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#     )
#   )
#   (Decoder): ModuleList(
#     (0): DBlock(
#       (layers): Sequential(
#         (0): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (1): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (2): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (3): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): DeepPoolLayer(
#               (pools): ModuleList(
#                 (0): AvgPool2d(kernel_size=8, stride=8, padding=0)
#                 (1): AvgPool2d(kernel_size=4, stride=4, padding=0)
#                 (2): AvgPool2d(kernel_size=2, stride=2, padding=0)
#               )
#               (convs): ModuleList(
#                 (0-2): 3 x Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#               (dynas): ModuleList(
#                 (0-2): 3 x dynamic_filter(
#                   (conv): Conv2d(128, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (bn): BatchNorm2d(72, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (act): Tanh()
#                   (pad): ReflectionPad2d((1, 1, 1, 1))
#                   (ap): AdaptiveAvgPool2d(output_size=(1, 1))
#                   (gap): AdaptiveAvgPool2d(output_size=1)
#                 )
#               )
#               (relu): GELU(approximate='none')
#               (conv_sum): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             )
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#       )
#     )
#     (1): DBlock(
#       (layers): Sequential(
#         (0): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (1): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (2): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (3): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): DeepPoolLayer(
#               (pools): ModuleList(
#                 (0): AvgPool2d(kernel_size=8, stride=8, padding=0)
#                 (1): AvgPool2d(kernel_size=4, stride=4, padding=0)
#                 (2): AvgPool2d(kernel_size=2, stride=2, padding=0)
#               )
#               (convs): ModuleList(
#                 (0-2): 3 x Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#               (dynas): ModuleList(
#                 (0-2): 3 x dynamic_filter(
#                   (conv): Conv2d(64, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (bn): BatchNorm2d(72, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (act): Tanh()
#                   (pad): ReflectionPad2d((1, 1, 1, 1))
#                   (ap): AdaptiveAvgPool2d(output_size=(1, 1))
#                   (gap): AdaptiveAvgPool2d(output_size=1)
#                 )
#               )
#               (relu): GELU(approximate='none')
#               (conv_sum): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             )
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#       )
#     )
#     (2): DBlock(
#       (layers): Sequential(
#         (0): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (1): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (2): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (3): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): DeepPoolLayer(
#               (pools): ModuleList(
#                 (0): AvgPool2d(kernel_size=8, stride=8, padding=0)
#                 (1): AvgPool2d(kernel_size=4, stride=4, padding=0)
#                 (2): AvgPool2d(kernel_size=2, stride=2, padding=0)
#               )
#               (convs): ModuleList(
#                 (0-2): 3 x Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#               (dynas): ModuleList(
#                 (0-2): 3 x dynamic_filter(
#                   (conv): Conv2d(32, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (bn): BatchNorm2d(72, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (act): Tanh()
#                   (pad): ReflectionPad2d((1, 1, 1, 1))
#                   (ap): AdaptiveAvgPool2d(output_size=(1, 1))
#                   (gap): AdaptiveAvgPool2d(output_size=1)
#                 )
#               )
#               (relu): GELU(approximate='none')
#               (conv_sum): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             )
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#       )
#     )
#   )
#   (Convs): ModuleList(
#     (0): BasicConv(
#       (main): Sequential(
#         (0): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1))
#         (1): GELU(approximate='none')
#       )
#     )
#     (1): BasicConv(
#       (main): Sequential(
#         (0): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#         (1): GELU(approximate='none')
#       )
#     )
#   )
#   (ConvsOut): ModuleList(
#     (0): BasicConv(
#       (main): Sequential(
#         (0): Conv2d(128, 3, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#     )
#     (1): BasicConv(
#       (main): Sequential(
#         (0): Conv2d(64, 3, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#     )
#   )
#   (FAM1): FAM(
#     (merge): BasicConv(
#       (main): Sequential(
#         (0): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#     )
#   )
#   (SCM1): SCM(
#     (main): Sequential(
#       (0): BasicConv(
#         (main): Sequential(
#           (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): GELU(approximate='none')
#         )
#       )
#       (1): BasicConv(
#         (main): Sequential(
#           (0): Conv2d(32, 64, kernel_size=(1, 1), stride=(1, 1))
#           (1): GELU(approximate='none')
#         )
#       )
#       (2): BasicConv(
#         (main): Sequential(
#           (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): GELU(approximate='none')
#         )
#       )
#       (3): BasicConv(
#         (main): Sequential(
#           (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1))
#         )
#       )
#       (4): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#     )
#   )
#   (FAM2): FAM(
#     (merge): BasicConv(
#       (main): Sequential(
#         (0): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#     )
#   )
#   (SCM2): SCM(
#     (main): Sequential(
#       (0): BasicConv(
#         (main): Sequential(
#           (0): Conv2d(3, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): GELU(approximate='none')
#         )
#       )
#       (1): BasicConv(
#         (main): Sequential(
#           (0): Conv2d(16, 32, kernel_size=(1, 1), stride=(1, 1))
#           (1): GELU(approximate='none')
#         )
#       )
#       (2): BasicConv(
#         (main): Sequential(
#           (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): GELU(approximate='none')
#         )
#       )
#       (3): BasicConv(
#         (main): Sequential(
#           (0): Conv2d(32, 64, kernel_size=(1, 1), stride=(1, 1))
#         )
#       )
#       (4): InstanceNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#     )
#   )
# )
# 1 iter PSNR_dehazing: 14.94 ssim: 0.805733
# 1 iter PSNR: 14.94 time: 0.025942
# 2 iter PSNR_dehazing: 9.39 ssim: 0.646373
# 2 iter PSNR: 9.39 time: 0.020584
# 3 iter PSNR_dehazing: 13.92 ssim: 0.784394
# 3 iter PSNR: 13.92 time: 0.021054
# 4 iter PSNR_dehazing: 13.06 ssim: 0.764271
# 4 iter PSNR: 13.06 time: 0.020549
# 5 iter PSNR_dehazing: 12.31 ssim: 0.745121
# 5 iter PSNR: 12.31 time: 0.020498
# 6 iter PSNR_dehazing: 11.66 ssim: 0.726845
# 6 iter PSNR: 11.66 time: 0.020432
# 7 iter PSNR_dehazing: 11.10 ssim: 0.709357
# 7 iter PSNR: 11.10 time: 0.020357
# 8 iter PSNR_dehazing: 10.60 ssim: 0.692621
# 8 iter PSNR: 10.60 time: 0.020391
# 9 iter PSNR_dehazing: 10.15 ssim: 0.676562
# 9 iter PSNR: 10.15 time: 0.020552
# 10 iter PSNR_dehazing: 9.75 ssim: 0.661141
# 10 iter PSNR: 9.75 time: 0.021104
# 11 iter PSNR_dehazing: 17.83 ssim: 0.825831
# 11 iter PSNR: 17.83 time: 0.020628
# 12 iter PSNR_dehazing: 11.89 ssim: 0.701744
# 12 iter PSNR: 11.89 time: 0.020711
# 13 iter PSNR_dehazing: 16.80 ssim: 0.808867
# 13 iter PSNR: 16.80 time: 0.020695
# 14 iter PSNR_dehazing: 15.91 ssim: 0.793152
# 14 iter PSNR: 15.91 time: 0.020808
# 15 iter PSNR_dehazing: 15.13 ssim: 0.778327
# 15 iter PSNR: 15.13 time: 0.020513
# 16 iter PSNR_dehazing: 14.44 ssim: 0.764244
# 16 iter PSNR: 14.44 time: 0.020786
# 17 iter PSNR_dehazing: 13.82 ssim: 0.750746
# 17 iter PSNR: 13.82 time: 0.020781
# 18 iter PSNR_dehazing: 13.26 ssim: 0.737800
# 18 iter PSNR: 13.26 time: 0.020597
# 19 iter PSNR_dehazing: 12.76 ssim: 0.725330
# 19 iter PSNR: 12.76 time: 0.020739
# 20 iter PSNR_dehazing: 12.30 ssim: 0.713307
# 20 iter PSNR: 12.30 time: 0.020535
# 21 iter PSNR_dehazing: 16.41 ssim: 0.715932
# 21 iter PSNR: 16.41 time: 0.020645
# 22 iter PSNR_dehazing: 10.20 ssim: 0.545404
# 22 iter PSNR: 10.20 time: 0.020868
# 23 iter PSNR_dehazing: 15.31 ssim: 0.688681
# 23 iter PSNR: 15.31 time: 0.020675
# 24 iter PSNR_dehazing: 14.36 ssim: 0.664578
# 24 iter PSNR: 14.36 time: 0.020702
# 25 iter PSNR_dehazing: 13.54 ssim: 0.642878
# 25 iter PSNR: 13.54 time: 0.020728
# 26 iter PSNR_dehazing: 12.82 ssim: 0.623164
# 26 iter PSNR: 12.82 time: 0.020747
# 27 iter PSNR_dehazing: 12.18 ssim: 0.605100
# 27 iter PSNR: 12.18 time: 0.020567
# 28 iter PSNR_dehazing: 11.61 ssim: 0.588457
# 28 iter PSNR: 11.61 time: 0.020658
# 29 iter PSNR_dehazing: 11.10 ssim: 0.573079
# 29 iter PSNR: 11.10 time: 0.020739
# 30 iter PSNR_dehazing: 10.63 ssim: 0.558757
# 30 iter PSNR: 10.63 time: 0.020786
# 31 iter PSNR_dehazing: 13.83 ssim: 0.661856
# 31 iter PSNR: 13.83 time: 0.021653
# 32 iter PSNR_dehazing: 7.75 ssim: 0.467003
# 32 iter PSNR: 7.75 time: 0.022164
# 33 iter PSNR_dehazing: 12.70 ssim: 0.631745
# 33 iter PSNR: 12.70 time: 0.020886
# 34 iter PSNR_dehazing: 11.76 ssim: 0.604592
# 34 iter PSNR: 11.76 time: 0.020757
# 35 iter PSNR_dehazing: 10.94 ssim: 0.579885
# 35 iter PSNR: 10.94 time: 0.020823
# 36 iter PSNR_dehazing: 10.24 ssim: 0.557257
# 36 iter PSNR: 10.24 time: 0.021013
# 37 iter PSNR_dehazing: 9.62 ssim: 0.536394
# 37 iter PSNR: 9.62 time: 0.020841
# 38 iter PSNR_dehazing: 9.07 ssim: 0.517102
# 38 iter PSNR: 9.07 time: 0.020774
# 39 iter PSNR_dehazing: 8.58 ssim: 0.499215
# 39 iter PSNR: 8.58 time: 0.020543
# 40 iter PSNR_dehazing: 8.14 ssim: 0.482521
# 40 iter PSNR: 8.14 time: 0.020569
# 41 iter PSNR_dehazing: 16.31 ssim: 0.835639
# 41 iter PSNR: 16.31 time: 0.020986
# 42 iter PSNR_dehazing: 10.43 ssim: 0.643277
# 42 iter PSNR: 10.43 time: 0.020551
# 43 iter PSNR_dehazing: 15.27 ssim: 0.809477
# 43 iter PSNR: 15.27 time: 0.020309
# 44 iter PSNR_dehazing: 14.37 ssim: 0.784656
# 44 iter PSNR: 14.37 time: 0.020926
# 45 iter PSNR_dehazing: 13.59 ssim: 0.761140
# 45 iter PSNR: 13.59 time: 0.021092
# 46 iter PSNR_dehazing: 12.90 ssim: 0.738861
# 46 iter PSNR: 12.90 time: 0.020478
# 47 iter PSNR_dehazing: 12.30 ssim: 0.717719
# 47 iter PSNR: 12.30 time: 0.020614
# 48 iter PSNR_dehazing: 11.76 ssim: 0.697642
# 48 iter PSNR: 11.76 time: 0.020592
# 49 iter PSNR_dehazing: 11.27 ssim: 0.678585
# 49 iter PSNR: 11.27 time: 0.021565
# 50 iter PSNR_dehazing: 10.83 ssim: 0.660464
# 50 iter PSNR: 10.83 time: 0.021079
# 51 iter PSNR_dehazing: 16.12 ssim: 0.851947
# 51 iter PSNR: 16.12 time: 0.020763
# 52 iter PSNR_dehazing: 10.36 ssim: 0.670531
# 52 iter PSNR: 10.36 time: 0.022035
# 53 iter PSNR_dehazing: 15.08 ssim: 0.827203
# 53 iter PSNR: 15.08 time: 0.021231
# 54 iter PSNR_dehazing: 14.20 ssim: 0.803706
# 54 iter PSNR: 14.20 time: 0.021132
# 55 iter PSNR_dehazing: 13.43 ssim: 0.781429
# 55 iter PSNR: 13.43 time: 0.021085
# 56 iter PSNR_dehazing: 12.77 ssim: 0.760408
# 56 iter PSNR: 12.77 time: 0.021047
# 57 iter PSNR_dehazing: 12.17 ssim: 0.740464
# 57 iter PSNR: 12.17 time: 0.021101
# 58 iter PSNR_dehazing: 11.65 ssim: 0.721569
# 58 iter PSNR: 11.65 time: 0.020917
# 59 iter PSNR_dehazing: 11.17 ssim: 0.703654
# 59 iter PSNR: 11.17 time: 0.021139
# 60 iter PSNR_dehazing: 10.75 ssim: 0.686669
# 60 iter PSNR: 10.75 time: 0.021031
# 61 iter PSNR_dehazing: 17.63 ssim: 0.884826
# 61 iter PSNR: 17.63 time: 0.021223
# 62 iter PSNR_dehazing: 11.86 ssim: 0.713530
# 62 iter PSNR: 11.86 time: 0.021164
# 63 iter PSNR_dehazing: 16.62 ssim: 0.862411
# 63 iter PSNR: 16.62 time: 0.021003
# 64 iter PSNR_dehazing: 15.75 ssim: 0.840772
# 64 iter PSNR: 15.75 time: 0.020922
# 65 iter PSNR_dehazing: 14.99 ssim: 0.819989
# 65 iter PSNR: 14.99 time: 0.021077
# 66 iter PSNR_dehazing: 14.31 ssim: 0.800121
# 66 iter PSNR: 14.31 time: 0.021095
# 67 iter PSNR_dehazing: 13.72 ssim: 0.781171
# 67 iter PSNR: 13.72 time: 0.021229
# 68 iter PSNR_dehazing: 13.18 ssim: 0.763041
# 68 iter PSNR: 13.18 time: 0.023349
# 69 iter PSNR_dehazing: 12.70 ssim: 0.745741
# 69 iter PSNR: 12.70 time: 0.021379
# 70 iter PSNR_dehazing: 12.26 ssim: 0.729270
# 70 iter PSNR: 12.26 time: 0.021130
# 71 iter PSNR_dehazing: 16.91 ssim: 0.896957
# 71 iter PSNR: 16.91 time: 0.021038
# 72 iter PSNR_dehazing: 11.37 ssim: 0.751487
# 72 iter PSNR: 11.37 time: 0.021256
# 73 iter PSNR_dehazing: 15.94 ssim: 0.879850
# 73 iter PSNR: 15.94 time: 0.021040
# 74 iter PSNR_dehazing: 15.10 ssim: 0.862822
# 74 iter PSNR: 15.10 time: 0.020678
# 75 iter PSNR_dehazing: 14.37 ssim: 0.846006
# 75 iter PSNR: 14.37 time: 0.020786
# 76 iter PSNR_dehazing: 13.72 ssim: 0.829424
# 76 iter PSNR: 13.72 time: 0.021115
# 77 iter PSNR_dehazing: 13.14 ssim: 0.813170
# 77 iter PSNR: 13.14 time: 0.020801
# 78 iter PSNR_dehazing: 12.63 ssim: 0.797217
# 78 iter PSNR: 12.63 time: 0.020882
# 79 iter PSNR_dehazing: 12.17 ssim: 0.781583
# 79 iter PSNR: 12.17 time: 0.020725
# 80 iter PSNR_dehazing: 11.75 ssim: 0.766371
# 80 iter PSNR: 11.75 time: 0.020873
# 81 iter PSNR_dehazing: 17.34 ssim: 0.905568
# 81 iter PSNR: 17.34 time: 0.020832
# 82 iter PSNR_dehazing: 11.75 ssim: 0.752670
# 82 iter PSNR: 11.75 time: 0.020780
# 83 iter PSNR_dehazing: 16.37 ssim: 0.888731
# 83 iter PSNR: 16.37 time: 0.020804
# 84 iter PSNR_dehazing: 15.52 ssim: 0.871589
# 84 iter PSNR: 15.52 time: 0.026639
# 85 iter PSNR_dehazing: 14.78 ssim: 0.854283
# 85 iter PSNR: 14.78 time: 0.021201
# 86 iter PSNR_dehazing: 14.13 ssim: 0.836976
# 86 iter PSNR: 14.13 time: 0.021039
# 87 iter PSNR_dehazing: 13.55 ssim: 0.819732
# 87 iter PSNR: 13.55 time: 0.021016
# 88 iter PSNR_dehazing: 13.03 ssim: 0.802608
# 88 iter PSNR: 13.03 time: 0.020997
# 89 iter PSNR_dehazing: 12.56 ssim: 0.785681
# 89 iter PSNR: 12.56 time: 0.020886
# 90 iter PSNR_dehazing: 12.14 ssim: 0.769064
# 90 iter PSNR: 12.14 time: 0.021197
# 91 iter PSNR_dehazing: 17.44 ssim: 0.900350
# 91 iter PSNR: 17.44 time: 0.020778
# 92 iter PSNR_dehazing: 12.18 ssim: 0.728068
# 92 iter PSNR: 12.18 time: 0.021053
# 93 iter PSNR_dehazing: 16.52 ssim: 0.879715
# 93 iter PSNR: 16.52 time: 0.021052
# 94 iter PSNR_dehazing: 15.72 ssim: 0.859226
# 94 iter PSNR: 15.72 time: 0.020899
# 95 iter PSNR_dehazing: 15.02 ssim: 0.839008
# 95 iter PSNR: 15.02 time: 0.020877
# 96 iter PSNR_dehazing: 14.41 ssim: 0.819193
# 96 iter PSNR: 14.41 time: 0.020712
# 97 iter PSNR_dehazing: 13.86 ssim: 0.799824
# 97 iter PSNR: 13.86 time: 0.020914
# 98 iter PSNR_dehazing: 13.37 ssim: 0.780984
# 98 iter PSNR: 13.37 time: 0.020599
# 99 iter PSNR_dehazing: 12.93 ssim: 0.762750
# 99 iter PSNR: 12.93 time: 0.022488
# 100 iter PSNR_dehazing: 12.54 ssim: 0.745087
# 100 iter PSNR: 12.54 time: 0.021345
# 101 iter PSNR_dehazing: 17.16 ssim: 0.906282
# 101 iter PSNR: 17.16 time: 0.022286
# 102 iter PSNR_dehazing: 11.40 ssim: 0.767268
# 102 iter PSNR: 11.40 time: 0.021063
# 103 iter PSNR_dehazing: 16.14 ssim: 0.889189
# 103 iter PSNR: 16.14 time: 0.023298
# 104 iter PSNR_dehazing: 15.26 ssim: 0.872357
# 104 iter PSNR: 15.26 time: 0.021353
# 105 iter PSNR_dehazing: 14.50 ssim: 0.855935
# 105 iter PSNR: 14.50 time: 0.021052
# 106 iter PSNR_dehazing: 13.83 ssim: 0.839945
# 106 iter PSNR: 13.83 time: 0.021023
# 107 iter PSNR_dehazing: 13.24 ssim: 0.824449
# 107 iter PSNR: 13.24 time: 0.020987
# 108 iter PSNR_dehazing: 12.70 ssim: 0.809433
# 108 iter PSNR: 12.70 time: 0.020940
# 109 iter PSNR_dehazing: 12.23 ssim: 0.794932
# 109 iter PSNR: 12.23 time: 0.022084
# 110 iter PSNR_dehazing: 11.80 ssim: 0.780910
# 110 iter PSNR: 11.80 time: 0.020811
# 111 iter PSNR_dehazing: 14.03 ssim: 0.752501
# 111 iter PSNR: 14.03 time: 0.020801
# 112 iter PSNR_dehazing: 8.53 ssim: 0.584926
# 112 iter PSNR: 8.53 time: 0.020780
# 113 iter PSNR_dehazing: 13.01 ssim: 0.728089
# 113 iter PSNR: 13.01 time: 0.021858
# 114 iter PSNR_dehazing: 12.15 ssim: 0.705668
# 114 iter PSNR: 12.15 time: 0.021016
# 115 iter PSNR_dehazing: 11.41 ssim: 0.684849
# 115 iter PSNR: 11.41 time: 0.022065
# 116 iter PSNR_dehazing: 10.77 ssim: 0.665365
# 116 iter PSNR: 10.77 time: 0.020664
# 117 iter PSNR_dehazing: 10.20 ssim: 0.647142
# 117 iter PSNR: 10.20 time: 0.021753
# 118 iter PSNR_dehazing: 9.71 ssim: 0.630035
# 118 iter PSNR: 9.71 time: 0.021848
# 119 iter PSNR_dehazing: 9.27 ssim: 0.613983
# 119 iter PSNR: 9.27 time: 0.021875
# 120 iter PSNR_dehazing: 8.88 ssim: 0.598985
# 120 iter PSNR: 8.88 time: 0.020902
# 121 iter PSNR_dehazing: 15.66 ssim: 0.820262
# 121 iter PSNR: 15.66 time: 0.020868
# 122 iter PSNR_dehazing: 10.01 ssim: 0.658784
# 122 iter PSNR: 10.01 time: 0.021224
# 123 iter PSNR_dehazing: 14.64 ssim: 0.798331
# 123 iter PSNR: 14.64 time: 0.020556
# 124 iter PSNR_dehazing: 13.76 ssim: 0.777725
# 124 iter PSNR: 13.76 time: 0.020742
# 125 iter PSNR_dehazing: 13.01 ssim: 0.758202
# 125 iter PSNR: 13.01 time: 0.021100
# 126 iter PSNR_dehazing: 12.35 ssim: 0.739640
# 126 iter PSNR: 12.35 time: 0.020284
# 127 iter PSNR_dehazing: 11.78 ssim: 0.722011
# 127 iter PSNR: 11.78 time: 0.020263
# 128 iter PSNR_dehazing: 11.26 ssim: 0.705140
# 128 iter PSNR: 11.26 time: 0.020807
# 129 iter PSNR_dehazing: 10.80 ssim: 0.689002
# 129 iter PSNR: 10.80 time: 0.021510
# 130 iter PSNR_dehazing: 10.39 ssim: 0.673586
# 130 iter PSNR: 10.39 time: 0.020547
# 131 iter PSNR_dehazing: 12.42 ssim: 0.747770
# 131 iter PSNR: 12.42 time: 0.020725
# 132 iter PSNR_dehazing: 7.30 ssim: 0.527431
# 132 iter PSNR: 7.30 time: 0.020760
# 133 iter PSNR_dehazing: 11.43 ssim: 0.714662
# 133 iter PSNR: 11.43 time: 0.021238
# 134 iter PSNR_dehazing: 10.60 ssim: 0.684139
# 134 iter PSNR: 10.60 time: 0.020451
# 135 iter PSNR_dehazing: 9.90 ssim: 0.656332
# 135 iter PSNR: 9.90 time: 0.020854
# 136 iter PSNR_dehazing: 9.31 ssim: 0.630241
# 136 iter PSNR: 9.31 time: 0.020732
# 137 iter PSNR_dehazing: 8.79 ssim: 0.606210
# 137 iter PSNR: 8.79 time: 0.021654
# 138 iter PSNR_dehazing: 8.35 ssim: 0.584101
# 138 iter PSNR: 8.35 time: 0.034333
# 139 iter PSNR_dehazing: 7.95 ssim: 0.563617
# 139 iter PSNR: 7.95 time: 0.021737
# 140 iter PSNR_dehazing: 7.61 ssim: 0.544784
# 140 iter PSNR: 7.61 time: 0.021043
# 141 iter PSNR_dehazing: 13.86 ssim: 0.761172
# 141 iter PSNR: 13.86 time: 0.021127
# 142 iter PSNR_dehazing: 8.47 ssim: 0.545122
# 142 iter PSNR: 8.47 time: 0.021171
# 143 iter PSNR_dehazing: 12.85 ssim: 0.730984
# 143 iter PSNR: 12.85 time: 0.021046
# 144 iter PSNR_dehazing: 12.00 ssim: 0.702389
# 144 iter PSNR: 12.00 time: 0.020636
# 145 iter PSNR_dehazing: 11.27 ssim: 0.675375
# 145 iter PSNR: 11.27 time: 0.022127
# 146 iter PSNR_dehazing: 10.64 ssim: 0.649701
# 146 iter PSNR: 10.64 time: 0.020757
# 147 iter PSNR_dehazing: 10.10 ssim: 0.625465
# 147 iter PSNR: 10.10 time: 0.020731
# 148 iter PSNR_dehazing: 9.61 ssim: 0.602927
# 148 iter PSNR: 9.61 time: 0.020899
# 149 iter PSNR_dehazing: 9.19 ssim: 0.582161
# 149 iter PSNR: 9.19 time: 0.022013
# 150 iter PSNR_dehazing: 8.81 ssim: 0.562933
# 150 iter PSNR: 8.81 time: 0.021036
# 151 iter PSNR_dehazing: 15.79 ssim: 0.849833
# 151 iter PSNR: 15.79 time: 0.020851
# 152 iter PSNR_dehazing: 9.85 ssim: 0.671295
# 152 iter PSNR: 9.85 time: 0.021211
# 153 iter PSNR_dehazing: 14.71 ssim: 0.825433
# 153 iter PSNR: 14.71 time: 0.022502
# 154 iter PSNR_dehazing: 13.79 ssim: 0.802261
# 154 iter PSNR: 13.79 time: 0.021247
# 155 iter PSNR_dehazing: 13.00 ssim: 0.780321
# 155 iter PSNR: 13.00 time: 0.026420
# 156 iter PSNR_dehazing: 12.31 ssim: 0.759529
# 156 iter PSNR: 12.31 time: 0.021480
# 157 iter PSNR_dehazing: 11.70 ssim: 0.739782
# 157 iter PSNR: 11.70 time: 0.021403
# 158 iter PSNR_dehazing: 11.16 ssim: 0.721161
# 158 iter PSNR: 11.16 time: 0.021091
# 159 iter PSNR_dehazing: 10.68 ssim: 0.703551
# 159 iter PSNR: 10.68 time: 0.020972
# 160 iter PSNR_dehazing: 10.24 ssim: 0.686989
# 160 iter PSNR: 10.24 time: 0.021182
# 161 iter PSNR_dehazing: 18.00 ssim: 0.922912
# 161 iter PSNR: 18.00 time: 0.022349
# 162 iter PSNR_dehazing: 12.81 ssim: 0.837311
# 162 iter PSNR: 12.81 time: 0.021009
# 163 iter PSNR_dehazing: 17.12 ssim: 0.912099
# 163 iter PSNR: 17.12 time: 0.021079
# 164 iter PSNR_dehazing: 16.34 ssim: 0.901656
# 164 iter PSNR: 16.34 time: 0.021374
# 165 iter PSNR_dehazing: 15.65 ssim: 0.891557
# 165 iter PSNR: 15.65 time: 0.022260
# 166 iter PSNR_dehazing: 15.04 ssim: 0.881763
# 166 iter PSNR: 15.04 time: 0.021058
# 167 iter PSNR_dehazing: 14.50 ssim: 0.872288
# 167 iter PSNR: 14.50 time: 0.020958
# 168 iter PSNR_dehazing: 14.01 ssim: 0.863118
# 168 iter PSNR: 14.01 time: 0.020889
# 169 iter PSNR_dehazing: 13.57 ssim: 0.854237
# 169 iter PSNR: 13.57 time: 0.022310
# 170 iter PSNR_dehazing: 13.17 ssim: 0.845646
# 170 iter PSNR: 13.17 time: 0.021199
# 171 iter PSNR_dehazing: 15.62 ssim: 0.832639
# 171 iter PSNR: 15.62 time: 0.024517
# 172 iter PSNR_dehazing: 10.07 ssim: 0.603689
# 172 iter PSNR: 10.07 time: 0.022374
# 173 iter PSNR_dehazing: 14.61 ssim: 0.803630
# 173 iter PSNR: 14.61 time: 0.020829
# 174 iter PSNR_dehazing: 13.75 ssim: 0.775497
# 174 iter PSNR: 13.75 time: 0.020899
# 175 iter PSNR_dehazing: 13.01 ssim: 0.748027
# 175 iter PSNR: 13.01 time: 0.020708
# 176 iter PSNR_dehazing: 12.36 ssim: 0.721355
# 176 iter PSNR: 12.36 time: 0.020734
# 177 iter PSNR_dehazing: 11.79 ssim: 0.695700
# 177 iter PSNR: 11.79 time: 0.021179
# 178 iter PSNR_dehazing: 11.29 ssim: 0.671066
# 178 iter PSNR: 11.29 time: 0.020701
# 179 iter PSNR_dehazing: 10.84 ssim: 0.647490
# 179 iter PSNR: 10.84 time: 0.020748
# 180 iter PSNR_dehazing: 10.43 ssim: 0.624995
# 180 iter PSNR: 10.43 time: 0.020772
# 181 iter PSNR_dehazing: 16.12 ssim: 0.825022
# 181 iter PSNR: 16.12 time: 0.021100
# 182 iter PSNR_dehazing: 10.44 ssim: 0.616727
# 182 iter PSNR: 10.44 time: 0.020964
# 183 iter PSNR_dehazing: 15.11 ssim: 0.798651
# 183 iter PSNR: 15.11 time: 0.020854
# 184 iter PSNR_dehazing: 14.24 ssim: 0.773112
# 184 iter PSNR: 14.24 time: 0.021096
# 185 iter PSNR_dehazing: 13.48 ssim: 0.748428
# 185 iter PSNR: 13.48 time: 0.021399
# 186 iter PSNR_dehazing: 12.82 ssim: 0.724539
# 186 iter PSNR: 12.82 time: 0.020805
# 187 iter PSNR_dehazing: 12.24 ssim: 0.701421
# 187 iter PSNR: 12.24 time: 0.020963
# 188 iter PSNR_dehazing: 11.71 ssim: 0.679158
# 188 iter PSNR: 11.71 time: 0.020890
# 189 iter PSNR_dehazing: 11.25 ssim: 0.657554
# 189 iter PSNR: 11.25 time: 0.021037
# 190 iter PSNR_dehazing: 10.82 ssim: 0.636821
# 190 iter PSNR: 10.82 time: 0.021110
# 191 iter PSNR_dehazing: 16.16 ssim: 0.842201
# 191 iter PSNR: 16.16 time: 0.024580
# 192 iter PSNR_dehazing: 10.51 ssim: 0.643546
# 192 iter PSNR: 10.51 time: 0.020843
# 193 iter PSNR_dehazing: 15.15 ssim: 0.816826
# 193 iter PSNR: 15.15 time: 0.020939
# 194 iter PSNR_dehazing: 14.28 ssim: 0.792276
# 194 iter PSNR: 14.28 time: 0.020817
# 195 iter PSNR_dehazing: 13.53 ssim: 0.768643
# 195 iter PSNR: 13.53 time: 0.020782
# 196 iter PSNR_dehazing: 12.87 ssim: 0.745827
# 196 iter PSNR: 12.87 time: 0.020759
# 197 iter PSNR_dehazing: 12.29 ssim: 0.723770
# 197 iter PSNR: 12.29 time: 0.021177
# 198 iter PSNR_dehazing: 11.77 ssim: 0.702523
# 198 iter PSNR: 11.77 time: 0.020722
# 199 iter PSNR_dehazing: 11.30 ssim: 0.682126
# 199 iter PSNR: 11.30 time: 0.020920
# 200 iter PSNR_dehazing: 10.89 ssim: 0.662484
# 200 iter PSNR: 10.89 time: 0.020860
# 201 iter PSNR_dehazing: 12.84 ssim: 0.744394
# 201 iter PSNR: 12.84 time: 0.021154
# 202 iter PSNR_dehazing: 7.55 ssim: 0.493679
# 202 iter PSNR: 7.55 time: 0.020991
# 203 iter PSNR_dehazing: 11.82 ssim: 0.710406
# 203 iter PSNR: 11.82 time: 0.020954
# 204 iter PSNR_dehazing: 10.98 ssim: 0.678123
# 204 iter PSNR: 10.98 time: 0.021071
# 205 iter PSNR_dehazing: 10.26 ssim: 0.647457
# 205 iter PSNR: 10.26 time: 0.020970
# 206 iter PSNR_dehazing: 9.65 ssim: 0.618255
# 206 iter PSNR: 9.65 time: 0.020782
# 207 iter PSNR_dehazing: 9.12 ssim: 0.590489
# 207 iter PSNR: 9.12 time: 0.020568
# 208 iter PSNR_dehazing: 8.65 ssim: 0.564170
# 208 iter PSNR: 8.65 time: 0.020597
# 209 iter PSNR_dehazing: 8.24 ssim: 0.539257
# 209 iter PSNR: 8.24 time: 0.020720
# 210 iter PSNR_dehazing: 7.88 ssim: 0.515743
# 210 iter PSNR: 7.88 time: 0.020794
# 211 iter PSNR_dehazing: 17.03 ssim: 0.839714
# 211 iter PSNR: 17.03 time: 0.020722
# 212 iter PSNR_dehazing: 10.77 ssim: 0.683239
# 212 iter PSNR: 10.77 time: 0.020468
# 213 iter PSNR_dehazing: 15.92 ssim: 0.818292
# 213 iter PSNR: 15.92 time: 0.020673
# 214 iter PSNR_dehazing: 14.97 ssim: 0.798250
# 214 iter PSNR: 14.97 time: 0.020699
# 215 iter PSNR_dehazing: 14.14 ssim: 0.779357
# 215 iter PSNR: 14.14 time: 0.020505
# 216 iter PSNR_dehazing: 13.41 ssim: 0.761406
# 216 iter PSNR: 13.41 time: 0.020874
# 217 iter PSNR_dehazing: 12.77 ssim: 0.744362
# 217 iter PSNR: 12.77 time: 0.020818
# 218 iter PSNR_dehazing: 12.19 ssim: 0.728063
# 218 iter PSNR: 12.19 time: 0.020672
# 219 iter PSNR_dehazing: 11.67 ssim: 0.712498
# 219 iter PSNR: 11.67 time: 0.020956
# 220 iter PSNR_dehazing: 11.20 ssim: 0.697548
# 220 iter PSNR: 11.20 time: 0.021131
# 221 iter PSNR_dehazing: 15.01 ssim: 0.678885
# 221 iter PSNR: 15.01 time: 0.021057
# 222 iter PSNR_dehazing: 8.86 ssim: 0.526284
# 222 iter PSNR: 8.86 time: 0.020663
# 223 iter PSNR_dehazing: 13.88 ssim: 0.655670
# 223 iter PSNR: 13.88 time: 0.020658
# 224 iter PSNR_dehazing: 12.93 ssim: 0.634807
# 224 iter PSNR: 12.93 time: 0.020419
# 225 iter PSNR_dehazing: 12.11 ssim: 0.615742
# 225 iter PSNR: 12.11 time: 0.020520
# 226 iter PSNR_dehazing: 11.40 ssim: 0.598181
# 226 iter PSNR: 11.40 time: 0.020852
# 227 iter PSNR_dehazing: 10.77 ssim: 0.581864
# 227 iter PSNR: 10.77 time: 0.020670
# 228 iter PSNR_dehazing: 10.21 ssim: 0.566640
# 228 iter PSNR: 10.21 time: 0.020576
# 229 iter PSNR_dehazing: 9.72 ssim: 0.552358
# 229 iter PSNR: 9.72 time: 0.020470
# 230 iter PSNR_dehazing: 9.27 ssim: 0.538953
# 230 iter PSNR: 9.27 time: 0.021569
# 231 iter PSNR_dehazing: 12.96 ssim: 0.628646
# 231 iter PSNR: 12.96 time: 0.020455
# 232 iter PSNR_dehazing: 7.23 ssim: 0.458008
# 232 iter PSNR: 7.23 time: 0.020329
# 233 iter PSNR_dehazing: 11.88 ssim: 0.600931
# 233 iter PSNR: 11.88 time: 0.020797
# 234 iter PSNR_dehazing: 10.97 ssim: 0.576438
# 234 iter PSNR: 10.97 time: 0.020448
# 235 iter PSNR_dehazing: 10.20 ssim: 0.554521
# 235 iter PSNR: 10.20 time: 0.020380
# 236 iter PSNR_dehazing: 9.54 ssim: 0.534694
# 236 iter PSNR: 9.54 time: 0.020628
# 237 iter PSNR_dehazing: 8.96 ssim: 0.516666
# 237 iter PSNR: 8.96 time: 0.021376
# 238 iter PSNR_dehazing: 8.45 ssim: 0.500160
# 238 iter PSNR: 8.45 time: 0.021195
# 239 iter PSNR_dehazing: 8.00 ssim: 0.484973
# 239 iter PSNR: 8.00 time: 0.020747
# 240 iter PSNR_dehazing: 7.59 ssim: 0.470969
# 240 iter PSNR: 7.59 time: 0.020297
# 241 iter PSNR_dehazing: 15.45 ssim: 0.792295
# 241 iter PSNR: 15.45 time: 0.020693
# 242 iter PSNR_dehazing: 9.53 ssim: 0.603758
# 242 iter PSNR: 9.53 time: 0.020533
# 243 iter PSNR_dehazing: 14.36 ssim: 0.765069
# 243 iter PSNR: 14.36 time: 0.020762
# 244 iter PSNR_dehazing: 13.44 ssim: 0.739953
# 244 iter PSNR: 13.44 time: 0.020437
# 245 iter PSNR_dehazing: 12.65 ssim: 0.716623
# 245 iter PSNR: 12.65 time: 0.020479
# 246 iter PSNR_dehazing: 11.97 ssim: 0.694847
# 246 iter PSNR: 11.97 time: 0.020278
# 247 iter PSNR_dehazing: 11.36 ssim: 0.674401
# 247 iter PSNR: 11.36 time: 0.020236
# 248 iter PSNR_dehazing: 10.83 ssim: 0.655164
# 248 iter PSNR: 10.83 time: 0.020507
# 249 iter PSNR_dehazing: 10.35 ssim: 0.637044
# 249 iter PSNR: 10.35 time: 0.020196
# 250 iter PSNR_dehazing: 9.92 ssim: 0.619909
# 250 iter PSNR: 9.92 time: 0.020526
# 251 iter PSNR_dehazing: 12.51 ssim: 0.693784
# 251 iter PSNR: 12.51 time: 0.020418
# 252 iter PSNR_dehazing: 7.11 ssim: 0.482471
# 252 iter PSNR: 7.11 time: 0.020899
# 253 iter PSNR_dehazing: 11.48 ssim: 0.662994
# 253 iter PSNR: 11.48 time: 0.020833
# 254 iter PSNR_dehazing: 10.62 ssim: 0.634685
# 254 iter PSNR: 10.62 time: 0.021335
# 255 iter PSNR_dehazing: 9.89 ssim: 0.608556
# 255 iter PSNR: 9.89 time: 0.021614
# 256 iter PSNR_dehazing: 9.26 ssim: 0.584115
# 256 iter PSNR: 9.26 time: 0.020960
# 257 iter PSNR_dehazing: 8.72 ssim: 0.561251
# 257 iter PSNR: 8.72 time: 0.021039
# 258 iter PSNR_dehazing: 8.24 ssim: 0.539774
# 258 iter PSNR: 8.24 time: 0.020914
# 259 iter PSNR_dehazing: 7.82 ssim: 0.519508
# 259 iter PSNR: 7.82 time: 0.020819
# 260 iter PSNR_dehazing: 7.45 ssim: 0.500436
# 260 iter PSNR: 7.45 time: 0.020954
# 261 iter PSNR_dehazing: 14.45 ssim: 0.707428
# 261 iter PSNR: 14.45 time: 0.020916
# 262 iter PSNR_dehazing: 8.50 ssim: 0.529578
# 262 iter PSNR: 8.50 time: 0.020723
# 263 iter PSNR_dehazing: 13.35 ssim: 0.681688
# 263 iter PSNR: 13.35 time: 0.020950
# 264 iter PSNR_dehazing: 12.43 ssim: 0.658090
# 264 iter PSNR: 12.43 time: 0.020732
# 265 iter PSNR_dehazing: 11.63 ssim: 0.636163
# 265 iter PSNR: 11.63 time: 0.021155
# 266 iter PSNR_dehazing: 10.94 ssim: 0.615727
# 266 iter PSNR: 10.94 time: 0.020616
# 267 iter PSNR_dehazing: 10.34 ssim: 0.596519
# 267 iter PSNR: 10.34 time: 0.020530
# 268 iter PSNR_dehazing: 9.80 ssim: 0.578417
# 268 iter PSNR: 9.80 time: 0.020603
# 269 iter PSNR_dehazing: 9.32 ssim: 0.561281
# 269 iter PSNR: 9.32 time: 0.020946
# 270 iter PSNR_dehazing: 8.89 ssim: 0.545061
# 270 iter PSNR: 8.89 time: 0.020853
# 271 iter PSNR_dehazing: 18.64 ssim: 0.801151
# 271 iter PSNR: 18.64 time: 0.020509
# 272 iter PSNR_dehazing: 12.15 ssim: 0.672480
# 272 iter PSNR: 12.15 time: 0.022903
# 273 iter PSNR_dehazing: 17.52 ssim: 0.781930
# 273 iter PSNR: 17.52 time: 0.020757
# 274 iter PSNR_dehazing: 16.54 ssim: 0.764582
# 274 iter PSNR: 16.54 time: 0.020868
# 275 iter PSNR_dehazing: 15.69 ssim: 0.748702
# 275 iter PSNR: 15.69 time: 0.020586
# 276 iter PSNR_dehazing: 14.94 ssim: 0.733984
# 276 iter PSNR: 14.94 time: 0.020733
# 277 iter PSNR_dehazing: 14.26 ssim: 0.720223
# 277 iter PSNR: 14.26 time: 0.021087
# 278 iter PSNR_dehazing: 13.66 ssim: 0.707273
# 278 iter PSNR: 13.66 time: 0.020753
# 279 iter PSNR_dehazing: 13.11 ssim: 0.695057
# 279 iter PSNR: 13.11 time: 0.020431
# 280 iter PSNR_dehazing: 12.61 ssim: 0.683503
# 280 iter PSNR: 12.61 time: 0.020709
# 281 iter PSNR_dehazing: 14.80 ssim: 0.756840
# 281 iter PSNR: 14.80 time: 0.020794
# 282 iter PSNR_dehazing: 8.96 ssim: 0.590587
# 282 iter PSNR: 8.96 time: 0.020430
# 283 iter PSNR_dehazing: 13.73 ssim: 0.733650
# 283 iter PSNR: 13.73 time: 0.020609
# 284 iter PSNR_dehazing: 12.82 ssim: 0.712073
# 284 iter PSNR: 12.82 time: 0.020865
# 285 iter PSNR_dehazing: 12.04 ssim: 0.691842
# 285 iter PSNR: 12.04 time: 0.020998
# 286 iter PSNR_dehazing: 11.36 ssim: 0.672709
# 286 iter PSNR: 11.36 time: 0.020628
# 287 iter PSNR_dehazing: 10.76 ssim: 0.654642
# 287 iter PSNR: 10.76 time: 0.020919
# 288 iter PSNR_dehazing: 10.23 ssim: 0.637446
# 288 iter PSNR: 10.23 time: 0.020797
# 289 iter PSNR_dehazing: 9.76 ssim: 0.621077
# 289 iter PSNR: 9.76 time: 0.020947
# 290 iter PSNR_dehazing: 9.34 ssim: 0.605487
# 290 iter PSNR: 9.34 time: 0.022049
# 291 iter PSNR_dehazing: 12.34 ssim: 0.626991
# 291 iter PSNR: 12.34 time: 0.020863
# 292 iter PSNR_dehazing: 6.87 ssim: 0.436812
# 292 iter PSNR: 6.87 time: 0.020705
# 293 iter PSNR_dehazing: 11.29 ssim: 0.597662
# 293 iter PSNR: 11.29 time: 0.020650
# 294 iter PSNR_dehazing: 10.42 ssim: 0.571323
# 294 iter PSNR: 10.42 time: 0.020619
# 295 iter PSNR_dehazing: 9.68 ssim: 0.547390
# 295 iter PSNR: 9.68 time: 0.020480
# 296 iter PSNR_dehazing: 9.05 ssim: 0.525383
# 296 iter PSNR: 9.05 time: 0.020728
# 297 iter PSNR_dehazing: 8.50 ssim: 0.505094
# 297 iter PSNR: 8.50 time: 0.020842
# 298 iter PSNR_dehazing: 8.01 ssim: 0.486208
# 298 iter PSNR: 8.01 time: 0.021091
# 299 iter PSNR_dehazing: 7.59 ssim: 0.468637
# 299 iter PSNR: 7.59 time: 0.020395
# 300 iter PSNR_dehazing: 7.21 ssim: 0.452200
# 300 iter PSNR: 7.21 time: 0.020712
# 301 iter PSNR_dehazing: 14.01 ssim: 0.559352
# 301 iter PSNR: 14.01 time: 0.020815
# 302 iter PSNR_dehazing: 7.75 ssim: 0.397631
# 302 iter PSNR: 7.75 time: 0.020865
# 303 iter PSNR_dehazing: 12.86 ssim: 0.533205
# 303 iter PSNR: 12.86 time: 0.020702
# 304 iter PSNR_dehazing: 11.88 ssim: 0.510066
# 304 iter PSNR: 11.88 time: 0.020802
# 305 iter PSNR_dehazing: 11.05 ssim: 0.489307
# 305 iter PSNR: 11.05 time: 0.021111
# 306 iter PSNR_dehazing: 10.33 ssim: 0.470542
# 306 iter PSNR: 10.33 time: 0.026925
# 307 iter PSNR_dehazing: 9.69 ssim: 0.453390
# 307 iter PSNR: 9.69 time: 0.024879
# 308 iter PSNR_dehazing: 9.12 ssim: 0.437757
# 308 iter PSNR: 9.12 time: 0.026067
# 309 iter PSNR_dehazing: 8.62 ssim: 0.423283
# 309 iter PSNR: 8.62 time: 0.021047
# 310 iter PSNR_dehazing: 8.16 ssim: 0.409990
# 310 iter PSNR: 8.16 time: 0.020948
# 311 iter PSNR_dehazing: 14.21 ssim: 0.663623
# 311 iter PSNR: 14.21 time: 0.021904
# 312 iter PSNR_dehazing: 8.27 ssim: 0.461876
# 312 iter PSNR: 8.27 time: 0.020866
# 313 iter PSNR_dehazing: 13.12 ssim: 0.630506
# 313 iter PSNR: 13.12 time: 0.021067
# 314 iter PSNR_dehazing: 12.19 ssim: 0.601560
# 314 iter PSNR: 12.19 time: 0.020952
# 315 iter PSNR_dehazing: 11.40 ssim: 0.575709
# 315 iter PSNR: 11.40 time: 0.020899
# 316 iter PSNR_dehazing: 10.71 ssim: 0.552412
# 316 iter PSNR: 10.71 time: 0.020808
# 317 iter PSNR_dehazing: 10.10 ssim: 0.531253
# 317 iter PSNR: 10.10 time: 0.020922
# 318 iter PSNR_dehazing: 9.57 ssim: 0.511822
# 318 iter PSNR: 9.57 time: 0.021307
# 319 iter PSNR_dehazing: 9.09 ssim: 0.493898
# 319 iter PSNR: 9.09 time: 0.021072
# 320 iter PSNR_dehazing: 8.66 ssim: 0.477282
# 320 iter PSNR: 8.66 time: 0.020717
# 321 iter PSNR_dehazing: 17.62 ssim: 0.741846
# 321 iter PSNR: 17.62 time: 0.021216
# 322 iter PSNR_dehazing: 11.16 ssim: 0.535277
# 322 iter PSNR: 11.16 time: 0.025410
# 323 iter PSNR_dehazing: 16.47 ssim: 0.712291
# 323 iter PSNR: 16.47 time: 0.021463
# 324 iter PSNR_dehazing: 15.48 ssim: 0.682309
# 324 iter PSNR: 15.48 time: 0.021866
# 325 iter PSNR_dehazing: 14.63 ssim: 0.655215
# 325 iter PSNR: 14.63 time: 0.021642
# 326 iter PSNR_dehazing: 13.88 ssim: 0.630449
# 326 iter PSNR: 13.88 time: 0.020964
# 327 iter PSNR_dehazing: 13.22 ssim: 0.607891
# 327 iter PSNR: 13.22 time: 0.020849
# 328 iter PSNR_dehazing: 12.62 ssim: 0.587513
# 328 iter PSNR: 12.62 time: 0.021011
# 329 iter PSNR_dehazing: 12.09 ssim: 0.568904
# 329 iter PSNR: 12.09 time: 0.020714
# 330 iter PSNR_dehazing: 11.60 ssim: 0.551494
# 330 iter PSNR: 11.60 time: 0.020894
# 331 iter PSNR_dehazing: 16.49 ssim: 0.746429
# 331 iter PSNR: 16.49 time: 0.021439
# 332 iter PSNR_dehazing: 10.23 ssim: 0.544301
# 332 iter PSNR: 10.23 time: 0.020838
# 333 iter PSNR_dehazing: 15.37 ssim: 0.716015
# 333 iter PSNR: 15.37 time: 0.020955
# 334 iter PSNR_dehazing: 14.41 ssim: 0.688429
# 334 iter PSNR: 14.41 time: 0.020972
# 335 iter PSNR_dehazing: 13.58 ssim: 0.663115
# 335 iter PSNR: 13.58 time: 0.020772
# 336 iter PSNR_dehazing: 12.85 ssim: 0.639742
# 336 iter PSNR: 12.85 time: 0.020734
# 337 iter PSNR_dehazing: 12.21 ssim: 0.617978
# 337 iter PSNR: 12.21 time: 0.021065
# 338 iter PSNR_dehazing: 11.64 ssim: 0.597728
# 338 iter PSNR: 11.64 time: 0.021208
# 339 iter PSNR_dehazing: 11.12 ssim: 0.578764
# 339 iter PSNR: 11.12 time: 0.021474
# 340 iter PSNR_dehazing: 10.66 ssim: 0.561001
# 340 iter PSNR: 10.66 time: 0.020866
# 341 iter PSNR_dehazing: 16.17 ssim: 0.879419
# 341 iter PSNR: 16.17 time: 0.020669
# 342 iter PSNR_dehazing: 10.36 ssim: 0.720284
# 342 iter PSNR: 10.36 time: 0.020420
# 343 iter PSNR_dehazing: 15.12 ssim: 0.858461
# 343 iter PSNR: 15.12 time: 0.020552
# 344 iter PSNR_dehazing: 14.21 ssim: 0.838203
# 344 iter PSNR: 14.21 time: 0.020689
# 345 iter PSNR_dehazing: 13.44 ssim: 0.818762
# 345 iter PSNR: 13.44 time: 0.021705
# 346 iter PSNR_dehazing: 12.76 ssim: 0.800183
# 346 iter PSNR: 12.76 time: 0.021343
# 347 iter PSNR_dehazing: 12.17 ssim: 0.782494
# 347 iter PSNR: 12.17 time: 0.020654
# 348 iter PSNR_dehazing: 11.64 ssim: 0.765674
# 348 iter PSNR: 11.64 time: 0.020768
# 349 iter PSNR_dehazing: 11.17 ssim: 0.749695
# 349 iter PSNR: 11.17 time: 0.021468
# 350 iter PSNR_dehazing: 10.74 ssim: 0.734625
# 350 iter PSNR: 10.74 time: 0.020842
# 351 iter PSNR_dehazing: 15.21 ssim: 0.816069
# 351 iter PSNR: 15.21 time: 0.020797
# 352 iter PSNR_dehazing: 9.85 ssim: 0.648756
# 352 iter PSNR: 9.85 time: 0.020735
# 353 iter PSNR_dehazing: 14.22 ssim: 0.793158
# 353 iter PSNR: 14.22 time: 0.026386
# 354 iter PSNR_dehazing: 13.38 ssim: 0.771465
# 354 iter PSNR: 13.38 time: 0.021176
# 355 iter PSNR_dehazing: 12.66 ssim: 0.750938
# 355 iter PSNR: 12.66 time: 0.021163
# 356 iter PSNR_dehazing: 12.03 ssim: 0.731474
# 356 iter PSNR: 12.03 time: 0.022332
# 357 iter PSNR_dehazing: 11.48 ssim: 0.713059
# 357 iter PSNR: 11.48 time: 0.021370
# 358 iter PSNR_dehazing: 11.00 ssim: 0.695636
# 358 iter PSNR: 11.00 time: 0.021043
# 359 iter PSNR_dehazing: 10.57 ssim: 0.679095
# 359 iter PSNR: 10.57 time: 0.021015
# 360 iter PSNR_dehazing: 10.19 ssim: 0.663467
# 360 iter PSNR: 10.19 time: 0.020855
# 361 iter PSNR_dehazing: 19.53 ssim: 0.923634
# 361 iter PSNR: 19.53 time: 0.021059
# 362 iter PSNR_dehazing: 14.06 ssim: 0.814602
# 362 iter PSNR: 14.06 time: 0.021025
# 363 iter PSNR_dehazing: 18.65 ssim: 0.909999
# 363 iter PSNR: 18.65 time: 0.021147
# 364 iter PSNR_dehazing: 17.86 ssim: 0.896674
# 364 iter PSNR: 17.86 time: 0.021120
# 365 iter PSNR_dehazing: 17.15 ssim: 0.883737
# 365 iter PSNR: 17.15 time: 0.021335
# 366 iter PSNR_dehazing: 16.50 ssim: 0.871236
# 366 iter PSNR: 16.50 time: 0.021156
# 367 iter PSNR_dehazing: 15.92 ssim: 0.859135
# 367 iter PSNR: 15.92 time: 0.021018
# 368 iter PSNR_dehazing: 15.39 ssim: 0.847468
# 368 iter PSNR: 15.39 time: 0.021234
# 369 iter PSNR_dehazing: 14.91 ssim: 0.836142
# 369 iter PSNR: 14.91 time: 0.021348
# 370 iter PSNR_dehazing: 14.47 ssim: 0.825227
# 370 iter PSNR: 14.47 time: 0.021105
# 371 iter PSNR_dehazing: 13.53 ssim: 0.761321
# 371 iter PSNR: 13.53 time: 0.021060
# 372 iter PSNR_dehazing: 7.90 ssim: 0.553136
# 372 iter PSNR: 7.90 time: 0.021244
# 373 iter PSNR_dehazing: 12.47 ssim: 0.730803
# 373 iter PSNR: 12.47 time: 0.022048
# 374 iter PSNR_dehazing: 11.58 ssim: 0.702567
# 374 iter PSNR: 11.58 time: 0.021684
# 375 iter PSNR_dehazing: 10.83 ssim: 0.676457
# 375 iter PSNR: 10.83 time: 0.020642
# 376 iter PSNR_dehazing: 10.17 ssim: 0.652091
# 376 iter PSNR: 10.17 time: 0.020719
# 377 iter PSNR_dehazing: 9.60 ssim: 0.629418
# 377 iter PSNR: 9.60 time: 0.022938
# 378 iter PSNR_dehazing: 9.10 ssim: 0.608298
# 378 iter PSNR: 9.10 time: 0.020977
# 379 iter PSNR_dehazing: 8.65 ssim: 0.588604
# 379 iter PSNR: 8.65 time: 0.020706
# 380 iter PSNR_dehazing: 8.25 ssim: 0.570257
# 380 iter PSNR: 8.25 time: 0.021013
# 381 iter PSNR_dehazing: 16.36 ssim: 0.754748
# 381 iter PSNR: 16.36 time: 0.021732
# 382 iter PSNR_dehazing: 10.43 ssim: 0.632081
# 382 iter PSNR: 10.43 time: 0.020641
# 383 iter PSNR_dehazing: 15.32 ssim: 0.735295
# 383 iter PSNR: 15.32 time: 0.021238
# 384 iter PSNR_dehazing: 14.42 ssim: 0.718178
# 384 iter PSNR: 14.42 time: 0.024997
# 385 iter PSNR_dehazing: 13.64 ssim: 0.702835
# 385 iter PSNR: 13.64 time: 0.022073
# 386 iter PSNR_dehazing: 12.95 ssim: 0.688850
# 386 iter PSNR: 12.95 time: 0.020877
# 387 iter PSNR_dehazing: 12.33 ssim: 0.675927
# 387 iter PSNR: 12.33 time: 0.020705
# 388 iter PSNR_dehazing: 11.78 ssim: 0.663963
# 388 iter PSNR: 11.78 time: 0.021032
# 389 iter PSNR_dehazing: 11.29 ssim: 0.652702
# 389 iter PSNR: 11.29 time: 0.021935
# 390 iter PSNR_dehazing: 10.84 ssim: 0.642111
# 390 iter PSNR: 10.84 time: 0.020994
# 391 iter PSNR_dehazing: 17.10 ssim: 0.895017
# 391 iter PSNR: 17.10 time: 0.021429
# 392 iter PSNR_dehazing: 11.37 ssim: 0.756592
# 392 iter PSNR: 11.37 time: 0.021088
# 393 iter PSNR_dehazing: 16.08 ssim: 0.878583
# 393 iter PSNR: 16.08 time: 0.021094
# 394 iter PSNR_dehazing: 15.21 ssim: 0.862307
# 394 iter PSNR: 15.21 time: 0.022296
# 395 iter PSNR_dehazing: 14.45 ssim: 0.846260
# 395 iter PSNR: 14.45 time: 0.020914
# 396 iter PSNR_dehazing: 13.79 ssim: 0.830485
# 396 iter PSNR: 13.79 time: 0.020972
# 397 iter PSNR_dehazing: 13.19 ssim: 0.815062
# 397 iter PSNR: 13.19 time: 0.021014
# 398 iter PSNR_dehazing: 12.66 ssim: 0.799907
# 398 iter PSNR: 12.66 time: 0.021282
# 399 iter PSNR_dehazing: 12.19 ssim: 0.785124
# 399 iter PSNR: 12.19 time: 0.021111
# 400 iter PSNR_dehazing: 11.76 ssim: 0.770689
# 400 iter PSNR: 11.76 time: 0.021236
# 401 iter PSNR_dehazing: 12.81 ssim: 0.789897
# 401 iter PSNR: 12.81 time: 0.021272
# 402 iter PSNR_dehazing: 7.62 ssim: 0.597989
# 402 iter PSNR: 7.62 time: 0.021170
# 403 iter PSNR_dehazing: 11.81 ssim: 0.760844
# 403 iter PSNR: 11.81 time: 0.020900
# 404 iter PSNR_dehazing: 10.97 ssim: 0.734103
# 404 iter PSNR: 10.97 time: 0.020849
# 405 iter PSNR_dehazing: 10.27 ssim: 0.709565
# 405 iter PSNR: 10.27 time: 0.022412
# 406 iter PSNR_dehazing: 9.67 ssim: 0.686985
# 406 iter PSNR: 9.67 time: 0.021078
# 407 iter PSNR_dehazing: 9.15 ssim: 0.666330
# 407 iter PSNR: 9.15 time: 0.022259
# 408 iter PSNR_dehazing: 8.69 ssim: 0.647175
# 408 iter PSNR: 8.69 time: 0.021273
# 409 iter PSNR_dehazing: 8.29 ssim: 0.629471
# 409 iter PSNR: 8.29 time: 0.022826
# 410 iter PSNR_dehazing: 7.94 ssim: 0.613131
# 410 iter PSNR: 7.94 time: 0.020756
# 411 iter PSNR_dehazing: 17.38 ssim: 0.838220
# 411 iter PSNR: 17.38 time: 0.020986
# 412 iter PSNR_dehazing: 11.18 ssim: 0.695248
# 412 iter PSNR: 11.18 time: 0.020976
# 413 iter PSNR_dehazing: 16.30 ssim: 0.818540
# 413 iter PSNR: 16.30 time: 0.021224
# 414 iter PSNR_dehazing: 15.36 ssim: 0.799995
# 414 iter PSNR: 15.36 time: 0.020822
# 415 iter PSNR_dehazing: 14.54 ssim: 0.782473
# 415 iter PSNR: 14.54 time: 0.020785
# 416 iter PSNR_dehazing: 13.81 ssim: 0.765891
# 416 iter PSNR: 13.81 time: 0.020921
# 417 iter PSNR_dehazing: 13.17 ssim: 0.750232
# 417 iter PSNR: 13.17 time: 0.020691
# 418 iter PSNR_dehazing: 12.60 ssim: 0.735408
# 418 iter PSNR: 12.60 time: 0.020584
# 419 iter PSNR_dehazing: 12.08 ssim: 0.721314
# 419 iter PSNR: 12.08 time: 0.020537
# 420 iter PSNR_dehazing: 11.61 ssim: 0.707977
# 420 iter PSNR: 11.61 time: 0.020739
# 421 iter PSNR_dehazing: 13.84 ssim: 0.722182
# 421 iter PSNR: 13.84 time: 0.022578
# 422 iter PSNR_dehazing: 8.21 ssim: 0.536175
# 422 iter PSNR: 8.21 time: 0.020718
# 423 iter PSNR_dehazing: 12.79 ssim: 0.694904
# 423 iter PSNR: 12.79 time: 0.020749
# 424 iter PSNR_dehazing: 11.90 ssim: 0.669913
# 424 iter PSNR: 11.90 time: 0.021059
# 425 iter PSNR_dehazing: 11.14 ssim: 0.646843
# 425 iter PSNR: 11.14 time: 0.020950
# 426 iter PSNR_dehazing: 10.49 ssim: 0.625411
# 426 iter PSNR: 10.49 time: 0.021362
# 427 iter PSNR_dehazing: 9.92 ssim: 0.605280
# 427 iter PSNR: 9.92 time: 0.020885
# 428 iter PSNR_dehazing: 9.42 ssim: 0.586384
# 428 iter PSNR: 9.42 time: 0.020884
# 429 iter PSNR_dehazing: 8.97 ssim: 0.568603
# 429 iter PSNR: 8.97 time: 0.020668
# 430 iter PSNR_dehazing: 8.57 ssim: 0.551951
# 430 iter PSNR: 8.57 time: 0.020874
# 431 iter PSNR_dehazing: 17.34 ssim: 0.841270
# 431 iter PSNR: 17.34 time: 0.020813
# 432 iter PSNR_dehazing: 11.39 ssim: 0.692183
# 432 iter PSNR: 11.39 time: 0.020666
# 433 iter PSNR_dehazing: 16.30 ssim: 0.820363
# 433 iter PSNR: 16.30 time: 0.020699
# 434 iter PSNR_dehazing: 15.40 ssim: 0.800896
# 434 iter PSNR: 15.40 time: 0.021321
# 435 iter PSNR_dehazing: 14.61 ssim: 0.782655
# 435 iter PSNR: 14.61 time: 0.020668
# 436 iter PSNR_dehazing: 13.92 ssim: 0.765497
# 436 iter PSNR: 13.92 time: 0.020946
# 437 iter PSNR_dehazing: 13.30 ssim: 0.749219
# 437 iter PSNR: 13.30 time: 0.020849
# 438 iter PSNR_dehazing: 12.75 ssim: 0.733859
# 438 iter PSNR: 12.75 time: 0.020888
# 439 iter PSNR_dehazing: 12.25 ssim: 0.719247
# 439 iter PSNR: 12.25 time: 0.020930
# 440 iter PSNR_dehazing: 11.80 ssim: 0.705389
# 440 iter PSNR: 11.80 time: 0.020957
# 441 iter PSNR_dehazing: 13.33 ssim: 0.609859
# 441 iter PSNR: 13.33 time: 0.021583
# 442 iter PSNR_dehazing: 7.40 ssim: 0.396363
# 442 iter PSNR: 7.40 time: 0.021448
# 443 iter PSNR_dehazing: 12.22 ssim: 0.576459
# 443 iter PSNR: 12.22 time: 0.021528
# 444 iter PSNR_dehazing: 11.29 ssim: 0.546595
# 444 iter PSNR: 11.29 time: 0.020949
# 445 iter PSNR_dehazing: 10.50 ssim: 0.519501
# 445 iter PSNR: 10.50 time: 0.021107
# 446 iter PSNR_dehazing: 9.81 ssim: 0.494795
# 446 iter PSNR: 9.81 time: 0.021218
# 447 iter PSNR_dehazing: 9.21 ssim: 0.471998
# 447 iter PSNR: 9.21 time: 0.020925
# 448 iter PSNR_dehazing: 8.68 ssim: 0.450949
# 448 iter PSNR: 8.68 time: 0.020915
# 449 iter PSNR_dehazing: 8.21 ssim: 0.431429
# 449 iter PSNR: 8.21 time: 0.021033
# 450 iter PSNR_dehazing: 7.78 ssim: 0.413291
# 450 iter PSNR: 7.78 time: 0.020666
# 451 iter PSNR_dehazing: 16.33 ssim: 0.819757
# 451 iter PSNR: 16.33 time: 0.020608
# 452 iter PSNR_dehazing: 10.25 ssim: 0.619607
# 452 iter PSNR: 10.25 time: 0.020787
# 453 iter PSNR_dehazing: 15.23 ssim: 0.792434
# 453 iter PSNR: 15.23 time: 0.020989
# 454 iter PSNR_dehazing: 14.30 ssim: 0.766628
# 454 iter PSNR: 14.30 time: 0.020838
# 455 iter PSNR_dehazing: 13.49 ssim: 0.742208
# 455 iter PSNR: 13.49 time: 0.020947
# 456 iter PSNR_dehazing: 12.78 ssim: 0.719059
# 456 iter PSNR: 12.78 time: 0.022155
# 457 iter PSNR_dehazing: 12.16 ssim: 0.697161
# 457 iter PSNR: 12.16 time: 0.020597
# 458 iter PSNR_dehazing: 11.61 ssim: 0.676286
# 458 iter PSNR: 11.61 time: 0.020524
# 459 iter PSNR_dehazing: 11.11 ssim: 0.656462
# 459 iter PSNR: 11.11 time: 0.021839
# 460 iter PSNR_dehazing: 10.66 ssim: 0.637590
# 460 iter PSNR: 10.66 time: 0.021318
# 461 iter PSNR_dehazing: 15.31 ssim: 0.788436
# 461 iter PSNR: 15.31 time: 0.022585
# 462 iter PSNR_dehazing: 9.47 ssim: 0.562322
# 462 iter PSNR: 9.47 time: 0.022040
# 463 iter PSNR_dehazing: 14.24 ssim: 0.757897
# 463 iter PSNR: 14.24 time: 0.022322
# 464 iter PSNR_dehazing: 13.34 ssim: 0.728826
# 464 iter PSNR: 13.34 time: 0.020754
# 465 iter PSNR_dehazing: 12.56 ssim: 0.701278
# 465 iter PSNR: 12.56 time: 0.020877
# 466 iter PSNR_dehazing: 11.88 ssim: 0.674972
# 466 iter PSNR: 11.88 time: 0.020706
# 467 iter PSNR_dehazing: 11.29 ssim: 0.650071
# 467 iter PSNR: 11.29 time: 0.020949
# 468 iter PSNR_dehazing: 10.76 ssim: 0.626432
# 468 iter PSNR: 10.76 time: 0.020759
# 469 iter PSNR_dehazing: 10.28 ssim: 0.603886
# 469 iter PSNR: 10.28 time: 0.021540
# 470 iter PSNR_dehazing: 9.86 ssim: 0.582551
# 470 iter PSNR: 9.86 time: 0.020839
# 471 iter PSNR_dehazing: 15.91 ssim: 0.778261
# 471 iter PSNR: 15.91 time: 0.020801
# 472 iter PSNR_dehazing: 9.96 ssim: 0.550081
# 472 iter PSNR: 9.96 time: 0.021012
# 473 iter PSNR_dehazing: 14.83 ssim: 0.745702
# 473 iter PSNR: 14.83 time: 0.021090
# 474 iter PSNR_dehazing: 13.91 ssim: 0.715335
# 474 iter PSNR: 13.91 time: 0.020753
# 475 iter PSNR_dehazing: 13.12 ssim: 0.686979
# 475 iter PSNR: 13.12 time: 0.020921
# 476 iter PSNR_dehazing: 12.43 ssim: 0.660416
# 476 iter PSNR: 12.43 time: 0.021234
# 477 iter PSNR_dehazing: 11.82 ssim: 0.635449
# 477 iter PSNR: 11.82 time: 0.021980
# 478 iter PSNR_dehazing: 11.28 ssim: 0.612080
# 478 iter PSNR: 11.28 time: 0.020815
# 479 iter PSNR_dehazing: 10.80 ssim: 0.590104
# 479 iter PSNR: 10.80 time: 0.020885
# 480 iter PSNR_dehazing: 10.36 ssim: 0.569425
# 480 iter PSNR: 10.36 time: 0.020833
# 481 iter PSNR_dehazing: 16.56 ssim: 0.813649
# 481 iter PSNR: 16.56 time: 0.020889
# 482 iter PSNR_dehazing: 10.67 ssim: 0.605488
# 482 iter PSNR: 10.67 time: 0.021198
# 483 iter PSNR_dehazing: 15.50 ssim: 0.783482
# 483 iter PSNR: 15.50 time: 0.020787
# 484 iter PSNR_dehazing: 14.59 ssim: 0.755615
# 484 iter PSNR: 14.59 time: 0.020875
# 485 iter PSNR_dehazing: 13.81 ssim: 0.729782
# 485 iter PSNR: 13.81 time: 0.020721
# 486 iter PSNR_dehazing: 13.12 ssim: 0.705704
# 486 iter PSNR: 13.12 time: 0.020959
# 487 iter PSNR_dehazing: 12.52 ssim: 0.683196
# 487 iter PSNR: 12.52 time: 0.020919
# 488 iter PSNR_dehazing: 11.98 ssim: 0.662094
# 488 iter PSNR: 11.98 time: 0.020510
# 489 iter PSNR_dehazing: 11.50 ssim: 0.642133
# 489 iter PSNR: 11.50 time: 0.021057
# 490 iter PSNR_dehazing: 11.06 ssim: 0.623299
# 490 iter PSNR: 11.06 time: 0.020915
# 491 iter PSNR_dehazing: 15.79 ssim: 0.806541
# 491 iter PSNR: 15.79 time: 0.021986
# 492 iter PSNR_dehazing: 9.94 ssim: 0.571046
# 492 iter PSNR: 9.94 time: 0.021007
# 493 iter PSNR_dehazing: 14.73 ssim: 0.775018
# 493 iter PSNR: 14.73 time: 0.021662
# 494 iter PSNR_dehazing: 13.82 ssim: 0.744843
# 494 iter PSNR: 13.82 time: 0.021168
# 495 iter PSNR_dehazing: 13.04 ssim: 0.716203
# 495 iter PSNR: 13.04 time: 0.021069
# 496 iter PSNR_dehazing: 12.36 ssim: 0.688799
# 496 iter PSNR: 12.36 time: 0.021299
# 497 iter PSNR_dehazing: 11.76 ssim: 0.662706
# 497 iter PSNR: 11.76 time: 0.020933
# 498 iter PSNR_dehazing: 11.23 ssim: 0.637999
# 498 iter PSNR: 11.23 time: 0.020773
# 499 iter PSNR_dehazing: 10.76 ssim: 0.614545
# 499 iter PSNR: 10.76 time: 0.020742
# 500 iter PSNR_dehazing: 10.33 ssim: 0.592219
# 500 iter PSNR: 10.33 time: 0.020822
# ==========================================================
# The average PSNR is 12.24 dB
# The average SSIM is 0.69106 dB
# Average time: 0.021142
