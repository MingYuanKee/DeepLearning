# %% [markdown]
# Prep
# ==

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
# !pip install tensorboard einops scikit-image opencv-python pytorch_msssim warmup-scheduler
# Out:
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.10/dist-packages (2.14.1)
# Collecting einops
#   Downloading einops-0.7.0-py3-none-any.whl (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.6/44.6 kB 1.7 MB/s eta 0:00:00
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.10/dist-packages (0.19.3)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (4.8.0.76)
# Collecting pytorch_msssim
#   Downloading pytorch_msssim-1.0.0-py3-none-any.whl (7.7 kB)
# Collecting warmup-scheduler
#   Downloading warmup_scheduler-0.3.tar.gz (2.1 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (1.59.2)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (2.17.3)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (3.5.1)
# Requirement already satisfied: numpy>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (1.23.5)
# Requirement already satisfied: protobuf>=3.19.6 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (2.31.0)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (67.7.2)
# Requirement already satisfied: six>1.9 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (1.16.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (3.0.1)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image) (1.11.3)
# Requirement already satisfied: networkx>=2.2 in /usr/local/lib/python3.10/dist-packages (from scikit-image) (3.2.1)
# Requirement already satisfied: pillow!=7.1.0,!=7.1.1,!=8.3.0,>=6.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-image) (9.4.0)
# Requirement already satisfied: imageio>=2.4.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image) (2.31.6)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.10/dist-packages (from scikit-image) (2023.9.26)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image) (1.4.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from scikit-image) (23.2)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from pytorch_msssim) (2.1.0+cu118)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard) (2023.7.22)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard) (2.1.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->pytorch_msssim) (3.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch->pytorch_msssim) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->pytorch_msssim) (1.12)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->pytorch_msssim) (3.1.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch->pytorch_msssim) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch->pytorch_msssim) (2.1.0)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard) (3.2.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->pytorch_msssim) (1.3.0)
# Building wheels for collected packages: warmup-scheduler
#   Building wheel for warmup-scheduler (setup.py) ... done
#   Created wheel for warmup-scheduler: filename=warmup_scheduler-0.3-py3-none-any.whl size=2968 sha256=93a6bf8936fe562d5faf1dd089078a88df55851487894b05aa553cb103983832
#   Stored in directory: /root/.cache/pip/wheels/59/01/9e/d1820991c32916e9808c940f572b462f3e46427f3e76c4d852
# Successfully built warmup-scheduler
# Installing collected packages: warmup-scheduler, einops, pytorch_msssim
# Successfully installed einops-0.7.0 pytorch_msssim-1.0.0 warmup-scheduler-0.3

# %%
# !pip install pytorch-msssim
# Out:
# Requirement already satisfied: pytorch-msssim in /usr/local/lib/python3.10/dist-packages (1.0.0)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from pytorch-msssim) (2.1.0+cu118)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->pytorch-msssim) (3.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch->pytorch-msssim) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->pytorch-msssim) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->pytorch-msssim) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->pytorch-msssim) (3.1.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch->pytorch-msssim) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch->pytorch-msssim) (2.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->pytorch-msssim) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->pytorch-msssim) (1.3.0)

# %%
# !pip install warmup-scheduler
# Out:
# Requirement already satisfied: warmup-scheduler in /usr/local/lib/python3.10/dist-packages (0.3)

# %%
#path = "/content/drive/MyDrive/reside-indoor"
# !unzip  ./drive/MyDrive/reside-indoor/indoor_train.zip -d ./reside-indoorMY/ > trainlog.txt
# !unzip  ./drive/MyDrive/reside-indoor/indoor_test.zip -d ./reside-indoorMY/ >testlog.txt
#/content/reside-indoorMY/train/hazy

# %%
path = "/content/reside-indoorMY"
#/content/reside-indoorMY/train/hazy
#path = "/content/reside-indoorMY"
#path = "./reside-indoorMY"

# %% [markdown]
# Data Augment
# ==

# %%
import random
import torchvision.transforms as transforms
import torchvision.transforms.functional as FUNCTIONAL


class PairRandomCrop(transforms.RandomCrop):

    def __call__(self, image, label):

        if self.padding is not None:
            image = FUNCTIONAL.pad(image, self.padding, self.fill, self.padding_mode)
            label = FUNCTIONAL.pad(label, self.padding, self.fill, self.padding_mode)

        # pad the width if needed
        if self.pad_if_needed and image.size[0] < self.size[1]:
            image = FUNCTIONAL.pad(image, (self.size[1] - image.size[0], 0), self.fill, self.padding_mode)
            label = FUNCTIONAL.pad(label, (self.size[1] - label.size[0], 0), self.fill, self.padding_mode)
        # pad the height if needed
        if self.pad_if_needed and image.size[1] < self.size[0]:
            image = FUNCTIONAL.pad(image, (0, self.size[0] - image.size[1]), self.fill, self.padding_mode)
            label = FUNCTIONAL.pad(label, (0, self.size[0] - image.size[1]), self.fill, self.padding_mode)

        i, j, h, w = self.get_params(image, self.size)

        return FUNCTIONAL.crop(image, i, j, h, w), FUNCTIONAL.crop(label, i, j, h, w)


class PairCompose(transforms.Compose):
    def __call__(self, image, label):
        for t in self.transforms:
            image, label = t(image, label)
        return image, label


class PairRandomHorizontalFilp(transforms.RandomHorizontalFlip):
    def __call__(self, img, label):
        """
        Args:
            img (PIL Image): Image to be flipped.

        Returns:
            PIL Image: Randomly flipped image.
        """
        if random.random() < self.p:
            return FUNCTIONAL.hflip(img), FUNCTIONAL.hflip(label)
        return img, label


class PairToTensor(transforms.ToTensor):
    def __call__(self, pic, label):
        """
        Args:
            pic (PIL Image or numpy.ndarray): Image to be converted to tensor.

        Returns:
            Tensor: Converted image.
        """
        return FUNCTIONAL.to_tensor(pic), FUNCTIONAL.to_tensor(label)

# %% [markdown]
# Data Loader
# ==

# %%
import os
import torch
import numpy as np
from PIL import Image as Image
from torch.utils.data import Dataset, DataLoader


def train_dataloader(path, batch_size=1, num_workers=0, use_transform=True): # we change batch size = 1, but the original batch size = 64
    image_dir = os.path.join(path, 'train')

    transform = None
    if use_transform:
        transform = PairCompose(
            [
                PairRandomCrop(256),
                PairRandomHorizontalFilp(),
                PairToTensor()
            ]
        )
    dataloader = DataLoader(
        DeblurDataset(image_dir, transform=transform),
        batch_size=batch_size,
        shuffle=True,
        num_workers=num_workers,
        pin_memory=True
    )
    return dataloader


def test_dataloader(path, batch_size=1, num_workers=0):
    image_dir = os.path.join(path, 'test')
    dataloader = DataLoader(
        DeblurDataset(image_dir, is_test=True),
        batch_size=batch_size,
        shuffle=False,
        num_workers=num_workers,
        pin_memory=True
    )

    return dataloader


def valid_dataloader(path, batch_size=1, num_workers=0):
    dataloader = DataLoader(
        DeblurDataset(os.path.join(path, 'test')),
        batch_size=batch_size,
        shuffle=False,
        num_workers=num_workers
    )

    return dataloader


class DeblurDataset(Dataset):
    def __init__(self, image_dir, transform=None, is_test=False):
        self.image_dir = image_dir
        self.image_list = os.listdir(os.path.join(image_dir, 'hazy/'))
        self._check_image(self.image_list)
        self.image_list.sort()
        self.transform = transform
        self.is_test = is_test

    def __len__(self):
        return len(self.image_list)

    def __getitem__(self, idx):
        image = Image.open(os.path.join(self.image_dir, 'hazy', self.image_list[idx]))
        label = Image.open(os.path.join(self.image_dir, 'gt', self.image_list[idx].split('_')[0]+'.png'))

        if self.transform:
            image, label = self.transform(image, label)
        else:
            image = FUNCTIONAL.to_tensor(image)
            label = FUNCTIONAL.to_tensor(label)
        if self.is_test:
            name = self.image_list[idx]
            return image, label, name
        return image, label

    @staticmethod
    def _check_image(lst):
        for x in lst:
            splits = x.split('.')
            if splits[-1] not in ['png', 'jpg', 'jpeg']:
                raise ValueError

# %% [markdown]
# Utils
# ==

# %%
import time
import numpy as np


class Adder(object):
    def __init__(self):
        self.count = 0
        self.num = float(0)

    def reset(self):
        self.count = 0
        self.num = float(0)

    def __call__(self, num):
        self.count += 1
        self.num += num

    def average(self):
        return self.num / self.count


class Timer(object):
    def __init__(self, option='s'):
        self.tm = 0
        self.option = option
        if option == 's':
            self.devider = 1
        elif option == 'm':
            self.devider = 60
        else:
            self.devider = 3600

    def tic(self):
        self.tm = time.time()

    def toc(self):
        return (time.time() - self.tm) / self.devider


def check_lr(optimizer):
    for i, param_group in enumerate(optimizer.param_groups):
        lr = param_group['lr']
    return lr

# %% [markdown]
# Eval
# ==

# %%
from skimage.metrics import peak_signal_noise_ratio
from pytorch_msssim import ssim
import torch.nn.functional as fe

from skimage import img_as_ubyte
import cv2

def _eval(model, args):
    state_dict = torch.load(args.test_model)
    model.load_state_dict(state_dict['model'])
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    dataloader = test_dataloader(args.data_dir, batch_size=1, num_workers=0)
    torch.cuda.empty_cache()
    adder = Adder()
    model.eval()
    factor = 32
    with torch.no_grad():
        psnr_adder = Adder()
        ssim_adder = Adder()

        for iter_idx, data in enumerate(dataloader):
            input_img, label_img, name = data

            input_img = input_img.to(device)

            h, w = input_img.shape[2], input_img.shape[3]
            H, W = ((h+factor)//factor)*factor, ((w+factor)//factor*factor)
            padh = H-h if h%factor!=0 else 0
            padw = W-w if w%factor!=0 else 0
            input_img = fe.pad(input_img, (0, padw, 0, padh), 'reflect')

            tm = time.time()

            pred = model(input_img)[2]
            pred = pred[:,:,:h,:w]

            elapsed = time.time() - tm
            adder(elapsed)

            pred_clip = torch.clamp(pred, 0, 1)

            pred_numpy = pred_clip.squeeze(0).cpu().numpy()
            label_numpy = label_img.squeeze(0).cpu().numpy()


            label_img = (label_img).cuda()
            psnr_val = 10 * torch.log10(1 / fe.mse_loss(pred_clip, label_img))
            down_ratio = max(1, round(min(H, W) / 256))
            ssim_val = ssim(fe.adaptive_avg_pool2d(pred_clip, (int(H / down_ratio), int(W / down_ratio))),
                            fe.adaptive_avg_pool2d(label_img, (int(H / down_ratio), int(W / down_ratio))),
                            data_range=1, size_average=False)
            print('%d iter PSNR_dehazing: %.2f ssim: %f' % (iter_idx + 1, psnr_val, ssim_val))
            ssim_adder(ssim_val)

            if args.save_image:
                save_name = os.path.join(args.result_dir, name[0])
                pred_clip += 0.5 / 255
                pred = FUNCTIONAL.to_pil_image(pred_clip.squeeze(0).cpu(), 'RGB')
                pred.save(save_name)

            psnr_mimo = peak_signal_noise_ratio(pred_numpy, label_numpy, data_range=1)
            psnr_adder(psnr_val)

            print('%d iter PSNR: %.2f time: %f' % (iter_idx + 1, psnr_mimo, elapsed))

        print('==========================================================')
        print('The average PSNR is %.2f dB' % (psnr_adder.average()))
        print('The average SSIM is %.5f dB' % (ssim_adder.average()))

        print("Average time: %f" % adder.average())

# %% [markdown]
# Layers
# ==

# %%
import torch
import torch.nn as nn
import torch.nn.functional as fl
import math

class BasicConv(nn.Module):
    def __init__(self, in_channel, out_channel, kernel_size, stride, bias=True, norm=False, relu=True, transpose=False):
        super(BasicConv, self).__init__()
        if bias and norm:
            bias = False

        padding = kernel_size // 2
        layers = list()
        if transpose:
            padding = kernel_size // 2 -1
            layers.append(nn.ConvTranspose2d(in_channel, out_channel, kernel_size, padding=padding, stride=stride, bias=bias))
        else:
            layers.append(
                nn.Conv2d(in_channel, out_channel, kernel_size, padding=padding, stride=stride, bias=bias))
        if norm:
            layers.append(nn.BatchNorm2d(out_channel))
        if relu:
            layers.append(nn.GELU())
        self.main = nn.Sequential(*layers)

    def forward(self, x):
        return self.main(x)


class ResBlock(nn.Module):
    def __init__(self, in_channel, out_channel, filter=False):
        super(ResBlock, self).__init__()
        self.main = nn.Sequential(
            BasicConv(in_channel, out_channel, kernel_size=3, stride=1, relu=True),
            DeepPoolLayer(in_channel, out_channel) if filter else nn.Identity(),
            BasicConv(out_channel, out_channel, kernel_size=3, stride=1, relu=False)
        )

    def forward(self, x):
        return self.main(x) + x


class DeepPoolLayer(nn.Module):
    def __init__(self, k, k_out):
        super(DeepPoolLayer, self).__init__()
        self.pools_sizes = [8,4,2]
        pools, convs, dynas = [],[],[]
        for i in self.pools_sizes:
            pools.append(nn.AvgPool2d(kernel_size=i, stride=i))
            convs.append(nn.Conv2d(k, k, 3, 1, 1, bias=False))
            dynas.append(dynamic_filter(inchannels=k, kernel_size=3))
        self.pools = nn.ModuleList(pools)
        self.convs = nn.ModuleList(convs)
        self.dynas = nn.ModuleList(dynas)
        self.relu = nn.GELU()
        self.conv_sum = nn.Conv2d(k, k_out, 3, 1, 1, bias=False)

    def forward(self, x):
        x_size = x.size()
        resl = x
        for i in range(len(self.pools_sizes)):
            if i == 0:
                y = self.dynas[i](self.convs[i](self.pools[i](x)))
            else:
                y = self.dynas[i](self.convs[i](self.pools[i](x)+y_up))
            resl = torch.add(resl, fl.interpolate(y, x_size[2:], mode='bilinear', align_corners=True))
            if i != len(self.pools_sizes)-1:
                y_up = fl.interpolate(y, scale_factor=2, mode='bilinear', align_corners=True)
        resl = self.relu(resl)
        resl = self.conv_sum(resl)

        return resl

class dynamic_filter(nn.Module):
    def __init__(self, inchannels, kernel_size=3, stride=1, group=8):
        super(dynamic_filter, self).__init__()

        self.stride = stride
        self.kernel_size = kernel_size
        self.group = group

        self.conv = nn.Conv2d(inchannels, group*kernel_size**2, kernel_size=1, stride=1, bias=False)
        self.bn = nn.BatchNorm2d(group*kernel_size**2)
        self.act = nn.Tanh()

        nn.init.kaiming_normal_(self.conv.weight, mode='fan_out', nonlinearity='relu')
        self.lamb_l = nn.Parameter(torch.zeros(inchannels), requires_grad=True)
        self.lamb_h = nn.Parameter(torch.zeros(inchannels), requires_grad=True)
        self.pad = nn.ReflectionPad2d(kernel_size//2)

        self.ap = nn.AdaptiveAvgPool2d((1, 1))
        self.gap = nn.AdaptiveAvgPool2d(1)

        self.inside_all = nn.Parameter(torch.zeros(inchannels,1,1), requires_grad=True)

    def forward(self, x):
        identity_input = x
        # the Conv_{3x3} layer in eq.3 is included in DeepPoolLayer.convs
        low_filter = self.ap(x)
        low_filter = self.conv(low_filter)
        low_filter = self.bn(low_filter)

        n, c, h, w = x.shape
        x = fl.unfold(self.pad(x), kernel_size=self.kernel_size).reshape(n, self.group, c//self.group, self.kernel_size**2, h*w)

        n,c1,p,q = low_filter.shape
        low_filter = low_filter.reshape(n, c1//self.kernel_size**2, self.kernel_size**2, p*q).unsqueeze(2)
        low_filter = self.act(low_filter)
        low_part = torch.sum(x * low_filter, dim=3).reshape(n, c, h, w)

        # the variables here are slightly different from the paper: (code) --> (paper)
        # low_filter --> A (eq.3)
        # In Eq.7, X*A'= X*(A_{l} + WA_{h})
        #              = X*A_{l} + WX*(A - A_{l})
        #              = X*A_{l} + WX*A - WX*A_{l}
        #              = WX*A - X*A_{l}(W-1)
        # we substitute gap for A_{l} for simplicity, which is a coarser low-frequency filter
        out_low = low_part * (self.inside_all + 1.) - self.inside_all * self.gap(identity_input)

        out_low = out_low * self.lamb_l[None,:,None,None]
        out_high = (identity_input) * (self.lamb_h[None,:,None,None] + 1.)

        return out_low + out_high

# %% [markdown]
# IRNeXt
# ==

# %%
import torch
import torch.nn as nn
import torch.nn.functional as fwd

class EBlock(nn.Module):
    def __init__(self, out_channel, num_res=8):
        super(EBlock, self).__init__()

        layers = [ResBlock(out_channel, out_channel) for _ in range(num_res-1)]
        layers.append(ResBlock(out_channel, out_channel, filter=True))
        self.layers = nn.Sequential(*layers)

    def forward(self, x):
        return self.layers(x)


class DBlock(nn.Module):
    def __init__(self, channel, num_res=8):
        super(DBlock, self).__init__()

        layers = [ResBlock(channel, channel) for _ in range(num_res-1)]
        layers.append(ResBlock(channel, channel, filter=True))
        self.layers = nn.Sequential(*layers)

    def forward(self, x):
        return self.layers(x)


class SCM(nn.Module):
    def __init__(self, out_plane):
        super(SCM, self).__init__()

        self.main = nn.Sequential(
            BasicConv(3, out_plane//4, kernel_size=3, stride=1, relu=True),
            BasicConv(out_plane // 4, out_plane // 2, kernel_size=1, stride=1, relu=True),
            BasicConv(out_plane // 2, out_plane // 2, kernel_size=3, stride=1, relu=True),
            BasicConv(out_plane // 2, out_plane, kernel_size=1, stride=1, relu=False),
            nn.InstanceNorm2d(out_plane, affine=True)
        )

    def forward(self, x):
        x = self.main(x)
        return x

class FAM(nn.Module):
    def __init__(self, channel):
        super(FAM, self).__init__()

        self.merge = BasicConv(channel*2, channel, kernel_size=3, stride=1, relu=False)

    def forward(self, x1, x2):
        return self.merge(torch.cat([x1, x2], dim=1))

class IRNeXt(nn.Module):
    def __init__(self, num_res=4):
        super(IRNeXt, self).__init__()

        base_channel = 32
        self.Encoder = nn.ModuleList([
            EBlock(base_channel, num_res),
            EBlock(base_channel*2, num_res),
            EBlock(base_channel*4, num_res),
        ])

        self.feat_extract = nn.ModuleList([
            BasicConv(3, base_channel, kernel_size=3, relu=True, stride=1),
            BasicConv(base_channel, base_channel*2, kernel_size=3, relu=True, stride=2),
            BasicConv(base_channel*2, base_channel*4, kernel_size=3, relu=True, stride=2),
            BasicConv(base_channel*4, base_channel*2, kernel_size=4, relu=True, stride=2, transpose=True),
            BasicConv(base_channel*2, base_channel, kernel_size=4, relu=True, stride=2, transpose=True),
            BasicConv(base_channel, 3, kernel_size=3, relu=False, stride=1)
        ])

        self.Decoder = nn.ModuleList([
            DBlock(base_channel * 4, num_res),
            DBlock(base_channel * 2, num_res),
            DBlock(base_channel, num_res)
        ])

        self.Convs = nn.ModuleList([
            BasicConv(base_channel * 4, base_channel * 2, kernel_size=1, relu=True, stride=1),
            BasicConv(base_channel * 2, base_channel, kernel_size=1, relu=True, stride=1),
        ])

        self.ConvsOut = nn.ModuleList(
            [
                BasicConv(base_channel * 4, 3, kernel_size=3, relu=False, stride=1),
                BasicConv(base_channel * 2, 3, kernel_size=3, relu=False, stride=1),
            ]
        )

        self.FAM1 = FAM(base_channel * 4)
        self.SCM1 = SCM(base_channel * 4)
        self.FAM2 = FAM(base_channel * 2)
        self.SCM2 = SCM(base_channel * 2)

    def forward(self, x):
        x_2 = fwd.interpolate(x, scale_factor=0.5)
        x_4 = fwd.interpolate(x_2, scale_factor=0.5)
        z2 = self.SCM2(x_2)
        z4 = self.SCM1(x_4)

        outputs = list()
        # 256
        x_ = self.feat_extract[0](x)
        res1 = self.Encoder[0](x_)
        # 128
        z = self.feat_extract[1](res1)
        z = self.FAM2(z, z2)
        res2 = self.Encoder[1](z)
        # 64
        z = self.feat_extract[2](res2)
        z = self.FAM1(z, z4)
        z = self.Encoder[2](z)

        z = self.Decoder[0](z)
        z_ = self.ConvsOut[0](z)
        # 128
        z = self.feat_extract[3](z)
        outputs.append(z_+x_4)

        z = torch.cat([z, res2], dim=1)
        z = self.Convs[0](z)
        z = self.Decoder[1](z)
        z_ = self.ConvsOut[1](z)
        # 256
        z = self.feat_extract[4](z)
        outputs.append(z_+x_2)

        z = torch.cat([z, res1], dim=1)
        z = self.Convs[1](z)
        z = self.Decoder[2](z)
        z = self.feat_extract[5](z)
        outputs.append(z+x)

        return outputs


def build_net():
    return IRNeXt()

# %% [markdown]
# Valid
# ==

# %%
from skimage.metrics import peak_signal_noise_ratio
import torch.nn.functional as fv


def _valid(model, args, ep):
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    its = valid_dataloader(args.data_dir, batch_size=1, num_workers=0)
    model.eval()
    psnr_adder = Adder()

    with torch.no_grad():
        print('Start Evaluation')
        factor = 32
        for idx, data in enumerate(its):
            input_img, label_img = data
            input_img = input_img.to(device)

            h, w = input_img.shape[2], input_img.shape[3]
            H, W = ((h+factor)//factor)*factor, ((w+factor)//factor*factor)
            padh = H-h if h%factor!=0 else 0
            padw = W-w if w%factor!=0 else 0
            input_img = fv.pad(input_img, (0, padw, 0, padh), 'reflect')

            if not os.path.exists(os.path.join(args.result_dir, '%d' % (ep))):
                os.mkdir(os.path.join(args.result_dir, '%d' % (ep)))

            pred = model(input_img)[2]
            pred = pred[:,:,:h,:w]

            pred_clip = torch.clamp(pred, 0, 1)
            p_numpy = pred_clip.squeeze(0).cpu().numpy()
            label_numpy = label_img.squeeze(0).cpu().numpy()

            psnr = peak_signal_noise_ratio(p_numpy, label_numpy, data_range=1)

            psnr_adder(psnr)
            print('\r%03d'%idx, end=' ')

    print('\n')
    model.train()
    return psnr_adder.average()

# %% [markdown]
# SGLD
# ==

# %%
""" Custom optimizer implementations to track various runtime statistics """

from torch.optim import Optimizer


class SGLD(Optimizer):
    r"""Implements stochastic gradient descent (optionally with momentum).
    Nesterov momentum is based on the formula from
    `On the importance of initialization and momentum in deep learning`__.
    Args:
        params (iterable): iterable of parameters to optimize or dicts defining
            parameter groups
        lr (float): learning rate
        momentum (float, optional): momentum factor (default: 0)
        weight_decay (float, optional): weight decay (L2 penalty) (default: 0)
        dampening (float, optional): dampening for momentum (default: 0)
        nesterov (bool, optional): enables Nesterov momentum (default: False)
        noise_scale (float, optional): variance of isotropic noise for langevin
    Example:
        >>> optimizer = torch.optim.SGD(model.parameters(), lr=0.1, momentum=0.9)
        >>> optimizer.zero_grad()
        >>> loss_fn(model(input), target).backward()
        >>> optimizer.step()
    __ http://www.cs.toronto.edu/%7Ehinton/absps/momentum.pdf
    .. note::
        The implementation of SGD with Momentum/Nesterov subtly differs from
        Sutskever et. al. and implementations in some other frameworks.
        Considering the specific case of Momentum, the update can be written as
        .. math::
                  v = \rho * v + g \\
                  p = p - lr * v
        where p, g, v and :math:`\rho` denote the parameters, gradient,
        velocity, and momentum respectively.
        This is in contrast to Sutskever et. al. and
        other frameworks which employ an update of the form
        .. math::
             v = \rho * v + lr * g \\
             p = p - v
        The Nesterov version is analogously modified.
    """

    def __init__(self, params, lr, momentum=0, dampening=0,
                 weight_decay=0, nesterov=False,
                 noise_scale=0.01):
        if lr < 0.0:
            raise ValueError("Invalid learning rate: {}".format(lr))
        if momentum < 0.0:
            raise ValueError("Invalid momentum value: {}".format(momentum))
        if weight_decay < 0.0:
            raise ValueError("Invalid weight_decay value: {}".format(weight_decay))

        defaults = dict(lr=lr, momentum=momentum, dampening=dampening,
                        weight_decay=weight_decay, nesterov=nesterov)
        if nesterov and (momentum <= 0 or dampening != 0):
            raise ValueError("Nesterov momentum requires a momentum and zero dampening")
        super(SGLD, self).__init__(params, defaults)
        self.noise_scale = noise_scale

    def __setstate__(self, state):
        super(SGLD, self).__setstate__(state)
        for group in self.param_groups:
            group.setdefault('nesterov', False)

    def step(self, closure=None):
        """Performs a single optimization step.
        Arguments:
            closure (callable, optional): A closure that reevaluates the model
                and returns the loss.

        returns norm of the step we took for variance analysis later
        """
        loss = None
        if closure is not None:
            loss = closure()

        for group in self.param_groups:
            weight_decay = group['weight_decay']
            momentum = group['momentum']
            dampening = group['dampening']
            nesterov = group['nesterov']

            for p in group['params']:
                if p.grad is None:
                    continue
                d_p = p.grad.data

                if weight_decay != 0:
                    d_p.add_(weight_decay, p.data)
                if momentum != 0:
                    param_state = self.state[p]
                    if 'momentum_buffer' not in param_state:
                        buf = param_state['momentum_buffer'] = torch.zeros_like(p.data)
                        buf.mul_(momentum).add_(d_p)
                    else:
                        buf = param_state['momentum_buffer']
                        buf.mul_(momentum).add_(1 - dampening, d_p)
                    if nesterov:
                        d_p = d_p.add(momentum, buf)
                    else:
                        d_p = buf

                p.data.add_(-group['lr'], d_p)
                p.data.add_(np.sqrt(self.noise_scale), torch.randn_like(p.data))
        return loss

# %% [markdown]
# TRAIN
# ==

# %%
from torch.utils.tensorboard import SummaryWriter
import torch.nn.functional as ft
import torch.optim as optim


from warmup_scheduler import GradualWarmupScheduler

def _train(model, args):
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    model.to(device)
    criterion = torch.nn.L1Loss().to(device)
    optimizer = optim.SGD(model.parameters(), lr=args.learning_rate, momentum=args.momentum_value, nesterov=True)

    #optimizer = SGLD(params=model.parameters(), lr=args.learning_rate, weight_decay=args.weight_decay)
    dataloader = train_dataloader(args.data_dir, args.batch_size, args.num_worker)
    max_iter = len(dataloader)
    warmup_epochs=3
    scheduler_cosine = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=args.num_epoch-warmup_epochs, eta_min=1e-6)
    scheduler = GradualWarmupScheduler(optimizer, multiplier=1, total_epoch=warmup_epochs, after_scheduler=scheduler_cosine)
    scheduler.step()
    epoch = 1
    if args.resume:
        state = torch.load(args.resume)
        epoch = state['epoch']
        optimizer.load_state_dict(state['optimizer'])
        model.load_state_dict(state['model'])
        print('Resume from %d'%epoch)
        epoch += 1
        for i in range(epoch-1):
          scheduler.step()

    writer = SummaryWriter()
    epoch_pixel_adder = Adder()
    epoch_fft_adder = Adder()
    iter_pixel_adder = Adder()
    iter_fft_adder = Adder()
    epoch_timer = Timer('m')
    iter_timer = Timer('m')
    best_psnr=-1

    for epoch_idx in range(epoch, args.num_epoch + 1):

        epoch_timer.tic()
        iter_timer.tic()
        for iter_idx, batch_data in enumerate(dataloader):

            input_img, label_img = batch_data
            input_img = input_img.to(device)
            label_img = label_img.to(device)

            optimizer.zero_grad()
            pred_img = model(input_img)
            label_img2 = ft.interpolate(label_img, scale_factor=0.5, mode='bilinear')
            label_img4 = ft.interpolate(label_img, scale_factor=0.25, mode='bilinear')
            l1 = criterion(pred_img[0], label_img4)
            l2 = criterion(pred_img[1], label_img2)
            l3 = criterion(pred_img[2], label_img)
            loss_content = l1+l2+l3

            label_fft1 = torch.fft.fft2(label_img4, dim=(-2,-1))
            label_fft1 = torch.stack((label_fft1.real, label_fft1.imag), -1)

            pred_fft1 = torch.fft.fft2(pred_img[0], dim=(-2,-1))
            pred_fft1 = torch.stack((pred_fft1.real, pred_fft1.imag), -1)

            label_fft2 = torch.fft.fft2(label_img2, dim=(-2,-1))
            label_fft2 = torch.stack((label_fft2.real, label_fft2.imag), -1)

            pred_fft2 = torch.fft.fft2(pred_img[1], dim=(-2,-1))
            pred_fft2 = torch.stack((pred_fft2.real, pred_fft2.imag), -1)

            label_fft3 = torch.fft.fft2(label_img, dim=(-2,-1))
            label_fft3 = torch.stack((label_fft3.real, label_fft3.imag), -1)

            pred_fft3 = torch.fft.fft2(pred_img[2], dim=(-2,-1))
            pred_fft3 = torch.stack((pred_fft3.real, pred_fft3.imag), -1)

            f1 = criterion(pred_fft1, label_fft1)
            f2 = criterion(pred_fft2, label_fft2)
            f3 = criterion(pred_fft3, label_fft3)
            loss_fft = f1+f2+f3

            loss = loss_content + 0.1 * loss_fft
            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), 0.001)
            optimizer.step()

            iter_pixel_adder(loss_content.item())
            iter_fft_adder(loss_fft.item())

            epoch_pixel_adder(loss_content.item())
            epoch_fft_adder(loss_fft.item())

            if (iter_idx + 1) % args.print_freq == 0:
                print("Time: %7.4f Epoch: %03d Iter: %4d/%4d LR: %.10f Loss content: %7.4f Loss fft: %7.4f" % (
                    iter_timer.toc(), epoch_idx, iter_idx + 1, max_iter, scheduler.get_lr()[0], iter_pixel_adder.average(),
                    iter_fft_adder.average()))
                writer.add_scalar('Pixel Loss', iter_pixel_adder.average(), iter_idx + (epoch_idx-1)* max_iter)
                writer.add_scalar('FFT Loss', iter_fft_adder.average(), iter_idx + (epoch_idx - 1) * max_iter)

                iter_timer.tic()
                iter_pixel_adder.reset()
                iter_fft_adder.reset()
        overwrite_name = os.path.join(args.model_save_dir, 'model.pkl')
        torch.save({'model': model.state_dict(),
                    'optimizer': optimizer.state_dict(),
                    'epoch': epoch_idx}, overwrite_name)

        if epoch_idx % args.save_freq == 0:
            save_name = os.path.join(args.model_save_dir, 'model_%d.pkl' % epoch_idx)
            torch.save({'model': model.state_dict()}, save_name)
        print("EPOCH: %02d\nElapsed time: %4.2f Epoch Pixel Loss: %7.4f Epoch FFT Loss: %7.4f" % (
            epoch_idx, epoch_timer.toc(), epoch_pixel_adder.average(), epoch_fft_adder.average()))
        epoch_fft_adder.reset()
        epoch_pixel_adder.reset()
        scheduler.step()
        if epoch_idx % args.valid_freq == 0:
            val = _valid(model, args, epoch_idx)
            print('%03d epoch \n Average PSNR %.2f dB' % (epoch_idx, val))
            writer.add_scalar('PSNR', val, epoch_idx)
            if val >= best_psnr:
                torch.save({'model': model.state_dict()}, os.path.join(args.model_save_dir, 'Best.pkl'))
    save_name = os.path.join(args.model_save_dir, 'Final.pkl')
    torch.save({'model': model.state_dict()}, save_name)

# %% [markdown]
# Main (test model)
# ==

# %%
import os
import torch
import torchvision.transforms as transforms
# from torch.backends import cudnn # Uncomment if you need it

class Args:
    model_name = 'IRNeXt'
    mode = 'train'
    data_dir = path

    # Train
    batch_size = 4
    learning_rate = 1e-4
    weight_decay = 0
    num_epoch = 20
    print_freq = 100
    num_worker = 8
    save_freq = 10
    valid_freq = 10
    momentum_value = 0.6

    resume = ''
    #/content/drive/MyDrive/MYresults2/IRNeXt/ITS/model.pkl
    # Test
    test_model = '/content/drive/MyDrive/MYresults2__6/IRNeXt/ITS/Final.pkl'
    save_image = False

    # Directories (set these as per your requirement)
    model_save_dir = os.path.join('/content/drive/MyDrive/MYresults2__6/', 'IRNeXt', 'ITS/')
    result_dir = os.path.join('/content/drive/MyDrive/MYresults2__6/', model_name, 'test')

def main(args):
    # CUDNN
    # cudnn.benchmark = True # Uncomment if you need it

    if not os.path.exists('/content/drive/MyDrive/MYresults2__6/'):
        os.makedirs(args.model_save_dir)
    if not os.path.exists('/content/drive/MyDrive/MYresults2__6/' + args.model_name + '/'):
        os.makedirs('/content/drive/MyDrive/MYresults2__6/' + args.model_name + '/')
    if not os.path.exists(args.model_save_dir):
        os.makedirs(args.model_save_dir)
    if not os.path.exists(args.result_dir):
        os.makedirs(args.result_dir)

    model = build_net()  # Make sure to define build_net or import it if it's defined elsewhere
    print(model)

    if torch.cuda.is_available():
        model.cuda()
    if args.mode == 'train':
        _train(model, args)  # Make sure to define _train or import it if it's defined elsewhere

    elif args.mode == 'test':
        _eval(model, args)   # Make sure to define _eval or import it if it's defined elsewhere

# Replace parser.parse_args() with an instance of the Args class
args = Args()
if not os.path.exists(args.model_save_dir):
    os.makedirs(args.model_save_dir)
# Copying files (make sure these paths are correct)
command = 'cp ' + 'models/layers.py ' + args.model_save_dir
os.system(command)
command = 'cp ' + 'models/IRNeXt.py ' + args.model_save_dir
os.system(command)
command = 'cp ' + 'train.py ' + args.model_save_dir
os.system(command)
command = 'cp ' + 'main.py ' + args.model_save_dir
os.system(command)
print(args)
main(args)
# Out:
# <__main__.Args object at 0x7b03173c11b0>
# IRNeXt(
#   (Encoder): ModuleList(
#     (0): EBlock(
#       (layers): Sequential(
#         (0): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (1): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (2): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (3): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): DeepPoolLayer(
#               (pools): ModuleList(
#                 (0): AvgPool2d(kernel_size=8, stride=8, padding=0)
#                 (1): AvgPool2d(kernel_size=4, stride=4, padding=0)
#                 (2): AvgPool2d(kernel_size=2, stride=2, padding=0)
#               )
#               (convs): ModuleList(
#                 (0-2): 3 x Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#               (dynas): ModuleList(
#                 (0-2): 3 x dynamic_filter(
#                   (conv): Conv2d(32, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (bn): BatchNorm2d(72, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (act): Tanh()
#                   (pad): ReflectionPad2d((1, 1, 1, 1))
#                   (ap): AdaptiveAvgPool2d(output_size=(1, 1))
#                   (gap): AdaptiveAvgPool2d(output_size=1)
#                 )
#               )
#               (relu): GELU(approximate='none')
#               (conv_sum): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             )
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#       )
#     )
#     (1): EBlock(
#       (layers): Sequential(
#         (0): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (1): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (2): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (3): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): DeepPoolLayer(
#               (pools): ModuleList(
#                 (0): AvgPool2d(kernel_size=8, stride=8, padding=0)
#                 (1): AvgPool2d(kernel_size=4, stride=4, padding=0)
#                 (2): AvgPool2d(kernel_size=2, stride=2, padding=0)
#               )
#               (convs): ModuleList(
#                 (0-2): 3 x Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#               (dynas): ModuleList(
#                 (0-2): 3 x dynamic_filter(
#                   (conv): Conv2d(64, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (bn): BatchNorm2d(72, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (act): Tanh()
#                   (pad): ReflectionPad2d((1, 1, 1, 1))
#                   (ap): AdaptiveAvgPool2d(output_size=(1, 1))
#                   (gap): AdaptiveAvgPool2d(output_size=1)
#                 )
#               )
#               (relu): GELU(approximate='none')
#               (conv_sum): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             )
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#       )
#     )
#     (2): EBlock(
#       (layers): Sequential(
#         (0): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (1): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (2): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (3): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): DeepPoolLayer(
#               (pools): ModuleList(
#                 (0): AvgPool2d(kernel_size=8, stride=8, padding=0)
#                 (1): AvgPool2d(kernel_size=4, stride=4, padding=0)
#                 (2): AvgPool2d(kernel_size=2, stride=2, padding=0)
#               )
#               (convs): ModuleList(
#                 (0-2): 3 x Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#               (dynas): ModuleList(
#                 (0-2): 3 x dynamic_filter(
#                   (conv): Conv2d(128, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (bn): BatchNorm2d(72, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (act): Tanh()
#                   (pad): ReflectionPad2d((1, 1, 1, 1))
#                   (ap): AdaptiveAvgPool2d(output_size=(1, 1))
#                   (gap): AdaptiveAvgPool2d(output_size=1)
#                 )
#               )
#               (relu): GELU(approximate='none')
#               (conv_sum): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             )
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#       )
#     )
#   )
#   (feat_extract): ModuleList(
#     (0): BasicConv(
#       (main): Sequential(
#         (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): GELU(approximate='none')
#       )
#     )
#     (1): BasicConv(
#       (main): Sequential(
#         (0): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         (1): GELU(approximate='none')
#       )
#     )
#     (2): BasicConv(
#       (main): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         (1): GELU(approximate='none')
#       )
#     )
#     (3): BasicConv(
#       (main): Sequential(
#         (0): ConvTranspose2d(128, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#         (1): GELU(approximate='none')
#       )
#     )
#     (4): BasicConv(
#       (main): Sequential(
#         (0): ConvTranspose2d(64, 32, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#         (1): GELU(approximate='none')
#       )
#     )
#     (5): BasicConv(
#       (main): Sequential(
#         (0): Conv2d(32, 3, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#     )
#   )
#   (Decoder): ModuleList(
#     (0): DBlock(
#       (layers): Sequential(
#         (0): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (1): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (2): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (3): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): DeepPoolLayer(
#               (pools): ModuleList(
#                 (0): AvgPool2d(kernel_size=8, stride=8, padding=0)
#                 (1): AvgPool2d(kernel_size=4, stride=4, padding=0)
#                 (2): AvgPool2d(kernel_size=2, stride=2, padding=0)
#               )
#               (convs): ModuleList(
#                 (0-2): 3 x Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#               (dynas): ModuleList(
#                 (0-2): 3 x dynamic_filter(
#                   (conv): Conv2d(128, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (bn): BatchNorm2d(72, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (act): Tanh()
#                   (pad): ReflectionPad2d((1, 1, 1, 1))
#                   (ap): AdaptiveAvgPool2d(output_size=(1, 1))
#                   (gap): AdaptiveAvgPool2d(output_size=1)
#                 )
#               )
#               (relu): GELU(approximate='none')
#               (conv_sum): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             )
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#       )
#     )
#     (1): DBlock(
#       (layers): Sequential(
#         (0): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (1): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (2): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (3): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): DeepPoolLayer(
#               (pools): ModuleList(
#                 (0): AvgPool2d(kernel_size=8, stride=8, padding=0)
#                 (1): AvgPool2d(kernel_size=4, stride=4, padding=0)
#                 (2): AvgPool2d(kernel_size=2, stride=2, padding=0)
#               )
#               (convs): ModuleList(
#                 (0-2): 3 x Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#               (dynas): ModuleList(
#                 (0-2): 3 x dynamic_filter(
#                   (conv): Conv2d(64, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (bn): BatchNorm2d(72, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (act): Tanh()
#                   (pad): ReflectionPad2d((1, 1, 1, 1))
#                   (ap): AdaptiveAvgPool2d(output_size=(1, 1))
#                   (gap): AdaptiveAvgPool2d(output_size=1)
#                 )
#               )
#               (relu): GELU(approximate='none')
#               (conv_sum): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             )
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#       )
#     )
#     (2): DBlock(
#       (layers): Sequential(
#         (0): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (1): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (2): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (3): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): DeepPoolLayer(
#               (pools): ModuleList(
#                 (0): AvgPool2d(kernel_size=8, stride=8, padding=0)
#                 (1): AvgPool2d(kernel_size=4, stride=4, padding=0)
#                 (2): AvgPool2d(kernel_size=2, stride=2, padding=0)
#               )
#               (convs): ModuleList(
#                 (0-2): 3 x Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#               (dynas): ModuleList(
#                 (0-2): 3 x dynamic_filter(
#                   (conv): Conv2d(32, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (bn): BatchNorm2d(72, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (act): Tanh()
#                   (pad): ReflectionPad2d((1, 1, 1, 1))
#                   (ap): AdaptiveAvgPool2d(output_size=(1, 1))
#                   (gap): AdaptiveAvgPool2d(output_size=1)
#                 )
#               )
#               (relu): GELU(approximate='none')
#               (conv_sum): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             )
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#       )
#     )
#   )
#   (Convs): ModuleList(
#     (0): BasicConv(
#       (main): Sequential(
#         (0): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1))
#         (1): GELU(approximate='none')
#       )
#     )
#     (1): BasicConv(
#       (main): Sequential(
#         (0): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#         (1): GELU(approximate='none')
#       )
#     )
#   )
#   (ConvsOut): ModuleList(
#     (0): BasicConv(
#       (main): Sequential(
#         (0): Conv2d(128, 3, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#     )
#     (1): BasicConv(
#       (main): Sequential(
#         (0): Conv2d(64, 3, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#     )
#   )
#   (FAM1): FAM(
#     (merge): BasicConv(
#       (main): Sequential(
#         (0): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#     )
#   )
#   (SCM1): SCM(
#     (main): Sequential(
#       (0): BasicConv(
#         (main): Sequential(
#           (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): GELU(approximate='none')
#         )
#       )
#       (1): BasicConv(
#         (main): Sequential(
#           (0): Conv2d(32, 64, kernel_size=(1, 1), stride=(1, 1))
#           (1): GELU(approximate='none')
#         )
#       )
#       (2): BasicConv(
#         (main): Sequential(
#           (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): GELU(approximate='none')
#         )
#       )
#       (3): BasicConv(
#         (main): Sequential(
#           (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1))
#         )
#       )
#       (4): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#     )
#   )
#   (FAM2): FAM(
#     (merge): BasicConv(
#       (main): Sequential(
#         (0): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#     )
#   )
#   (SCM2): SCM(
#     (main): Sequential(
#       (0): BasicConv(
#         (main): Sequential(
#           (0): Conv2d(3, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): GELU(approximate='none')
#         )
#       )
#       (1): BasicConv(
#         (main): Sequential(
#           (0): Conv2d(16, 32, kernel_size=(1, 1), stride=(1, 1))
#           (1): GELU(approximate='none')
#         )
#       )
#       (2): BasicConv(
#         (main): Sequential(
#           (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): GELU(approximate='none')
#         )
#       )
#       (3): BasicConv(
#         (main): Sequential(
#           (0): Conv2d(32, 64, kernel_size=(1, 1), stride=(1, 1))
#         )
#       )
#       (4): InstanceNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#     )
#   )
# )
# Time:  0.1973 Epoch: 001 Iter:  100/3498 LR: 0.0000333333 Loss content:  0.7482 Loss fft:  9.8823
# Time:  0.1873 Epoch: 001 Iter:  200/3498 LR: 0.0000333333 Loss content:  0.7314 Loss fft:  9.9393
# Time:  0.1871 Epoch: 001 Iter:  300/3498 LR: 0.0000333333 Loss content:  0.7410 Loss fft:  9.7833
# Time:  0.1871 Epoch: 001 Iter:  400/3498 LR: 0.0000333333 Loss content:  0.7167 Loss fft: 10.0039
# Time:  0.1871 Epoch: 001 Iter:  500/3498 LR: 0.0000333333 Loss content:  0.7084 Loss fft:  9.7968
# Time:  0.1874 Epoch: 001 Iter:  600/3498 LR: 0.0000333333 Loss content:  0.7040 Loss fft:  9.6907
# Time:  0.1872 Epoch: 001 Iter:  700/3498 LR: 0.0000333333 Loss content:  0.7165 Loss fft:  9.8590
# Time:  0.1872 Epoch: 001 Iter:  800/3498 LR: 0.0000333333 Loss content:  0.7300 Loss fft:  9.8716
# Time:  0.1871 Epoch: 001 Iter:  900/3498 LR: 0.0000333333 Loss content:  0.7302 Loss fft:  9.8452
# Time:  0.1871 Epoch: 001 Iter: 1000/3498 LR: 0.0000333333 Loss content:  0.7153 Loss fft:  9.8623
# Time:  0.1872 Epoch: 001 Iter: 1100/3498 LR: 0.0000333333 Loss content:  0.7330 Loss fft:  9.7139
# Time:  0.1873 Epoch: 001 Iter: 1200/3498 LR: 0.0000333333 Loss content:  0.7206 Loss fft:  9.8038
# Time:  0.1873 Epoch: 001 Iter: 1300/3498 LR: 0.0000333333 Loss content:  0.7486 Loss fft:  9.8222
# Time:  0.1872 Epoch: 001 Iter: 1400/3498 LR: 0.0000333333 Loss content:  0.7493 Loss fft:  9.6903
# Time:  0.1918 Epoch: 001 Iter: 1500/3498 LR: 0.0000333333 Loss content:  0.7263 Loss fft:  9.8977
# Time:  0.1875 Epoch: 001 Iter: 1600/3498 LR: 0.0000333333 Loss content:  0.7177 Loss fft:  9.6959
# Time:  0.1872 Epoch: 001 Iter: 1700/3498 LR: 0.0000333333 Loss content:  0.7040 Loss fft:  9.6053
# Time:  0.1872 Epoch: 001 Iter: 1800/3498 LR: 0.0000333333 Loss content:  0.7062 Loss fft:  9.6739
# Time:  0.1872 Epoch: 001 Iter: 1900/3498 LR: 0.0000333333 Loss content:  0.7305 Loss fft:  9.9670
# Time:  0.1872 Epoch: 001 Iter: 2000/3498 LR: 0.0000333333 Loss content:  0.7073 Loss fft:  9.6008
# Time:  0.1872 Epoch: 001 Iter: 2100/3498 LR: 0.0000333333 Loss content:  0.7160 Loss fft: 10.1071
# Time:  0.1871 Epoch: 001 Iter: 2200/3498 LR: 0.0000333333 Loss content:  0.7440 Loss fft:  9.9784
# Time:  0.1871 Epoch: 001 Iter: 2300/3498 LR: 0.0000333333 Loss content:  0.6904 Loss fft:  9.7897
# Time:  0.1872 Epoch: 001 Iter: 2400/3498 LR: 0.0000333333 Loss content:  0.7334 Loss fft:  9.6812
# Time:  0.1872 Epoch: 001 Iter: 2500/3498 LR: 0.0000333333 Loss content:  0.7409 Loss fft:  9.6627
# Time:  0.1873 Epoch: 001 Iter: 2600/3498 LR: 0.0000333333 Loss content:  0.7216 Loss fft:  9.8469
# Time:  0.1871 Epoch: 001 Iter: 2700/3498 LR: 0.0000333333 Loss content:  0.7362 Loss fft:  9.8572
# Time:  0.1871 Epoch: 001 Iter: 2800/3498 LR: 0.0000333333 Loss content:  0.7060 Loss fft: 10.0942
# Time:  0.1871 Epoch: 001 Iter: 2900/3498 LR: 0.0000333333 Loss content:  0.7186 Loss fft: 10.0021
# Time:  0.1871 Epoch: 001 Iter: 3000/3498 LR: 0.0000333333 Loss content:  0.7284 Loss fft:  9.7347
# Time:  0.1871 Epoch: 001 Iter: 3100/3498 LR: 0.0000333333 Loss content:  0.7320 Loss fft:  9.6310
# Time:  0.1871 Epoch: 001 Iter: 3200/3498 LR: 0.0000333333 Loss content:  0.7214 Loss fft:  9.6847
# Time:  0.1871 Epoch: 001 Iter: 3300/3498 LR: 0.0000333333 Loss content:  0.7209 Loss fft:  9.9581
# Time:  0.1871 Epoch: 001 Iter: 3400/3498 LR: 0.0000333333 Loss content:  0.7384 Loss fft:  9.9423
# EPOCH: 01
# Elapsed time: 6.57 Epoch Pixel Loss:  0.7240 Epoch FFT Loss:  9.8147
# Time:  0.1959 Epoch: 002 Iter:  100/3498 LR: 0.0000666667 Loss content:  0.7167 Loss fft:  9.6932
# Time:  0.1920 Epoch: 002 Iter:  200/3498 LR: 0.0000666667 Loss content:  0.7110 Loss fft:  9.9144
# Time:  0.1872 Epoch: 002 Iter:  300/3498 LR: 0.0000666667 Loss content:  0.7413 Loss fft:  9.7981
# Time:  0.1871 Epoch: 002 Iter:  400/3498 LR: 0.0000666667 Loss content:  0.7061 Loss fft:  9.8006
# Time:  0.1872 Epoch: 002 Iter:  500/3498 LR: 0.0000666667 Loss content:  0.7357 Loss fft: 10.1561
# Time:  0.1873 Epoch: 002 Iter:  600/3498 LR: 0.0000666667 Loss content:  0.7219 Loss fft: 10.0179
# Time:  0.1873 Epoch: 002 Iter:  700/3498 LR: 0.0000666667 Loss content:  0.6952 Loss fft:  9.8246
# Time:  0.1877 Epoch: 002 Iter:  800/3498 LR: 0.0000666667 Loss content:  0.7075 Loss fft:  9.8320
# Time:  0.1871 Epoch: 002 Iter:  900/3498 LR: 0.0000666667 Loss content:  0.7070 Loss fft:  9.9683
# Time:  0.1872 Epoch: 002 Iter: 1000/3498 LR: 0.0000666667 Loss content:  0.7240 Loss fft: 10.0624
# Time:  0.1872 Epoch: 002 Iter: 1100/3498 LR: 0.0000666667 Loss content:  0.7221 Loss fft:  9.6237
# Time:  0.1873 Epoch: 002 Iter: 1200/3498 LR: 0.0000666667 Loss content:  0.7286 Loss fft: 10.0318
# Time:  0.1873 Epoch: 002 Iter: 1300/3498 LR: 0.0000666667 Loss content:  0.7326 Loss fft:  9.6819
# Time:  0.1872 Epoch: 002 Iter: 1400/3498 LR: 0.0000666667 Loss content:  0.7329 Loss fft:  9.7841
# Time:  0.1873 Epoch: 002 Iter: 1500/3498 LR: 0.0000666667 Loss content:  0.7122 Loss fft:  9.7371
# Time:  0.1874 Epoch: 002 Iter: 1600/3498 LR: 0.0000666667 Loss content:  0.7095 Loss fft:  9.6066
# Time:  0.1872 Epoch: 002 Iter: 1700/3498 LR: 0.0000666667 Loss content:  0.7328 Loss fft:  9.9604
# Time:  0.1872 Epoch: 002 Iter: 1800/3498 LR: 0.0000666667 Loss content:  0.7208 Loss fft:  9.6940
# Time:  0.1874 Epoch: 002 Iter: 1900/3498 LR: 0.0000666667 Loss content:  0.7207 Loss fft:  9.9441
# Time:  0.1872 Epoch: 002 Iter: 2000/3498 LR: 0.0000666667 Loss content:  0.7181 Loss fft:  9.8150
# Time:  0.1874 Epoch: 002 Iter: 2100/3498 LR: 0.0000666667 Loss content:  0.7162 Loss fft:  9.9809
# Time:  0.1874 Epoch: 002 Iter: 2200/3498 LR: 0.0000666667 Loss content:  0.7143 Loss fft:  9.8559
# Time:  0.1873 Epoch: 002 Iter: 2300/3498 LR: 0.0000666667 Loss content:  0.7272 Loss fft:  9.8280
# Time:  0.1872 Epoch: 002 Iter: 2400/3498 LR: 0.0000666667 Loss content:  0.7116 Loss fft:  9.7338
# Time:  0.1904 Epoch: 002 Iter: 2500/3498 LR: 0.0000666667 Loss content:  0.7334 Loss fft: 10.0327
# Time:  0.1871 Epoch: 002 Iter: 2600/3498 LR: 0.0000666667 Loss content:  0.7463 Loss fft:  9.6667
# Time:  0.1872 Epoch: 002 Iter: 2700/3498 LR: 0.0000666667 Loss content:  0.7292 Loss fft:  9.7199
# Time:  0.1872 Epoch: 002 Iter: 2800/3498 LR: 0.0000666667 Loss content:  0.7283 Loss fft: 10.0344
# Time:  0.1872 Epoch: 002 Iter: 2900/3498 LR: 0.0000666667 Loss content:  0.7158 Loss fft:  9.5143
# Time:  0.1874 Epoch: 002 Iter: 3000/3498 LR: 0.0000666667 Loss content:  0.7430 Loss fft:  9.8315
# Time:  0.1872 Epoch: 002 Iter: 3100/3498 LR: 0.0000666667 Loss content:  0.7112 Loss fft:  9.6933
# Time:  0.1872 Epoch: 002 Iter: 3200/3498 LR: 0.0000666667 Loss content:  0.7234 Loss fft:  9.9674
# Time:  0.1872 Epoch: 002 Iter: 3300/3498 LR: 0.0000666667 Loss content:  0.7313 Loss fft:  9.6110
# Time:  0.1871 Epoch: 002 Iter: 3400/3498 LR: 0.0000666667 Loss content:  0.7104 Loss fft:  9.6698
# EPOCH: 02
# Elapsed time: 6.57 Epoch Pixel Loss:  0.7221 Epoch FFT Loss:  9.8255
# Time:  0.1968 Epoch: 003 Iter:  100/3498 LR: 0.0001000000 Loss content:  0.7212 Loss fft:  9.8178
# Time:  0.1872 Epoch: 003 Iter:  200/3498 LR: 0.0001000000 Loss content:  0.7263 Loss fft:  9.7696
# Time:  0.1871 Epoch: 003 Iter:  300/3498 LR: 0.0001000000 Loss content:  0.7251 Loss fft:  9.5843
# Time:  0.1872 Epoch: 003 Iter:  400/3498 LR: 0.0001000000 Loss content:  0.7317 Loss fft:  9.6216
# Time:  0.1873 Epoch: 003 Iter:  500/3498 LR: 0.0001000000 Loss content:  0.7144 Loss fft:  9.6940
# Time:  0.1872 Epoch: 003 Iter:  600/3498 LR: 0.0001000000 Loss content:  0.7236 Loss fft:  9.6783
# Time:  0.1873 Epoch: 003 Iter:  700/3498 LR: 0.0001000000 Loss content:  0.7342 Loss fft:  9.7991
# Time:  0.1871 Epoch: 003 Iter:  800/3498 LR: 0.0001000000 Loss content:  0.7125 Loss fft:  9.7721
# Time:  0.1871 Epoch: 003 Iter:  900/3498 LR: 0.0001000000 Loss content:  0.7229 Loss fft:  9.9112
# Time:  0.1872 Epoch: 003 Iter: 1000/3498 LR: 0.0001000000 Loss content:  0.7672 Loss fft:  9.7484
# Time:  0.1872 Epoch: 003 Iter: 1100/3498 LR: 0.0001000000 Loss content:  0.7451 Loss fft:  9.5792
# Time:  0.1922 Epoch: 003 Iter: 1200/3498 LR: 0.0001000000 Loss content:  0.7179 Loss fft:  9.6110
# Time:  0.1870 Epoch: 003 Iter: 1300/3498 LR: 0.0001000000 Loss content:  0.7317 Loss fft: 10.1794
# Time:  0.1871 Epoch: 003 Iter: 1400/3498 LR: 0.0001000000 Loss content:  0.7007 Loss fft:  9.4416
# Time:  0.1872 Epoch: 003 Iter: 1500/3498 LR: 0.0001000000 Loss content:  0.7156 Loss fft:  9.6145
# Time:  0.1872 Epoch: 003 Iter: 1600/3498 LR: 0.0001000000 Loss content:  0.7306 Loss fft:  9.9982
# Time:  0.1871 Epoch: 003 Iter: 1700/3498 LR: 0.0001000000 Loss content:  0.7080 Loss fft:  9.6405
# Time:  0.1871 Epoch: 003 Iter: 1800/3498 LR: 0.0001000000 Loss content:  0.7238 Loss fft:  9.5213
# Time:  0.1872 Epoch: 003 Iter: 1900/3498 LR: 0.0001000000 Loss content:  0.7139 Loss fft:  9.7186
# Time:  0.1872 Epoch: 003 Iter: 2000/3498 LR: 0.0001000000 Loss content:  0.7391 Loss fft:  9.7613
# Time:  0.1874 Epoch: 003 Iter: 2100/3498 LR: 0.0001000000 Loss content:  0.7045 Loss fft:  9.8317
# Time:  0.1873 Epoch: 003 Iter: 2200/3498 LR: 0.0001000000 Loss content:  0.7156 Loss fft:  9.9713
# Time:  0.1873 Epoch: 003 Iter: 2300/3498 LR: 0.0001000000 Loss content:  0.7685 Loss fft:  9.9369
# Time:  0.1872 Epoch: 003 Iter: 2400/3498 LR: 0.0001000000 Loss content:  0.7248 Loss fft:  9.9280
# Time:  0.1874 Epoch: 003 Iter: 2500/3498 LR: 0.0001000000 Loss content:  0.7248 Loss fft:  9.9921
# Time:  0.1872 Epoch: 003 Iter: 2600/3498 LR: 0.0001000000 Loss content:  0.7007 Loss fft: 10.0933
# Time:  0.1872 Epoch: 003 Iter: 2700/3498 LR: 0.0001000000 Loss content:  0.7109 Loss fft:  9.8011
# Time:  0.1872 Epoch: 003 Iter: 2800/3498 LR: 0.0001000000 Loss content:  0.7040 Loss fft:  9.9109
# Time:  0.1872 Epoch: 003 Iter: 2900/3498 LR: 0.0001000000 Loss content:  0.7153 Loss fft:  9.7946
# Time:  0.1872 Epoch: 003 Iter: 3000/3498 LR: 0.0001000000 Loss content:  0.7156 Loss fft:  9.9289
# Time:  0.1873 Epoch: 003 Iter: 3100/3498 LR: 0.0001000000 Loss content:  0.7028 Loss fft:  9.9881
# Time:  0.1873 Epoch: 003 Iter: 3200/3498 LR: 0.0001000000 Loss content:  0.6950 Loss fft:  9.7095
# Time:  0.1873 Epoch: 003 Iter: 3300/3498 LR: 0.0001000000 Loss content:  0.7071 Loss fft:  9.7711
# Time:  0.1904 Epoch: 003 Iter: 3400/3498 LR: 0.0001000000 Loss content:  0.7524 Loss fft:  9.9068
# EPOCH: 03
# Elapsed time: 6.57 Epoch Pixel Loss:  0.7219 Epoch FFT Loss:  9.8075
# /usr/local/lib/python3.10/dist-packages/torch/optim/lr_scheduler.py:809: UserWarning: To get the last learning rate computed by the scheduler, please use `get_last_lr()`.
#   warnings.warn("To get the last learning rate computed by the scheduler, "
# Time:  0.1957 Epoch: 004 Iter:  100/3498 LR: 0.0001000000 Loss content:  0.7137 Loss fft:  9.8561
# Time:  0.1871 Epoch: 004 Iter:  200/3498 LR: 0.0001000000 Loss content:  0.7169 Loss fft:  9.9771
# Time:  0.1872 Epoch: 004 Iter:  300/3498 LR: 0.0001000000 Loss content:  0.7000 Loss fft:  9.7873
# Time:  0.1872 Epoch: 004 Iter:  400/3498 LR: 0.0001000000 Loss content:  0.7510 Loss fft:  9.9291
# Time:  0.1875 Epoch: 004 Iter:  500/3498 LR: 0.0001000000 Loss content:  0.7144 Loss fft:  9.9170
# Time:  0.1873 Epoch: 004 Iter:  600/3498 LR: 0.0001000000 Loss content:  0.7197 Loss fft:  9.9030
# Time:  0.1872 Epoch: 004 Iter:  700/3498 LR: 0.0001000000 Loss content:  0.7040 Loss fft:  9.9340
# Time:  0.1870 Epoch: 004 Iter:  800/3498 LR: 0.0001000000 Loss content:  0.7290 Loss fft:  9.9439
# Time:  0.1872 Epoch: 004 Iter:  900/3498 LR: 0.0001000000 Loss content:  0.7294 Loss fft:  9.9459
# Time:  0.1872 Epoch: 004 Iter: 1000/3498 LR: 0.0001000000 Loss content:  0.7040 Loss fft:  9.9018
# Time:  0.1872 Epoch: 004 Iter: 1100/3498 LR: 0.0001000000 Loss content:  0.7257 Loss fft:  9.9302
# Time:  0.1871 Epoch: 004 Iter: 1200/3498 LR: 0.0001000000 Loss content:  0.7338 Loss fft:  9.5532
# Time:  0.1871 Epoch: 004 Iter: 1300/3498 LR: 0.0001000000 Loss content:  0.7060 Loss fft:  9.9556
# Time:  0.1871 Epoch: 004 Iter: 1400/3498 LR: 0.0001000000 Loss content:  0.7238 Loss fft:  9.6855
# Time:  0.1871 Epoch: 004 Iter: 1500/3498 LR: 0.0001000000 Loss content:  0.7339 Loss fft:  9.8433
# Time:  0.1875 Epoch: 004 Iter: 1600/3498 LR: 0.0001000000 Loss content:  0.7201 Loss fft:  9.8672
# Time:  0.1871 Epoch: 004 Iter: 1700/3498 LR: 0.0001000000 Loss content:  0.7380 Loss fft:  9.8792
# Time:  0.1871 Epoch: 004 Iter: 1800/3498 LR: 0.0001000000 Loss content:  0.7164 Loss fft:  9.9962
# Time:  0.1872 Epoch: 004 Iter: 1900/3498 LR: 0.0001000000 Loss content:  0.7459 Loss fft:  9.7929
# Time:  0.1871 Epoch: 004 Iter: 2000/3498 LR: 0.0001000000 Loss content:  0.6995 Loss fft:  9.7451
# Time:  0.1916 Epoch: 004 Iter: 2100/3498 LR: 0.0001000000 Loss content:  0.7035 Loss fft:  9.6108
# Time:  0.1873 Epoch: 004 Iter: 2200/3498 LR: 0.0001000000 Loss content:  0.7399 Loss fft:  9.7765
# Time:  0.1872 Epoch: 004 Iter: 2300/3498 LR: 0.0001000000 Loss content:  0.6960 Loss fft:  9.6854
# Time:  0.1874 Epoch: 004 Iter: 2400/3498 LR: 0.0001000000 Loss content:  0.7345 Loss fft:  9.8284
# Time:  0.1874 Epoch: 004 Iter: 2500/3498 LR: 0.0001000000 Loss content:  0.7284 Loss fft:  9.7715
# Time:  0.1872 Epoch: 004 Iter: 2600/3498 LR: 0.0001000000 Loss content:  0.7173 Loss fft:  9.6068
# Time:  0.1871 Epoch: 004 Iter: 2700/3498 LR: 0.0001000000 Loss content:  0.7145 Loss fft:  9.6528
# Time:  0.1873 Epoch: 004 Iter: 2800/3498 LR: 0.0001000000 Loss content:  0.7145 Loss fft:  9.7989
# Time:  0.1871 Epoch: 004 Iter: 2900/3498 LR: 0.0001000000 Loss content:  0.7206 Loss fft:  9.8051
# Time:  0.1873 Epoch: 004 Iter: 3000/3498 LR: 0.0001000000 Loss content:  0.7424 Loss fft:  9.9215
# Time:  0.1873 Epoch: 004 Iter: 3100/3498 LR: 0.0001000000 Loss content:  0.7064 Loss fft:  9.9476
# Time:  0.1871 Epoch: 004 Iter: 3200/3498 LR: 0.0001000000 Loss content:  0.7338 Loss fft:  9.6436
# Time:  0.1871 Epoch: 004 Iter: 3300/3498 LR: 0.0001000000 Loss content:  0.7370 Loss fft: 10.2604
# Time:  0.1872 Epoch: 004 Iter: 3400/3498 LR: 0.0001000000 Loss content:  0.7282 Loss fft:  9.7295
# EPOCH: 04
# Elapsed time: 6.56 Epoch Pixel Loss:  0.7212 Epoch FFT Loss:  9.8301
# Time:  0.1959 Epoch: 005 Iter:  100/3498 LR: 0.0000983215 Loss content:  0.6984 Loss fft:  9.7913
# Time:  0.1871 Epoch: 005 Iter:  200/3498 LR: 0.0000983215 Loss content:  0.7099 Loss fft:  9.9030
# Time:  0.1871 Epoch: 005 Iter:  300/3498 LR: 0.0000983215 Loss content:  0.6987 Loss fft:  9.8586
# Time:  0.1872 Epoch: 005 Iter:  400/3498 LR: 0.0000983215 Loss content:  0.7162 Loss fft:  9.6785
# Time:  0.1871 Epoch: 005 Iter:  500/3498 LR: 0.0000983215 Loss content:  0.6816 Loss fft:  9.6073
# Time:  0.1871 Epoch: 005 Iter:  600/3498 LR: 0.0000983215 Loss content:  0.7313 Loss fft: 10.0369
# Time:  0.1870 Epoch: 005 Iter:  700/3498 LR: 0.0000983215 Loss content:  0.7391 Loss fft:  9.8544
# Time:  0.1918 Epoch: 005 Iter:  800/3498 LR: 0.0000983215 Loss content:  0.7107 Loss fft:  9.7239
# Time:  0.1872 Epoch: 005 Iter:  900/3498 LR: 0.0000983215 Loss content:  0.7133 Loss fft:  9.7648
# Time:  0.1871 Epoch: 005 Iter: 1000/3498 LR: 0.0000983215 Loss content:  0.7312 Loss fft:  9.8692
# Time:  0.1872 Epoch: 005 Iter: 1100/3498 LR: 0.0000983215 Loss content:  0.7171 Loss fft:  9.8381
# Time:  0.1871 Epoch: 005 Iter: 1200/3498 LR: 0.0000983215 Loss content:  0.7337 Loss fft:  9.7415
# Time:  0.1871 Epoch: 005 Iter: 1300/3498 LR: 0.0000983215 Loss content:  0.7350 Loss fft:  9.7974
# Time:  0.1870 Epoch: 005 Iter: 1400/3498 LR: 0.0000983215 Loss content:  0.7264 Loss fft:  9.8719
# Time:  0.1871 Epoch: 005 Iter: 1500/3498 LR: 0.0000983215 Loss content:  0.7204 Loss fft:  9.9612
# Time:  0.1870 Epoch: 005 Iter: 1600/3498 LR: 0.0000983215 Loss content:  0.7011 Loss fft:  9.9770
# Time:  0.1872 Epoch: 005 Iter: 1700/3498 LR: 0.0000983215 Loss content:  0.7145 Loss fft:  9.7045
# Time:  0.1872 Epoch: 005 Iter: 1800/3498 LR: 0.0000983215 Loss content:  0.7180 Loss fft:  9.8965
# Time:  0.1874 Epoch: 005 Iter: 1900/3498 LR: 0.0000983215 Loss content:  0.6984 Loss fft:  9.7482
# Time:  0.1872 Epoch: 005 Iter: 2000/3498 LR: 0.0000983215 Loss content:  0.7468 Loss fft:  9.7132
# Time:  0.1873 Epoch: 005 Iter: 2100/3498 LR: 0.0000983215 Loss content:  0.7178 Loss fft: 10.0920
# Time:  0.1871 Epoch: 005 Iter: 2200/3498 LR: 0.0000983215 Loss content:  0.7160 Loss fft:  9.7418
# Time:  0.1871 Epoch: 005 Iter: 2300/3498 LR: 0.0000983215 Loss content:  0.7363 Loss fft:  9.5832
# Time:  0.1871 Epoch: 005 Iter: 2400/3498 LR: 0.0000983215 Loss content:  0.7291 Loss fft:  9.5838
# Time:  0.1873 Epoch: 005 Iter: 2500/3498 LR: 0.0000983215 Loss content:  0.7280 Loss fft:  9.9276
# Time:  0.1871 Epoch: 005 Iter: 2600/3498 LR: 0.0000983215 Loss content:  0.7243 Loss fft:  9.7230
# Time:  0.1871 Epoch: 005 Iter: 2700/3498 LR: 0.0000983215 Loss content:  0.7163 Loss fft:  9.9744
# Time:  0.1870 Epoch: 005 Iter: 2800/3498 LR: 0.0000983215 Loss content:  0.7206 Loss fft:  9.8388
# Time:  0.1870 Epoch: 005 Iter: 2900/3498 LR: 0.0000983215 Loss content:  0.7164 Loss fft:  9.9797
# Time:  0.1871 Epoch: 005 Iter: 3000/3498 LR: 0.0000983215 Loss content:  0.7164 Loss fft:  9.5566
# Time:  0.1904 Epoch: 005 Iter: 3100/3498 LR: 0.0000983215 Loss content:  0.7187 Loss fft:  9.8162
# Time:  0.1872 Epoch: 005 Iter: 3200/3498 LR: 0.0000983215 Loss content:  0.7092 Loss fft:  9.7538
# Time:  0.1872 Epoch: 005 Iter: 3300/3498 LR: 0.0000983215 Loss content:  0.7273 Loss fft:  9.9841
# Time:  0.1871 Epoch: 005 Iter: 3400/3498 LR: 0.0000983215 Loss content:  0.7103 Loss fft:  9.4448
# EPOCH: 05
# Elapsed time: 6.57 Epoch Pixel Loss:  0.7183 Epoch FFT Loss:  9.8023
# Time:  0.1966 Epoch: 006 Iter:  100/3498 LR: 0.0000942212 Loss content:  0.7168 Loss fft:  9.8278
# Time:  0.1874 Epoch: 006 Iter:  200/3498 LR: 0.0000942212 Loss content:  0.7454 Loss fft:  9.8365
# Time:  0.1873 Epoch: 006 Iter:  300/3498 LR: 0.0000942212 Loss content:  0.7553 Loss fft:  9.8940
# Time:  0.1873 Epoch: 006 Iter:  400/3498 LR: 0.0000942212 Loss content:  0.7461 Loss fft:  9.7397
# Time:  0.1872 Epoch: 006 Iter:  500/3498 LR: 0.0000942212 Loss content:  0.7312 Loss fft:  9.7773
# Time:  0.1872 Epoch: 006 Iter:  600/3498 LR: 0.0000942212 Loss content:  0.7333 Loss fft:  9.9793
# Time:  0.1873 Epoch: 006 Iter:  700/3498 LR: 0.0000942212 Loss content:  0.7083 Loss fft:  9.5499
# Time:  0.1873 Epoch: 006 Iter:  800/3498 LR: 0.0000942212 Loss content:  0.7285 Loss fft: 10.1449
# Time:  0.1873 Epoch: 006 Iter:  900/3498 LR: 0.0000942212 Loss content:  0.7178 Loss fft:  9.7428
# Time:  0.1873 Epoch: 006 Iter: 1000/3498 LR: 0.0000942212 Loss content:  0.7024 Loss fft:  9.8275
# Time:  0.1872 Epoch: 006 Iter: 1100/3498 LR: 0.0000942212 Loss content:  0.7117 Loss fft:  9.8064
# Time:  0.1874 Epoch: 006 Iter: 1200/3498 LR: 0.0000942212 Loss content:  0.7157 Loss fft:  9.9028
# Time:  0.1873 Epoch: 006 Iter: 1300/3498 LR: 0.0000942212 Loss content:  0.7156 Loss fft:  9.8496
# Time:  0.1875 Epoch: 006 Iter: 1400/3498 LR: 0.0000942212 Loss content:  0.7120 Loss fft:  9.7968
# Time:  0.1872 Epoch: 006 Iter: 1500/3498 LR: 0.0000942212 Loss content:  0.7122 Loss fft:  9.8462
# Time:  0.1873 Epoch: 006 Iter: 1600/3498 LR: 0.0000942212 Loss content:  0.7102 Loss fft:  9.8704
# Time:  0.1873 Epoch: 006 Iter: 1700/3498 LR: 0.0000942212 Loss content:  0.7041 Loss fft:  9.9853
# Time:  0.1924 Epoch: 006 Iter: 1800/3498 LR: 0.0000942212 Loss content:  0.7025 Loss fft:  9.6742
# Time:  0.1874 Epoch: 006 Iter: 1900/3498 LR: 0.0000942212 Loss content:  0.7162 Loss fft:  9.4465
# Time:  0.1873 Epoch: 006 Iter: 2000/3498 LR: 0.0000942212 Loss content:  0.6996 Loss fft:  9.6102
# Time:  0.1873 Epoch: 006 Iter: 2100/3498 LR: 0.0000942212 Loss content:  0.7194 Loss fft:  9.8376
# Time:  0.1875 Epoch: 006 Iter: 2200/3498 LR: 0.0000942212 Loss content:  0.7194 Loss fft:  9.5434
# Time:  0.1873 Epoch: 006 Iter: 2300/3498 LR: 0.0000942212 Loss content:  0.7372 Loss fft:  9.8842
# Time:  0.1875 Epoch: 006 Iter: 2400/3498 LR: 0.0000942212 Loss content:  0.7185 Loss fft:  9.6421
# Time:  0.1875 Epoch: 006 Iter: 2500/3498 LR: 0.0000942212 Loss content:  0.7261 Loss fft:  9.7419
# Time:  0.1875 Epoch: 006 Iter: 2600/3498 LR: 0.0000942212 Loss content:  0.7290 Loss fft:  9.8093
# Time:  0.1875 Epoch: 006 Iter: 2700/3498 LR: 0.0000942212 Loss content:  0.6996 Loss fft:  9.6766
# Time:  0.1876 Epoch: 006 Iter: 2800/3498 LR: 0.0000942212 Loss content:  0.7185 Loss fft:  9.6560
# Time:  0.1875 Epoch: 006 Iter: 2900/3498 LR: 0.0000942212 Loss content:  0.7005 Loss fft:  9.6861
# Time:  0.1875 Epoch: 006 Iter: 3000/3498 LR: 0.0000942212 Loss content:  0.7142 Loss fft:  9.7888
# Time:  0.1874 Epoch: 006 Iter: 3100/3498 LR: 0.0000942212 Loss content:  0.7033 Loss fft:  9.7968
# Time:  0.1874 Epoch: 006 Iter: 3200/3498 LR: 0.0000942212 Loss content:  0.7136 Loss fft:  9.6614
# Time:  0.1878 Epoch: 006 Iter: 3300/3498 LR: 0.0000942212 Loss content:  0.7209 Loss fft:  9.6022
# Time:  0.1873 Epoch: 006 Iter: 3400/3498 LR: 0.0000942212 Loss content:  0.7230 Loss fft:  9.6592
# EPOCH: 06
# Elapsed time: 6.57 Epoch Pixel Loss:  0.7179 Epoch FFT Loss:  9.7683
# Time:  0.1968 Epoch: 007 Iter:  100/3498 LR: 0.0000886874 Loss content:  0.7095 Loss fft:  9.7275
# Time:  0.1873 Epoch: 007 Iter:  200/3498 LR: 0.0000886874 Loss content:  0.6888 Loss fft:  9.5237
# Time:  0.1874 Epoch: 007 Iter:  300/3498 LR: 0.0000886874 Loss content:  0.7194 Loss fft:  9.6004
# Time:  0.1874 Epoch: 007 Iter:  400/3498 LR: 0.0000886874 Loss content:  0.7228 Loss fft:  9.5517
# Time:  0.1921 Epoch: 007 Iter:  500/3498 LR: 0.0000886874 Loss content:  0.6984 Loss fft:  9.8034
# Time:  0.1874 Epoch: 007 Iter:  600/3498 LR: 0.0000886874 Loss content:  0.7102 Loss fft:  9.5716
# Time:  0.1871 Epoch: 007 Iter:  700/3498 LR: 0.0000886874 Loss content:  0.7144 Loss fft:  9.5556
# Time:  0.1873 Epoch: 007 Iter:  800/3498 LR: 0.0000886874 Loss content:  0.7221 Loss fft:  9.7126
# Time:  0.1872 Epoch: 007 Iter:  900/3498 LR: 0.0000886874 Loss content:  0.7137 Loss fft:  9.8397
# Time:  0.1874 Epoch: 007 Iter: 1100/3498 LR: 0.0000886874 Loss content:  0.7208 Loss fft:  9.6274
# Time:  0.1872 Epoch: 007 Iter: 1200/3498 LR: 0.0000886874 Loss content:  0.7127 Loss fft:  9.7107
# Time:  0.1873 Epoch: 007 Iter: 1300/3498 LR: 0.0000886874 Loss content:  0.7118 Loss fft:  9.5756
# Time:  0.1873 Epoch: 007 Iter: 1400/3498 LR: 0.0000886874 Loss content:  0.7445 Loss fft: 10.1423
# Time:  0.1872 Epoch: 007 Iter: 1500/3498 LR: 0.0000886874 Loss content:  0.7193 Loss fft:  9.8898
# Time:  0.1873 Epoch: 007 Iter: 1600/3498 LR: 0.0000886874 Loss content:  0.7112 Loss fft: 10.0278
# Time:  0.1876 Epoch: 007 Iter: 1700/3498 LR: 0.0000886874 Loss content:  0.7022 Loss fft:  9.8411
# Time:  0.1878 Epoch: 007 Iter: 1800/3498 LR: 0.0000886874 Loss content:  0.7372 Loss fft:  9.8881
# Time:  0.1875 Epoch: 007 Iter: 1900/3498 LR: 0.0000886874 Loss content:  0.6960 Loss fft:  9.8345
# Time:  0.1874 Epoch: 007 Iter: 2000/3498 LR: 0.0000886874 Loss content:  0.6886 Loss fft:  9.5699
# Time:  0.1875 Epoch: 007 Iter: 2100/3498 LR: 0.0000886874 Loss content:  0.7147 Loss fft:  9.6602
# Time:  0.1873 Epoch: 007 Iter: 2200/3498 LR: 0.0000886874 Loss content:  0.7292 Loss fft:  9.8869
# Time:  0.1873 Epoch: 007 Iter: 2300/3498 LR: 0.0000886874 Loss content:  0.7113 Loss fft:  9.8201
# Time:  0.1873 Epoch: 007 Iter: 2400/3498 LR: 0.0000886874 Loss content:  0.7094 Loss fft:  9.7859
# Time:  0.1875 Epoch: 007 Iter: 2500/3498 LR: 0.0000886874 Loss content:  0.7150 Loss fft:  9.5889
# Time:  0.1873 Epoch: 007 Iter: 2600/3498 LR: 0.0000886874 Loss content:  0.7359 Loss fft:  9.9659
# Time:  0.1906 Epoch: 007 Iter: 2700/3498 LR: 0.0000886874 Loss content:  0.6940 Loss fft:  9.5167
# Time:  0.1873 Epoch: 007 Iter: 2800/3498 LR: 0.0000886874 Loss content:  0.7441 Loss fft:  9.9296
# Time:  0.1873 Epoch: 007 Iter: 2900/3498 LR: 0.0000886874 Loss content:  0.7148 Loss fft: 10.0773
# Time:  0.1874 Epoch: 007 Iter: 3000/3498 LR: 0.0000886874 Loss content:  0.7279 Loss fft:  9.5368
# Time:  0.1875 Epoch: 007 Iter: 3100/3498 LR: 0.0000886874 Loss content:  0.7107 Loss fft:  9.7567
# Time:  0.1874 Epoch: 007 Iter: 3200/3498 LR: 0.0000886874 Loss content:  0.7184 Loss fft:  9.6805
# Time:  0.1873 Epoch: 007 Iter: 3300/3498 LR: 0.0000886874 Loss content:  0.7019 Loss fft:  9.9326
# Time:  0.1875 Epoch: 007 Iter: 3400/3498 LR: 0.0000886874 Loss content:  0.7479 Loss fft: 10.0047
# EPOCH: 07
# Elapsed time: 6.58 Epoch Pixel Loss:  0.7156 Epoch FFT Loss:  9.7621
# Time:  0.1966 Epoch: 008 Iter:  100/3498 LR: 0.0000819070 Loss content:  0.7012 Loss fft:  9.7325
# Time:  0.1874 Epoch: 008 Iter:  200/3498 LR: 0.0000819070 Loss content:  0.7295 Loss fft:  9.5773
# Time:  0.1873 Epoch: 008 Iter:  300/3498 LR: 0.0000819070 Loss content:  0.7212 Loss fft:  9.8036
# Time:  0.1872 Epoch: 008 Iter:  400/3498 LR: 0.0000819070 Loss content:  0.7185 Loss fft:  9.5942
# Time:  0.1874 Epoch: 008 Iter:  500/3498 LR: 0.0000819070 Loss content:  0.7179 Loss fft:  9.7174
# Time:  0.1875 Epoch: 008 Iter:  600/3498 LR: 0.0000819070 Loss content:  0.7126 Loss fft:  9.7798
# Time:  0.1875 Epoch: 008 Iter:  700/3498 LR: 0.0000819070 Loss content:  0.7080 Loss fft:  9.4840
# Time:  0.1873 Epoch: 008 Iter:  800/3498 LR: 0.0000819070 Loss content:  0.7121 Loss fft:  9.7407
# Time:  0.1872 Epoch: 008 Iter:  900/3498 LR: 0.0000819070 Loss content:  0.7195 Loss fft:  9.8468
# Time:  0.1873 Epoch: 008 Iter: 1000/3498 LR: 0.0000819070 Loss content:  0.7359 Loss fft: 10.0490
# ...
# Time:  0.1871 Epoch: 016 Iter: 1300/3498 LR: 0.0000151017 Loss content:  0.7278 Loss fft:  9.6855
# Time:  0.1872 Epoch: 016 Iter: 1400/3498 LR: 0.0000151017 Loss content:  0.7186 Loss fft: 10.0754
# Time:  0.1872 Epoch: 016 Iter: 1500/3498 LR: 0.0000151017 Loss content:  0.6972 Loss fft:  9.6917
# Time:  0.1874 Epoch: 016 Iter: 1600/3498 LR: 0.0000151017 Loss content:  0.7307 Loss fft:  9.7924
# Time:  0.1872 Epoch: 016 Iter: 1700/3498 LR: 0.0000151017 Loss content:  0.7203 Loss fft:  9.9832
# Time:  0.1872 Epoch: 016 Iter: 1800/3498 LR: 0.0000151017 Loss content:  0.7027 Loss fft:  9.7633
# Time:  0.1871 Epoch: 016 Iter: 1900/3498 LR: 0.0000151017 Loss content:  0.6768 Loss fft:  9.5769
# Time:  0.1872 Epoch: 016 Iter: 2000/3498 LR: 0.0000151017 Loss content:  0.7177 Loss fft:  9.4844
# Time:  0.1873 Epoch: 016 Iter: 2100/3498 LR: 0.0000151017 Loss content:  0.7125 Loss fft:  9.5663
# Time:  0.1872 Epoch: 016 Iter: 2200/3498 LR: 0.0000151017 Loss content:  0.7135 Loss fft:  9.8557
# Time:  0.1871 Epoch: 016 Iter: 2300/3498 LR: 0.0000151017 Loss content:  0.7088 Loss fft:  9.6316
# Time:  0.1908 Epoch: 016 Iter: 2400/3498 LR: 0.0000151017 Loss content:  0.7217 Loss fft:  9.8208
# Time:  0.1872 Epoch: 016 Iter: 2500/3498 LR: 0.0000151017 Loss content:  0.6967 Loss fft:  9.5746
# Time:  0.1874 Epoch: 016 Iter: 2600/3498 LR: 0.0000151017 Loss content:  0.6985 Loss fft:  9.4605
# Time:  0.1873 Epoch: 016 Iter: 2700/3498 LR: 0.0000151017 Loss content:  0.7147 Loss fft:  9.6999
# Time:  0.1873 Epoch: 016 Iter: 2800/3498 LR: 0.0000151017 Loss content:  0.7053 Loss fft:  9.8361
# Time:  0.1875 Epoch: 016 Iter: 2900/3498 LR: 0.0000151017 Loss content:  0.7193 Loss fft:  9.5199
# Time:  0.1875 Epoch: 016 Iter: 3000/3498 LR: 0.0000151017 Loss content:  0.7011 Loss fft:  9.6616
# Time:  0.1876 Epoch: 016 Iter: 3100/3498 LR: 0.0000151017 Loss content:  0.7031 Loss fft:  9.8276
# Time:  0.1875 Epoch: 016 Iter: 3200/3498 LR: 0.0000151017 Loss content:  0.6868 Loss fft:  9.5576
# Time:  0.1874 Epoch: 016 Iter: 3300/3498 LR: 0.0000151017 Loss content:  0.6994 Loss fft:  9.8201
# Time:  0.1875 Epoch: 016 Iter: 3400/3498 LR: 0.0000151017 Loss content:  0.7009 Loss fft:  9.6188
# EPOCH: 16
# Elapsed time: 6.58 Epoch Pixel Loss:  0.7095 Epoch FFT Loss:  9.7224
# Time:  0.1962 Epoch: 017 Iter:  100/3498 LR: 0.0000094853 Loss content:  0.7171 Loss fft:  9.6989
# Time:  0.1871 Epoch: 017 Iter:  200/3498 LR: 0.0000094853 Loss content:  0.7390 Loss fft:  9.7503
# Time:  0.1873 Epoch: 017 Iter:  300/3498 LR: 0.0000094853 Loss content:  0.6974 Loss fft:  9.4238
# Time:  0.1874 Epoch: 017 Iter:  400/3498 LR: 0.0000094853 Loss content:  0.7120 Loss fft:  9.9617
# Time:  0.1872 Epoch: 017 Iter:  500/3498 LR: 0.0000094853 Loss content:  0.7111 Loss fft:  9.3559
# Time:  0.1875 Epoch: 017 Iter:  600/3498 LR: 0.0000094853 Loss content:  0.7242 Loss fft:  9.7737
# Time:  0.1873 Epoch: 017 Iter:  700/3498 LR: 0.0000094853 Loss content:  0.7132 Loss fft:  9.7692
# Time:  0.1874 Epoch: 017 Iter:  800/3498 LR: 0.0000094853 Loss content:  0.7314 Loss fft:  9.7866
# Time:  0.1874 Epoch: 017 Iter:  900/3498 LR: 0.0000094853 Loss content:  0.7015 Loss fft:  9.6266
# Time:  0.1873 Epoch: 017 Iter: 1000/3498 LR: 0.0000094853 Loss content:  0.7218 Loss fft:  9.9901
# Time:  0.1923 Epoch: 017 Iter: 1100/3498 LR: 0.0000094853 Loss content:  0.6995 Loss fft:  9.7340
# Time:  0.1876 Epoch: 017 Iter: 1200/3498 LR: 0.0000094853 Loss content:  0.6795 Loss fft:  9.6976
# Time:  0.1876 Epoch: 017 Iter: 1300/3498 LR: 0.0000094853 Loss content:  0.7140 Loss fft:  9.8149
# Time:  0.1875 Epoch: 017 Iter: 1400/3498 LR: 0.0000094853 Loss content:  0.7084 Loss fft: 10.0855
# Time:  0.1877 Epoch: 017 Iter: 1500/3498 LR: 0.0000094853 Loss content:  0.7074 Loss fft:  9.5906
# Time:  0.1876 Epoch: 017 Iter: 1600/3498 LR: 0.0000094853 Loss content:  0.7031 Loss fft:  9.7695
# Time:  0.1875 Epoch: 017 Iter: 1700/3498 LR: 0.0000094853 Loss content:  0.7013 Loss fft:  9.5667
# Time:  0.1875 Epoch: 017 Iter: 1800/3498 LR: 0.0000094853 Loss content:  0.6987 Loss fft:  9.6242
# Time:  0.1875 Epoch: 017 Iter: 1900/3498 LR: 0.0000094853 Loss content:  0.6980 Loss fft:  9.8507
# Time:  0.1875 Epoch: 017 Iter: 2000/3498 LR: 0.0000094853 Loss content:  0.7455 Loss fft:  9.7485
# Time:  0.1876 Epoch: 017 Iter: 2100/3498 LR: 0.0000094853 Loss content:  0.7073 Loss fft:  9.7091
# Time:  0.1877 Epoch: 017 Iter: 2200/3498 LR: 0.0000094853 Loss content:  0.7215 Loss fft:  9.6624
# Time:  0.1878 Epoch: 017 Iter: 2300/3498 LR: 0.0000094853 Loss content:  0.7267 Loss fft:  9.8825
# Time:  0.1877 Epoch: 017 Iter: 2400/3498 LR: 0.0000094853 Loss content:  0.7020 Loss fft:  9.6348
# Time:  0.1876 Epoch: 017 Iter: 2500/3498 LR: 0.0000094853 Loss content:  0.7119 Loss fft:  9.8560
# Time:  0.1877 Epoch: 017 Iter: 2600/3498 LR: 0.0000094853 Loss content:  0.7010 Loss fft:  9.5030
# Time:  0.1874 Epoch: 017 Iter: 2700/3498 LR: 0.0000094853 Loss content:  0.7142 Loss fft:  9.7534
# Time:  0.1871 Epoch: 017 Iter: 2800/3498 LR: 0.0000094853 Loss content:  0.7083 Loss fft:  9.8042
# Time:  0.1872 Epoch: 017 Iter: 2900/3498 LR: 0.0000094853 Loss content:  0.7037 Loss fft:  9.8988
# Time:  0.1872 Epoch: 017 Iter: 3000/3498 LR: 0.0000094853 Loss content:  0.7030 Loss fft:  9.7270
# Time:  0.1871 Epoch: 017 Iter: 3100/3498 LR: 0.0000094853 Loss content:  0.6886 Loss fft:  9.6924
# Time:  0.1871 Epoch: 017 Iter: 3200/3498 LR: 0.0000094853 Loss content:  0.7025 Loss fft:  9.4728
# Time:  0.1872 Epoch: 017 Iter: 3300/3498 LR: 0.0000094853 Loss content:  0.7146 Loss fft:  9.7032
# Time:  0.1902 Epoch: 017 Iter: 3400/3498 LR: 0.0000094853 Loss content:  0.7130 Loss fft:  9.8048
# EPOCH: 17
# Elapsed time: 6.58 Epoch Pixel Loss:  0.7104 Epoch FFT Loss:  9.7297
# Time:  0.1960 Epoch: 018 Iter:  100/3498 LR: 0.0000052550 Loss content:  0.7169 Loss fft:  9.6699
# Time:  0.1871 Epoch: 018 Iter:  200/3498 LR: 0.0000052550 Loss content:  0.7108 Loss fft:  9.8301
# Time:  0.1872 Epoch: 018 Iter:  300/3498 LR: 0.0000052550 Loss content:  0.7193 Loss fft:  9.7340
# Time:  0.1872 Epoch: 018 Iter:  400/3498 LR: 0.0000052550 Loss content:  0.7081 Loss fft:  9.4945
# Time:  0.1875 Epoch: 018 Iter:  500/3498 LR: 0.0000052550 Loss content:  0.7174 Loss fft:  9.6409
# Time:  0.1874 Epoch: 018 Iter:  600/3498 LR: 0.0000052550 Loss content:  0.7342 Loss fft:  9.7478
# Time:  0.1872 Epoch: 018 Iter:  700/3498 LR: 0.0000052550 Loss content:  0.7184 Loss fft: 10.1079
# Time:  0.1873 Epoch: 018 Iter:  800/3498 LR: 0.0000052550 Loss content:  0.7079 Loss fft:  9.6987
# Time:  0.1872 Epoch: 018 Iter:  900/3498 LR: 0.0000052550 Loss content:  0.6849 Loss fft:  9.7298
# Time:  0.1873 Epoch: 018 Iter: 1000/3498 LR: 0.0000052550 Loss content:  0.7051 Loss fft:  9.7765
# Time:  0.1871 Epoch: 018 Iter: 1100/3498 LR: 0.0000052550 Loss content:  0.7287 Loss fft:  9.7487
# Time:  0.1872 Epoch: 018 Iter: 1200/3498 LR: 0.0000052550 Loss content:  0.7138 Loss fft:  9.8114
# Time:  0.1873 Epoch: 018 Iter: 1300/3498 LR: 0.0000052550 Loss content:  0.7080 Loss fft:  9.7130
# Time:  0.1874 Epoch: 018 Iter: 1400/3498 LR: 0.0000052550 Loss content:  0.7032 Loss fft:  9.5620
# Time:  0.1872 Epoch: 018 Iter: 1500/3498 LR: 0.0000052550 Loss content:  0.7235 Loss fft:  9.5518
# Time:  0.1871 Epoch: 018 Iter: 1600/3498 LR: 0.0000052550 Loss content:  0.6906 Loss fft:  9.7611
# Time:  0.1874 Epoch: 018 Iter: 1700/3498 LR: 0.0000052550 Loss content:  0.7205 Loss fft:  9.6337
# Time:  0.1873 Epoch: 018 Iter: 1800/3498 LR: 0.0000052550 Loss content:  0.7152 Loss fft:  9.8599
# Time:  0.1874 Epoch: 018 Iter: 1900/3498 LR: 0.0000052550 Loss content:  0.7056 Loss fft:  9.6325
# Time:  0.1874 Epoch: 018 Iter: 2000/3498 LR: 0.0000052550 Loss content:  0.7087 Loss fft:  9.9206
# Time:  0.1918 Epoch: 018 Iter: 2100/3498 LR: 0.0000052550 Loss content:  0.7022 Loss fft:  9.9595
# Time:  0.1874 Epoch: 018 Iter: 2200/3498 LR: 0.0000052550 Loss content:  0.7070 Loss fft:  9.5542
# Time:  0.1874 Epoch: 018 Iter: 2300/3498 LR: 0.0000052550 Loss content:  0.7126 Loss fft:  9.4100
# Time:  0.1874 Epoch: 018 Iter: 2400/3498 LR: 0.0000052550 Loss content:  0.7043 Loss fft:  9.5012
# Time:  0.1874 Epoch: 018 Iter: 2500/3498 LR: 0.0000052550 Loss content:  0.7176 Loss fft:  9.6321
# Time:  0.1873 Epoch: 018 Iter: 2600/3498 LR: 0.0000052550 Loss content:  0.6829 Loss fft:  9.7380
# Time:  0.1874 Epoch: 018 Iter: 2700/3498 LR: 0.0000052550 Loss content:  0.7246 Loss fft:  9.6301
# Time:  0.1873 Epoch: 018 Iter: 2800/3498 LR: 0.0000052550 Loss content:  0.7095 Loss fft:  9.7748
# Time:  0.1874 Epoch: 018 Iter: 2900/3498 LR: 0.0000052550 Loss content:  0.6885 Loss fft:  9.5069
# Time:  0.1874 Epoch: 018 Iter: 3000/3498 LR: 0.0000052550 Loss content:  0.7183 Loss fft:  9.4775
# Time:  0.1872 Epoch: 018 Iter: 3100/3498 LR: 0.0000052550 Loss content:  0.7198 Loss fft:  9.5829
# Time:  0.1873 Epoch: 018 Iter: 3200/3498 LR: 0.0000052550 Loss content:  0.6967 Loss fft:  9.6582
# Time:  0.1873 Epoch: 018 Iter: 3300/3498 LR: 0.0000052550 Loss content:  0.7227 Loss fft: 10.0041
# Time:  0.1873 Epoch: 018 Iter: 3400/3498 LR: 0.0000052550 Loss content:  0.7003 Loss fft: 10.0082
# EPOCH: 18
# Elapsed time: 6.57 Epoch Pixel Loss:  0.7099 Epoch FFT Loss:  9.7097
# Time:  0.1964 Epoch: 019 Iter:  100/3498 LR: 0.0000025070 Loss content:  0.7082 Loss fft:  9.7400
# Time:  0.1874 Epoch: 019 Iter:  200/3498 LR: 0.0000025070 Loss content:  0.7102 Loss fft:  9.4480
# Time:  0.1875 Epoch: 019 Iter:  300/3498 LR: 0.0000025070 Loss content:  0.7432 Loss fft:  9.6583
# Time:  0.1874 Epoch: 019 Iter:  400/3498 LR: 0.0000025070 Loss content:  0.7173 Loss fft:  9.7807
# Time:  0.1895 Epoch: 019 Iter:  500/3498 LR: 0.0000025070 Loss content:  0.7053 Loss fft:  9.5504
# Time:  0.1876 Epoch: 019 Iter:  600/3498 LR: 0.0000025070 Loss content:  0.7327 Loss fft:  9.6787
# Time:  0.1878 Epoch: 019 Iter:  700/3498 LR: 0.0000025070 Loss content:  0.7014 Loss fft:  9.4990
# Time:  0.1931 Epoch: 019 Iter:  800/3498 LR: 0.0000025070 Loss content:  0.7106 Loss fft:  9.7097
# Time:  0.1874 Epoch: 019 Iter:  900/3498 LR: 0.0000025070 Loss content:  0.6959 Loss fft:  9.7475
# Time:  0.1876 Epoch: 019 Iter: 1000/3498 LR: 0.0000025070 Loss content:  0.6753 Loss fft:  9.8706
# Time:  0.1873 Epoch: 019 Iter: 1100/3498 LR: 0.0000025070 Loss content:  0.6962 Loss fft:  9.7611
# Time:  0.1875 Epoch: 019 Iter: 1200/3498 LR: 0.0000025070 Loss content:  0.7152 Loss fft:  9.9092
# Time:  0.1875 Epoch: 019 Iter: 1300/3498 LR: 0.0000025070 Loss content:  0.7181 Loss fft:  9.7664
# Time:  0.1873 Epoch: 019 Iter: 1400/3498 LR: 0.0000025070 Loss content:  0.7164 Loss fft:  9.7502
# Time:  0.1872 Epoch: 019 Iter: 1500/3498 LR: 0.0000025070 Loss content:  0.7175 Loss fft:  9.8557
# Time:  0.1872 Epoch: 019 Iter: 1600/3498 LR: 0.0000025070 Loss content:  0.7074 Loss fft:  9.7491
# Time:  0.1874 Epoch: 019 Iter: 1700/3498 LR: 0.0000025070 Loss content:  0.7280 Loss fft:  9.7439
# Time:  0.1875 Epoch: 019 Iter: 1800/3498 LR: 0.0000025070 Loss content:  0.7110 Loss fft:  9.8038
# Time:  0.1875 Epoch: 019 Iter: 1900/3498 LR: 0.0000025070 Loss content:  0.6809 Loss fft:  9.9159
# Time:  0.1873 Epoch: 019 Iter: 2000/3498 LR: 0.0000025070 Loss content:  0.6837 Loss fft:  9.5505
# Time:  0.1874 Epoch: 019 Iter: 2100/3498 LR: 0.0000025070 Loss content:  0.7063 Loss fft:  9.5848
# Time:  0.1877 Epoch: 019 Iter: 2200/3498 LR: 0.0000025070 Loss content:  0.7232 Loss fft:  9.7853
# Time:  0.1873 Epoch: 019 Iter: 2300/3498 LR: 0.0000025070 Loss content:  0.6913 Loss fft:  9.5492
# Time:  0.1874 Epoch: 019 Iter: 2400/3498 LR: 0.0000025070 Loss content:  0.7227 Loss fft:  9.6614
# Time:  0.1874 Epoch: 019 Iter: 2500/3498 LR: 0.0000025070 Loss content:  0.7026 Loss fft:  9.4800
# Time:  0.1874 Epoch: 019 Iter: 2600/3498 LR: 0.0000025070 Loss content:  0.6967 Loss fft:  9.4990
# Time:  0.1874 Epoch: 019 Iter: 2700/3498 LR: 0.0000025070 Loss content:  0.7007 Loss fft:  9.8774
# Time:  0.1878 Epoch: 019 Iter: 2800/3498 LR: 0.0000025070 Loss content:  0.7122 Loss fft:  9.5035
# Time:  0.1876 Epoch: 019 Iter: 2900/3498 LR: 0.0000025070 Loss content:  0.7154 Loss fft:  9.7562
# Time:  0.1909 Epoch: 019 Iter: 3000/3498 LR: 0.0000025070 Loss content:  0.7022 Loss fft:  9.7484
# Time:  0.1875 Epoch: 019 Iter: 3100/3498 LR: 0.0000025070 Loss content:  0.7031 Loss fft:  9.6725
# Time:  0.1874 Epoch: 019 Iter: 3200/3498 LR: 0.0000025070 Loss content:  0.7057 Loss fft:  9.8078
# Time:  0.1875 Epoch: 019 Iter: 3300/3498 LR: 0.0000025070 Loss content:  0.6934 Loss fft:  9.5054
# Time:  0.1874 Epoch: 019 Iter: 3400/3498 LR: 0.0000025070 Loss content:  0.7012 Loss fft:  9.7470
# EPOCH: 19
# Elapsed time: 6.58 Epoch Pixel Loss:  0.7074 Epoch FFT Loss:  9.6872
# Time:  0.1975 Epoch: 020 Iter:  100/3498 LR: 0.0000012125 Loss content:  0.7151 Loss fft:  9.5190
# Time:  0.1874 Epoch: 020 Iter:  200/3498 LR: 0.0000012125 Loss content:  0.7244 Loss fft:  9.8356
# Time:  0.1873 Epoch: 020 Iter:  300/3498 LR: 0.0000012125 Loss content:  0.7215 Loss fft:  9.7556
# Time:  0.1875 Epoch: 020 Iter:  400/3498 LR: 0.0000012125 Loss content:  0.7321 Loss fft:  9.5918
# Time:  0.1873 Epoch: 020 Iter:  500/3498 LR: 0.0000012125 Loss content:  0.7113 Loss fft:  9.7763
# Time:  0.1877 Epoch: 020 Iter:  600/3498 LR: 0.0000012125 Loss content:  0.7206 Loss fft:  9.8635
# Time:  0.1878 Epoch: 020 Iter:  700/3498 LR: 0.0000012125 Loss content:  0.6986 Loss fft:  9.4704
# Time:  0.1875 Epoch: 020 Iter:  800/3498 LR: 0.0000012125 Loss content:  0.6991 Loss fft:  9.6741
# Time:  0.1874 Epoch: 020 Iter:  900/3498 LR: 0.0000012125 Loss content:  0.6943 Loss fft:  9.6859
# Time:  0.1874 Epoch: 020 Iter: 1000/3498 LR: 0.0000012125 Loss content:  0.7114 Loss fft:  9.8320
# Time:  0.1874 Epoch: 020 Iter: 1100/3498 LR: 0.0000012125 Loss content:  0.7022 Loss fft:  9.7954
# Time:  0.1875 Epoch: 020 Iter: 1200/3498 LR: 0.0000012125 Loss content:  0.7169 Loss fft:  9.5014
# Time:  0.1874 Epoch: 020 Iter: 1300/3498 LR: 0.0000012125 Loss content:  0.6967 Loss fft:  9.6363
# Time:  0.1875 Epoch: 020 Iter: 1400/3498 LR: 0.0000012125 Loss content:  0.7173 Loss fft:  9.5442
# Time:  0.1874 Epoch: 020 Iter: 1500/3498 LR: 0.0000012125 Loss content:  0.7013 Loss fft:  9.6648
# Time:  0.1874 Epoch: 020 Iter: 1600/3498 LR: 0.0000012125 Loss content:  0.7090 Loss fft:  9.5736
# Time:  0.1875 Epoch: 020 Iter: 1700/3498 LR: 0.0000012125 Loss content:  0.7181 Loss fft:  9.8048
# Time:  0.1922 Epoch: 020 Iter: 1800/3498 LR: 0.0000012125 Loss content:  0.7040 Loss fft:  9.8014
# Time:  0.1873 Epoch: 020 Iter: 1900/3498 LR: 0.0000012125 Loss content:  0.7368 Loss fft:  9.8308
# Time:  0.1874 Epoch: 020 Iter: 2000/3498 LR: 0.0000012125 Loss content:  0.7102 Loss fft:  9.8787
# Time:  0.1874 Epoch: 020 Iter: 2100/3498 LR: 0.0000012125 Loss content:  0.7171 Loss fft:  9.7137
# Time:  0.1874 Epoch: 020 Iter: 2200/3498 LR: 0.0000012125 Loss content:  0.7053 Loss fft:  9.7842
# Time:  0.1875 Epoch: 020 Iter: 2300/3498 LR: 0.0000012125 Loss content:  0.6999 Loss fft:  9.6588
# Time:  0.1872 Epoch: 020 Iter: 2400/3498 LR: 0.0000012125 Loss content:  0.6919 Loss fft:  9.5870
# Time:  0.1873 Epoch: 020 Iter: 2500/3498 LR: 0.0000012125 Loss content:  0.7079 Loss fft:  9.6706
# Time:  0.1876 Epoch: 020 Iter: 2600/3498 LR: 0.0000012125 Loss content:  0.6976 Loss fft:  9.6638
# Time:  0.1875 Epoch: 020 Iter: 2700/3498 LR: 0.0000012125 Loss content:  0.6977 Loss fft:  9.8063
# Time:  0.1876 Epoch: 020 Iter: 2800/3498 LR: 0.0000012125 Loss content:  0.7162 Loss fft:  9.4723
# Time:  0.1873 Epoch: 020 Iter: 2900/3498 LR: 0.0000012125 Loss content:  0.6850 Loss fft:  9.7989
# Time:  0.1872 Epoch: 020 Iter: 3000/3498 LR: 0.0000012125 Loss content:  0.6989 Loss fft:  9.8128
# Time:  0.1873 Epoch: 020 Iter: 3100/3498 LR: 0.0000012125 Loss content:  0.7201 Loss fft:  9.6302
# Time:  0.1873 Epoch: 020 Iter: 3200/3498 LR: 0.0000012125 Loss content:  0.6803 Loss fft:  9.8384
# Time:  0.1874 Epoch: 020 Iter: 3300/3498 LR: 0.0000012125 Loss content:  0.7179 Loss fft:  9.8572
# Time:  0.1873 Epoch: 020 Iter: 3400/3498 LR: 0.0000012125 Loss content:  0.7024 Loss fft:  9.5167
# EPOCH: 20
# Elapsed time: 6.58 Epoch Pixel Loss:  0.7087 Epoch FFT Loss:  9.7032
# Start Evaluation
# 499
#
# 020 epoch
#  Average PSNR 12.06 dB

# %%
state_last = torch.load('/content/drive/MyDrive/MYresults/IRNeXt/ITS/model.pkl')

# %% [markdown]
# Test
# ==

# %%
import os
import torch
import torchvision.transforms as transforms
# from torch.backends import cudnn # Uncomment if you need it

class Args:
    model_name = 'IRNeXt'
    mode = 'test'
    data_dir = path

    # Train
    batch_size = 4
    learning_rate = 1e-4
    weight_decay = 0
    num_epoch = 20
    print_freq = 100
    num_worker = 8
    save_freq = 10
    valid_freq = 10
    momentum_value = 0.6

    resume = ''
    #/content/drive/MyDrive/MYresults2/IRNeXt/ITS/model.pkl
    # Test
    test_model = '/content/drive/MyDrive/MYresults2__6/IRNeXt/ITS/Final.pkl'
    save_image = False

    # Directories (set these as per your requirement)
    model_save_dir = os.path.join('/content/drive/MyDrive/MYresults2__6/', 'IRNeXt', 'ITS/')
    result_dir = os.path.join('/content/drive/MyDrive/MYresults2__6/', model_name, 'test')

def main(args):
    # CUDNN
    # cudnn.benchmark = True # Uncomment if you need it

    if not os.path.exists('/content/drive/MyDrive/MYresults2__6/'):
        os.makedirs(args.model_save_dir)
    if not os.path.exists('/content/drive/MyDrive/MYresults2__6/' + args.model_name + '/'):
        os.makedirs('/content/drive/MyDrive/MYresults2__6/' + args.model_name + '/')
    if not os.path.exists(args.model_save_dir):
        os.makedirs(args.model_save_dir)
    if not os.path.exists(args.result_dir):
        os.makedirs(args.result_dir)

    model = build_net()  # Make sure to define build_net or import it if it's defined elsewhere
    print(model)

    if torch.cuda.is_available():
        model.cuda()
    if args.mode == 'train':
        _train(model, args)  # Make sure to define _train or import it if it's defined elsewhere

    elif args.mode == 'test':
        _eval(model, args)   # Make sure to define _eval or import it if it's defined elsewhere

# Replace parser.parse_args() with an instance of the Args class
args = Args()
if not os.path.exists(args.model_save_dir):
    os.makedirs(args.model_save_dir)
# Copying files (make sure these paths are correct)
command = 'cp ' + 'models/layers.py ' + args.model_save_dir
os.system(command)
command = 'cp ' + 'models/IRNeXt.py ' + args.model_save_dir
os.system(command)
command = 'cp ' + 'train.py ' + args.model_save_dir
os.system(command)
command = 'cp ' + 'main.py ' + args.model_save_dir
os.system(command)
print(args)
main(args)
# Out:
# <__main__.Args object at 0x7b030bfffcd0>
# IRNeXt(
#   (Encoder): ModuleList(
#     (0): EBlock(
#       (layers): Sequential(
#         (0): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (1): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (2): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (3): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): DeepPoolLayer(
#               (pools): ModuleList(
#                 (0): AvgPool2d(kernel_size=8, stride=8, padding=0)
#                 (1): AvgPool2d(kernel_size=4, stride=4, padding=0)
#                 (2): AvgPool2d(kernel_size=2, stride=2, padding=0)
#               )
#               (convs): ModuleList(
#                 (0-2): 3 x Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#               (dynas): ModuleList(
#                 (0-2): 3 x dynamic_filter(
#                   (conv): Conv2d(32, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (bn): BatchNorm2d(72, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (act): Tanh()
#                   (pad): ReflectionPad2d((1, 1, 1, 1))
#                   (ap): AdaptiveAvgPool2d(output_size=(1, 1))
#                   (gap): AdaptiveAvgPool2d(output_size=1)
#                 )
#               )
#               (relu): GELU(approximate='none')
#               (conv_sum): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             )
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#       )
#     )
#     (1): EBlock(
#       (layers): Sequential(
#         (0): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (1): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (2): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (3): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): DeepPoolLayer(
#               (pools): ModuleList(
#                 (0): AvgPool2d(kernel_size=8, stride=8, padding=0)
#                 (1): AvgPool2d(kernel_size=4, stride=4, padding=0)
#                 (2): AvgPool2d(kernel_size=2, stride=2, padding=0)
#               )
#               (convs): ModuleList(
#                 (0-2): 3 x Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#               (dynas): ModuleList(
#                 (0-2): 3 x dynamic_filter(
#                   (conv): Conv2d(64, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (bn): BatchNorm2d(72, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (act): Tanh()
#                   (pad): ReflectionPad2d((1, 1, 1, 1))
#                   (ap): AdaptiveAvgPool2d(output_size=(1, 1))
#                   (gap): AdaptiveAvgPool2d(output_size=1)
#                 )
#               )
#               (relu): GELU(approximate='none')
#               (conv_sum): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             )
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#       )
#     )
#     (2): EBlock(
#       (layers): Sequential(
#         (0): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (1): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (2): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (3): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): DeepPoolLayer(
#               (pools): ModuleList(
#                 (0): AvgPool2d(kernel_size=8, stride=8, padding=0)
#                 (1): AvgPool2d(kernel_size=4, stride=4, padding=0)
#                 (2): AvgPool2d(kernel_size=2, stride=2, padding=0)
#               )
#               (convs): ModuleList(
#                 (0-2): 3 x Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#               (dynas): ModuleList(
#                 (0-2): 3 x dynamic_filter(
#                   (conv): Conv2d(128, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (bn): BatchNorm2d(72, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (act): Tanh()
#                   (pad): ReflectionPad2d((1, 1, 1, 1))
#                   (ap): AdaptiveAvgPool2d(output_size=(1, 1))
#                   (gap): AdaptiveAvgPool2d(output_size=1)
#                 )
#               )
#               (relu): GELU(approximate='none')
#               (conv_sum): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             )
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#       )
#     )
#   )
#   (feat_extract): ModuleList(
#     (0): BasicConv(
#       (main): Sequential(
#         (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): GELU(approximate='none')
#       )
#     )
#     (1): BasicConv(
#       (main): Sequential(
#         (0): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         (1): GELU(approximate='none')
#       )
#     )
#     (2): BasicConv(
#       (main): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         (1): GELU(approximate='none')
#       )
#     )
#     (3): BasicConv(
#       (main): Sequential(
#         (0): ConvTranspose2d(128, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#         (1): GELU(approximate='none')
#       )
#     )
#     (4): BasicConv(
#       (main): Sequential(
#         (0): ConvTranspose2d(64, 32, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#         (1): GELU(approximate='none')
#       )
#     )
#     (5): BasicConv(
#       (main): Sequential(
#         (0): Conv2d(32, 3, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#     )
#   )
#   (Decoder): ModuleList(
#     (0): DBlock(
#       (layers): Sequential(
#         (0): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (1): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (2): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (3): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): DeepPoolLayer(
#               (pools): ModuleList(
#                 (0): AvgPool2d(kernel_size=8, stride=8, padding=0)
#                 (1): AvgPool2d(kernel_size=4, stride=4, padding=0)
#                 (2): AvgPool2d(kernel_size=2, stride=2, padding=0)
#               )
#               (convs): ModuleList(
#                 (0-2): 3 x Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#               (dynas): ModuleList(
#                 (0-2): 3 x dynamic_filter(
#                   (conv): Conv2d(128, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (bn): BatchNorm2d(72, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (act): Tanh()
#                   (pad): ReflectionPad2d((1, 1, 1, 1))
#                   (ap): AdaptiveAvgPool2d(output_size=(1, 1))
#                   (gap): AdaptiveAvgPool2d(output_size=1)
#                 )
#               )
#               (relu): GELU(approximate='none')
#               (conv_sum): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             )
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#       )
#     )
#     (1): DBlock(
#       (layers): Sequential(
#         (0): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (1): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (2): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (3): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): DeepPoolLayer(
#               (pools): ModuleList(
#                 (0): AvgPool2d(kernel_size=8, stride=8, padding=0)
#                 (1): AvgPool2d(kernel_size=4, stride=4, padding=0)
#                 (2): AvgPool2d(kernel_size=2, stride=2, padding=0)
#               )
#               (convs): ModuleList(
#                 (0-2): 3 x Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#               (dynas): ModuleList(
#                 (0-2): 3 x dynamic_filter(
#                   (conv): Conv2d(64, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (bn): BatchNorm2d(72, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (act): Tanh()
#                   (pad): ReflectionPad2d((1, 1, 1, 1))
#                   (ap): AdaptiveAvgPool2d(output_size=(1, 1))
#                   (gap): AdaptiveAvgPool2d(output_size=1)
#                 )
#               )
#               (relu): GELU(approximate='none')
#               (conv_sum): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             )
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#       )
#     )
#     (2): DBlock(
#       (layers): Sequential(
#         (0): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (1): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (2): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): Identity()
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#         (3): ResBlock(
#           (main): Sequential(
#             (0): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (1): GELU(approximate='none')
#               )
#             )
#             (1): DeepPoolLayer(
#               (pools): ModuleList(
#                 (0): AvgPool2d(kernel_size=8, stride=8, padding=0)
#                 (1): AvgPool2d(kernel_size=4, stride=4, padding=0)
#                 (2): AvgPool2d(kernel_size=2, stride=2, padding=0)
#               )
#               (convs): ModuleList(
#                 (0-2): 3 x Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#               (dynas): ModuleList(
#                 (0-2): 3 x dynamic_filter(
#                   (conv): Conv2d(32, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (bn): BatchNorm2d(72, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (act): Tanh()
#                   (pad): ReflectionPad2d((1, 1, 1, 1))
#                   (ap): AdaptiveAvgPool2d(output_size=(1, 1))
#                   (gap): AdaptiveAvgPool2d(output_size=1)
#                 )
#               )
#               (relu): GELU(approximate='none')
#               (conv_sum): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             )
#             (2): BasicConv(
#               (main): Sequential(
#                 (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               )
#             )
#           )
#         )
#       )
#     )
#   )
#   (Convs): ModuleList(
#     (0): BasicConv(
#       (main): Sequential(
#         (0): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1))
#         (1): GELU(approximate='none')
#       )
#     )
#     (1): BasicConv(
#       (main): Sequential(
#         (0): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#         (1): GELU(approximate='none')
#       )
#     )
#   )
#   (ConvsOut): ModuleList(
#     (0): BasicConv(
#       (main): Sequential(
#         (0): Conv2d(128, 3, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#     )
#     (1): BasicConv(
#       (main): Sequential(
#         (0): Conv2d(64, 3, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#     )
#   )
#   (FAM1): FAM(
#     (merge): BasicConv(
#       (main): Sequential(
#         (0): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#     )
#   )
#   (SCM1): SCM(
#     (main): Sequential(
#       (0): BasicConv(
#         (main): Sequential(
#           (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): GELU(approximate='none')
#         )
#       )
#       (1): BasicConv(
#         (main): Sequential(
#           (0): Conv2d(32, 64, kernel_size=(1, 1), stride=(1, 1))
#           (1): GELU(approximate='none')
#         )
#       )
#       (2): BasicConv(
#         (main): Sequential(
#           (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): GELU(approximate='none')
#         )
#       )
#       (3): BasicConv(
#         (main): Sequential(
#           (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1))
#         )
#       )
#       (4): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#     )
#   )
#   (FAM2): FAM(
#     (merge): BasicConv(
#       (main): Sequential(
#         (0): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#     )
#   )
#   (SCM2): SCM(
#     (main): Sequential(
#       (0): BasicConv(
#         (main): Sequential(
#           (0): Conv2d(3, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): GELU(approximate='none')
#         )
#       )
#       (1): BasicConv(
#         (main): Sequential(
#           (0): Conv2d(16, 32, kernel_size=(1, 1), stride=(1, 1))
#           (1): GELU(approximate='none')
#         )
#       )
#       (2): BasicConv(
#         (main): Sequential(
#           (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): GELU(approximate='none')
#         )
#       )
#       (3): BasicConv(
#         (main): Sequential(
#           (0): Conv2d(32, 64, kernel_size=(1, 1), stride=(1, 1))
#         )
#       )
#       (4): InstanceNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#     )
#   )
# )
# 1 iter PSNR_dehazing: 14.72 ssim: 0.801705
# 1 iter PSNR: 14.72 time: 0.026559
# 2 iter PSNR_dehazing: 9.12 ssim: 0.645663
# 2 iter PSNR: 9.12 time: 0.019101
# 3 iter PSNR_dehazing: 13.68 ssim: 0.780814
# 3 iter PSNR: 13.68 time: 0.018770
# 4 iter PSNR_dehazing: 12.80 ssim: 0.761083
# 4 iter PSNR: 12.80 time: 0.019916
# 5 iter PSNR_dehazing: 12.05 ssim: 0.742288
# 5 iter PSNR: 12.05 time: 0.018245
# 6 iter PSNR_dehazing: 11.40 ssim: 0.724345
# 6 iter PSNR: 11.40 time: 0.018147
# 7 iter PSNR_dehazing: 10.83 ssim: 0.707183
# 7 iter PSNR: 10.83 time: 0.018323
# 8 iter PSNR_dehazing: 10.33 ssim: 0.690773
# 8 iter PSNR: 10.33 time: 0.020628
# 9 iter PSNR_dehazing: 9.88 ssim: 0.675061
# 9 iter PSNR: 9.88 time: 0.018151
# 10 iter PSNR_dehazing: 9.48 ssim: 0.660012
# 10 iter PSNR: 9.48 time: 0.018256
# 11 iter PSNR_dehazing: 17.64 ssim: 0.817612
# 11 iter PSNR: 17.64 time: 0.019711
# 12 iter PSNR_dehazing: 11.60 ssim: 0.695517
# 12 iter PSNR: 11.60 time: 0.018394
# 13 iter PSNR_dehazing: 16.57 ssim: 0.801391
# 13 iter PSNR: 16.57 time: 0.018143
# 14 iter PSNR_dehazing: 15.66 ssim: 0.786099
# 14 iter PSNR: 15.66 time: 0.018089
# 15 iter PSNR_dehazing: 14.86 ssim: 0.771529
# 15 iter PSNR: 14.86 time: 0.018132
# 16 iter PSNR_dehazing: 14.16 ssim: 0.757604
# 16 iter PSNR: 14.16 time: 0.018348
# 17 iter PSNR_dehazing: 13.54 ssim: 0.744218
# 17 iter PSNR: 13.54 time: 0.018823
# 18 iter PSNR_dehazing: 12.98 ssim: 0.731358
# 18 iter PSNR: 12.98 time: 0.018691
# 19 iter PSNR_dehazing: 12.48 ssim: 0.718959
# 19 iter PSNR: 12.48 time: 0.022776
# 20 iter PSNR_dehazing: 12.02 ssim: 0.707009
# 20 iter PSNR: 12.02 time: 0.019309
# 21 iter PSNR_dehazing: 16.14 ssim: 0.706566
# 21 iter PSNR: 16.14 time: 0.018610
# 22 iter PSNR_dehazing: 9.98 ssim: 0.544580
# 22 iter PSNR: 9.98 time: 0.018405
# 23 iter PSNR_dehazing: 15.04 ssim: 0.681367
# 23 iter PSNR: 15.04 time: 0.018682
# 24 iter PSNR_dehazing: 14.10 ssim: 0.658766
# 24 iter PSNR: 14.10 time: 0.019062
# 25 iter PSNR_dehazing: 13.28 ssim: 0.638232
# 25 iter PSNR: 13.28 time: 0.018547
# 26 iter PSNR_dehazing: 12.57 ssim: 0.619454
# 26 iter PSNR: 12.57 time: 0.018649
# 27 iter PSNR_dehazing: 11.94 ssim: 0.602166
# 27 iter PSNR: 11.94 time: 0.018493
# 28 iter PSNR_dehazing: 11.37 ssim: 0.586173
# 28 iter PSNR: 11.37 time: 0.018529
# 29 iter PSNR_dehazing: 10.86 ssim: 0.571351
# 29 iter PSNR: 10.86 time: 0.018890
# 30 iter PSNR_dehazing: 10.40 ssim: 0.557510
# 30 iter PSNR: 10.40 time: 0.018709
# 31 iter PSNR_dehazing: 13.46 ssim: 0.651235
# 31 iter PSNR: 13.46 time: 0.018777
# 32 iter PSNR_dehazing: 7.51 ssim: 0.463548
# 32 iter PSNR: 7.51 time: 0.018431
# 33 iter PSNR_dehazing: 12.36 ssim: 0.622752
# 33 iter PSNR: 12.36 time: 0.018865
# 34 iter PSNR_dehazing: 11.44 ssim: 0.596843
# 34 iter PSNR: 11.44 time: 0.018967
# 35 iter PSNR_dehazing: 10.65 ssim: 0.573126
# 35 iter PSNR: 10.65 time: 0.020576
# 36 iter PSNR_dehazing: 9.96 ssim: 0.551302
# 36 iter PSNR: 9.96 time: 0.019297
# 37 iter PSNR_dehazing: 9.35 ssim: 0.531114
# 37 iter PSNR: 9.35 time: 0.018840
# 38 iter PSNR_dehazing: 8.81 ssim: 0.512384
# 38 iter PSNR: 8.81 time: 0.018778
# 39 iter PSNR_dehazing: 8.33 ssim: 0.494976
# 39 iter PSNR: 8.33 time: 0.018905
# 40 iter PSNR_dehazing: 7.90 ssim: 0.478703
# 40 iter PSNR: 7.90 time: 0.018985
# 41 iter PSNR_dehazing: 16.24 ssim: 0.831364
# 41 iter PSNR: 16.24 time: 0.018572
# 42 iter PSNR_dehazing: 10.25 ssim: 0.647536
# 42 iter PSNR: 10.25 time: 0.018769
# 43 iter PSNR_dehazing: 15.15 ssim: 0.806563
# 43 iter PSNR: 15.15 time: 0.020522
# 44 iter PSNR_dehazing: 14.23 ssim: 0.783013
# 44 iter PSNR: 14.23 time: 0.018533
# 45 iter PSNR_dehazing: 13.44 ssim: 0.760655
# 45 iter PSNR: 13.44 time: 0.018586
# 46 iter PSNR_dehazing: 12.74 ssim: 0.739418
# 46 iter PSNR: 12.74 time: 0.019775
# 47 iter PSNR_dehazing: 12.13 ssim: 0.719208
# 47 iter PSNR: 12.13 time: 0.019298
# 48 iter PSNR_dehazing: 11.58 ssim: 0.699960
# 48 iter PSNR: 11.58 time: 0.018976
# 49 iter PSNR_dehazing: 11.09 ssim: 0.681632
# 49 iter PSNR: 11.09 time: 0.018683
# 50 iter PSNR_dehazing: 10.65 ssim: 0.664160
# 50 iter PSNR: 10.65 time: 0.018776
# 51 iter PSNR_dehazing: 15.96 ssim: 0.845198
# 51 iter PSNR: 15.96 time: 0.018827
# 52 iter PSNR_dehazing: 10.12 ssim: 0.669573
# 52 iter PSNR: 10.12 time: 0.019061
# 53 iter PSNR_dehazing: 14.89 ssim: 0.821367
# 53 iter PSNR: 14.89 time: 0.018564
# 54 iter PSNR_dehazing: 13.99 ssim: 0.798695
# 54 iter PSNR: 13.99 time: 0.018857
# 55 iter PSNR_dehazing: 13.21 ssim: 0.777161
# 55 iter PSNR: 13.21 time: 0.018609
# 56 iter PSNR_dehazing: 12.53 ssim: 0.756798
# 56 iter PSNR: 12.53 time: 0.018924
# 57 iter PSNR_dehazing: 11.94 ssim: 0.737448
# 57 iter PSNR: 11.94 time: 0.018576
# 58 iter PSNR_dehazing: 11.41 ssim: 0.719100
# 58 iter PSNR: 11.41 time: 0.018584
# 59 iter PSNR_dehazing: 10.94 ssim: 0.701696
# 59 iter PSNR: 10.94 time: 0.018642
# 60 iter PSNR_dehazing: 10.51 ssim: 0.685215
# 60 iter PSNR: 10.51 time: 0.021363
# 61 iter PSNR_dehazing: 17.58 ssim: 0.876657
# 61 iter PSNR: 17.58 time: 0.020657
# 62 iter PSNR_dehazing: 11.65 ssim: 0.712064
# 62 iter PSNR: 11.65 time: 0.018838
# 63 iter PSNR_dehazing: 16.51 ssim: 0.855140
# 63 iter PSNR: 16.51 time: 0.019340
# 64 iter PSNR_dehazing: 15.60 ssim: 0.834414
# 64 iter PSNR: 15.60 time: 0.019142
# 65 iter PSNR_dehazing: 14.82 ssim: 0.814504
# 65 iter PSNR: 14.82 time: 0.018827
# 66 iter PSNR_dehazing: 14.13 ssim: 0.795451
# 66 iter PSNR: 14.13 time: 0.018947
# 67 iter PSNR_dehazing: 13.52 ssim: 0.777255
# 67 iter PSNR: 13.52 time: 0.019134
# 68 iter PSNR_dehazing: 12.98 ssim: 0.759817
# 68 iter PSNR: 12.98 time: 0.018705
# 69 iter PSNR_dehazing: 12.49 ssim: 0.743154
# 69 iter PSNR: 12.49 time: 0.018729
# 70 iter PSNR_dehazing: 12.05 ssim: 0.727270
# 70 iter PSNR: 12.05 time: 0.018925
# 71 iter PSNR_dehazing: 17.18 ssim: 0.897502
# 71 iter PSNR: 17.18 time: 0.018677
# 72 iter PSNR_dehazing: 11.31 ssim: 0.753550
# 72 iter PSNR: 11.31 time: 0.018692
# 73 iter PSNR_dehazing: 16.11 ssim: 0.880514
# 73 iter PSNR: 16.11 time: 0.018605
# 74 iter PSNR_dehazing: 15.20 ssim: 0.863627
# 74 iter PSNR: 15.20 time: 0.018681
# 75 iter PSNR_dehazing: 14.42 ssim: 0.846964
# 75 iter PSNR: 14.42 time: 0.018915
# 76 iter PSNR_dehazing: 13.74 ssim: 0.830536
# 76 iter PSNR: 13.74 time: 0.022382
# 77 iter PSNR_dehazing: 13.14 ssim: 0.814451
# 77 iter PSNR: 13.14 time: 0.018344
# 78 iter PSNR_dehazing: 12.61 ssim: 0.798673
# 78 iter PSNR: 12.61 time: 0.019098
# 79 iter PSNR_dehazing: 12.13 ssim: 0.783221
# 79 iter PSNR: 12.13 time: 0.018837
# 80 iter PSNR_dehazing: 11.70 ssim: 0.768210
# 80 iter PSNR: 11.70 time: 0.018605
# 81 iter PSNR_dehazing: 17.49 ssim: 0.906616
# 81 iter PSNR: 17.49 time: 0.018540
# 82 iter PSNR_dehazing: 11.63 ssim: 0.756747
# 82 iter PSNR: 11.63 time: 0.018755
# 83 iter PSNR_dehazing: 16.43 ssim: 0.889911
# 83 iter PSNR: 16.43 time: 0.018962
# 84 iter PSNR_dehazing: 15.53 ssim: 0.872965
# 84 iter PSNR: 15.53 time: 0.018507
# 85 iter PSNR_dehazing: 14.75 ssim: 0.855914
# 85 iter PSNR: 14.75 time: 0.018693
# 86 iter PSNR_dehazing: 14.07 ssim: 0.838906
# 86 iter PSNR: 14.07 time: 0.018694
# 87 iter PSNR_dehazing: 13.47 ssim: 0.822011
# 87 iter PSNR: 13.47 time: 0.018591
# 88 iter PSNR_dehazing: 12.94 ssim: 0.805273
# 88 iter PSNR: 12.94 time: 0.018584
# 89 iter PSNR_dehazing: 12.46 ssim: 0.788784
# 89 iter PSNR: 12.46 time: 0.019100
# 90 iter PSNR_dehazing: 12.03 ssim: 0.772629
# 90 iter PSNR: 12.03 time: 0.018617
# 91 iter PSNR_dehazing: 17.73 ssim: 0.896958
# 91 iter PSNR: 17.73 time: 0.019950
# 92 iter PSNR_dehazing: 12.07 ssim: 0.733284
# 92 iter PSNR: 12.07 time: 0.023139
# 93 iter PSNR_dehazing: 16.70 ssim: 0.877069
# 93 iter PSNR: 16.70 time: 0.022971
# 94 iter PSNR_dehazing: 15.82 ssim: 0.857416
# 94 iter PSNR: 15.82 time: 0.018858
# 95 iter PSNR_dehazing: 15.07 ssim: 0.838094
# 95 iter PSNR: 15.07 time: 0.018766
# 96 iter PSNR_dehazing: 14.41 ssim: 0.819245
# 96 iter PSNR: 14.41 time: 0.018642
# 97 iter PSNR_dehazing: 13.83 ssim: 0.800902
# 97 iter PSNR: 13.83 time: 0.019414
# 98 iter PSNR_dehazing: 13.32 ssim: 0.783126
# 98 iter PSNR: 13.32 time: 0.018294
# 99 iter PSNR_dehazing: 12.86 ssim: 0.765951
# 99 iter PSNR: 12.86 time: 0.018366
# 100 iter PSNR_dehazing: 12.45 ssim: 0.749318
# 100 iter PSNR: 12.45 time: 0.018424
# 101 iter PSNR_dehazing: 17.12 ssim: 0.902848
# 101 iter PSNR: 17.12 time: 0.018605
# 102 iter PSNR_dehazing: 11.22 ssim: 0.766749
# 102 iter PSNR: 11.22 time: 0.019196
# 103 iter PSNR_dehazing: 16.05 ssim: 0.885847
# 103 iter PSNR: 16.05 time: 0.018602
# 104 iter PSNR_dehazing: 15.14 ssim: 0.869253
# 104 iter PSNR: 15.14 time: 0.018729
# 105 iter PSNR_dehazing: 14.36 ssim: 0.853152
# 105 iter PSNR: 14.36 time: 0.020502
# 106 iter PSNR_dehazing: 13.67 ssim: 0.837524
# 106 iter PSNR: 13.67 time: 0.019688
# 107 iter PSNR_dehazing: 13.07 ssim: 0.822413
# 107 iter PSNR: 13.07 time: 0.020099
# 108 iter PSNR_dehazing: 12.53 ssim: 0.807784
# 108 iter PSNR: 12.53 time: 0.018850
# 109 iter PSNR_dehazing: 12.05 ssim: 0.793668
# 109 iter PSNR: 12.05 time: 0.018880
# 110 iter PSNR_dehazing: 11.61 ssim: 0.780022
# 110 iter PSNR: 11.61 time: 0.019056
# 111 iter PSNR_dehazing: 13.99 ssim: 0.753595
# 111 iter PSNR: 13.99 time: 0.018709
# 112 iter PSNR_dehazing: 8.39 ssim: 0.591114
# 112 iter PSNR: 8.39 time: 0.018507
# 113 iter PSNR_dehazing: 12.94 ssim: 0.730338
# 113 iter PSNR: 12.94 time: 0.019116
# 114 iter PSNR_dehazing: 12.06 ssim: 0.708819
# 114 iter PSNR: 12.06 time: 0.020378
# 115 iter PSNR_dehazing: 11.31 ssim: 0.688723
# 115 iter PSNR: 11.31 time: 0.019069
# 116 iter PSNR_dehazing: 10.65 ssim: 0.669839
# 116 iter PSNR: 10.65 time: 0.018364
# 117 iter PSNR_dehazing: 10.09 ssim: 0.652116
# 117 iter PSNR: 10.09 time: 0.018475
# 118 iter PSNR_dehazing: 9.59 ssim: 0.635411
# 118 iter PSNR: 9.59 time: 0.018878
# 119 iter PSNR_dehazing: 9.14 ssim: 0.619692
# 119 iter PSNR: 9.14 time: 0.018441
# 120 iter PSNR_dehazing: 8.75 ssim: 0.604959
# 120 iter PSNR: 8.75 time: 0.018408
# 121 iter PSNR_dehazing: 15.66 ssim: 0.820189
# 121 iter PSNR: 15.66 time: 0.018346
# 122 iter PSNR_dehazing: 9.90 ssim: 0.663316
# 122 iter PSNR: 9.90 time: 0.018652
# 123 iter PSNR_dehazing: 14.60 ssim: 0.799069
# 123 iter PSNR: 14.60 time: 0.018392
# 124 iter PSNR_dehazing: 13.70 ssim: 0.779145
# 124 iter PSNR: 13.70 time: 0.018321
# 125 iter PSNR_dehazing: 12.93 ssim: 0.760211
# 125 iter PSNR: 12.93 time: 0.018374
# 126 iter PSNR_dehazing: 12.26 ssim: 0.742170
# 126 iter PSNR: 12.26 time: 0.018837
# 127 iter PSNR_dehazing: 11.68 ssim: 0.725006
# 127 iter PSNR: 11.68 time: 0.022739
# 128 iter PSNR_dehazing: 11.16 ssim: 0.708563
# 128 iter PSNR: 11.16 time: 0.018440
# 129 iter PSNR_dehazing: 10.69 ssim: 0.692821
# 129 iter PSNR: 10.69 time: 0.019181
# 130 iter PSNR_dehazing: 10.27 ssim: 0.677773
# 130 iter PSNR: 10.27 time: 0.018243
# 131 iter PSNR_dehazing: 12.29 ssim: 0.754503
# 131 iter PSNR: 12.29 time: 0.019049
# 132 iter PSNR_dehazing: 7.15 ssim: 0.531757
# 132 iter PSNR: 7.15 time: 0.018300
# 133 iter PSNR_dehazing: 11.29 ssim: 0.721940
# 133 iter PSNR: 11.29 time: 0.018395
# 134 iter PSNR_dehazing: 10.46 ssim: 0.691635
# 134 iter PSNR: 10.46 time: 0.019972
# 135 iter PSNR_dehazing: 9.76 ssim: 0.663727
# 135 iter PSNR: 9.76 time: 0.019975
# 136 iter PSNR_dehazing: 9.16 ssim: 0.637305
# 136 iter PSNR: 9.16 time: 0.020010
# 137 iter PSNR_dehazing: 8.64 ssim: 0.612783
# 137 iter PSNR: 8.64 time: 0.023712
# 138 iter PSNR_dehazing: 8.20 ssim: 0.590118
# 138 iter PSNR: 8.20 time: 0.019758
# 139 iter PSNR_dehazing: 7.80 ssim: 0.569067
# 139 iter PSNR: 7.80 time: 0.018518
# 140 iter PSNR_dehazing: 7.45 ssim: 0.549667
# 140 iter PSNR: 7.45 time: 0.018651
# 141 iter PSNR_dehazing: 13.87 ssim: 0.774569
# 141 iter PSNR: 13.87 time: 0.018808
# 142 iter PSNR_dehazing: 8.37 ssim: 0.561243
# 142 iter PSNR: 8.37 time: 0.018380
# 143 iter PSNR_dehazing: 12.82 ssim: 0.746118
# 143 iter PSNR: 12.82 time: 0.018454
# 144 iter PSNR_dehazing: 11.95 ssim: 0.718965
# 144 iter PSNR: 11.95 time: 0.019241
# 145 iter PSNR_dehazing: 11.21 ssim: 0.693065
# 145 iter PSNR: 11.21 time: 0.018898
# 146 iter PSNR_dehazing: 10.57 ssim: 0.668148
# 146 iter PSNR: 10.57 time: 0.018277
# 147 iter PSNR_dehazing: 10.01 ssim: 0.644294
# 147 iter PSNR: 10.01 time: 0.018005
# 148 iter PSNR_dehazing: 9.53 ssim: 0.621709
# 148 iter PSNR: 9.53 time: 0.018031
# 149 iter PSNR_dehazing: 9.09 ssim: 0.600380
# 149 iter PSNR: 9.09 time: 0.018471
# 150 iter PSNR_dehazing: 8.71 ssim: 0.580220
# 150 iter PSNR: 8.71 time: 0.018600
# 151 iter PSNR_dehazing: 15.65 ssim: 0.844941
# 151 iter PSNR: 15.65 time: 0.022095
# 152 iter PSNR_dehazing: 9.68 ssim: 0.670696
# 152 iter PSNR: 9.68 time: 0.019096
# 153 iter PSNR_dehazing: 14.56 ssim: 0.821341
# 153 iter PSNR: 14.56 time: 0.018215
# 154 iter PSNR_dehazing: 13.64 ssim: 0.798827
# 154 iter PSNR: 13.64 time: 0.018284
# 155 iter PSNR_dehazing: 12.84 ssim: 0.777443
# 155 iter PSNR: 12.84 time: 0.018623
# 156 iter PSNR_dehazing: 12.15 ssim: 0.757143
# 156 iter PSNR: 12.15 time: 0.018511
# 157 iter PSNR_dehazing: 11.54 ssim: 0.737844
# 157 iter PSNR: 11.54 time: 0.018144
# 158 iter PSNR_dehazing: 11.00 ssim: 0.719617
# 158 iter PSNR: 11.00 time: 0.018247
# 159 iter PSNR_dehazing: 10.51 ssim: 0.702366
# 159 iter PSNR: 10.51 time: 0.018628
# 160 iter PSNR_dehazing: 10.08 ssim: 0.686121
# 160 iter PSNR: 10.08 time: 0.018733
# 161 iter PSNR_dehazing: 18.54 ssim: 0.924869
# 161 iter PSNR: 18.54 time: 0.018239
# 162 iter PSNR_dehazing: 12.82 ssim: 0.839047
# 162 iter PSNR: 12.82 time: 0.018978
# 163 iter PSNR_dehazing: 17.50 ssim: 0.913952
# 163 iter PSNR: 17.50 time: 0.019332
# 164 iter PSNR_dehazing: 16.62 ssim: 0.903432
# 164 iter PSNR: 16.62 time: 0.020891
# 165 iter PSNR_dehazing: 15.86 ssim: 0.893278
# 165 iter PSNR: 15.86 time: 0.027316
# 166 iter PSNR_dehazing: 15.19 ssim: 0.883457
# 166 iter PSNR: 15.19 time: 0.021282
# 167 iter PSNR_dehazing: 14.61 ssim: 0.873969
# 167 iter PSNR: 14.61 time: 0.020946
# 168 iter PSNR_dehazing: 14.08 ssim: 0.864794
# 168 iter PSNR: 14.08 time: 0.018274
# 169 iter PSNR_dehazing: 13.62 ssim: 0.855925
# 169 iter PSNR: 13.62 time: 0.018211
# 170 iter PSNR_dehazing: 13.20 ssim: 0.847352
# 170 iter PSNR: 13.20 time: 0.018405
# 171 iter PSNR_dehazing: 15.59 ssim: 0.836609
# 171 iter PSNR: 15.59 time: 0.018825
# 172 iter PSNR_dehazing: 9.92 ssim: 0.616167
# 172 iter PSNR: 9.92 time: 0.018196
# 173 iter PSNR_dehazing: 14.54 ssim: 0.808885
# 173 iter PSNR: 14.54 time: 0.018381
# 174 iter PSNR_dehazing: 13.65 ssim: 0.781910
# 174 iter PSNR: 13.65 time: 0.018259
# 175 iter PSNR_dehazing: 12.89 ssim: 0.755521
# 175 iter PSNR: 12.89 time: 0.018160
# 176 iter PSNR_dehazing: 12.23 ssim: 0.729857
# 176 iter PSNR: 12.23 time: 0.018278
# 177 iter PSNR_dehazing: 11.65 ssim: 0.705140
# 177 iter PSNR: 11.65 time: 0.018130
# 178 iter PSNR_dehazing: 11.14 ssim: 0.681378
# 178 iter PSNR: 11.14 time: 0.018127
# 179 iter PSNR_dehazing: 10.69 ssim: 0.658598
# 179 iter PSNR: 10.69 time: 0.018145
# 180 iter PSNR_dehazing: 10.28 ssim: 0.636841
# 180 iter PSNR: 10.28 time: 0.018500
# 181 iter PSNR_dehazing: 16.15 ssim: 0.827832
# 181 iter PSNR: 16.15 time: 0.018703
# 182 iter PSNR_dehazing: 10.30 ssim: 0.629899
# 182 iter PSNR: 10.30 time: 0.018249
# 183 iter PSNR_dehazing: 15.08 ssim: 0.803043
# 183 iter PSNR: 15.08 time: 0.017789
# 184 iter PSNR_dehazing: 14.17 ssim: 0.778939
# 184 iter PSNR: 14.17 time: 0.017865
# 185 iter PSNR_dehazing: 13.40 ssim: 0.755569
# 185 iter PSNR: 13.40 time: 0.018088
# 186 iter PSNR_dehazing: 12.72 ssim: 0.732886
# 186 iter PSNR: 12.72 time: 0.018565
# 187 iter PSNR_dehazing: 12.12 ssim: 0.710866
# 187 iter PSNR: 12.12 time: 0.018383
# 188 iter PSNR_dehazing: 11.59 ssim: 0.689624
# 188 iter PSNR: 11.59 time: 0.018115
# 189 iter PSNR_dehazing: 11.12 ssim: 0.668982
# 189 iter PSNR: 11.12 time: 0.018147
# 190 iter PSNR_dehazing: 10.69 ssim: 0.649141
# 190 iter PSNR: 10.69 time: 0.019018
# 191 iter PSNR_dehazing: 16.12 ssim: 0.840398
# 191 iter PSNR: 16.12 time: 0.018138
# 192 iter PSNR_dehazing: 10.34 ssim: 0.648347
# 192 iter PSNR: 10.34 time: 0.018343
# 193 iter PSNR_dehazing: 15.06 ssim: 0.816101
# 193 iter PSNR: 15.06 time: 0.018442
# 194 iter PSNR_dehazing: 14.17 ssim: 0.792517
# 194 iter PSNR: 14.17 time: 0.018374
# 195 iter PSNR_dehazing: 13.40 ssim: 0.769743
# 195 iter PSNR: 13.40 time: 0.022626
# 196 iter PSNR_dehazing: 12.73 ssim: 0.747705
# 196 iter PSNR: 12.73 time: 0.022189
# 197 iter PSNR_dehazing: 12.14 ssim: 0.726359
# 197 iter PSNR: 12.14 time: 0.023231
# 198 iter PSNR_dehazing: 11.61 ssim: 0.705748
# 198 iter PSNR: 11.61 time: 0.018522
# 199 iter PSNR_dehazing: 11.15 ssim: 0.685922
# 199 iter PSNR: 11.15 time: 0.020416
# 200 iter PSNR_dehazing: 10.72 ssim: 0.666803
# 200 iter PSNR: 10.72 time: 0.018762
# 201 iter PSNR_dehazing: 12.68 ssim: 0.747370
# 201 iter PSNR: 12.68 time: 0.017883
# 202 iter PSNR_dehazing: 7.38 ssim: 0.505289
# 202 iter PSNR: 7.38 time: 0.018518
# 203 iter PSNR_dehazing: 11.66 ssim: 0.714730
# 203 iter PSNR: 11.66 time: 0.018391
# 204 iter PSNR_dehazing: 10.81 ssim: 0.683674
# 204 iter PSNR: 10.81 time: 0.018426
# 205 iter PSNR_dehazing: 10.09 ssim: 0.654102
# 205 iter PSNR: 10.09 time: 0.018340
# 206 iter PSNR_dehazing: 9.48 ssim: 0.625907
# 206 iter PSNR: 9.48 time: 0.018102
# 207 iter PSNR_dehazing: 8.94 ssim: 0.599065
# 207 iter PSNR: 8.94 time: 0.018099
# 208 iter PSNR_dehazing: 8.48 ssim: 0.573601
# 208 iter PSNR: 8.48 time: 0.018131
# 209 iter PSNR_dehazing: 8.07 ssim: 0.549496
# 209 iter PSNR: 8.07 time: 0.018654
# 210 iter PSNR_dehazing: 7.70 ssim: 0.526730
# 210 iter PSNR: 7.70 time: 0.021994
# 211 iter PSNR_dehazing: 16.73 ssim: 0.830312
# 211 iter PSNR: 16.73 time: 0.019217
# 212 iter PSNR_dehazing: 10.51 ssim: 0.678369
# 212 iter PSNR: 10.51 time: 0.019580
# 213 iter PSNR_dehazing: 15.62 ssim: 0.809803
# 213 iter PSNR: 15.62 time: 0.023012
# 214 iter PSNR_dehazing: 14.67 ssim: 0.790480
# 214 iter PSNR: 14.67 time: 0.023047
# 215 iter PSNR_dehazing: 13.85 ssim: 0.772181
# 215 iter PSNR: 13.85 time: 0.022481
# 216 iter PSNR_dehazing: 13.13 ssim: 0.754730
# 216 iter PSNR: 13.13 time: 0.022546
# 217 iter PSNR_dehazing: 12.49 ssim: 0.738122
# 217 iter PSNR: 12.49 time: 0.022396
# 218 iter PSNR_dehazing: 11.91 ssim: 0.722213
# 218 iter PSNR: 11.91 time: 0.022478
# 219 iter PSNR_dehazing: 11.40 ssim: 0.706999
# 219 iter PSNR: 11.40 time: 0.023639
# 220 iter PSNR_dehazing: 10.93 ssim: 0.692376
# 220 iter PSNR: 10.93 time: 0.022637
# 221 iter PSNR_dehazing: 14.62 ssim: 0.671393
# 221 iter PSNR: 14.62 time: 0.022797
# 222 iter PSNR_dehazing: 8.60 ssim: 0.522657
# 222 iter PSNR: 8.60 time: 0.022519
# 223 iter PSNR_dehazing: 13.52 ssim: 0.649180
# 223 iter PSNR: 13.52 time: 0.022519
# 224 iter PSNR_dehazing: 12.59 ssim: 0.629009
# 224 iter PSNR: 12.59 time: 0.022946
# 225 iter PSNR_dehazing: 11.79 ssim: 0.610456
# 225 iter PSNR: 11.79 time: 0.023726
# 226 iter PSNR_dehazing: 11.10 ssim: 0.593298
# 226 iter PSNR: 11.10 time: 0.022407
# 227 iter PSNR_dehazing: 10.48 ssim: 0.577313
# 227 iter PSNR: 10.48 time: 0.018279
# 228 iter PSNR_dehazing: 9.94 ssim: 0.562365
# 228 iter PSNR: 9.94 time: 0.018052
# 229 iter PSNR_dehazing: 9.45 ssim: 0.548324
# 229 iter PSNR: 9.45 time: 0.018310
# 230 iter PSNR_dehazing: 9.00 ssim: 0.535134
# 230 iter PSNR: 9.00 time: 0.018524
# 231 iter PSNR_dehazing: 12.62 ssim: 0.619889
# 231 iter PSNR: 12.62 time: 0.018051
# 232 iter PSNR_dehazing: 7.00 ssim: 0.454241
# 232 iter PSNR: 7.00 time: 0.018311
# 233 iter PSNR_dehazing: 11.57 ssim: 0.593361
# 233 iter PSNR: 11.57 time: 0.018395
# 234 iter PSNR_dehazing: 10.69 ssim: 0.569729
# 234 iter PSNR: 10.69 time: 0.018483
# 235 iter PSNR_dehazing: 9.93 ssim: 0.548481
# 235 iter PSNR: 9.93 time: 0.018299
# 236 iter PSNR_dehazing: 9.28 ssim: 0.529202
# 236 iter PSNR: 9.28 time: 0.021527
# 237 iter PSNR_dehazing: 8.71 ssim: 0.511628
# 237 iter PSNR: 8.71 time: 0.018489
# 238 iter PSNR_dehazing: 8.21 ssim: 0.495511
# 238 iter PSNR: 8.21 time: 0.019792
# 239 iter PSNR_dehazing: 7.76 ssim: 0.480655
# 239 iter PSNR: 7.76 time: 0.019018
# 240 iter PSNR_dehazing: 7.36 ssim: 0.466943
# 240 iter PSNR: 7.36 time: 0.022651
# 241 iter PSNR_dehazing: 15.08 ssim: 0.779793
# 241 iter PSNR: 15.08 time: 0.019761
# 242 iter PSNR_dehazing: 9.24 ssim: 0.600090
# 242 iter PSNR: 9.24 time: 0.023525
# 243 iter PSNR_dehazing: 14.01 ssim: 0.754376
# 243 iter PSNR: 14.01 time: 0.017842
# 244 iter PSNR_dehazing: 13.10 ssim: 0.730671
# 244 iter PSNR: 13.10 time: 0.018260
# 245 iter PSNR_dehazing: 12.32 ssim: 0.708483
# 245 iter PSNR: 12.32 time: 0.017986
# 246 iter PSNR_dehazing: 11.65 ssim: 0.687658
# 246 iter PSNR: 11.65 time: 0.018756
# 247 iter PSNR_dehazing: 11.05 ssim: 0.668048
# 247 iter PSNR: 11.05 time: 0.017853
# 248 iter PSNR_dehazing: 10.52 ssim: 0.649550
# 248 iter PSNR: 10.52 time: 0.017767
# 249 iter PSNR_dehazing: 10.05 ssim: 0.632113
# 249 iter PSNR: 10.05 time: 0.017808
# 250 iter PSNR_dehazing: 9.63 ssim: 0.615623
# 250 iter PSNR: 9.63 time: 0.018021
# 251 iter PSNR_dehazing: 12.34 ssim: 0.692538
# 251 iter PSNR: 12.34 time: 0.017879
# 252 iter PSNR_dehazing: 6.96 ssim: 0.486363
# 252 iter PSNR: 6.96 time: 0.017980
# 253 iter PSNR_dehazing: 11.31 ssim: 0.662636
# 253 iter PSNR: 11.31 time: 0.018608
# 254 iter PSNR_dehazing: 10.45 ssim: 0.635083
# 254 iter PSNR: 10.45 time: 0.019365
# 255 iter PSNR_dehazing: 9.73 ssim: 0.609622
# 255 iter PSNR: 9.73 time: 0.018371
# 256 iter PSNR_dehazing: 9.10 ssim: 0.585765
# 256 iter PSNR: 9.10 time: 0.018377
# 257 iter PSNR_dehazing: 8.56 ssim: 0.563427
# 257 iter PSNR: 8.56 time: 0.018512
# 258 iter PSNR_dehazing: 8.08 ssim: 0.542430
# 258 iter PSNR: 8.08 time: 0.018499
# 259 iter PSNR_dehazing: 7.66 ssim: 0.522606
# 259 iter PSNR: 7.66 time: 0.018748
# 260 iter PSNR_dehazing: 7.29 ssim: 0.503950
# 260 iter PSNR: 7.29 time: 0.018345
# 261 iter PSNR_dehazing: 14.19 ssim: 0.701605
# 261 iter PSNR: 14.19 time: 0.018784
# 262 iter PSNR_dehazing: 8.31 ssim: 0.528545
# 262 iter PSNR: 8.31 time: 0.018450
# 263 iter PSNR_dehazing: 13.11 ssim: 0.676831
# 263 iter PSNR: 13.11 time: 0.018453
# 264 iter PSNR_dehazing: 12.19 ssim: 0.653995
# 264 iter PSNR: 12.19 time: 0.018589
# 265 iter PSNR_dehazing: 11.41 ssim: 0.632702
# 265 iter PSNR: 11.41 time: 0.020457
# 266 iter PSNR_dehazing: 10.73 ssim: 0.612799
# 266 iter PSNR: 10.73 time: 0.018394
# 267 iter PSNR_dehazing: 10.13 ssim: 0.594062
# 267 iter PSNR: 10.13 time: 0.023106
# 268 iter PSNR_dehazing: 9.60 ssim: 0.576373
# 268 iter PSNR: 9.60 time: 0.018619
# 269 iter PSNR_dehazing: 9.13 ssim: 0.559604
# 269 iter PSNR: 9.13 time: 0.019252
# 270 iter PSNR_dehazing: 8.70 ssim: 0.543721
# 270 iter PSNR: 8.70 time: 0.018396
# 271 iter PSNR_dehazing: 18.31 ssim: 0.791486
# 271 iter PSNR: 18.31 time: 0.018522
# 272 iter PSNR_dehazing: 11.89 ssim: 0.667691
# 272 iter PSNR: 11.89 time: 0.018940
# 273 iter PSNR_dehazing: 17.18 ssim: 0.773507
# 273 iter PSNR: 17.18 time: 0.018530
# 274 iter PSNR_dehazing: 16.22 ssim: 0.757032
# 274 iter PSNR: 16.22 time: 0.018823
# 275 iter PSNR_dehazing: 15.38 ssim: 0.741814
# 275 iter PSNR: 15.38 time: 0.020265
# 276 iter PSNR_dehazing: 14.64 ssim: 0.727620
# 276 iter PSNR: 14.64 time: 0.019911
# 277 iter PSNR_dehazing: 13.97 ssim: 0.714290
# 277 iter PSNR: 13.97 time: 0.018323
# 278 iter PSNR_dehazing: 13.38 ssim: 0.701699
# 278 iter PSNR: 13.38 time: 0.018324
# 279 iter PSNR_dehazing: 12.83 ssim: 0.689780
# 279 iter PSNR: 12.83 time: 0.018452
# 280 iter PSNR_dehazing: 12.34 ssim: 0.678488
# 280 iter PSNR: 12.34 time: 0.018624
# 281 iter PSNR_dehazing: 14.60 ssim: 0.750825
# 281 iter PSNR: 14.60 time: 0.018784
# 282 iter PSNR_dehazing: 8.79 ssim: 0.588019
# 282 iter PSNR: 8.79 time: 0.019059
# 283 iter PSNR_dehazing: 13.53 ssim: 0.728119
# 283 iter PSNR: 13.53 time: 0.020052
# 284 iter PSNR_dehazing: 12.62 ssim: 0.706991
# 284 iter PSNR: 12.62 time: 0.019047
# 285 iter PSNR_dehazing: 11.85 ssim: 0.687180
# 285 iter PSNR: 11.85 time: 0.018456
# 286 iter PSNR_dehazing: 11.17 ssim: 0.668449
# 286 iter PSNR: 11.17 time: 0.018565
# 287 iter PSNR_dehazing: 10.58 ssim: 0.650762
# 287 iter PSNR: 10.58 time: 0.018790
# 288 iter PSNR_dehazing: 10.06 ssim: 0.633927
# 288 iter PSNR: 10.06 time: 0.018724
# 289 iter PSNR_dehazing: 9.59 ssim: 0.617893
# 289 iter PSNR: 9.59 time: 0.020132
# 290 iter PSNR_dehazing: 9.17 ssim: 0.602620
# 290 iter PSNR: 9.17 time: 0.018486
# 291 iter PSNR_dehazing: 12.12 ssim: 0.622153
# 291 iter PSNR: 12.12 time: 0.018471
# 292 iter PSNR_dehazing: 6.70 ssim: 0.436753
# 292 iter PSNR: 6.70 time: 0.018684
# 293 iter PSNR_dehazing: 11.09 ssim: 0.593752
# 293 iter PSNR: 11.09 time: 0.018685
# 294 iter PSNR_dehazing: 10.23 ssim: 0.568148
# 294 iter PSNR: 10.23 time: 0.018675
# 295 iter PSNR_dehazing: 9.50 ssim: 0.544840
# 295 iter PSNR: 9.50 time: 0.018947
# 296 iter PSNR_dehazing: 8.87 ssim: 0.523372
# 296 iter PSNR: 8.87 time: 0.018186
# 297 iter PSNR_dehazing: 8.33 ssim: 0.503559
# 297 iter PSNR: 8.33 time: 0.020253
# 298 iter PSNR_dehazing: 7.85 ssim: 0.485099
# 298 iter PSNR: 7.85 time: 0.018911
# 299 iter PSNR_dehazing: 7.42 ssim: 0.467910
# 299 iter PSNR: 7.42 time: 0.018527
# 300 iter PSNR_dehazing: 7.04 ssim: 0.451820
# 300 iter PSNR: 7.04 time: 0.019075
# 301 iter PSNR_dehazing: 13.65 ssim: 0.553539
# 301 iter PSNR: 13.65 time: 0.018858
# 302 iter PSNR_dehazing: 7.56 ssim: 0.395341
# 302 iter PSNR: 7.56 time: 0.020229
# 303 iter PSNR_dehazing: 12.53 ssim: 0.528397
# 303 iter PSNR: 12.53 time: 0.019207
# 304 iter PSNR_dehazing: 11.59 ssim: 0.505936
# 304 iter PSNR: 11.59 time: 0.018847
# 305 iter PSNR_dehazing: 10.78 ssim: 0.485664
# 305 iter PSNR: 10.78 time: 0.018860
# 306 iter PSNR_dehazing: 10.08 ssim: 0.467263
# 306 iter PSNR: 10.08 time: 0.018812
# 307 iter PSNR_dehazing: 9.46 ssim: 0.450399
# 307 iter PSNR: 9.46 time: 0.018584
# 308 iter PSNR_dehazing: 8.90 ssim: 0.434990
# 308 iter PSNR: 8.90 time: 0.020021
# 309 iter PSNR_dehazing: 8.41 ssim: 0.420700
# 309 iter PSNR: 8.41 time: 0.022799
# 310 iter PSNR_dehazing: 7.96 ssim: 0.407562
# 310 iter PSNR: 7.96 time: 0.018860
# 311 iter PSNR_dehazing: 13.98 ssim: 0.653640
# 311 iter PSNR: 13.98 time: 0.024072
# 312 iter PSNR_dehazing: 8.10 ssim: 0.464466
# 312 iter PSNR: 8.10 time: 0.019984
# 313 iter PSNR_dehazing: 12.90 ssim: 0.623743
# 313 iter PSNR: 12.90 time: 0.018571
# 314 iter PSNR_dehazing: 11.99 ssim: 0.597121
# 314 iter PSNR: 11.99 time: 0.018612
# 315 iter PSNR_dehazing: 11.20 ssim: 0.573042
# 315 iter PSNR: 11.20 time: 0.019345
# 316 iter PSNR_dehazing: 10.52 ssim: 0.551128
# 316 iter PSNR: 10.52 time: 0.018547
# 317 iter PSNR_dehazing: 9.92 ssim: 0.531072
# 317 iter PSNR: 9.92 time: 0.018559
# 318 iter PSNR_dehazing: 9.39 ssim: 0.512549
# 318 iter PSNR: 9.39 time: 0.019170
# 319 iter PSNR_dehazing: 8.91 ssim: 0.495363
# 319 iter PSNR: 8.91 time: 0.018581
# 320 iter PSNR_dehazing: 8.49 ssim: 0.479365
# 320 iter PSNR: 8.49 time: 0.019096
# 321 iter PSNR_dehazing: 17.22 ssim: 0.714676
# 321 iter PSNR: 17.22 time: 0.018600
# 322 iter PSNR_dehazing: 10.93 ssim: 0.527715
# 322 iter PSNR: 10.93 time: 0.018821
# 323 iter PSNR_dehazing: 16.11 ssim: 0.686208
# 323 iter PSNR: 16.11 time: 0.019063
# 324 iter PSNR_dehazing: 15.15 ssim: 0.660551
# 324 iter PSNR: 15.15 time: 0.019363
# 325 iter PSNR_dehazing: 14.32 ssim: 0.637113
# 325 iter PSNR: 14.32 time: 0.018833
# 326 iter PSNR_dehazing: 13.59 ssim: 0.615368
# 326 iter PSNR: 13.59 time: 0.020271
# 327 iter PSNR_dehazing: 12.94 ssim: 0.595181
# 327 iter PSNR: 12.94 time: 0.019408
# 328 iter PSNR_dehazing: 12.36 ssim: 0.576556
# 328 iter PSNR: 12.36 time: 0.019427
# 329 iter PSNR_dehazing: 11.84 ssim: 0.559237
# 329 iter PSNR: 11.84 time: 0.019227
# 330 iter PSNR_dehazing: 11.36 ssim: 0.542968
# 330 iter PSNR: 11.36 time: 0.018894
# 331 iter PSNR_dehazing: 16.20 ssim: 0.732284
# 331 iter PSNR: 16.20 time: 0.019222
# 332 iter PSNR_dehazing: 10.03 ssim: 0.541590
# 332 iter PSNR: 10.03 time: 0.021122
# 333 iter PSNR_dehazing: 15.09 ssim: 0.704397
# 333 iter PSNR: 15.09 time: 0.019137
# 334 iter PSNR_dehazing: 14.15 ssim: 0.678755
# 334 iter PSNR: 14.15 time: 0.019072
# 335 iter PSNR_dehazing: 13.33 ssim: 0.655000
# 335 iter PSNR: 13.33 time: 0.019170
# 336 iter PSNR_dehazing: 12.61 ssim: 0.632909
# 336 iter PSNR: 12.61 time: 0.019385
# 337 iter PSNR_dehazing: 11.98 ssim: 0.612222
# 337 iter PSNR: 11.98 time: 0.019947
# 338 iter PSNR_dehazing: 11.41 ssim: 0.592898
# 338 iter PSNR: 11.41 time: 0.020160
# 339 iter PSNR_dehazing: 10.91 ssim: 0.574727
# 339 iter PSNR: 10.91 time: 0.019808
# 340 iter PSNR_dehazing: 10.45 ssim: 0.557666
# 340 iter PSNR: 10.45 time: 0.023063
# 341 iter PSNR_dehazing: 15.77 ssim: 0.870445
# 341 iter PSNR: 15.77 time: 0.023114
# 342 iter PSNR_dehazing: 9.98 ssim: 0.713801
# 342 iter PSNR: 9.98 time: 0.018528
# 343 iter PSNR_dehazing: 14.71 ssim: 0.849655
# 343 iter PSNR: 14.71 time: 0.019110
# 344 iter PSNR_dehazing: 13.80 ssim: 0.829627
# 344 iter PSNR: 13.80 time: 0.018821
# 345 iter PSNR_dehazing: 13.03 ssim: 0.810454
# 345 iter PSNR: 13.03 time: 0.021322
# 346 iter PSNR_dehazing: 12.36 ssim: 0.792164
# 346 iter PSNR: 12.36 time: 0.023751
# 347 iter PSNR_dehazing: 11.77 ssim: 0.774771
# 347 iter PSNR: 11.77 time: 0.023207
# 348 iter PSNR_dehazing: 11.25 ssim: 0.758238
# 348 iter PSNR: 11.25 time: 0.023747
# 349 iter PSNR_dehazing: 10.78 ssim: 0.742545
# 349 iter PSNR: 10.78 time: 0.018635
# 350 iter PSNR_dehazing: 10.36 ssim: 0.727777
# 350 iter PSNR: 10.36 time: 0.018712
# 351 iter PSNR_dehazing: 15.04 ssim: 0.815503
# 351 iter PSNR: 15.04 time: 0.020985
# 352 iter PSNR_dehazing: 9.55 ssim: 0.652979
# 352 iter PSNR: 9.55 time: 0.019075
# 353 iter PSNR_dehazing: 14.00 ssim: 0.793598
# 353 iter PSNR: 14.00 time: 0.018992
# 354 iter PSNR_dehazing: 13.14 ssim: 0.772783
# 354 iter PSNR: 13.14 time: 0.019252
# 355 iter PSNR_dehazing: 12.40 ssim: 0.753010
# 355 iter PSNR: 12.40 time: 0.025201
# 356 iter PSNR_dehazing: 11.76 ssim: 0.734141
# 356 iter PSNR: 11.76 time: 0.019581
# 357 iter PSNR_dehazing: 11.20 ssim: 0.716199
# 357 iter PSNR: 11.20 time: 0.018257
# 358 iter PSNR_dehazing: 10.71 ssim: 0.699154
# 358 iter PSNR: 10.71 time: 0.018771
# 359 iter PSNR_dehazing: 10.28 ssim: 0.682913
# 359 iter PSNR: 10.28 time: 0.023848
# 360 iter PSNR_dehazing: 9.89 ssim: 0.667532
# 360 iter PSNR: 9.89 time: 0.018764
# 361 iter PSNR_dehazing: 19.45 ssim: 0.913344
# 361 iter PSNR: 19.45 time: 0.020214
# 362 iter PSNR_dehazing: 13.50 ssim: 0.811393
# 362 iter PSNR: 13.50 time: 0.018121
# 363 iter PSNR_dehazing: 18.41 ssim: 0.900553
# 363 iter PSNR: 18.41 time: 0.018531
# 364 iter PSNR_dehazing: 17.51 ssim: 0.888190
# 364 iter PSNR: 17.51 time: 0.018164
# 365 iter PSNR_dehazing: 16.73 ssim: 0.876193
# 365 iter PSNR: 16.73 time: 0.018105
# 366 iter PSNR_dehazing: 16.03 ssim: 0.864555
# 366 iter PSNR: 16.03 time: 0.018373
# 367 iter PSNR_dehazing: 15.42 ssim: 0.853267
# 367 iter PSNR: 15.42 time: 0.018370
# 368 iter PSNR_dehazing: 14.87 ssim: 0.842341
# 368 iter PSNR: 14.87 time: 0.018296
# 369 iter PSNR_dehazing: 14.37 ssim: 0.831697
# 369 iter PSNR: 14.37 time: 0.018674
# 370 iter PSNR_dehazing: 13.92 ssim: 0.821421
# 370 iter PSNR: 13.92 time: 0.023593
# 371 iter PSNR_dehazing: 13.35 ssim: 0.757258
# 371 iter PSNR: 13.35 time: 0.018592
# 372 iter PSNR_dehazing: 7.74 ssim: 0.552818
# 372 iter PSNR: 7.74 time: 0.018527
# 373 iter PSNR_dehazing: 12.30 ssim: 0.727526
# 373 iter PSNR: 12.30 time: 0.019051
# 374 iter PSNR_dehazing: 11.41 ssim: 0.699932
# 374 iter PSNR: 11.41 time: 0.018216
# 375 iter PSNR_dehazing: 10.66 ssim: 0.674344
# 375 iter PSNR: 10.66 time: 0.019006
# 376 iter PSNR_dehazing: 10.00 ssim: 0.650421
# 376 iter PSNR: 10.00 time: 0.020314
# 377 iter PSNR_dehazing: 9.44 ssim: 0.628124
# 377 iter PSNR: 9.44 time: 0.018536
# 378 iter PSNR_dehazing: 8.93 ssim: 0.607315
# 378 iter PSNR: 8.93 time: 0.018703
# 379 iter PSNR_dehazing: 8.49 ssim: 0.587881
# 379 iter PSNR: 8.49 time: 0.018716
# 380 iter PSNR_dehazing: 8.09 ssim: 0.569752
# 380 iter PSNR: 8.09 time: 0.018988
# 381 iter PSNR_dehazing: 16.40 ssim: 0.754206
# 381 iter PSNR: 16.40 time: 0.018360
# 382 iter PSNR_dehazing: 10.31 ssim: 0.640165
# 382 iter PSNR: 10.31 time: 0.018890
# 383 iter PSNR_dehazing: 15.30 ssim: 0.736664
# 383 iter PSNR: 15.30 time: 0.018376
# 384 iter PSNR_dehazing: 14.37 ssim: 0.721009
# 384 iter PSNR: 14.37 time: 0.019330
# 385 iter PSNR_dehazing: 13.56 ssim: 0.706808
# 385 iter PSNR: 13.56 time: 0.018874
# 386 iter PSNR_dehazing: 12.86 ssim: 0.693789
# 386 iter PSNR: 12.86 time: 0.018430
# 387 iter PSNR_dehazing: 12.23 ssim: 0.681673
# 387 iter PSNR: 12.23 time: 0.018929
# 388 iter PSNR_dehazing: 11.68 ssim: 0.670402
# 388 iter PSNR: 11.68 time: 0.018723
# 389 iter PSNR_dehazing: 11.17 ssim: 0.659751
# 389 iter PSNR: 11.17 time: 0.018649
# 390 iter PSNR_dehazing: 10.72 ssim: 0.649712
# 390 iter PSNR: 10.72 time: 0.018376
# 391 iter PSNR_dehazing: 17.17 ssim: 0.894990
# 391 iter PSNR: 17.17 time: 0.018616
# 392 iter PSNR_dehazing: 11.25 ssim: 0.756764
# 392 iter PSNR: 11.25 time: 0.019559
# 393 iter PSNR_dehazing: 16.09 ssim: 0.878454
# 393 iter PSNR: 16.09 time: 0.018497
# 394 iter PSNR_dehazing: 15.18 ssim: 0.862153
# 394 iter PSNR: 15.18 time: 0.018475
# 395 iter PSNR_dehazing: 14.40 ssim: 0.846123
# 395 iter PSNR: 14.40 time: 0.018740
# 396 iter PSNR_dehazing: 13.71 ssim: 0.830387
# 396 iter PSNR: 13.71 time: 0.018577
# 397 iter PSNR_dehazing: 13.11 ssim: 0.815006
# 397 iter PSNR: 13.11 time: 0.018624
# 398 iter PSNR_dehazing: 12.57 ssim: 0.799913
# 398 iter PSNR: 12.57 time: 0.018982
# 399 iter PSNR_dehazing: 12.08 ssim: 0.785188
# 399 iter PSNR: 12.08 time: 0.022659
# 400 iter PSNR_dehazing: 11.65 ssim: 0.770808
# 400 iter PSNR: 11.65 time: 0.018571
# 401 iter PSNR_dehazing: 12.67 ssim: 0.787197
# 401 iter PSNR: 12.67 time: 0.018528
# 402 iter PSNR_dehazing: 7.47 ssim: 0.599372
# 402 iter PSNR: 7.47 time: 0.018479
# 403 iter PSNR_dehazing: 11.67 ssim: 0.758997
# 403 iter PSNR: 11.67 time: 0.018624
# 404 iter PSNR_dehazing: 10.83 ssim: 0.732978
# 404 iter PSNR: 10.83 time: 0.018985
# 405 iter PSNR_dehazing: 10.12 ssim: 0.709051
# 405 iter PSNR: 10.12 time: 0.018578
# 406 iter PSNR_dehazing: 9.52 ssim: 0.686962
# 406 iter PSNR: 9.52 time: 0.018575
# 407 iter PSNR_dehazing: 9.00 ssim: 0.666706
# 407 iter PSNR: 9.00 time: 0.018572
# 408 iter PSNR_dehazing: 8.54 ssim: 0.647873
# 408 iter PSNR: 8.54 time: 0.018450
# 409 iter PSNR_dehazing: 8.14 ssim: 0.630432
# 409 iter PSNR: 8.14 time: 0.018310
# 410 iter PSNR_dehazing: 7.79 ssim: 0.614304
# 410 iter PSNR: 7.79 time: 0.018236
# 411 iter PSNR_dehazing: 17.19 ssim: 0.825805
# 411 iter PSNR: 17.19 time: 0.018557
# 412 iter PSNR_dehazing: 10.96 ssim: 0.689067
# 412 iter PSNR: 10.96 time: 0.018897
# 413 iter PSNR_dehazing: 16.08 ssim: 0.806780
# 413 iter PSNR: 16.08 time: 0.022862
# 414 iter PSNR_dehazing: 15.13 ssim: 0.789007
# 414 iter PSNR: 15.13 time: 0.023475
# 415 iter PSNR_dehazing: 14.31 ssim: 0.772296
# 415 iter PSNR: 14.31 time: 0.022673
# 416 iter PSNR_dehazing: 13.59 ssim: 0.756498
# 416 iter PSNR: 13.59 time: 0.017896
# 417 iter PSNR_dehazing: 12.94 ssim: 0.741585
# 417 iter PSNR: 12.94 time: 0.018495
# 418 iter PSNR_dehazing: 12.37 ssim: 0.727447
# 418 iter PSNR: 12.37 time: 0.018836
# 419 iter PSNR_dehazing: 11.85 ssim: 0.713993
# 419 iter PSNR: 11.85 time: 0.018138
# 420 iter PSNR_dehazing: 11.39 ssim: 0.701248
# 420 iter PSNR: 11.39 time: 0.018019
# 421 iter PSNR_dehazing: 13.61 ssim: 0.717330
# 421 iter PSNR: 13.61 time: 0.018498
# 422 iter PSNR_dehazing: 8.02 ssim: 0.536676
# 422 iter PSNR: 8.02 time: 0.018463
# 423 iter PSNR_dehazing: 12.57 ssim: 0.691075
# 423 iter PSNR: 12.57 time: 0.018581
# 424 iter PSNR_dehazing: 11.69 ssim: 0.666941
# 424 iter PSNR: 11.69 time: 0.022858
# 425 iter PSNR_dehazing: 10.94 ssim: 0.644588
# 425 iter PSNR: 10.94 time: 0.019762
# 426 iter PSNR_dehazing: 10.29 ssim: 0.623777
# 426 iter PSNR: 10.29 time: 0.017978
# 427 iter PSNR_dehazing: 9.72 ssim: 0.604193
# 427 iter PSNR: 9.72 time: 0.017964
# 428 iter PSNR_dehazing: 9.22 ssim: 0.585769
# 428 iter PSNR: 9.22 time: 0.018149
# 429 iter PSNR_dehazing: 8.78 ssim: 0.568409
# 429 iter PSNR: 8.78 time: 0.017962
# 430 iter PSNR_dehazing: 8.38 ssim: 0.552122
# 430 iter PSNR: 8.38 time: 0.017855
# 431 iter PSNR_dehazing: 17.27 ssim: 0.831369
# 431 iter PSNR: 17.27 time: 0.017979
# 432 iter PSNR_dehazing: 11.21 ssim: 0.689953
# 432 iter PSNR: 11.21 time: 0.018173
# 433 iter PSNR_dehazing: 16.18 ssim: 0.812167
# 433 iter PSNR: 16.18 time: 0.018215
# 434 iter PSNR_dehazing: 15.25 ssim: 0.794011
# 434 iter PSNR: 15.25 time: 0.018131
# 435 iter PSNR_dehazing: 14.45 ssim: 0.776810
# 435 iter PSNR: 14.45 time: 0.018177
# 436 iter PSNR_dehazing: 13.75 ssim: 0.760513
# 436 iter PSNR: 13.75 time: 0.018843
# 437 iter PSNR_dehazing: 13.13 ssim: 0.744958
# 437 iter PSNR: 13.13 time: 0.017874
# 438 iter PSNR_dehazing: 12.57 ssim: 0.730206
# 438 iter PSNR: 12.57 time: 0.018255
# 439 iter PSNR_dehazing: 12.07 ssim: 0.716128
# 439 iter PSNR: 12.07 time: 0.018053
# 440 iter PSNR_dehazing: 11.62 ssim: 0.702748
# 440 iter PSNR: 11.62 time: 0.024030
# 441 iter PSNR_dehazing: 13.03 ssim: 0.603871
# 441 iter PSNR: 13.03 time: 0.024290
# 442 iter PSNR_dehazing: 7.21 ssim: 0.398755
# 442 iter PSNR: 7.21 time: 0.027789
# 443 iter PSNR_dehazing: 11.95 ssim: 0.572230
# 443 iter PSNR: 11.95 time: 0.023683
# 444 iter PSNR_dehazing: 11.05 ssim: 0.543769
# 444 iter PSNR: 11.05 time: 0.022998
# 445 iter PSNR_dehazing: 10.27 ssim: 0.517818
# 445 iter PSNR: 10.27 time: 0.018538
# 446 iter PSNR_dehazing: 9.59 ssim: 0.494075
# 446 iter PSNR: 9.59 time: 0.022872
# 447 iter PSNR_dehazing: 9.00 ssim: 0.472089
# 447 iter PSNR: 9.00 time: 0.019460
# 448 iter PSNR_dehazing: 8.48 ssim: 0.451746
# 448 iter PSNR: 8.48 time: 0.022980
# 449 iter PSNR_dehazing: 8.01 ssim: 0.432831
# 449 iter PSNR: 8.01 time: 0.018610
# 450 iter PSNR_dehazing: 7.59 ssim: 0.415217
# 450 iter PSNR: 7.59 time: 0.019002
# 451 iter PSNR_dehazing: 16.05 ssim: 0.810532
# 451 iter PSNR: 16.05 time: 0.020664
# 452 iter PSNR_dehazing: 10.02 ssim: 0.616812
# 452 iter PSNR: 10.02 time: 0.018559
# 453 iter PSNR_dehazing: 14.96 ssim: 0.784306
# 453 iter PSNR: 14.96 time: 0.017930
# 454 iter PSNR_dehazing: 14.03 ssim: 0.759468
# 454 iter PSNR: 14.03 time: 0.023831
# 455 iter PSNR_dehazing: 13.23 ssim: 0.735888
# 455 iter PSNR: 13.23 time: 0.018935
# 456 iter PSNR_dehazing: 12.53 ssim: 0.713495
# 456 iter PSNR: 12.53 time: 0.018881
# 457 iter PSNR_dehazing: 11.92 ssim: 0.692259
# 457 iter PSNR: 11.92 time: 0.022757
# 458 iter PSNR_dehazing: 11.37 ssim: 0.671982
# 458 iter PSNR: 11.37 time: 0.018416
# 459 iter PSNR_dehazing: 10.87 ssim: 0.652697
# 459 iter PSNR: 10.87 time: 0.019454
# 460 iter PSNR_dehazing: 10.43 ssim: 0.634334
# 460 iter PSNR: 10.43 time: 0.018125
# 461 iter PSNR_dehazing: 15.15 ssim: 0.786336
# 461 iter PSNR: 15.15 time: 0.018606
# 462 iter PSNR_dehazing: 9.30 ssim: 0.566625
# 462 iter PSNR: 9.30 time: 0.018556
# 463 iter PSNR_dehazing: 14.07 ssim: 0.756951
# 463 iter PSNR: 14.07 time: 0.018459
# 464 iter PSNR_dehazing: 13.16 ssim: 0.728900
# 464 iter PSNR: 13.16 time: 0.020178
# 465 iter PSNR_dehazing: 12.38 ssim: 0.702241
# 465 iter PSNR: 12.38 time: 0.018366
# 466 iter PSNR_dehazing: 11.70 ssim: 0.676718
# 466 iter PSNR: 11.70 time: 0.018190
# 467 iter PSNR_dehazing: 11.11 ssim: 0.652490
# 467 iter PSNR: 11.11 time: 0.018360
# 468 iter PSNR_dehazing: 10.58 ssim: 0.629432
# 468 iter PSNR: 10.58 time: 0.018260
# 469 iter PSNR_dehazing: 10.11 ssim: 0.607392
# 469 iter PSNR: 10.11 time: 0.017961
# 470 iter PSNR_dehazing: 9.68 ssim: 0.586483
# 470 iter PSNR: 9.68 time: 0.018315
# 471 iter PSNR_dehazing: 15.68 ssim: 0.768833
# 471 iter PSNR: 15.68 time: 0.018383
# 472 iter PSNR_dehazing: 9.76 ssim: 0.550271
# 472 iter PSNR: 9.76 time: 0.018637
# 473 iter PSNR_dehazing: 14.60 ssim: 0.737998
# 473 iter PSNR: 14.60 time: 0.018701
# 474 iter PSNR_dehazing: 13.68 ssim: 0.709123
# 474 iter PSNR: 13.68 time: 0.018450
# 475 iter PSNR_dehazing: 12.90 ssim: 0.682062
# 475 iter PSNR: 12.90 time: 0.018373
# 476 iter PSNR_dehazing: 12.21 ssim: 0.656632
# 476 iter PSNR: 12.21 time: 0.018451
# 477 iter PSNR_dehazing: 11.61 ssim: 0.632655
# 477 iter PSNR: 11.61 time: 0.020108
# 478 iter PSNR_dehazing: 11.07 ssim: 0.610166
# 478 iter PSNR: 11.07 time: 0.018666
# 479 iter PSNR_dehazing: 10.59 ssim: 0.588960
# 479 iter PSNR: 10.59 time: 0.018644
# 480 iter PSNR_dehazing: 10.16 ssim: 0.568984
# 480 iter PSNR: 10.16 time: 0.019214
# 481 iter PSNR_dehazing: 16.34 ssim: 0.799070
# 481 iter PSNR: 16.34 time: 0.018956
# 482 iter PSNR_dehazing: 10.45 ssim: 0.602999
# 482 iter PSNR: 10.45 time: 0.018837
# 483 iter PSNR_dehazing: 15.27 ssim: 0.771599
# 483 iter PSNR: 15.27 time: 0.018151
# 484 iter PSNR_dehazing: 14.36 ssim: 0.745924
# 484 iter PSNR: 14.36 time: 0.018433
# 485 iter PSNR_dehazing: 13.57 ssim: 0.721826
# 485 iter PSNR: 13.57 time: 0.018419
# 486 iter PSNR_dehazing: 12.89 ssim: 0.699127
# 486 iter PSNR: 12.89 time: 0.018460
# 487 iter PSNR_dehazing: 12.29 ssim: 0.677745
# 487 iter PSNR: 12.29 time: 0.020364
# 488 iter PSNR_dehazing: 11.75 ssim: 0.657567
# 488 iter PSNR: 11.75 time: 0.018510
# 489 iter PSNR_dehazing: 11.27 ssim: 0.638381
# 489 iter PSNR: 11.27 time: 0.018587
# 490 iter PSNR_dehazing: 10.84 ssim: 0.620215
# 490 iter PSNR: 10.84 time: 0.020718
# 491 iter PSNR_dehazing: 15.62 ssim: 0.801870
# 491 iter PSNR: 15.62 time: 0.018766
# 492 iter PSNR_dehazing: 9.75 ssim: 0.574501
# 492 iter PSNR: 9.75 time: 0.018454
# 493 iter PSNR_dehazing: 14.55 ssim: 0.771745
# 493 iter PSNR: 14.55 time: 0.018833
# 494 iter PSNR_dehazing: 13.64 ssim: 0.742834
# 494 iter PSNR: 13.64 time: 0.018738
# 495 iter PSNR_dehazing: 12.86 ssim: 0.715313
# 495 iter PSNR: 12.86 time: 0.018852
# 496 iter PSNR_dehazing: 12.18 ssim: 0.688897
# 496 iter PSNR: 12.18 time: 0.018719
# 497 iter PSNR_dehazing: 11.58 ssim: 0.663659
# 497 iter PSNR: 11.58 time: 0.020834
# 498 iter PSNR_dehazing: 11.05 ssim: 0.639688
# 498 iter PSNR: 11.05 time: 0.023384
# 499 iter PSNR_dehazing: 10.57 ssim: 0.616893
# 499 iter PSNR: 10.57 time: 0.022966
# 500 iter PSNR_dehazing: 10.14 ssim: 0.595148
# 500 iter PSNR: 10.14 time: 0.018813
# ==========================================================
# The average PSNR is 12.06 dB
# The average SSIM is 0.68955 dB
# Average time: 0.019295
